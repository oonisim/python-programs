# %% [markdown]
# # Parsing SEC Filing XBRL HTML Document
#
#
# ## Objective
#
# Parse the filing XBRL file in HTML format (```.htm```) to extract financial statement element values.
#
# ## References
#
# * [XBRL Specification - Extensible Business Reporting Language (XBRL) 2.1](https://www.xbrl.org/Specification/XBRL-2.1/REC-2003-12-31/XBRL-2.1-REC-2003-12-31+corrected-errata-2013-02-20.html)
#
# * [List of US GAAP Standards](https://xbrlsite.azurewebsites.net/2019/Prototype/references/us-gaap/)
# * [XBRL US - List of Elements](https://xbrl.us/data-rule/dqc_0015-le/)
#
# **Element Version**|**Element ID**|**Namespace**|**Element Label**|**Element Name**|**Balance Type**|**Definition**
# :-----:|:-----:|:-----:|:-----:|:-----:|:-----:|:-----:
# 1|1367|us-gaap|Interest Expense|InterestExpense|debit|Amount of the cost of borrowed funds accounted for as interest expense.
# 2|2692|us-gaap|Cash and Cash Equivalents, at Carrying Value|CashAndCashEquivalentsAtCarryingValue|debit|Amount of currency on hand as well as demand deposits with banks or financial institutions. Includes other kinds of accounts that have the general characteristics of demand deposits. Also includes short-term, highly liquid investments that are both readily convertible to known amounts of cash and so near their maturity that they present insignificant risk of changes in value because of changes in interest rates. Excludes cash and cash equivalents within disposal group and discontinued operation.
#
# ## XBRL Element
#
# * [Understanding the Financial Report Logical System](https://www.youtube.com/playlist?list=PLqMZRUzQ64B7EWamzDP-WaYbS_W0RL9nt)
# * [XBRL - What is us-gaap:OperatingSegmentsMember element anb where is it defined?](https://money.stackexchange.com/questions/148010/xbrl-what-is-us-gaapoperatingsegmentsmember-element-anb-where-is-it-defined)
#
# ### Example
# For instance, [Qorvo 2020 10K](https://www.sec.gov/Archives/edgar/data/1604778/000160477821000032/rfmd-20210403_htm.xml):
#
# ```
# <us-gaap:cashandcashequivalentsatcarryingvalue contextref="*" decimals="-3" id="..." unitref="usd">
#   1397880000
# </us-gaap:cashandcashequivalentsatcarryingvalue>,
# <us-gaap:cashandcashequivalentsatcarryingvalue contextref="***" decimals="-3" id="..." unitref="usd">
#   714939000
# </us-gaap:cashandcashequivalentsatcarryingvalue>,
# <us-gaap:cashandcashequivalentsatcarryingvalue contextref="***" decimals="-3" id="..." unitref="usd">
#  711035000
# </us-gaap:cashandcashequivalentsatcarryingvalue>
# ```
#
# Corresponds to the Cash and Cash equivalents in the Cash Flow statement.
#
# <img src="../image/edgar_qorvo_2020_10K_CF.png" align="left" width=800 />

# %% [markdown]
# ---
# # Setup

# %%
from typing import (
    List,
    Dict
)
import re
import requests
import unicodedata
import bs4
from bs4 import BeautifulSoup
from IPython.core.display import (
    display, 
    HTML
)

import numpy as np
import pandas as pd
pd.set_option('display.float_format', lambda x: ('%f' % x).rstrip('0').rstrip('.'))

# %%
# %%html
# <style>
# table {float:left}
# </style>
# Out:
# <style>
# table {float:left}
# </style>

# %%
def restore_windows_1252_characters(restore_string):
    """
        Replace C1 control characters in the Unicode string s by the
        characters at the corresponding code points in Windows-1252,
        where possible.
    """

    def to_windows_1252(match):
        try:
            return bytes([ord(match.group(0))]).decode('windows-1252')
        except UnicodeDecodeError:
            # No character at the corresponding code point: remove it.
            return ''
        
    return re.sub(r'[\u0080-\u0099]', to_windows_1252, restore_string)

# %% [markdown]
# ---
# # Load EDGAR Filing XBRL
#
# Download the ```_htm.xml``` file from EDGAR. SEC now requires user-agent header.

# %%
# define the url to specific html_text file
CIK = '1604778'
ACCESSION = '000160477821000032'

FILING_DIR_URL = f"https://www.sec.gov/Archives/edgar/data/{CIK}/{ACCESSION}"
XBRL_NAME = "rfmd-20210403_htm.xml"
XBRL_URL = "/".join([FILING_DIR_URL, XBRL_NAME])

XBRL_URL
# Out:
# 'https://www.sec.gov/Archives/edgar/data/1604778/000160477821000032/rfmd-20210403_htm.xml'

# %%
headers = {"User-Agent": "Company Name myname@company.com"}
response = requests.get(XBRL_URL, headers=headers)

if response.status_code == 200:
    content = response.content.decode("utf-8") 
else:
    print(f"{XBRL_URL} failed with status {response.status_code}")

# %%
soup = BeautifulSoup(content, 'html.parser')

# %% [markdown]
# ## Repoting period
#
# Each 10-K and 10-Q XBRL has the reporting period for the filing. To exclude the other period, e.g. pervious year or quarter, use the ```context id``` for the reporting period.
#
# For instances:
#
# ### QRVO 10-K 2020
#
# ```
# <context id="ifb6ce67cf6954ebf88471dd82daa9247_D20200329-20210403">
#     <entity>
#     <identifier scheme="http://www.sec.gov/CIK">0001604778</identifier>
#     </entity>
#     <period>
#         <startDate>2020-03-29</startDate>
#         <endDate>2021-04-03</endDate>
#     </period>
# </context>
# ```
#
# ### AMKR 10-K 2020
#
# ```
# <context id="i5fac0a392353427b8266f185495754d3_D20200101-20201231">
#     <entity>
#     <identifier scheme="http://www.sec.gov/CIK">0001047127</identifier>
#     </entity>
#     <period>
#         <startDate>2020-01-01</startDate>
#         <endDate>2020-12-31</endDate>
#     </period>
# </context>
# ```
#
# ### AAPL 10-Q 4th QTR 2020
#
# ```
# <context id="i6e431846933d461fb8c8c0bdf98c9758_D20200927-20201226">
#     <entity>
#     <identifier scheme="http://www.sec.gov/CIK">0000320193</identifier>
#     </entity>
#     <period>
#         <startDate>2020-09-27</startDate>
#         <endDate>2020-12-26</endDate>
#     </period>
# </context>
# ```

# %%
CONTEXT = None
for context in soup.find_all('context'):
    if context.find('period') and context.find('period').find('enddate'):
        CONTEXT = context
        break        
        
assert CONTEXT is not None, "Report period not found"

cik_value_in_statement = int(CONTEXT.find('identifier').text.strip())
assert int(CIK) == cik_value_in_statement, \
    "The CIK %s in statement does not match %s" % (cik_value_in_statement, int(CIK))

CONTEXT_ID = CONTEXT['id']
PERIOD = CONTEXT.find('period').find('enddate').text.strip()

print(f"PERIOD is {PERIOD}. CONTEXT_ID is {CONTEXT_ID}")
# Out:
# PERIOD is 2021-04-03. CONTEXT_ID is ifb6ce67cf6954ebf88471dd82daa9247_D20200329-20210403

# %% [markdown]
# ### Regexp to find all the contexts that match with PERIOD

# %%
contexts_regexp = "|".join([
    context['id']
    for context in soup.find_all('context') 
    if context.find('period') and context.find('period').find(['instant'], string=PERIOD)
])
contexts_regexp = rf"{CONTEXT_ID}|" + contexts_regexp
CONTEXT_REGEXP = re.compile(contexts_regexp)

# %%
# regexp to extract numeric string
REGEXP_NUMERIC = re.compile(r"\s*[\d.-]*\s*")

re.match(REGEXP_NUMERIC, " -123.12 ")
# Out:
# <re.Match object; span=(0, 9), match=' -123.12 '>

# %% [markdown]
# # Constant

# %%
# XBRL Namespace
NAMESPACE = "us-gaap"

# XBRL attribute conditions to match when extracting FS elements
ATTRIBUTES = {
    "contextref": CONTEXT_REGEXP,
    "decimals": True, 
    "unitref": True
}

# %%
CREDIT_ITEMS = set(map(str.lower, [
    f"{NAMESPACE}:Revenues",
    f"{NAMESPACE}:GrossProfit",
]))

DEBIT_ITEMS = set(map(str.lower, [
    f"{NAMESPACE}:CostOfRevenue",
    f"{NAMESPACE}:CostOfGoods",
    f"{NAMESPACE}:CostOfGoodsAndServicesSold",
    f"{NAMESPACE}:OperatingExpenses",
    f"{NAMESPACE}:ResearchAndDevelopmentExpense",
    f"{NAMESPACE}:SellingGeneralAndAdministrativeExpense",
    f"{NAMESPACE}:OtherCostAndExpenseOperating",
    f"{NAMESPACE}:IncomeTaxExpenseBenefit",
]))

# %% [markdown]
# # Utilities

# %%
def find_financial_elements(soup, element_names, attributes=ATTRIBUTES):
    """Find the financial statement elements from the XML/HTML source.
    Args:
        soup: BS4 source
        element_names: String or regexp instance to select the financial elements.
        attribute: tag attributes to select the financial elements
    Returns:
        List of BS4 tag objects that matched the element_names and attributes.
    """
    assert isinstance(soup, BeautifulSoup)
    assert isinstance(element_names, re.Pattern) or isinstance(element_names, str)

    names = element_names.lower() if isinstance(element_names, str) else element_names
    """
    return soup.findAll(
        name=names,
        string=REGEXP_NUMERIC,
        attrs=attributes
    """
    return [
        soup.find(
            name=names,
            string=REGEXP_NUMERIC,
            attrs=attributes
        )
    ]

# %%
def get_financial_element_numeric_values(elements):
    assert isinstance(elements, bs4.element.ResultSet) or isinstance(elements[0], bs4.element.Tag)
    
    values = []
    for element in elements:
        assert re.match(REGEXP_NUMERIC, element.text.strip()), f"Element must be numeric but {element.text}"
        values.append(float(element.text))
        
    return values

# %%
def display_items(elements):
    assert isinstance(elements, bs4.element.ResultSet) or isinstance(elements[0], bs4.element.Tag)
    for element in elements: # decimals="-3" means the displayed value is divied by 1000.
        print(f"{element.name} {element['unitref']:5} {element['decimals']:5} {element.text:15} ")

# %%
def get_financial_element_record(elements):
    assert isinstance(elements, bs4.element.ResultSet) or isinstance(elements[0], bs4.element.Tag)
    return [
        [
            'debit' if element.name in DEBIT_ITEMS else 'credit',
            element.name, 
            element['unitref'], 
            int(element['decimals']), 
            float(element.text), 
            element['contextref']
        ]
        for element in elements
    ]

# %%
def get_financial_element_columns():
    return ["type", "name", "unit", "decimals", "value", "context"]

# %% [markdown]
# ---
# # Statements of Income (P/L)

# %%
PL = []

# %% [markdown]
# ## Revenues

# %%
revenues = find_financial_elements(soup=soup, element_names=re.compile(rf"{NAMESPACE}:Revenues".lower()))

PL += get_financial_element_record(revenues)

display_items(revenues)
# Out:
# us-gaap:revenues usd   -3    4015307000

# %% [markdown]
# ## Cost of Revenues

# %%
names = re.compile("|".join([
    rf"^{NAMESPACE}:CostOfRevenue$",
    rf"^{NAMESPACE}:CostOfGoods$",
    rf"^{NAMESPACE}:CostOfGoodsAndServicesSold$",
]).lower())

costs_of_revenues = find_financial_elements(soup=soup, element_names=names)
PL += get_financial_element_record(costs_of_revenues)

display_items(costs_of_revenues)
# Out:
# us-gaap:costofgoodsandservicessold usd   -3    2131741000

# %% [markdown]
# ## Gross Profit

# %%
names = f"{NAMESPACE}:GrossProfit"
gross_profit = find_financial_elements(soup=soup, element_names=names)
PL += get_financial_element_record(gross_profit)

display_items(gross_profit)
# Out:
# us-gaap:grossprofit usd   -3    1883566000

# %% [markdown]
# ## Operating Expenses

# %%
names = f"{NAMESPACE}:OperatingExpenses".lower()
operating_expense_total = find_financial_elements(soup=soup, element_names=names)
PL += get_financial_element_record(costs_of_revenues)

display_items(operating_expense_total)
# Out:
# us-gaap:operatingexpenses usd   -3    976939000

# %% [markdown]
# ### Research and Development

# %%
names = f"{NAMESPACE}:ResearchAndDevelopmentExpense".lower()
operating_expense_r_and_d = find_financial_elements(soup=soup, element_names=names)
PL += get_financial_element_record(operating_expense_r_and_d)

display_items(operating_expense_r_and_d)
# Out:
# us-gaap:researchanddevelopmentexpense usd   -3    570395000

# %% [markdown]
# ### Administrative Expense

# %%
names = f"{NAMESPACE}:SellingGeneralAndAdministrativeExpense"
operating_expense_administrative = find_financial_elements(soup=soup, element_names=names)
PL += get_financial_element_record(operating_expense_administrative)

display_items(operating_expense_administrative)
# Out:
# us-gaap:sellinggeneralandadministrativeexpense usd   -3    367238000

# %% [markdown]
# ### Other expenses

# %%
names = f"{NAMESPACE}:OtherCostAndExpenseOperating"
operating_expense_other = find_financial_elements(soup=soup, element_names=names)
PL += get_financial_element_record(operating_expense_other)

display_items(operating_expense_other)
# Out:
# us-gaap:othercostandexpenseoperating usd   -3    39306000

# %% [markdown]
# ## Overting Income

# %%
names = f"{NAMESPACE}:OperatingIncomeLoss"
operating_income_or_loss = find_financial_elements(soup=soup, element_names=names)
PL += get_financial_element_record(operating_income_or_loss)

display_items(operating_income_or_loss)
# Out:
# us-gaap:operatingincomeloss usd   -3    906627000

# %%
df_PL = pd.DataFrame(PL, columns=get_financial_element_columns())
df_PL
# Out:
#      type                                            name unit  decimals  \
# 0  credit                                us-gaap:revenues  usd        -3
# 1   debit              us-gaap:costofgoodsandservicessold  usd        -3
# 2  credit                             us-gaap:grossprofit  usd        -3
# 3   debit              us-gaap:costofgoodsandservicessold  usd        -3
# 4   debit           us-gaap:researchanddevelopmentexpense  usd        -3
# 5   debit  us-gaap:sellinggeneralandadministrativeexpense  usd        -3
# 6   debit            us-gaap:othercostandexpenseoperating  usd        -3
# 7  credit                     us-gaap:operatingincomeloss  usd        -3
#
#        value                                            context
# 0 4015307000  ifb6ce67cf6954ebf88471dd82daa9247_D20200329-20...
# 1 2131741000  ifb6ce67cf6954ebf88471dd82daa9247_D20200329-20...
# 2 1883566000  ifb6ce67cf6954ebf88471dd82daa9247_D20200329-20...
# 3 2131741000  ifb6ce67cf6954ebf88471dd82daa9247_D20200329-20...
# 4  570395000  ifb6ce67cf6954ebf88471dd82daa9247_D20200329-20...
# 5  367238000  ifb6ce67cf6954ebf88471dd82daa9247_D20200329-20...
# 6   39306000  ifb6ce67cf6954ebf88471dd82daa9247_D20200329-20...
# 7  906627000  ifb6ce67cf6954ebf88471dd82daa9247_D20200329-20...

# %%
df_PL[df_PL['type'] == 'credit']['value'].sum()
# Out:
# 6805500000.0

# %%
df_PL[df_PL['type'] == 'debit']['value'].sum()
# Out:
# 5240421000.0

# %% [markdown]
# ---
# # Balance Sheet (B/S)

# %% [markdown]
# ## Cash & Cash Equivalents
#
# Look for the cash and cash equivalents for the reporting perid in the Balance Sheet and Cash Flow statements of the  10-K.

# %%
names = f"{NAMESPACE}:CashAndCashEquivalentsAtCarryingValue"

cash_equivalents = find_financial_elements(soup=soup, element_names=names)
display_items(cash_equivalents)
# Out:
# us-gaap:cashandcashequivalentsatcarryingvalue usd   -3    1397880000

# %% [markdown]
# ---

# %% [markdown]
# ## Shares Outstanding

# %%
names = re.compile("|".join([
    rf"{NAMESPACE}:SharesOutstanding",
    rf"{NAMESPACE}:CommonStockSharesOutstanding",
    rf"{NAMESPACE}:CommonStockOtherSharesOutstanding",
]).lower())

shares_outstanding = find_financial_elements(soup=soup, element_names=names)
display_items(shares_outstanding)
# Out:
# us-gaap:commonstocksharesoutstanding shares -3    112557000

# %% [markdown]
# ---

# %% [markdown]
# # Loading Edgar XBRL in HTML
#
# Download the ```.htm``` file from EDGAR.

# %%
XBRL_HTML_NAME = "rfmd-20210403.htm"
XBRL_HTML_URL = "/".join([FILING_DIR_URL, XBRL_HTML_NAME])

XBRL_HTML_URL
# Out:
# 'https://www.sec.gov/Archives/edgar/data/1604778/000160477821000032/rfmd-20210403.htm'

# %%
headers = {"User-Agent": "Company Name myname@company.com"}
response = requests.get(XBRL_HTML_URL, headers=headers)

if response.status_code == 200:
    content = response.content.decode("utf-8") 
else:
    print(f"{XBRL_HTML_URL} failed with status {response.status_code}")

# %%
soup = BeautifulSoup(content, 'html.parser')
# soup

# %%
# NOTE: In HTML, "name" is a tag attribute, NOT the tag name.
gaap_elements = soup.findAll(
    string=re.compile(r"[ 0-9.,]"),
    attrs={
        "name" : re.compile("us-gaap:.*"), 
        "contextref": re.compile(contexts_regexp),
        "decimals": True, 
        "unitref": True
    }
)

for element in gaap_elements: # Scale="3" means the value is per 1000.
    # print(element.prettify(formatter="html"))
    print(f"{element['name']:60} {element.text:15} {element['unitref']:12} {element['decimals']:5}")
# Out:
# us-gaap:AllowanceForDoubtfulAccountsReceivableCurrent        331             usd          -3
# us-gaap:PreferredStockParOrStatedValuePerShare               0.0001          usdPerShare  INF
# us-gaap:PreferredStockSharesAuthorized                       5,000           shares       -3
# us-gaap:CommonStockParOrStatedValuePerShare                  0.0001          usdPerShare  4
# us-gaap:CommonStockSharesAuthorized                          405,000         shares       -3
# us-gaap:CommonStockSharesIssued                              112,557         shares       -3
# us-gaap:CommonStockSharesOutstanding                         112,557         shares       -3
# us-gaap:CashAndCashEquivalentsAtCarryingValue                1,397,880       usd          -3
# us-gaap:AccountsReceivableNetCurrent                         457,431         usd          -3
# us-gaap:InventoryNet                                         507,787         usd          -3
# us-gaap:PrepaidExpenseCurrent                                41,572          usd          -3
# us-gaap:OtherReceivables                                     27,324          usd          -3
# us-gaap:OtherAssetsCurrent                                   51,810          usd          -3
# us-gaap:AssetsCurrent                                        2,483,804       usd          -3
# us-gaap:PropertyPlantAndEquipmentNet                         1,266,031       usd          -3
# us-gaap:Goodwill                                             2,642,708       usd          -3
# us-gaap:IntangibleAssetsNetExcludingGoodwill                 611,155         usd          -3
# us-gaap:LongTermInvestments                                  35,370          usd          -3
# us-gaap:OtherAssetsNoncurrent                                182,402         usd          -3
# us-gaap:Assets                                               7,221,470       usd          -3
# us-gaap:AccountsPayableCurrent                               313,868         usd          -3
# us-gaap:AccruedLiabilitiesCurrent                            255,060         usd          -3
# us-gaap:LongTermDebtCurrent                                  5,092           usd          -3
# us-gaap:OtherLiabilitiesCurrent                              107,561         usd          -3
# us-gaap:LiabilitiesCurrent                                   681,581         usd          -3
# us-gaap:LongTermDebt                                         1,742,550       usd          -3
# us-gaap:OtherLiabilitiesNoncurrent                           167,914         usd          -3
# us-gaap:Liabilities                                          2,592,045       usd          -3
# us-gaap:CommonStocksIncludingAdditionalPaidInCapital         4,244,740       usd          -3
# us-gaap:AccumulatedOtherComprehensiveIncomeLossNetOfTax      29,649          usd          -3
# us-gaap:RetainedEarningsAccumulatedDeficit                   355,036         usd          -3
# us-gaap:StockholdersEquity                                   4,629,425       usd          -3
# us-gaap:LiabilitiesAndStockholdersEquity                     7,221,470       usd          -3
# us-gaap:Revenues                                             4,015,307       usd          -3
# us-gaap:CostOfGoodsAndServicesSold                           2,131,741       usd          -3
# us-gaap:GrossProfit                                          1,883,566       usd          -3
# us-gaap:ResearchAndDevelopmentExpense                        570,395         usd          -3
# us-gaap:SellingGeneralAndAdministrativeExpense               367,238         usd          -3
# us-gaap:OtherCostAndExpenseOperating                         39,306          usd          -3
# us-gaap:OperatingExpenses                                    976,939         usd          -3
# us-gaap:OperatingIncomeLoss                                  906,627         usd          -3
# us-gaap:InterestExpense                                      75,198          usd          -3
# us-gaap:OtherNonoperatingIncomeExpense                       24,049          usd          -3
# us-gaap:IncomeLossFromContinuingOperationsBeforeIncomeTaxesMinorityInterestAndIncomeLossFromEquityMethodInvestments 807,380         usd          -3
# us-gaap:IncomeTaxExpenseBenefit                              73,769          usd          -3
# us-gaap:NetIncomeLoss                                        733,611         usd          -3
# us-gaap:EarningsPerShareBasic                                6.43            usdPerShare  2
# us-gaap:EarningsPerShareDiluted                              6.32            usdPerShare  2
# us-gaap:WeightedAverageNumberOfSharesOutstandingBasic        114,034         shares       -3
# us-gaap:WeightedAverageNumberOfDilutedSharesOutstanding      116,016         shares       -3
# us-gaap:NetIncomeLoss                                        733,611         usd          -3
# us-gaap:OtherComprehensiveIncomeLossPensionAndOtherPostretirementBenefitPlansAdjustmentBeforeReclassificationAdjustmentsNetOfTax 597             usd          -3
# us-gaap:OtherComprehensiveIncomeForeignCurrencyTransactionAndTranslationGainLossBeforeReclassificationAndTax 27,859          usd          -3
# us-gaap:OtherComprehensiveIncomeLossForeignCurrencyTransactionAndTranslationReclassificationAdjustmentFromAOCIRealizedUponSaleOrLiquidationNetOfTax 16              usd          -3
# us-gaap:OtherComprehensiveIncomeLossReclassificationAdjustmentFromAOCIPensionAndOtherPostretirementBenefitPlansForNetGainLossNetOfTax 83              usd          -3
# us-gaap:OtherComprehensiveIncomeLossNetOfTax                 27,361          usd          -3
# us-gaap:ComprehensiveIncomeNetOfTax                          760,972         usd          -3
# us-gaap:NetIncomeLoss                                        733,611         usd          -3
# us-gaap:OtherComprehensiveIncomeLossNetOfTax                 27,361          usd          -3
# us-gaap:StockIssuedDuringPeriodSharesEmployeeStockPurchasePlans 417             shares       -3
# us-gaap:StockIssuedDuringPeriodValueEmployeeStockPurchasePlan 31,366          usd          -3
# us-gaap:StockRepurchasedDuringPeriodShares                   3,642           shares       -3
# us-gaap:StockRepurchasedDuringPeriodValue                    515,084         usd          -3
# us-gaap:StockIssuedDuringPeriodValueShareBasedCompensation   88,728          usd          -3
# us-gaap:CommonStockSharesOutstanding                         112,557         shares       -3
# us-gaap:CommonStocksIncludingAdditionalPaidInCapital         4,244,740       usd          -3
# us-gaap:AccumulatedOtherComprehensiveIncomeLossNetOfTax      29,649          usd          -3
# us-gaap:RetainedEarningsAccumulatedDeficit                   355,036         usd          -3
# us-gaap:StockholdersEquity                                   4,629,425       usd          -3
# us-gaap:NetIncomeLoss                                        733,611         usd          -3
# us-gaap:Depreciation                                         203,206         usd          -3
# us-gaap:AmortizationOfIntangibleAssets                       252,898         usd          -3
# us-gaap:GainsLossesOnExtinguishmentOfDebt                    61,991          usd          -3
# us-gaap:DeferredIncomeTaxExpenseBenefit                      18,136          usd          -3
# us-gaap:CostmethodInvestmentsOtherThanTemporaryImpairment    2,775           usd          -3
# us-gaap:ShareBasedCompensation                               89,322          usd          -3
# us-gaap:OtherOperatingActivitiesCashFlowStatement            2,151           usd          -3
# us-gaap:IncreaseDecreaseInAccountsReceivable                 91,275          usd          -3
# us-gaap:IncreaseDecreaseInInventories                        9,390           usd          -3
# us-gaap:IncreaseDecreaseInPrepaidDeferredExpenseAndOtherAssets 18,490          usd          -3
# us-gaap:IncreaseDecreaseInAccountsPayable                    34,201          usd          -3
# us-gaap:IncreaseDecreaseInAccruedLiabilities                 30,671          usd          -3
# us-gaap:IncreaseDecreaseInAccruedIncomeTaxesPayable          34,618          usd          -3
# us-gaap:IncreaseDecreaseInOtherOperatingLiabilities          20,778          usd          -3
# us-gaap:NetCashProvidedByUsedInOperatingActivities           1,301,853       usd          -3
# us-gaap:PaymentsToAcquirePropertyPlantAndEquipment           186,960         usd          -3
# us-gaap:PaymentsToAcquireBusinessesNetOfCashAcquired         47,069          usd          -3
# us-gaap:PaymentsForProceedsFromOtherInvestingActivities      15,371          usd          -3
# us-gaap:NetCashProvidedByUsedInInvestingActivities           218,658         usd          -3
# us-gaap:RepaymentsOfLongTermDebt                             1,087,994       usd          -3
# us-gaap:ProceedsFromRepaymentsOfDebt                         1,206,750       usd          -3
# us-gaap:PaymentsForRepurchaseOfCommonStock                   515,084         usd          -3
# us-gaap:ProceedsFromIssuanceOfSharesUnderIncentiveAndShareBasedCompensationPlansIncludingStockOptions 42,598          usd          -3
# us-gaap:PaymentsRelatedToTaxWithholdingForShareBasedCompensation 38,658          usd          -3
# us-gaap:ProceedsFromPaymentsForOtherFinancingActivities      9,535           usd          -3
# us-gaap:NetCashProvidedByUsedInFinancingActivities           401,923         usd          -3
# us-gaap:EffectOfExchangeRateOnCashCashEquivalentsRestrictedCashAndRestrictedCashEquivalents 1,425           usd          -3
# us-gaap:CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsPeriodIncreaseDecreaseIncludingExchangeRateEffect 682,697         usd          -3
# us-gaap:CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalents 1,398,309       usd          -3
# us-gaap:CashAndCashEquivalentsAtCarryingValue                1,397,880       usd          -3
# us-gaap:RestrictedCash                                       429             usd          -3
# us-gaap:CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalents 1,398,309       usd          -3
# us-gaap:InterestPaidNet                                      81,232          usd          -3
# us-gaap:IncomeTaxesPaid                                      53,236          usd          -3
# us-gaap:CapitalExpendituresIncurredButNotYetPaid             56,469          usd          -3
# us-gaap:AccruedSalariesCurrentAndNoncurrent                  135.4           usd          -5
# us-gaap:InterestPayableCurrentAndNoncurrent                  17.5            usd          -5
# us-gaap:RevenueRemainingPerformanceObligation                87.5            usd          -5
# us-gaap:EmployeeServiceShareBasedCompensationNonvestedAwardsTotalCompensationCostNotYetRecognized 103.7           usd          -5
# us-gaap:InventoryRawMaterialsNetOfReserves                   134,959         usd          -3
# us-gaap:InventoryWorkInProcessNetOfReserves                  283,067         usd          -3
# us-gaap:InventoryFinishedGoodsNetOfReserves                  89,761          usd          -3
# us-gaap:InventoryNet                                         507,787         usd          -3
# us-gaap:Land                                                 25,842          usd          -3
# us-gaap:BuildingsAndImprovementsGross                        411,180         usd          -3
# us-gaap:MachineryAndEquipmentGross                           2,282,059       usd          -3
# us-gaap:ConstructionInProgressGross                          108,563         usd          -3
# us-gaap:PropertyPlantAndEquipmentGross                       2,827,644       usd          -3
# us-gaap:AccumulatedDepreciationDepletionAndAmortizationPropertyPlantAndEquipment 1,561,613       usd          -3
# us-gaap:PropertyPlantAndEquipmentNet                         1,266,031       usd          -3
# us-gaap:BusinessCombinationContingentConsiderationLiabilityCurrent 10.0            usd          -5
# us-gaap:BusinessCombinationContingentConsiderationLiabilityCurrent 10.0            usd          -5
# us-gaap:IndefiniteLivedIntangibleAssetsExcludingGoodwill     9.6             usd          -3
# us-gaap:GoodwillPeriodIncreaseDecrease                       2,591           usd          -3
# us-gaap:GoodwillForeignCurrencyTranslationGainLoss           9,185           usd          -3
# us-gaap:Goodwill                                             2,034,383       usd          -3
# us-gaap:Goodwill                                             608,325         usd          -3
# us-gaap:Goodwill                                             2,642,708       usd          -3
# us-gaap:GoodwillImpairedAccumulatedImpairmentLoss            621.6           usd          -5
# us-gaap:FiniteLivedIntangibleAssetsGross                     1,295,113       usd          -3
# us-gaap:FiniteLivedIntangibleAssetsAccumulatedAmortization   750,044         usd          -3
# us-gaap:FiniteLivedIntangibleAssetsGross                     459,052         usd          -3
# us-gaap:FiniteLivedIntangibleAssetsAccumulatedAmortization   403,407         usd          -3
# us-gaap:FiniteLivedIntangibleAssetsGross                     2,368           usd          -3
# us-gaap:FiniteLivedIntangibleAssetsAccumulatedAmortization   2,076           usd          -3
# us-gaap:FiniteLivedIntangibleAssetsGross                     1,600           usd          -3
# us-gaap:FiniteLivedIntangibleAssetsAccumulatedAmortization   1,600           usd          -3
# us-gaap:FiniteLivedIntangibleAssetsGross                     1,090           usd          -3
# us-gaap:FiniteLivedIntangibleAssetsAccumulatedAmortization   636             usd          -3
# us-gaap:IndefiniteLivedIntangibleAssetsExcludingGoodwill     9,695           usd          -3
# us-gaap:IntangibleAssetsGrossExcludingGoodwill               1,768,918       usd          -3
# us-gaap:FiniteLivedIntangibleAssetsAccumulatedAmortization   1,157,763       usd          -3
# us-gaap:AmortizationOfIntangibleAssets                       252.9           usd          -5
# us-gaap:FiniteLivedIntangibleAssetsAmortizationExpenseNextTwelveMonths 122,000         usd          -3
# us-gaap:FiniteLivedIntangibleAssetsAmortizationExpenseYearTwo 106,000         usd          -3
# us-gaap:FiniteLivedIntangibleAssetsAmortizationExpenseYearThree 94,000          usd          -3
# us-gaap:FiniteLivedIntangibleAssetsAmortizationExpenseYearFour 79,000          usd          -3
# us-gaap:FiniteLivedIntangibleAssetsAmortizationExpenseYearFive 73,000          usd          -3
# us-gaap:EquityMethodInvestments                              29.8            usd          -5
# us-gaap:EquitySecuritiesFvNiUnrealizedGainLoss               21.5            usd          -5
# us-gaap:ProceedsFromLimitedPartnershipInvestments            5.9             usd          -5
# us-gaap:CostmethodInvestmentsOtherThanTemporaryImpairment    2.8             usd          -5
# us-gaap:MarketableSecurities                                 3,802           usd          -3
# us-gaap:MarketableSecurities                                 3,802           usd          -3
# us-gaap:DeferredCompensationPlanAssets                       32,824          usd          -3
# us-gaap:DeferredCompensationPlanAssets                       32,824          usd          -3
# us-gaap:BusinessCombinationContingentConsiderationLiabilityCurrent 10,000          usd          -3
# us-gaap:BusinessCombinationContingentConsiderationLiabilityCurrent 10,000          usd          -3
# us-gaap:OperatingLeaseRightOfUseAsset                        62,925          usd          -3
# us-gaap:OperatingLeaseLiabilityCurrent                       15,068          usd          -3
# us-gaap:OperatingLeaseLiabilityNoncurrent                    53,172          usd          -3
# us-gaap:OperatingLeaseExpense                                17,382          usd          -3
# us-gaap:ShortTermLeaseCost                                   7,062           usd          -3
# us-gaap:VariableLeaseCost                                    3,972           usd          -3
# us-gaap:OperatingLeasePayments                               18,697          usd          -3
# us-gaap:RightOfUseAssetObtainedInExchangeForOperatingLeaseLiability 12,899          usd          -3
# us-gaap:OperatingLeaseWeightedAverageDiscountRatePercent     3.82            number       4
# us-gaap:LesseeOperatingLeaseLiabilityPaymentsDueNextTwelveMonths 17,194          usd          -3
# us-gaap:LesseeOperatingLeaseLiabilityPaymentsDueYearTwo      12,608          usd          -3
# us-gaap:LesseeOperatingLeaseLiabilityPaymentsDueYearThree    9,823           usd          -3
# us-gaap:LesseeOperatingLeaseLiabilityPaymentsDueYearFour     7,715           usd          -3
# us-gaap:LesseeOperatingLeaseLiabilityPaymentsDueYearFive     7,603           usd          -3
# us-gaap:LesseeOperatingLeaseLiabilityPaymentsDueAfterYearFive 23,900          usd          -3
# us-gaap:LesseeOperatingLeaseLiabilityPaymentsDue             78,843          usd          -3
# us-gaap:LesseeOperatingLeaseLiabilityUndiscountedExcessAmount 10,603          usd          -3
# us-gaap:OperatingLeaseLiability                              68,240          usd          -3
# us-gaap:LongTermDebt                                         197,500         usd          -3
# us-gaap:LongTermDebt                                         850,000         usd          -3
# us-gaap:LongTermDebt                                         700,000         usd          -3
# us-gaap:LongTermDebt                                         1,617           usd          -3
# us-gaap:LongTermDebtCurrent                                  5,092           usd          -3
# us-gaap:LongTermDebt                                         1,742,550       usd          -3
# us-gaap:LongTermDebtMaturitiesRepaymentsOfPrincipalInNextRollingTwelveMonths 5,000           usd          -5
# us-gaap:LongTermDebtMaturitiesRepaymentsOfPrincipalInRollingYearTwo 7,500           usd          -5
# us-gaap:LongTermDebtMaturitiesRepaymentsOfPrincipalInRollingYearThree 7,500           usd          -5
# us-gaap:LongTermDebtMaturitiesRepaymentsOfPrincipalInRollingYearFour 10,000          usd          -5
# us-gaap:LongTermDebtMaturitiesRepaymentsOfPrincipalInRollingYearFive 167,500         usd          -5
# us-gaap:UnsecuredDebt                                        197,500         usd          -5
# us-gaap:LongTermDebtFairValue                                905.3           usd          -5
# us-gaap:LongTermDebtFairValue                                689.5           usd          -5
# us-gaap:LongTermDebt                                         850.0           usd          -3
# us-gaap:LongTermDebt                                         700.0           usd          -3
# us-gaap:InterestExpenseBorrowings                            79.3            usd          -5
# us-gaap:DefinedContributionPlanEmployerDiscretionaryContributionAmount 15.6            usd          -5
# us-gaap:DefinedBenefitPlanBenefitObligation                  14.0            usd          -5
# us-gaap:DefinedBenefitPlanNetPeriodicBenefitCost             0.6             usd          -5
# us-gaap:AssetsHeldInTrust                                    32.8            usd          -5
# us-gaap:AssetsHeldInTrustCurrent                             1.2             usd          -5
# us-gaap:AssetsHeldInTrustNoncurrent                          31.6            usd          -5
# us-gaap:PurchaseObligation                                   419.2           usd          -5
# us-gaap:RestructuringCharges                                 2.7             usd          -5
# us-gaap:RestructuringAndRelatedCostCostIncurredToDate1       93.4            usd          -5
# us-gaap:RestructuringAndRelatedCostExpectedCostRemaining1    0.1             usd          -5
# us-gaap:RestructuringCharges                                 2,722           usd          -3
# us-gaap:PaymentsForRestructuring                             3,615           usd          -3
# us-gaap:RestructuringReserve                                 776             usd          -3
# us-gaap:RestructuringReserve                                 162             usd          -3
# us-gaap:RestructuringReserve                                 938             usd          -3
# us-gaap:IncomeLossFromContinuingOperationsBeforeIncomeTaxesDomestic 125,362         usd          -3
# us-gaap:IncomeLossFromContinuingOperationsBeforeIncomeTaxesForeign 682,018         usd          -3
# us-gaap:IncomeLossFromContinuingOperationsBeforeIncomeTaxesMinorityInterestAndIncomeLossFromEquityMethodInvestments 807,380         usd          -3
# us-gaap:CurrentFederalTaxExpenseBenefit                      11,043          usd          -3
# us-gaap:CurrentStateAndLocalTaxExpenseBenefit                140             usd          -3
# us-gaap:CurrentForeignTaxExpenseBenefit                      80,722          usd          -3
# us-gaap:CurrentIncomeTaxExpenseBenefit                       91,905          usd          -3
# us-gaap:DeferredFederalIncomeTaxExpenseBenefit               35,545          usd          -3
# us-gaap:DeferredStateAndLocalIncomeTaxExpenseBenefit         3,771           usd          -3
# us-gaap:DeferredForeignIncomeTaxExpenseBenefit               57,452          usd          -3
# us-gaap:DeferredIncomeTaxExpenseBenefit                      18,136          usd          -3
# us-gaap:IncomeTaxExpenseBenefit                              73,769          usd          -3
# us-gaap:IncomeTaxReconciliationIncomeTaxExpenseBenefitAtFederalStatutoryIncomeTaxRate 169,550         usd          -3
# us-gaap:EffectiveIncomeTaxRateReconciliationAtFederalStatutoryIncomeTaxRate 21.0            number       3
# us-gaap:IncomeTaxReconciliationStateAndLocalIncomeTaxes      743             usd          -3
# us-gaap:EffectiveIncomeTaxRateReconciliationStateAndLocalIncomeTaxes 0.1             number       3
# us-gaap:IncomeTaxReconciliationTaxCredits                    92,532          usd          -3
# us-gaap:EffectiveIncomeTaxRateReconciliationTaxCredits       11.5            number       3
# us-gaap:IncomeTaxReconciliationChangeInEnactedTaxRate        22,286          usd          -3
# us-gaap:EffectiveIncomeTaxRateReconciliationChangeInEnactedTaxRate 2.8             number       3
# us-gaap:IncomeTaxReconciliationForeignIncomeTaxRateDifferential 85,851          usd          -3
# us-gaap:EffectiveIncomeTaxRateReconciliationForeignIncomeTaxRateDifferential 10.6            number       3
# us-gaap:IncomeTaxReconciliationChangeInDeferredTaxAssetsValuationAllowance 1,232           usd          -3
# us-gaap:EffectiveIncomeTaxRateReconciliationChangeInDeferredTaxAssetsValuationAllowance 0.2             number       3
# us-gaap:IncomeTaxReconciliationNondeductibleExpenseShareBasedCompensationCost 9,545           usd          -3
# us-gaap:EffectiveIncomeTaxRateReconciliationNondeductibleExpenseShareBasedCompensationCost 1.2             number       3
# us-gaap:IncomeTaxReconciliationTaxContingencies              9,979           usd          -3
# us-gaap:EffectiveIncomeTaxRateReconciliationTaxContingencies 1.2             number       3
# us-gaap:IncomeTaxReconciliationRepatriationOfForeignEarnings 100,830         usd          -3
# us-gaap:EffectiveIncomeTaxRateReconciliationRepatriationOfForeignEarnings 12.5            number       3
# us-gaap:IncomeTaxReconciliationOtherAdjustments              388             usd          -3
# us-gaap:EffectiveIncomeTaxRateReconciliationOtherAdjustments 0.1             number       3
# us-gaap:IncomeTaxExpenseBenefit                              73,769          usd          -3
# us-gaap:EffectiveIncomeTaxRateContinuingOperations           9.1             number       3
# us-gaap:DeferredTaxAssetsInventory                           9,632           usd          -3
# us-gaap:DeferredTaxAssetsTaxDeferredExpenseCompensationAndBenefitsShareBasedCompensationCost 14,444          usd          -3
# us-gaap:DeferredTaxAssetsOperatingLossCarryforwards          24,474          usd          -3
# us-gaap:DeferredTaxAssetsTaxCreditCarryforwardsResearch      106,825         usd          -3
# us-gaap:DeferredTaxAssetsTaxDeferredExpenseCompensationAndBenefitsEmployeeBenefits 19,357          usd          -3
# us-gaap:DeferredTaxAssetsOther                               8,662           usd          -3
# us-gaap:DeferredTaxAssetsGross                               199,341         usd          -3
# us-gaap:DeferredTaxAssetsValuationAllowance                  36,512          usd          -3
# us-gaap:DeferredTaxAssetsNet                                 162,829         usd          -3
# us-gaap:DeferredTaxLiabilitiesGoodwillAndIntangibleAssets    25,553          usd          -3
# us-gaap:DeferredTaxLiabilitiesPropertyPlantAndEquipment      59,756          usd          -3
# us-gaap:DeferredTaxLiabilitiesUndistributedForeignEarnings   21,747          usd          -3
# us-gaap:DeferredTaxLiabilitiesLeasingArrangements            14,663          usd          -3
# us-gaap:DeferredTaxLiabilitiesOther                          1,681           usd          -3
# us-gaap:DeferredTaxAssetsLiabilitiesNet                      17,145          usd          -3
# us-gaap:DeferredTaxAssetsDeferredIncome                      59,056          usd          -3
# us-gaap:DeferredTaxLiabilitiesTaxDeferredIncome              41,911          usd          -3
# us-gaap:DeferredTaxAssetsLiabilitiesNet                      17,145          usd          -3
# us-gaap:ValuationAllowanceDeferredTaxAssetChangeInAmount     1.2             usd          -5
# us-gaap:DeferredTaxAssetsValuationAllowance                  2.9             usd          -5
# us-gaap:DeferredTaxAssetsValuationAllowance                  33.6            usd          -5
# us-gaap:OperatingLossCarryforwards                           28.5            usd          -5
# us-gaap:OperatingLossCarryforwards                           139.9           usd          -5
# us-gaap:TaxCreditCarryforwardAmount                          150.7           usd          -5
# us-gaap:TaxCreditCarryforwardAmount                          65.0            usd          -5
# us-gaap:OperatingLossCarryforwards                           115.8           usd          -5
# us-gaap:OperatingLossCarryforwards                           22.1            usd          -5
# us-gaap:UnrecognizedTaxBenefitsIncreasesResultingFromAcquisition 0.5             usd          -5
# us-gaap:IncomeTaxHolidayAggregateDollarAmount                74.3            usd          -5
# us-gaap:UnrecognizedTaxBenefits                              134.1           usd          -5
# us-gaap:UnrecognizedTaxBenefitsThatWouldImpactEffectiveTaxRate 128.7           usd          -5
# us-gaap:UnrecognizedTaxBenefits                              134.1           usd          -5
# us-gaap:UnrecognizedTaxBenefitsIncreasesResultingFromCurrentPeriodTaxPositions 10,048          usd          -3
# us-gaap:UnrecognizedTaxBenefitsIncreasesResultingFromPriorPeriodTaxPositions 6,240           usd          -3
# us-gaap:UnrecognizedTaxBenefitsDecreasesResultingFromPriorPeriodTaxPositions 348             usd          -3
# us-gaap:UnrecognizedTaxBenefitsReductionsResultingFromLapseOfApplicableStatuteOfLimitations 1,094           usd          -3
# us-gaap:UnrecognizedTaxBenefits                              134,068         usd          -3
# us-gaap:UnrecognizedTaxBenefitsIncomeTaxPenaltiesAndInterestExpense 0.8             usd          -5
# us-gaap:UnrecognizedTaxBenefitsIncomeTaxPenaltiesAndInterestAccrued 6.2             usd          -5
# us-gaap:UnrecognizedTaxBenefits                              134.1           usd          -5
# us-gaap:UnrecognizedTaxBenefitsIncomeTaxPenaltiesAndInterestAccrued 6.2             usd          -5
# us-gaap:TaxesPayableCurrent                                  86.7            usd          -5
# us-gaap:IncomeTaxesReceivable                                3.5             usd          -5
# us-gaap:NetIncomeLoss                                        733,611         usd          -3
# us-gaap:WeightedAverageNumberOfSharesOutstandingBasic        114,034         shares       -3
# us-gaap:IncrementalCommonSharesAttributableToShareBasedPaymentArrangements 1,982           shares       -3
# us-gaap:WeightedAverageNumberOfDilutedSharesOutstanding      116,016         shares       -3
# us-gaap:EarningsPerShareBasic                                6.43            usdPerShare  2
# us-gaap:EarningsPerShareDiluted                              6.32            usdPerShare  2
# us-gaap:AntidilutiveSecuritiesExcludedFromComputationOfEarningsPerShareAmount 0.1             shares       -5
# us-gaap:ShareBasedCompensationArrangementByShareBasedPaymentAwardNumberOfSharesAuthorized 4.3             shares       -5
# us-gaap:ShareBasedCompensationArrangementByShareBasedPaymentAwardNumberOfSharesAvailableForGrant 2.7             shares       -5
# us-gaap:ShareBasedCompensationArrangementByShareBasedPaymentAwardNumberOfSharesAvailableForGrant 0.9             shares       -5
# us-gaap:ShareBasedCompensationArrangementByShareBasedPaymentAwardNumberOfSharesAuthorized 0.3             shares       -5
# us-gaap:ShareBasedCompensationArrangementByShareBasedPaymentAwardNumberOfSharesAvailableForGrant 0.3             shares       -5
# us-gaap:ShareBasedCompensationArrangementByShareBasedPaymentAwardNumberOfSharesAvailableForGrant 3.3             shares       -5
# us-gaap:ShareBasedCompensation                               89.3            usd          -5
# us-gaap:StockIssuedDuringPeriodSharesStockOptionsExercised   503             shares       -3
# us-gaap:ShareBasedCompensationArrangementsByShareBasedPaymentAwardOptionsExercisesInPeriodWeightedAverageExercisePrice 18.88           usdPerShare  2
# us-gaap:ShareBasedCompensationArrangementByShareBasedPaymentAwardOptionsExpirationsInPeriod 6               shares       -3
# us-gaap:ShareBasedCompensationArrangementsByShareBasedPaymentAwardOptionsExpirationsInPeriodWeightedAverageExercisePrice 22.13           usdPerShare  2
# us-gaap:ShareBasedCompensationArrangementByShareBasedPaymentAwardOptionsOutstandingNumber 458             shares       -3
# us-gaap:ShareBasedCompensationArrangementByShareBasedPaymentAwardOptionsOutstandingWeightedAverageExercisePrice 17.21           usdPerShare  2
# us-gaap:ShareBasedCompensationArrangementByShareBasedPaymentAwardOptionsOutstandingIntrinsicValue 80,465          usd          -3
# us-gaap:ShareBasedCompensationArrangementByShareBasedPaymentAwardOptionsVestedAndExpectedToVestOutstandingNumber 458             shares       -3
# us-gaap:ShareBasedCompensationArrangementByShareBasedPaymentAwardOptionsVestedAndExpectedToVestOutstandingWeightedAverageExercisePrice 17.21           usdPerShare  2
# us-gaap:ShareBasedCompensationArrangementByShareBasedPaymentAwardOptionsVestedAndExpectedToVestOutstandingAggregateIntrinsicValue 80,465          usd          -3
# us-gaap:ShareBasedCompensationArrangementByShareBasedPaymentAwardOptionsExercisableNumber 458             shares       -3
# us-gaap:ShareBasedCompensationArrangementByShareBasedPaymentAwardOptionsExercisableWeightedAverageExercisePrice 17.21           usdPerShare  2
# us-gaap:SharebasedCompensationArrangementBySharebasedPaymentAwardOptionsExercisableIntrinsicValue1 80,465          usd          -3
# us-gaap:SharePrice                                           192.90          usdPerShare  2
# us-gaap:ShareBasedCompensationArrangementByShareBasedPaymentAwardOptionsExercisesInPeriodTotalIntrinsicValue 66.7            usd          -5
# us-gaap:ProceedsFromStockOptionsExercised                    40.9            usd          -5
# us-gaap:ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsGrantsInPeriod 799             shares       -3
# us-gaap:ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsGrantsInPeriodWeightedAverageGrantDateFairValue 125.43          usdPerShare  2
# us-gaap:ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsVestedInPeriod 965             shares       -3
# us-gaap:ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsVestedInPeriodWeightedAverageGrantDateFairValue 70.07           usdPerShare  2
# us-gaap:ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsForfeitedInPeriod 66              shares       -3
# us-gaap:ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsForfeituresWeightedAverageGrantDateFairValue 86.02           usdPerShare  2
# us-gaap:ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsNonvestedNumber 1,859           shares       -3
# us-gaap:ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsNonvestedWeightedAverageGrantDateFairValue 93.22           usdPerShare  2
# us-gaap:EmployeeServiceShareBasedCompensationNonvestedAwardsTotalCompensationCostNotYetRecognized 103.7           usd          -5
# us-gaap:ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsVestedInPeriodTotalFairValue 121.8           usd          -5
# us-gaap:StockRepurchasedDuringPeriodShares                   3.6             shares       -5
# us-gaap:StockRepurchasedDuringPeriodValue                    515.1           usd          -5
# us-gaap:CommonStockCapitalSharesReservedForFutureIssuance    9.4             shares       -5
# us-gaap:CommonStockSharesAuthorized                          405.0           shares       -5
# us-gaap:ShareBasedCompensationArrangementByShareBasedPaymentAwardOptionsOutstandingNumber 458             shares       -3
# us-gaap:ShareBasedCompensationArrangementByShareBasedPaymentAwardNumberOfSharesAvailableForGrant 3,866           shares       -3
# us-gaap:ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsNonvestedNumber 1,859           shares       -3
# us-gaap:CommonStockCapitalSharesReservedForFutureIssuance    9,440           shares       -3
# us-gaap:Revenues                                             4,015,307       usd          -3
# us-gaap:OperatingIncomeLoss                                  906,627         usd          -3
# us-gaap:InterestExpense                                      75,198          usd          -3
# us-gaap:OtherNonoperatingIncomeExpense                       24,049          usd          -3
# us-gaap:IncomeLossFromContinuingOperationsBeforeIncomeTaxesMinorityInterestAndIncomeLossFromEquityMethodInvestments 807,380         usd          -3
# us-gaap:PropertyPlantAndEquipmentNet                         1,011,686       usd          -3
# us-gaap:PropertyPlantAndEquipmentNet                         200,346         usd          -3
# us-gaap:PropertyPlantAndEquipmentNet                         53,999          usd          -3

# %%
re.match(r"-[\d]*", "-123")
# Out:
# <re.Match object; span=(0, 4), match='-123'>

# %% [markdown]
# ## Extract pages from the XBRL in HTML

# %%
def split_document_html_into_pages(html: str):
    """
    Extract each page in the HTML tag using the HR tag string as the page break.
    HTML in DOCUMENT is sectioned into pages with the HR tag, e.g. 
    <hr align="CENTER" size="3" style="COLOR:#999999" width="100%"/>. 
    
    Args:
        HTML in string format, not BS4 tag object.
    """
    assert isinstance(html, str), f"Invalid arg of type {type(html)}"
    
    page_breaks_regexp = "|".join([
        re.escape(str(page_break)) 
        for page_break in BeautifulSoup(html, 'html.parser').find_all('hr', {'width':'100%'})
    ])
    pages = re.split(page_breaks_regexp, str(html))
    return pages

# %%
# NOTE: HTML needs "str" for the data argument, cannot accept bs4.element.Tag
HTML(data=str(soup.find('html').extract()))
# Out:
# <html xml:lang="en-US" xmlns="http://www.w3.org/1999/xhtml" xmlns:country="http://xbrl.sec.gov/country/2020-01-31" xmlns:dei="http://xbrl.sec.gov/dei/2020-01-31" xmlns:iso4217="http://www.xbrl.org/2003/iso4217" xmlns:ix="http://www.xbrl.org/2013/inlineXBRL" xmlns:ixt="http://www.xbrl.org/inlineXBRL/transformation/2015-02-26" xmlns:ixt-sec="http://www.sec.gov/inlineXBRL/transformation/2015-08-31" xmlns:link="http://www.xbrl.org/2003/linkbase" xmlns:rfmd="http://www.rfmd.com/20210403" xmlns:srt="http://fasb.org/srt/2020-01-31" xmlns:us-gaap="http://fasb.org/us-gaap/2020-01-31" xmlns:xbrldi="http://xbrl.org/2006/xbrldi" xmlns:xbrli="http://www.xbrl.org/2003/instance" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"><head><meta content="text/html" http-equiv="Content-Type"/>
# <title>rfmd-20210403</title></head><body><div style="display:none"><ix:header><ix:hidden><ix:nonnumeric contextref="ifb6ce67cf6954ebf88471dd82daa9247_D20200329-20210403" id="_f07afd31-132a-4306-b519-99fac6b157b1" name="dei:EntityCentralIndexKey">0001604778</ix:nonnumeric><ix:nonnumeric contextref="ifb6ce67cf6954ebf88471dd82daa9247_D20200329-20210403" id="_93c8e31d-cb1e-4e29-8d44-10520e92cbbe" name="dei:AmendmentFlag">false</ix:nonnumeric><ix:nonnumeric contextref="ifb6ce67cf6954ebf88471dd82daa9247_D20200329-20210403" id="_6516ab93-a8fe-4bd4-a662-2ec55a7e0778" name="dei:DocumentFiscalYearFocus">2021</ix:nonnumeric><ix:nonnumeric contextref="ifb6ce67cf6954ebf88471dd82daa9247_D20200329-20210403" id="_16c303fa-a46e-466c-95d5-95ef95bd2971" name="dei:DocumentFiscalPeriodFocus">FY</ix:nonnumeric><ix:nonnumeric contextref="ifb6ce67cf6954ebf88471dd82daa9247_D20200329-20210403" format="ixt:datemonthdayyear" id="_544218c8-8465-4ca0-be34-3a947891a49f" name="dei:DocumentPeriodEndDate">4/3/2021</ix:nonnumeric><ix:nonnumeric contextref="ifb6ce67cf6954ebf88471dd82daa9247_D20200329-20210403" id="_b77ab002-7084-4094-8274-4104fa38c95f" name="dei:IcfrAuditorAttestationFlag">true</ix:nonnumeric><ix:nonfraction contextref="i531402faf1d04969ac2b2ba0e1680766_I20210403" decimals="-3" id="_bfc7f048-22f4-463e-a6e3-01d2f2f616ad" name="us-gaap:AllowanceForDoubtfulAccountsReceivableCurrent" scale="3" unitref="usd">331</ix:nonfraction><ix:nonfraction contextref="i61ca1a85fc064eb1a4858bc0478ba964_I20200328" decimals="-3" id="_8d7bbb87-4f9e-4ee9-94b3-f7e57e08ad05" name="us-gaap:AllowanceForDoubtfulAccountsReceivableCurrent" scale="3" ...
