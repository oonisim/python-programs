# %% [markdown]
# # EDGAR XBRL XML URL
#
# Generate URLs to the XBRL XML files in the fileing directory in a parallel processing manner using Ray.

# %%
# !pip install -q ray

# %%
from typing import (
    List,
    Dict,
    Iterable
)
import os
import sys
import random
import logging
import time
import re
import requests
import bs4
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import ray
from IPython.core.display import (
    display, 
    HTML
)

# %%
from sec_edgar_constant import (
    NUM_CPUS,
    FS_TYPE_10K,
    FS_TYPE_10Q,
    EDGAR_HTTP_HEADERS,
)

from sec_edgar_filing_xbrl_listing import (
    list_files,
    index_xml_url,
    xbrl_url,
    director,
    load_edgar_xbrl_index_file,
    xbrl_file_path_to_save,
    save_to_csv,
)

# %%
pd.set_option('display.float_format', lambda x: ('%f' % x).rstrip('0').rstrip('.'))
pd.set_option('display.colheader_justify', 'center')

logging.basicConfig(level=logging.DEBUG)
handler = logging.StreamHandler(sys.stdout)

Logger = logging.getLogger(__name__)
Logger.addHandler(handler)

# %% [markdown]
# # Data
#
# ## EDGAR XBRL Directory Indices

# %%
indices = pd.read_csv(
    "../data/listing/2010QTR1", 
    sep="|",
    usecols=['CIK', 'Form Type', 'Date Filed', 'Filename'],
    parse_dates=['Date Filed'],
)
# Copy, not view
indices = indices[indices['Form Type'].isin([FS_TYPE_10Q, FS_TYPE_10K])]
indices.loc[:,  'Form Type'] = indices['Form Type'].astype('category')
print(len(indices))
indices
# Out:
# 513
#        CIK   Form Type Date Filed                   Filename
# 0    1000697    10-K   2010-02-26  edgar/data/1000697/0000950123-10-017583.txt
# 1    1001039    10-Q   2010-02-09  edgar/data/1001039/0001193125-10-025949.txt
# 3    1001082    10-K   2010-03-01  edgar/data/1001082/0000950123-10-018671.txt
# 4    1001838    10-K   2010-02-26  edgar/data/1001838/0001104659-10-010334.txt
# 5    1002638    10-Q   2010-02-04  edgar/data/1002638/0001193125-10-021715.txt
# ..       ...       ...        ...                                          ...
# 585    96223    10-K   2010-02-26    edgar/data/96223/0000096223-10-000004.txt
# 586    97216    10-K   2010-02-24    edgar/data/97216/0001104659-10-009153.txt
# 587    97476    10-K   2010-02-23    edgar/data/97476/0001140361-10-007923.txt
# 588    97745    10-K   2010-02-26    edgar/data/97745/0000097745-10-000008.txt
# 589     9892    10-K   2010-02-25     edgar/data/9892/0001193125-10-039864.txt
#
# [513 rows x 4 columns]

# %%
DIR_CSV_INDEX = "../data/listing/"

# %% [markdown]
# ## XBRL TXT directory path to directory listing index.xml URL

# %%
indices.loc[:, 'Filename'] = indices['Filename'].apply(index_xml_url)
indices
# Out:
#        CIK   Form Type Date Filed  \
# 0    1000697    10-K   2010-02-26
# 1    1001039    10-Q   2010-02-09
# 3    1001082    10-K   2010-03-01
# 4    1001838    10-K   2010-02-26
# 5    1002638    10-Q   2010-02-04
# ..       ...       ...        ...
# 585    96223    10-K   2010-02-26
# 586    97216    10-K   2010-02-24
# 587    97476    10-K   2010-02-23
# 588    97745    10-K   2010-02-26
# 589     9892    10-K   2010-02-25
#
#                                      Filename
# 0    https://sec.gov/Archives/edgar/data/1000697/000095012310017583/index.xml
# 1    https://sec.gov/Archives/edgar/data/1001039/000119312510025949/index.xml
# 3    https://sec.gov/Archives/edgar/data/1001082/000095012310018671/index.xml
# 4    https://sec.gov/Archives/edgar/data/1001838/000110465910010334/index.xml
# 5    https://sec.gov/Archives/edgar/data/1002638/000119312510021715/index.xml
# ..                                                                        ...
# 585    https://sec.gov/Archives/edgar/data/96223/000009622310000004/index.xml
# 586    https://sec.gov/Archives/edgar/data/97216/000110465910009153/index.xml
# 587    https://sec.gov/Archives/edgar/data/97476/000114036110007923/index.xml
# 588    https://sec.gov/Archives/edgar/data/97745/000009774510000008/index.xml
# 589     https://sec.gov/Archives/edgar/data/9892/000119312510039864/index.xml
#
# [513 rows x 4 columns]

# %% [markdown]
# ---

# %% [markdown]
# # Utilities

# %%
def split(tasks: Iterable, num: int):
    """Split tasks into num assignments and dispense them sequentially
    Args:
        tasks: tasks to split into assignments
        num: number of assignments to create
    Yields: An assignment, which is a slice of the tasks
    """
    assert num > 0
    assert len(tasks) > 0
    Logger.debug(f"createing {num} assignments for {len(tasks)} tasks")

    # Total size of the tasks
    total = len(tasks)
    
    # Each assignment has 'quota' size which can be zero if total < number of assignments.
    quota = int(total / num)

    # Left over after each assignment takes its 'quota'
    redisual = total % num

    start = 0
    while start < total:
        # As long as redisual is there, each assginemt has (quota + 1) as its tasks.
        if redisual > 0:
            size = quota + 1 
            redisual -= 1
        else:
            size = quota 
        
        end = start + size
        yield tasks[start : min(end, total)]

        start = end
        end += size

# %%
@ray.remote(num_returns=1)
def worker(df):
    """GET XBRL XML URL
    Args:
        df: Pandas dataframe of the XBRL indices in the format:
            |CIK|Company Name|Form Type|Date Filed|Filename|
    
    Returns: Pandas dataframe where "Filename" column is updated with XBRL XML URL.
    """
    assert len(df) > 0

    df.loc[:, 'Filename'] = df['Filename'].apply(xbrl_url)
    return df

# %% [markdown]
# # Start Ray

# %%
ray.init(num_cpus=NUM_CPUS, num_gpus=0)
# Out:
# {'node_ip_address': '192.168.13.128',
#  'raylet_ip_address': '192.168.13.128',
#  'redis_address': '192.168.13.128:60386',
#  'object_store_address': '/tmp/ray/session_2021-12-30_00-24-45_919192_24271/sockets/plasma_store',
#  'raylet_socket_name': '/tmp/ray/session_2021-12-30_00-24-45_919192_24271/sockets/raylet',
#  'webui_url': None,
#  'session_dir': '/tmp/ray/session_2021-12-30_00-24-45_919192_24271',
#  'metrics_export_port': 62687,
#  'node_id': '00f00ba77beb61d0480cdbc7acc8f759e3da1da90e6be8aa09611f69'}

# %% [markdown]
# # Steps

# %%
indices = indices.head(100)
indices
# Out:
#        CIK   Form Type Date Filed  \
# 0    1000697    10-K   2010-02-26
# 1    1001039    10-Q   2010-02-09
# 3    1001082    10-K   2010-03-01
# 4    1001838    10-K   2010-02-26
# 5    1002638    10-Q   2010-02-04
# ..       ...       ...        ...
# 105  1103982    10-K   2010-02-25
# 106  1105705    10-K   2010-02-19
# 107  1108524    10-K   2010-03-11
# 108  1109357    10-K   2010-02-05
# 109  1110783    10-Q   2010-01-08
#
#                                      Filename
# 0    https://sec.gov/Archives/edgar/data/1000697/000095012310017583/index.xml
# 1    https://sec.gov/Archives/edgar/data/1001039/000119312510025949/index.xml
# 3    https://sec.gov/Archives/edgar/data/1001082/000095012310018671/index.xml
# 4    https://sec.gov/Archives/edgar/data/1001838/000110465910010334/index.xml
# 5    https://sec.gov/Archives/edgar/data/1002638/000119312510021715/index.xml
# ..                                                                        ...
# 105  https://sec.gov/Archives/edgar/data/1103982/000119312510040106/index.xml
# 106  https://sec.gov/Archives/edgar/data/1105705/000095012310014479/index.xml
# 107  https://sec.gov/Archives/edgar/data/1108524/000119312510053838/index.xml
# 108  https://sec.gov/Archives/edgar/data/1109357/000119312510023280/index.xml
# 109  https://sec.gov/Archives/edgar/data/1110783/000095012310001322/index.xml
#
# [100 rows x 4 columns]

# %%
# --------------------------------------------------------------------------------
# Split dataframe to handle in parallel
# --------------------------------------------------------------------------------
assignment = split(tasks=indices, num=NUM_CPUS)

# %%
# --------------------------------------------------------------------------------
# Asynchronously invoke tasks
# --------------------------------------------------------------------------------
futures = [worker.remote(task) for task in assignment]
assert len(futures) == NUM_CPUS, f"Expected {NUM_CPUS} tasks but got {len(futures)}."

# %%
# %%time
waits = []
while futures:
    # --------------------------------------------------------------------------------
    # Take the object references from completed jobs
    # --------------------------------------------------------------------------------
    completed, futures = ray.wait(futures)
    
    # --------------------------------------------------------------------------------
    # Pass the object references to another asynchronous job
    # --------------------------------------------------------------------------------
    waits.extend(completed)
# Out:
# (pid=24373) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1000697/000095012310017583/index.xml]
# (pid=24370) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1047122/000119312510038391/index.xml]
# (pid=24376) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1067983/000119312510043450/index.xml]
# (pid=24371) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1058290/000119312510040500/index.xml]
# (pid=24372) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1013871/000095012310015824/index.xml]
# (pid=24373) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1000697/000095012310017583/.*_htm,.xml] identified.
# (pid=24373) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1000697/000095012310017583/wat-20091231.xml] identified
# (pid=24373) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1001039/000119312510025949/index.xml]
# (pid=24368) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1090012/000095012310017093/index.xml]
# (pid=24369) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1024478/000095012310009905/index.xml]
# (pid=24374) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1038357/000119312510042964/index.xml]
# (pid=24370) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1047122/000119312510038391/.*_htm,.xml] identified.
# (pid=24370) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1047122/000119312510038391/rtn-20091231.xml] identified
# (pid=24370) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1047862/000119312510036116/index.xml]
# (pid=24371) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1058290/000119312510040500/.*_htm,.xml] identified.
# (pid=24371) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1058290/000119312510040500/ctsh-20091231.xml] identified
# (pid=24371) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1059324/000119312510036866/index.xml]
# (pid=24372) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1013871/000095012310015824/.*_htm,.xml] identified.
# (pid=24372) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1013871/000095012310015824/nrg-20091231.xml] identified
# (pid=24372) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1014473/000119312510043162/index.xml]
# (pid=24376) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1067983/000119312510043450/.*_htm,.xml] identified.
# (pid=24376) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1067983/000119312510043450/brka-20091231.xml] identified
# (pid=24376) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1070412/000119312510025522/index.xml]
# (pid=24373) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/
INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1004980/000100498010000015/index.xml]
# (pid=24368) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1099534/000104746910001610/.*_htm,.xml] identified.
# (pid=24368) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1099534/000104746910001610/hcg-20091231.xml] identified
# (pid=24368) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1103982/000119312510040106/index.xml]
# (pid=24374) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/104207/000010420710000039/.*_htm,.xml] identified.
# (pid=24374) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/104207/000010420710000039/wag-20100228.xml] identified
# (pid=24374) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1043121/000119312510040838/index.xml]
# (pid=24370) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1053507/000119312510044876/.*_htm,.xml] identified.
# (pid=24370) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1053507/000119312510044876/amt-20091231.xml] identified
# (pid=24370) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1054374/000095012310008370/index.xml]
# (pid=24371) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1064728/000095012310016425/.*_htm,.xml] identified.
# (pid=24371) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1064728/000095012310016425/btu-20091231.xml] identified
# (pid=24371) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1065088/000119312510033324/index.xml]
# (pid=24372) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1018963/000095012310017084/.*_htm,.xml] identified.
# (pid=24372) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1018963/000095012310017084/ati-20091231.xml] identified
# (pid=24372) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1021860/000095012310017647/index.xml]
# (pid=24369) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1035267/000119312510016932/.*_htm,.xml] identified.
# (pid=24369) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1035267/000119312510016932/isrg-20091231.xml] identified
# (pid=24369) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/103682/000119312510042883/index.xml]
# (pid=24376) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1080224/000119312510072909/.*_htm,.xml] identified.
# (pid=24373) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1004980/000100498010000015/.*_htm,.xml] identified.
# (pid=24376) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1080224/000119312510072909/edgr-20091231.xml] identified
# (pid=24376) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1086195/000095012310007004/index.xml]
# (pid=24373) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1004980/000100498010000015/pcg-20091231.xml] identified
# (pid=24373) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/100826/000119312510043155/index.xml]
# (pid=24368) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1103982/000119312510040106/.*_htm,.xml] identified.
# (pid=24368) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1103982/000119312510040106/kft-20091231.xml] identified
# (pid=24368) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1105705/000095012310014479/index.xml]
# (pid=24374) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1043121/000119312510040838/.*_htm,.xml] identified.
# (pid=24374) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1043121/000119312510040838/cik000104312-20091231.xml] identified
# (pid=24374) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1043219/000115752310001176/index.xml]
# (pid=24371) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1065088/000119312510033324/.*_htm,.xml] identified.
# (pid=24371) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1065088/000119312510033324/ebay-20091231.xml] identified
# (pid=24371) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1065280/000119312510036181/index.xml]
# (pid=24370) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1054374/000095012310008370/.*_htm,.xml] identified.
# (pid=24370) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1054374/000095012310008370/brcm-20091231.xml] identified
# (pid=24370) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1056239/000095012310017377/index.xml]
# (pid=24372) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1021860/000095012310017647/.*_htm,.xml] identified.
# (pid=24372) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1021860/000095012310017647/nov-20091231.xml] identified
# (pid=24372) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1022079/000093041310000862/index.xml]
# (pid=24369) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/103682/000119312510042883/.*_htm,.xml] identified.
# (pid=24369) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/103682/000119312510042883/d-20091231.xml] identified
# (pid=24369) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1037016/000095012310017111/index.xml]
# (pid=24376) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1086195/000095012310007004/.*_htm,.xml] identified.
# (pid=24376) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1086195/000095012310007004/artg-20091231.xml] identified
# (pid=24376) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1086222/000119312510044561/index.xml]
# (pid=24373) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/100826/000119312510043155/.*_htm,.xml] identified.
# (pid=24373) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/100826/000119312510043155/aee-20091231.xml] identified
# (pid=24373) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/100885/000119312510023294/index.xml]
# (pid=24368) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1105705/000095012310014479/.*_htm,.xml] identified.
# (pid=24374) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1043219/000115752310001176/.*_htm,.xml] identified.
# (pid=24374) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1043219/000115752310001176/nly-20091231.xml] identified
# (pid=24374) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1043277/000119312510044679/index.xml]
# (pid=24368) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1105705/000095012310014479/twx-20091231.xml] identified
# (pid=24368) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1108524/000119312510053838/index.xml]
# (pid=24371) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1065280/000119312510036181/.*_htm,.xml] identified.
# (pid=24371) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1065280/000119312510036181/nflx-20091231.xml] identified
# (pid=24371) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/106535/000119312510041278/index.xml]
# (pid=24370) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1056239/000095012310017377/.*_htm,.xml] identified.
# (pid=24370) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1056239/000095012310017377/lll-20091231.xml] identified
# (pid=24370) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1056358/000105635810000020/index.xml]
# (pid=24372) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1022079/000093041310000862/.*_htm,.xml] identified.
# (pid=24372) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1022079/000093041310000862/dgx-20091231.xml] identified
# (pid=24372) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1022646/000095012310018286/index.xml]
# (pid=24369) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1037016/000095012310017111/.*_htm,.xml] identified.
# (pid=24369) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1037016/000095012310017111/nihd-20091231.xml] identified
# (pid=24369) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1037540/000119312510040826/index.xml]
# (pid=24376) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1086222/000119312510044561/.*_htm,.xml] identified.
# (pid=24376) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1086222/000119312510044561/akam-20091231.xml] identified
# (pid=24376) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/108772/000119312510043079/index.xml]
# (pid=24373) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/100885/000119312510023294/.*_htm,.xml] identified.
# (pid=24373) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/100885/000119312510023294/unp-20091231.xml] identified
# (pid=24373) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1010775/000119312510041620/index.xml]
# (pid=24374) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1043277/000119312510044679/.*_htm,.xml] identified.
# (pid=24374) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1043277/000119312510044679/chrw-20091231.xml] identified
# (pid=24374) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1043604/000095012310018160/index.xml]
# (pid=24368) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1108524/000119312510053838/.*_htm,.xml] identified.
# (pid=24368) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1108524/000119312510053838/crm-20100131.xml] identified
# (pid=24368) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1109357/000119312510023280/index.xml]
# (pid=24371) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/106535/000119312510041278/.*_htm,.xml] identified.
# (pid=24370) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1056358/000105635810000020/.*_htm,.xml] identified.
# (pid=24371) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/106535/000119312510041278/wy-20091231.xml] identified
# (pid=24371) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1066107/000095012310019484/index.xml]
# (pid=24370) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1056358/000105635810000020/mtex-20091231.xml] identified
# (pid=24370) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1058057/000119312510073247/index.xml]
# (pid=24369) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1037540/000119312510040826/.*_htm,.xml] identified.
# (pid=24369) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1037540/000119312510040826/bxp-20091231.xml] identified
# (pid=24369) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1037676/000095012310019343/index.xml]
# (pid=24372) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1022646/000095012310018286/.*_htm,.xml] identified.
# (pid=24372) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1022646/000095012310018286/upl-20091231.xml] identified
# (pid=24372) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1022671/000104746910001104/index.xml]
# (pid=24373) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1010775/000119312510041620/.*_htm,.xml] identified.
# (pid=24373) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1010775/000119312510041620/mir-20091231.xml] identified
# (pid=24373) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1011006/000119312510043149/index.xml]
# (pid=24376) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/108772/000119312510043079/.*_htm,.xml] identified.
# (pid=24376) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/108772/000119312510043079/xrx-20091231.xml] identified
# (pid=24376) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1087835/000095012310015194/index.xml]
# (pid=24368) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1109357/000119312510023280/.*_htm,.xml] identified.
# (pid=24368) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1109357/000119312510023280/exc-20091231.xml] identified
# (pid=24368) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1110783/000095012310001322/index.xml]
# (pid=24374) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1043604/000095012310018160/.*_htm,.xml] identified.
# (pid=24374) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1043604/000095012310018160/jnpr-20091231.xml] identified
# (pid=24374) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/10456/000095012310015380/index.xml]
# (pid=24370) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1058057/000119312510073247/.*_htm,.xml] identified.
# (pid=24371) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1066107/000095012310019484/.*_htm,.xml] identified.
# (pid=24371) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1066107/000095012310019484/ep-20091231.xml] identified
# (pid=24370) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1058057/000119312510073247/mrvl-20100130.xml] identified
# (pid=24372) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1022671/000104746910001104/.*_htm,.xml] identified.
# (pid=24372) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1022671/000104746910001104/stld-20091231.xml] identified
# (pid=24372) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1023131/000104746910001644/index.xml]
# (pid=24369) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1037676/000095012310019343/.*_htm,.xml] identified.
# (pid=24369) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1037676/000095012310019343/aci-20091231.xml] identified
# (pid=24369) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1037868/000095012310016787/index.xml]
# (pid=24373) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1011006/000119312510043149/.*_htm,.xml] identified.
# (pid=24373) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1011006/000119312510043149/yhoo-20091231.xml] identified
# (pid=24376) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1087835/000095012310015194/.*_htm,.xml] identified.
# (pid=24376) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1087835/000095012310015194/bgllc-20091226.xml] identified
# (pid=24368) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1110783/000095012310001322/.*_htm,.xml] identified.
# (pid=24368) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1110783/000095012310001322/mon-20091130.xml] identified
# (pid=24374) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/10456/000095012310015380/.*_htm,.xml] identified.
# (pid=24374) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/10456/000095012310015380/bax-20091231.xml] identified
# (pid=24374) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1045810/000104581010000006/index.xml]
# (pid=24372) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1023131/000104746910001644/.*_htm,.xml] identified.
# (pid=24372) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1023131/000104746910001644/cvd-20091231.xml] identified
# (pid=24369) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1037868/000095012310016787/.*_htm,.xml] identified.
# (pid=24369) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1037868/000095012310016787/ame-20091231.xml] identified
# (pid=24369) INFO:sec_edgar_filing_xbrl_listing:Identifying XBRL URL for the filing directory index [https://sec.gov/Archives/edgar/data/1037949/000119312510032428/index.xml]
# (pid=24374) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1045810/000104581010000006/.*_htm,.xml] identified.
# (pid=24374) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1045810/000104581010000006/nvda-20100131.xml] identified
# CPU times: user 1.34 s, sys: 940 ms, total: 2.28 s
# Wall time: 17.5 s
# (pid=24369) WARNING:sec_edgar_filing_xbrl_listing:No XBRL XML pattern [/Archives/edgar/data/1037949/000119312510032428/.*_htm,.xml] identified.
# (pid=24369) INFO:sec_edgar_filing_xbrl_listing:XBRL XML [https://sec.gov/Archives/edgar/data/1037949/000119312510032428/q-20091231.xml] identified

# %%
# --------------------------------------------------------------------------------
# Collect the results
# --------------------------------------------------------------------------------
assert len(waits) == NUM_CPUS, f"Expected {NUM_CPUS} tasks but got {len(waits)}."
results = ray.get(waits)

# %%
# %%time
df = pd.concat(results)
df.sort_index(inplace=True)
df
# Out:
# CPU times: user 28.3 ms, sys: 11.2 ms, total: 39.5 ms
# Wall time: 40.6 ms
#        CIK   Form Type Date Filed  \
# 0    1000697    10-K   2010-02-26
# 1    1001039    10-Q   2010-02-09
# 3    1001082    10-K   2010-03-01
# 4    1001838    10-K   2010-02-26
# 5    1002638    10-Q   2010-02-04
# ..       ...       ...        ...
# 105  1103982    10-K   2010-02-25
# 106  1105705    10-K   2010-02-19
# 107  1108524    10-K   2010-03-11
# 108  1109357    10-K   2010-02-05
# 109  1110783    10-Q   2010-01-08
#
#                                          Filename
# 0     https://sec.gov/Archives/edgar/data/1000697/000095012310017583/wat-20091231.xml
# 1     https://sec.gov/Archives/edgar/data/1001039/000119312510025949/dis-20100102.xml
# 3    https://sec.gov/Archives/edgar/data/1001082/000095012310018671/dish-20091231.xml
# 4    https://sec.gov/Archives/edgar/data/1001838/000110465910010334/scco-20091231.xml
# 5    https://sec.gov/Archives/edgar/data/1002638/000119312510021715/otex-20091231.xml
# ..                                                                                ...
# 105   https://sec.gov/Archives/edgar/data/1103982/000119312510040106/kft-20091231.xml
# 106   https://sec.gov/Archives/edgar/data/1105705/000095012310014479/twx-20091231.xml
# 107   https://sec.gov/Archives/edgar/data/1108524/000119312510053838/crm-20100131.xml
# 108   https://sec.gov/Archives/edgar/data/1109357/000119312510023280/exc-20091231.xml
# 109   https://sec.gov/Archives/edgar/data/1110783/000095012310001322/mon-20091130.xml
#
# [100 rows x 4 columns]

# %% [raw]
# @ray.remote(num_returns=1)
# def worker(urls):
#     """GET XML files from URLs"""
#     xmls = []
#
#     for url in urls:
#         # --------------------------------------------------------------------------------
#         # Retrieve SEC Filing XBRL XML from the URL
#         # --------------------------------------------------------------------------------
#         response = requests.get(url, headers=EDGAR_HTTP_HEADERS)
#         if response.status_code == 200:
#             print(f"Got XML from {url}")
#             # --------------------------------------------------------------------------------
#             # SEC Filing XML Filename
#             # --------------------------------------------------------------------------------
#             names.append(os.path.basename(url))
#
#             # --------------------------------------------------------------------------------
#             # The first HTML content in the XBRL XML
#             # --------------------------------------------------------------------------------
#             content = response.content.decode("utf-8")
#             xmls.append(content)
#         else:
#             assert False, f"{url} failed with status {response.status_code}"
#
#     return names, xmls

# %% [raw]
# os.makedirs("downloads", exist_ok=True)
#
# @ray.remote
# def save(references):
#
#     # --------------------------------------------------------------------------------
#     # ray.wait() returns a list of object-references (results) returned from workers.
#     # (one reference per worker)
#     # --------------------------------------------------------------------------------
#     results = ray.get(references)
#     while(results):
#         # --------------------------------------------------------------------------------
#         # Pick the first job result
#         # --------------------------------------------------------------------------------
#         result, *results = results
#
#         # --------------------------------------------------------------------------------
#         # result = [names, xmls] from each worker
#         # --------------------------------------------------------------------------------
#         names, xmls = result
#
#         # --------------------------------------------------------------------------------
#         # Save XML into a file with 'name'
#         # --------------------------------------------------------------------------------
#         for i in range(0, len(names)):
#             print(f"Saving XML into {names[i]}")
#             with open(f"./downloads/{names[i]}", "w") as f:
#                 f.write(xmls[i])

# %% [markdown]
# # Cleanup

# %%
ray.shutdown()

# %%
year = None
assert (re.match(r"[1-2][0-9][0-9][0-9]", year) if year else True), f"Invalid year {year}"
