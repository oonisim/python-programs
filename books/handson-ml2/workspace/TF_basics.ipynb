# %%
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
import numpy as np

print(tf.__version__)
print(keras.__version__)
# Out:
# 2.1.0
# 2.2.4-tf

# %% [markdown]
# # Utilities

# %%
import os
root_logdir = os.path.join(os.curdir, "my_logs")
print(os.getcwd())

def get_run_logdir():
    import time
    run_id = time.strftime("run_%Y_%m_%d-%H_%M_%S")
    return os.path.join(root_logdir, run_id)

run_logdir = get_run_logdir() # e.g., './my_logs/run_2019_06_07-15_15_22'
# Out:
# /home/oonisim/home/repositories/git/oonisim/handson-ml2/workspace

# %% [markdown]
# # Tensor

# %%
tf_single = tf.constant(2.0)
tf_single
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=2.0>

# %%
tf_1d = tf.constant([2.0, 3.0, 4.0])
tf_1d
# Out:
# <tf.Tensor: shape=(3,), dtype=float32, numpy=array([2., 3., 4.], dtype=float32)>

# %%
tf_2d = tf.constant([
    [3, 8],
    [2, 1]
])
tf_2d
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[3, 8],
#        [2, 1]], dtype=int32)>

# %%
filepaths = [
    '/home/oonisim/.keras/datasets/train.csv'
]
filepath = '/home/oonisim/.keras/datasets/train.csv'

# %%
def show_batch(dataset):
  for batch, label in dataset.take(1):
    for key, value in batch.items():
      print("{:20s}: {}".format(key,value.numpy()))

# %%
LABEL_COLUMN_TRAIN = 'Survived'
dataset = tf.data.experimental.make_csv_dataset(
      filepath,
      batch_size=5, # Artificially small to make examples easier to show.
      label_name=LABEL_COLUMN_TRAIN,
      na_value="?",
      num_epochs=1,
      ignore_errors=True, 
      header=True
)
dataset
# Out:
# <PrefetchDataset shapes: (OrderedDict([(PassengerId, (None,)), (Pclass, (None,)), (Name, (None,)), (Sex, (None,)), (Age, (None,)), (SibSp, (None,)), (Parch, (None,)), (Ticket, (None,)), (Fare, (None,)), (Cabin, (None,)), (Embarked, (None,))]), (None,)), types: (OrderedDict([(PassengerId, tf.int32), (Pclass, tf.int32), (Name, tf.string), (Sex, tf.string), (Age, tf.float32), (SibSp, tf.int32), (Parch, tf.int32), (Ticket, tf.string), (Fare, tf.float32), (Cabin, tf.string), (Embarked, tf.string)]), tf.int32)>

# %%
for element in dataset:
  print(element)
# Out:
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([333, 183, 319, 752, 883], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([1, 3, 1, 3, 3], dtype=int32)>), ('Name', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'Graham, Mr. George Edward',
#        b'Asplund, Master. Clarence Gustaf Hugo',
#        b'Wick, Miss. Mary Natalie', b'Moor, Master. Meier',
#        b'Dahlberg, Miss. Gerda Ulrika'], dtype=object)>), ('Sex', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'male', b'male', b'female', b'male', b'female'], dtype=object)>), ('Age', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([38.,  9., 31.,  6., 22.], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 4, 0, 0, 0], dtype=int32)>), ('Parch', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([1, 2, 2, 1, 0], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'PC 17582', b'347077', b'36928', b'392096', b'7552'], dtype=object)>), ('Fare', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([153.4625,  31.3875, 164.8667,  12.475 ,  10.5167], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'C91', b'', b'C7', b'E121', b''], dtype=object)>), ('Embarked', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'S', b'S', b'S', b'S', b'S'], dtype=object)>)]), <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 1, 1, 0], dtype=int32)>)
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([654, 394, 412, 128, 775], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([3, 1, 3, 3, 2], dtype=int32)>), ('Name', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'O\'Leary, Miss. Hanora "Norah"', b'Newell, Miss. Marjorie',
#        b'Hart, Mr. Henry', b'Madsen, Mr. Fridtjof Arne',
#        b'Hocking, Mrs. Elizabeth (Eliza Needs)'], dtype=object)>), ('Sex', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'female', b'female', b'male', b'male', b'female'], dtype=object)>), ('Age', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([ 0., 23.,  0., 24., 54.], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 1, 0, 0, 1], dtype=int32)>), ('Parch', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 0, 0, 3], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'330919', b'35273', b'394140', b'C 17369', b'29105'], dtype=object)>), ('Fare', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([  7.8292, 113.275 ,   6.8583,   7.1417,  23.    ], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'', b'D36', b'', b'', b''], dtype=object)>), ('Embarked', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'Q', b'C', b'Q', b'S', b'S'], dtype=object)>)]), <tf.Tensor: shape=(5,), dtype=int32, numpy=array([1, 1, 0, 1, 1], dtype=int32)>)
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([521,  81, 877, 266, 502], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([1, 3, 3, 2, 3], dtype=int32)>), ('Name', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'Perreault, Miss. Anne', b'Waelens, Mr. Achille',
#        b'Gustafsson, Mr. Alfred Ossian', b'Reeves, Mr. David',
#        b'Canavan, Miss. Mary'], dtype=object)>), ('Sex', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'female', b'male', b'male', b'male', b'female'], dtype=object)>), ('Age', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([30., 22., 20., 36., 21.], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 0, 0, 0], dtype=int32)>), ('Parch', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 0, 0, 0], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'12749', b'345767', b'7534', b'C.A. 17248', b'364846'],
#       dtype=object)>), ('Fare', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([93.5   ,  9.    ,  9.8458, 10.5   ,  7.75  ], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'B73', b'', b'', b'', b''], dtype=object)>), ('Embarked', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'S', b'S', b'S', b'S', b'Q'], dtype=object)>)]), <tf.Tensor: shape=(5,), dtype=int32, numpy=array([1, 0, 0, 0, 0], dtype=int32)>)
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([681, 117, 561, 803, 575], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([3, 3, 3, 1, 3], dtype=int32)>), ('Name', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'Peters, Miss. Katie', b'Connors, Mr. Patrick',
#        b'Morrow, Mr. Thomas Rowan',
#        b'Carter, Master. William Thornton II',
#        b'Rush, Mr. Alfred George John'], dtype=object)>), ('Sex', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'female', b'male', b'male', b'male', b'male'], dtype=object)>), ('Age', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([ 0. , 70.5,  0. , 11. , 16. ], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 0, 1, 0], dtype=int32)>), ('Parch', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 0, 2, 0], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'330935', b'370369', b'372622', b'113760', b'A/4. 20589'],
#       dtype=object)>), ('Fare', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([  8.1375,   7.75  ,   7.75  , 120.    ,   8.05  ], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'', b'', b'', b'B96 B98', b''], dtype=object)>), ('Embarked', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'Q', b'Q', b'Q', b'S', b'S'], dtype=object)>)]), <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 0, 1, 0], dtype=int32)>)
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([523, 668, 645, 629, 781], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([3, 3, 3, 3, 3], dtype=int32)>), ('Name', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'Lahoud, Mr. Sarkis', b'Rommetvedt, Mr. Knud Paust',
#        b'Baclini, Miss. Eugenie', b'Bostandyeff, Mr. Guentcho',
#        b'Ayoub, Miss. Banoura'], dtype=object)>), ('Sex', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'male', b'male', b'female', b'male', b'female'], dtype=object)>), ('Age', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([ 0.  ,  0.  ,  0.75, 26.  , 13.  ], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 2, 0, 0], dtype=int32)>), ('Parch', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 1, 0, 0], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'2624', b'312993', b'2666', b'349224', b'2687'], dtype=object)>), ('Fare', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([ 7.225 ,  7.775 , 19.2583,  7.8958,  7.2292], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'', b'', b'', b'', b''], dtype=object)>), ('Embarked', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'C', b'S', b'C', b'S', b'C'], dtype=object)>)]), <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 1, 0, 1], dtype=int32)>)
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([159, 517, 526, 380, 409], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([3, 2, 3, 3, 3], dtype=int32)>), ('Name', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'Smiljanic, Mr. Mile', b'Lemore, Mrs. (Amelia Milley)',
#        b'Farrell, Mr. James', b'Gustafsson, Mr. Karl Gideon',
#        b'Birkeland, Mr. Hans Martin Monsen'], dtype=object)>), ('Sex', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'male', b'female', b'male', b'male', b'male'], dtype=object)>), ('Age', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([ 0. , 34. , 40.5, 19. , 21. ], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 0, 0, 0], dtype=int32)>), ('Parch', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 0, 0, 0], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'315037', b'C.A. 34260', b'367232', b'347069', b'312992'],
#       dtype=object)>), ('Fare', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([ 8.6625, 10.5   ,  7.75  ,  7.775 ,  7.775 ], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'', b'F33', b'', b'', b''], dtype=object)>), ('Embarked', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'S', b'S', b'Q', b'S', b'S'], dtype=object)>)]), <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 1, 0, 0, 0], dtype=int32)>)
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([211, 631, 485, 316,  50], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([3, 1, 1, 3, 3], dtype=int32)>), ('Name', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'Ali, Mr. Ahmed', b'Barkworth, Mr. Algernon Henry Wilson',
#        b'Bishop, Mr. Dickinson H', b'Nilsson, Miss. Helmina Josefina',
#        b'Arnold-Franchi, Mrs. Josef (Josefine Franchi)'], dtype=object)>), ('Sex', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'male', b'male', b'male', b'female', b'female'], dtype=object)>), ('Age', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([24., 80., 25., 26., 18.], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 1, 0, 1], dtype=int32)>), ('Parch', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 0, 0, 0], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'SOTON/O.Q. 3101311', b'27042', b'11967', b'347470', b'349237'],
#       dtype=object)>), ('Fare', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([ 7.05  , 30.    , 91.0792,  7.8542, 17.8   ], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'', b'A23', b'B49', b'', b''], dtype=object)>), ('Embarked', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'S', b'S', b'C', b'S', b'S'], dtype=object)>)]), <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 1, 1, 1, 0], dtype=int32)>)
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([152, 146, 624, 694, 685], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([1, 2, 3, 3, 2], dtype=int32)>), ('Name', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'Pears, Mrs. Thomas (Edith Wearne)',
#        b'Nicholls, Mr. Joseph Charles', b'Hansen, Mr. Henry Damsgaard',
#        b'Saad, Mr. Khalil', b'Brown, Mr. Thomas William Solomon'],
#       dtype=object)>), ('Sex', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'female', b'male', b'male', b'male', b'male'], dtype=object)>), ('Age', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([22., 19., 21., 25., 60.], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([1, 1, 0, 0, 1], dtype=int32)>), ('Parch', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 1, 0, 0, 1], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'113776', b'C.A. 33112', b'350029', b'2672', b'29750'],
#       dtype=object)>), ('Fare', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([66.6   , 36.75  ,  7.8542,  7.225 , 39.    ], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'C2', b'', b'', b'', b''], dtype=object)>), ('Embarked', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'S', b'S', b'S', b'C', b'S'], dtype=object)>)]), <tf.Tensor: shape=(5,), dtype=int32, numpy=array([1, 0, 0, 0, 0], dtype=int32)>)
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([125, 280,  47, 203, 807], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([1, 3, 3, 3, 1], dtype=int32)>), ('Name', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'White, Mr. Percival Wayland',
#        b'Abbott, Mrs. Stanton (Rosa Hunt)', b'Lennon, Mr. Denis',
#        b'Johanson, Mr. Jakob Alfred', b'Andrews, Mr. Thomas Jr'],
#       dtype=object)>), ('Sex', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'male', b'female', b'male', b'male', b'male'], dtype=object)>), ('Age', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([54., 35.,  0., 34., 39.], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 1, 1, 0, 0], dtype=int32)>), ('Parch', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([1, 1, 0, 0, 0], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'35281', b'C.A. 2673', b'370371', b'3101264', b'112050'],
#       dtype=object)>), ('Fare', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([77.2875, 20.25  , 15.5   ,  6.4958,  0.    ], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'D26', b'', b'', b'', b'A36'], dtype=object)>), ('Embarked', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'S', b'S', b'Q', b'S', b'S'], dtype=object)>)]), <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 1, 0, 0, 0], dtype=int32)>)
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([669,  59, 503, 831, 571], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([3, 2, 3, 3, 2], dtype=int32)>), ('Name', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'Cook, Mr. Jacob', b'West, Miss. Constance Mirium',
#        b"O'Sullivan, Miss. Bridget Mary",
#        b'Yasbeck, Mrs. Antoni (Selini Alexander)', b'Harris, Mr. George'],
#       dtype=object)>), ('Sex', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'male', b'female', b'female', b'female', b'male'], dtype=object)>), ('Age', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([43.,  5.,  0., 15., 62.], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 1, 0, 1, 0], dtype=int32)>), ('Parch', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 2, 0, 0, 0], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'A/5 3536', b'C.A. 34651', b'330909', b'2659', b'S.W./PP 752'],
#       dtype=object)>), ('Fare', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([ 8.05  , 27.75  ,  7.6292, 14.4542, 10.5   ], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'', b'', b'', b'', b''], dtype=object)>), ('Embarked', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'S', b'S', b'Q', b'C', b'S'], dtype=object)>)]), <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 1, 0, 1, 1], dtype=int32)>)
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([ 15, 635, 751, 586, 483], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([3, 3, 2, 1, 3], dtype=int32)>), ('Name', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'Vestrom, Miss. Hulda Amanda Adolfina', b'Skoog, Miss. Mabel',
#        b'Wells, Miss. Joan', b'Taussig, Miss. Ruth',
#        b'Rouse, Mr. Richard Henry'], dtype=object)>), ('Sex', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'female', b'female', b'female', b'female', b'male'], dtype=object)>), ('Age', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([14.,  9.,  4., 18., 50.], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 3, 1, 0, 0], dtype=int32)>), ('Parch', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 2, 1, 2, 0], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'350406', b'347088', b'29103', b'110413', b'A/5 3594'],
#       dtype=object)>), ('Fare', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([ 7.8542, 27.9   , 23.    , 79.65  ,  8.05  ], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'', b'', b'', b'E68', b''], dtype=object)>), ('Embarked', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'S', b'S', b'S', b'S', b'S'], dtype=object)>)]), <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 1, 1, 0], dtype=int32)>)
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([719, 251, 724, 457, 100], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([3, 3, 2, 1, 2], dtype=int32)>), ('Name', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'McEvoy, Mr. Michael', b'Reed, Mr. James George',
#        b'Hodges, Mr. Henry Price', b'Millet, Mr. Francis Davis',
#        b'Kantor, Mr. Sinai'], dtype=object)>), ('Sex', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'male', b'male', b'male', b'male', b'male'], dtype=object)>), ('Age', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([ 0.,  0., 50., 65., 34.], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 0, 0, 1], dtype=int32)>), ('Parch', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 0, 0, 0], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'36568', b'362316', b'250643', b'13509', b'244367'], dtype=object)>), ('Fare', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([15.5 ,  7.25, 13.  , 26.55, 26.  ], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'', b'', b'', b'E38', b''], dtype=object)>), ('Embarked', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'Q', b'S', b'S', b'S', b'S'], dtype=object)>)]), <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 0, 0, 0], dtype=int32)>)
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([848, 647, 648, 386, 540], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([3, 3, 1, 2, 1], dtype=int32)>), ('Name', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'Markoff, Mr. Marin', b'Cor, Mr. Liudevit',
#        b'Simonius-Blumer, Col. Oberst Alfons',
#        b'Davies, Mr. Charles Henry',
#        b'Frolicher, Miss. Hedwig Margaritha'], dtype=object)>), ('Sex', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'male', b'male', b'male', b'male', b'female'], dtype=object)>), ('Age', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([35., 19., 56., 18., 22.], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 0, 0, 0], dtype=int32)>), ('Parch', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 0, 0, 2], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'349213', b'349231', b'13213', b'S.O.C. 14879', b'13568'],
#       dtype=object)>), ('Fare', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([ 7.8958,  7.8958, 35.5   , 73.5   , 49.5   ], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'', b'', b'A26', b'', b'B39'], dtype=object)>), ('Embarked', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'C', b'S', b'C', b'S', b'C'], dtype=object)>)]), <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 1, 0, 1], dtype=int32)>)
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([640, 477,  33,  43, 849], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([3, 2, 3, 3, 2], dtype=int32)>), ('Name', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'Thorneycroft, Mr. Percival', b'Renouf, Mr. Peter Henry',
#        b'Glynn, Miss. Mary Agatha', b'Kraeff, Mr. Theodor',
#        b'Harper, Rev. John'], dtype=object)>), ('Sex', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'male', b'male', b'female', b'male', b'male'], dtype=object)>), ('Age', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([ 0., 34.,  0.,  0., 28.], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([1, 1, 0, 0, 0], dtype=int32)>), ('Parch', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 0, 0, 1], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'376564', b'31027', b'335677', b'349253', b'248727'], dtype=object)>), ('Fare', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([16.1   , 21.    ,  7.75  ,  7.8958, 33.    ], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'', b'', b'', b'', b''], dtype=object)>), ('Embarked', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'S', b'S', b'Q', b'C', b'S'], dtype=object)>)]), <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 1, 0, 0], dtype=int32)>)
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([365, 131, 736, 506,  13], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([3, 3, 3, 1, 3], dtype=int32)>), ('Name', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b"O'Brien, Mr. Thomas", b'Drazenoic, Mr. Jozef',
#        b'Williams, Mr. Leslie',
#        b'Penasco y Castellana, Mr. Victor de Satode',
#        b'Saundercock, Mr. William Henry'], dtype=object)>), ('Sex', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'male', b'male', b'male', b'male', b'male'], dtype=object)>), ('Age', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([ 0. , 33. , 28.5, 18. , 20. ], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([1, 0, 0, 1, 0], dtype=int32)>), ('Parch', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 0, 0, 0], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'370365', b'349241', b'54636', b'PC 17758', b'A/5. 2151'],
#       dtype=object)>), ('Fare', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([ 15.5   ,   7.8958,  16.1   , 108.9   ,   8.05  ], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'', b'', b'', b'C65', b''], dtype=object)>), ('Embarked', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'Q', b'C', b'S', b'C', b'S'], dtype=object)>)]), <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 0, 0, 0], dtype=int32)>)
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([570, 686, 342, 273, 546], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([3, 2, 1, 2, 1], dtype=int32)>), ('Name', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'Jonsson, Mr. Carl', b'Laroche, Mr. Joseph Philippe Lemercier',
#        b'Fortune, Miss. Alice Elizabeth',
#        b'Mellinger, Mrs. (Elizabeth Anne Maidment)',
#        b'Nicholson, Mr. Arthur Ernest'], dtype=object)>), ('Sex', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'male', b'male', b'female', b'female', b'male'], dtype=object)>), ('Age', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([32., 25., 24., 41., 64.], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 1, 3, 0, 0], dtype=int32)>), ('Parch', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 2, 2, 1, 0], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'350417', b'SC/Paris 2123', b'19950', b'250644', b'693'],
#       dtype=object)>), ('Fare', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([  7.8542,  41.5792, 263.    ,  19.5   ,  26.    ], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'', b'', b'C23 C25 C27', b'', b''], dtype=object)>), ('Embarked', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'S', b'C', b'S', b'S', b'S'], dtype=object)>)]), <tf.Tensor: shape=(5,), dtype=int32, numpy=array([1, 0, 1, 1, 0], dtype=int32)>)
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([ 93, 700, 653, 358, 609], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([1, 3, 3, 2, 2], dtype=int32)>), ('Name', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'Chaffee, Mr. Herbert Fuller',
#        b'Humblen, Mr. Adolf Mathias Nicolai Olsen',
#        b'Kalvik, Mr. Johannes Halvorsen', b'Funk, Miss. Annie Clemmer',
#        b'Laroche, Mrs. Joseph (Juliette Marie Louise Lafargue)'],
#       dtype=object)>), ('Sex', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'male', b'male', b'male', b'female', b'female'], dtype=object)>), ('Age', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([46., 42., 21., 38., 22.], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([1, 0, 0, 0, 1], dtype=int32)>), ('Parch', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 0, 0, 2], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'W.E.P. 5734', b'348121', b'8475', b'237671', b'SC/Paris 2123'],
#       dtype=object)>), ('Fare', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([61.175 ,  7.65  ,  8.4333, 13.    , 41.5792], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'E31', b'F G63', b'', b'', b''], dtype=object)>), ('Embarked', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'S', b'S', b'S', b'S', b'C'], dtype=object)>)]), <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 0, 0, 1], dtype=int32)>)
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([187, 876, 471, 525, 292], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([3, 3, 3, 3, 1], dtype=int32)>), ('Name', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'O\'Brien, Mrs. Thomas (Johanna "Hannah" Godfrey)',
#        b'Najib, Miss. Adele Kiamie "Jane"', b'Keefe, Mr. Arthur',
#        b'Kassem, Mr. Fared', b'Bishop, Mrs. Dickinson H (Helen Walton)'],
#       dtype=object)>), ('Sex', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'female', b'female', b'male', b'male', b'female'], dtype=object)>), ('Age', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([ 0., 15.,  0.,  0., 19.], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([1, 0, 0, 0, 1], dtype=int32)>), ('Parch', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 0, 0, 0], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'370365', b'2667', b'323592', b'2700', b'11967'], dtype=object)>), ('Fare', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([15.5   ,  7.225 ,  7.25  ,  7.2292, 91.0792], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'', b'', b'', b'', b'B49'], dtype=object)>), ('Embarked', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'Q', b'C', b'S', b'C', b'C'], dtype=object)>)]), <tf.Tensor: shape=(5,), dtype=int32, numpy=array([1, 1, 0, 0, 1], dtype=int32)>)
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([195, 616, 383, 737, 817], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([1, 2, 3, 3, 3], dtype=int32)>), ('Name', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'Brown, Mrs. James Joseph (Margaret Tobin)',
#        b'Herman, Miss. Alice', b'Tikkanen, Mr. Juho',
#        b'Ford, Mrs. Edward (Margaret Ann Watson)',
#        b'Heininen, Miss. Wendla Maria'], dtype=object)>), ('Sex', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'female', b'female', b'male', b'female', b'female'], dtype=object)>), ('Age', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([44., 24., 32., 48., 23.], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 1, 0, 1, 0], dtype=int32)>), ('Parch', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 2, 0, 3, 0], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'PC 17610', b'220845', b'STON/O 2. 3101293', b'W./C. 6608',
#        b'STON/O2. 3101290'], dtype=object)>), ('Fare', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([27.7208, 65.    ,  7.925 , 34.375 ,  7.925 ], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'B4', b'', b'', b'', b''], dtype=object)>), ('Embarked', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'C', b'S', b'S', b'S', b'S'], dtype=object)>)]), <tf.Tensor: shape=(5,), dtype=int32, numpy=array([1, 1, 0, 0, 0], dtype=int32)>)
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([796, 580, 544, 551, 790], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([2, 3, 2, 1, 1], dtype=int32)>), ('Name', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'Otter, Mr. Richard', b'Jussila, Mr. Eiriik',
#        b'Beane, Mr. Edward', b'Thayer, Mr. John Borland Jr',
#        b'Guggenheim, Mr. Benjamin'], dtype=object)>), ('Sex', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'male', b'male', b'male', b'male', b'male'], dtype=object)>), ('Age', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([39., 32., 32., 17., 46.], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 1, 0, 0], dtype=int32)>), ('Parch', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 0, 2, 0], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'28213', b'STON/O 2. 3101286', b'2908', b'17421', b'PC 17593'],
#       dtype=object)>), ('Fare', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([ 13.    ,   7.925 ,  26.    , 110.8833,  79.2   ], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'', b'', b'', b'C70', b'B82 B84'], dtype=object)>), ('Embarked', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'S', b'S', b'S', b'C', b'C'], dtype=object)>)]), <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 1, 1, 1, 0], dtype=int32)>)
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([679, 247, 858, 455, 682], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([3, 3, 1, 3, 1], dtype=int32)>), ('Name', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'Goodwin, Mrs. Frederick (Augusta Tyler)',
#        b'Lindahl, Miss. Agda Thorilda Viktoria',
#        b'Daly, Mr. Peter Denis ', b'Peduzzi, Mr. Joseph',
#        b'Hassab, Mr. Hammad'], dtype=object)>), ('Sex', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'female', b'female', b'male', b'male', b'male'], dtype=object)>), ('Age', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([43., 25., 51.,  0., 27.], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([1, 0, 0, 0, 0], dtype=int32)>), ('Parch', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([6, 0, 0, 0, 0], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'CA 2144', b'347071', b'113055', b'A/5 2817', b'PC 17572'],
#       dtype=object)>), ('Fare', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([46.9   ,  7.775 , 26.55  ,  8.05  , 76.7292], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'', b'', b'E17', b'', b'D49'], dtype=object)>), ('Embarked', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'S', b'S', b'S', b'S', b'C'], dtype=object)>)]), <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 1, 0, 1], dtype=int32)>)
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([590, 842, 854, 515, 385], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([3, 2, 1, 3, 3], dtype=int32)>), ('Name', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'Murdlin, Mr. Joseph', b'Mudd, Mr. Thomas Charles',
#        b'Lines, Miss. Mary Conover', b'Coleff, Mr. Satio',
#        b'Plotcharsky, Mr. Vasil'], dtype=object)>), ('Sex', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'male', b'male', b'female', b'male', b'male'], dtype=object)>), ('Age', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([ 0., 16., 16., 24.,  0.], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 0, 0, 0], dtype=int32)>), ('Parch', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 1, 0, 0], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'A./5. 3235', b'S.O./P.P. 3', b'PC 17592', b'349209', b'349227'],
#       dtype=object)>), ('Fare', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([ 8.05  , 10.5   , 39.4   ,  7.4958,  7.8958], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'', b'', b'D28', b'', b''], dtype=object)>), ('Embarked', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'S', b'S', b'S', b'S', b'S'], dtype=object)>)]), <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 1, 0, 0], dtype=int32)>)
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([283, 320, 556,  10, 866], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([3, 1, 1, 2, 2], dtype=int32)>), ('Name', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'de Pelsmaeker, Mr. Alfons',
#        b'Spedden, Mrs. Frederic Oakley (Margaretta Corning Stone)',
#        b'Wright, Mr. George', b'Nasser, Mrs. Nicholas (Adele Achem)',
#        b'Bystrom, Mrs. (Karolina)'], dtype=object)>), ('Sex', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'male', b'female', b'male', b'female', b'female'], dtype=object)>), ('Age', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([16., 40., 62., 14., 42.], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 1, 0, 1, 0], dtype=int32)>), ('Parch', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 1, 0, 0, 0], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'345778', b'16966', b'113807', b'237736', b'236852'], dtype=object)>), ('Fare', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([  9.5   , 134.5   ,  26.55  ,  30.0708,  13.    ], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'', b'E34', b'', b'', b''], dtype=object)>), ('Embarked', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'S', b'C', b'S', b'C', b'S'], dtype=object)>)]), <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 1, 0, 1, 1], dtype=int32)>)
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([440, 644, 175, 490, 264], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([2, 3, 1, 3, 1], dtype=int32)>), ('Name', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'Kvillner, Mr. Johan Henrik Johannesson', b'Foo, Mr. Choong',
#        b'Smith, Mr. James Clinch',
#        b'Coutts, Master. Eden Leslie "Neville"', b'Harrison, Mr. William'],
#       dtype=object)>), ('Sex', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'male', b'male', b'male', b'male', b'male'], dtype=object)>), ('Age', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([31.,  0., 56.,  9., 40.], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 0, 1, 0], dtype=int32)>), ('Parch', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 0, 1, 0], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'C.A. 18723', b'1601', b'17764', b'C.A. 37671', b'112059'],
#       dtype=object)>), ('Fare', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([10.5   , 56.4958, 30.6958, 15.9   ,  0.    ], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'', b'', b'A7', b'', b'B94'], dtype=object)>), ('Embarked', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'S', b'S', b'C', b'S', b'S'], dtype=object)>)]), <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 1, 0, 1, 0], dtype=int32)>)
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([435, 130, 633, 208, 318], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([1, 3, 1, 3, 2], dtype=int32)>), ('Name', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'Silvey, Mr. William Baird', b'Ekstrom, Mr. Johan',
#        b'Stahelin-Maeglin, Dr. Max', b'Albimona, Mr. Nassef Cassem',
#        b'Moraweck, Dr. Ernest'], dtype=object)>), ('Sex', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'male', b'male', b'male', b'male', b'male'], dtype=object)>), ('Age', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([50., 45., 32., 26., 54.], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([1, 0, 0, 0, 0], dtype=int32)>), ('Parch', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 0, 0, 0], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'13507', b'347061', b'13214', b'2699', b'29011'], dtype=object)>), ('Fare', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([55.9   ,  6.975 , 30.5   , 18.7875, 14.    ], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'E44', b'', b'B50', b'', b''], dtype=object)>), ('Embarked', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'S', b'S', b'C', b'C', b'S'], dtype=object)>)]), <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 1, 1, 0], dtype=int32)>)
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([344, 343, 846, 591, 379], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([2, 2, 3, 3, 3], dtype=int32)>), ('Name', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'Sedgwick, Mr. Charles Frederick Waddington',
#        b'Collander, Mr. Erik Gustaf', b'Abbing, Mr. Anthony',
#        b'Rintamaki, Mr. Matti', b'Betros, Mr. Tannous'], dtype=object)>), ('Sex', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'male', b'male', b'male', b'male', b'male'], dtype=object)>), ('Age', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([25., 28., 42., 35., 20.], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 0, 0, 0], dtype=int32)>), ('Parch', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 0, 0, 0], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'244361', b'248740', b'C.A. 5547', b'STON/O 2. 3101273', b'2648'],
#       dtype=object)>), ('Fare', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([13.    , 13.    ,  7.55  ,  7.125 ,  4.0125], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'', b'', b'', b'', b''], dtype=object)>), ('Embarked', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'S', b'S', b'S', b'S', b'C'], dtype=object)>)]), <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 0, 0, 0], dtype=int32)>)
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([662, 601, 758, 298, 870], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([3, 2, 2, 1, 3], dtype=int32)>), ('Name', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'Badt, Mr. Mohamed',
#        b'Jacobsohn, Mrs. Sidney Samuel (Amy Frances Christy)',
#        b'Bailey, Mr. Percy Andrew', b'Allison, Miss. Helen Loraine',
#        b'Johnson, Master. Harold Theodor'], dtype=object)>), ('Sex', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'male', b'female', b'male', b'female', b'male'], dtype=object)>), ('Age', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([40., 24., 18.,  2.,  4.], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 2, 0, 1, 1], dtype=int32)>), ('Parch', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 1, 0, 2, 1], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'2623', b'243847', b'29108', b'113781', b'347742'], dtype=object)>), ('Fare', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([  7.225 ,  27.    ,  11.5   , 151.55  ,  11.1333], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'', b'', b'', b'C22 C26', b''], dtype=object)>), ('Embarked', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'C', b'S', b'S', b'S', b'S'], dtype=object)>)]), <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 1, 0, 0, 1], dtype=int32)>)
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([399, 382, 722, 407, 309], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([2, 3, 3, 3, 2], dtype=int32)>), ('Name', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'Pain, Dr. Alfred', b'Nakid, Miss. Maria ("Mary")',
#        b'Jensen, Mr. Svend Lauritz', b'Widegren, Mr. Carl/Charles Peter',
#        b'Abelson, Mr. Samuel'], dtype=object)>), ('Sex', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'male', b'female', b'male', b'male', b'male'], dtype=object)>), ('Age', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([23.,  1., 17., 51., 30.], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 1, 0, 1], dtype=int32)>), ('Parch', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 2, 0, 0, 0], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'244278', b'2653', b'350048', b'347064', b'P/PP 3381'],
#       dtype=object)>), ('Fare', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([10.5   , 15.7417,  7.0542,  7.75  , 24.    ], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'', b'', b'', b'', b''], dtype=object)>), ('Embarked', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'S', b'C', b'S', b'S', b'C'], dtype=object)>)]), <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 1, 0, 0, 0], dtype=int32)>)
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([384, 205, 163, 828, 663], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([1, 3, 3, 2, 1], dtype=int32)>), ('Name', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'Holverson, Mrs. Alexander Oskar (Mary Aline Towner)',
#        b'Cohen, Mr. Gurshon "Gus"', b'Bengtsson, Mr. John Viktor',
#        b'Mallet, Master. Andre', b'Colley, Mr. Edward Pomeroy'],
#       dtype=object)>), ('Sex', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'female', b'male', b'male', b'male', b'male'], dtype=object)>), ('Age', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([35., 18., 26.,  1., 47.], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([1, 0, 0, 0, 0], dtype=int32)>), ('Parch', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 0, 2, 0], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'113789', b'A/5 3540', b'347068', b'S.C./PARIS 2079', b'5727'],
#       dtype=object)>), ('Fare', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([52.    ,  8.05  ,  7.775 , 37.0042, 25.5875], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'', b'', b'', b'', b'E58'], dtype=object)>), ('Embarked', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'S', b'S', b'S', b'C', b'S'], dtype=object)>)]), <tf.Tensor: shape=(5,), dtype=int32, numpy=array([1, 1, 0, 1, 0], dtype=int32)>)
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([704, 177, 140,   7,  32], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([3, 3, 1, 1, 1], dtype=int32)>), ('Name', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'Gallagher, Mr. Martin', b'Lefebre, Master. Henry Forbes',
#        b'Giglio, Mr. Victor', b'McCarthy, Mr. Timothy J',
#        b'Spencer, Mrs. William Augustus (Marie Eugenie)'], dtype=object)>), ('Sex', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'male', b'male', b'male', b'male', b'female'], dtype=object)>), ('Age', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([25.,  0., 24., 54.,  0.], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 3, 0, 0, 1], dtype=int32)>), ('Parch', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 1, 0, 0, 0], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'36864', b'4133', b'PC 17593', b'17463', b'PC 17569'],
#       dtype=object)>), ('Fare', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([  7.7417,  25.4667,  79.2   ,  51.8625, 146.5208], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'', b'', b'B86', b'E46', b'B78'], dtype=object)>), ('Embarked', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'Q', b'S', b'C', b'S', b'C'], dtype=object)>)]), <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 0, 0, 1], dtype=int32)>)
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([522, 762, 725, 735, 285], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([3, 3, 1, 2, 1], dtype=int32)>), ('Name', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'Vovk, Mr. Janko', b'Nirva, Mr. Iisakki Antino Aijo',
#        b'Chambers, Mr. Norman Campbell', b'Troupiansky, Mr. Moses Aaron',
#        b'Smith, Mr. Richard William'], dtype=object)>), ('Sex', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'male', b'male', b'male', b'male', b'male'], dtype=object)>), ('Age', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([22., 41., 27., 23.,  0.], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 1, 0, 0], dtype=int32)>), ('Parch', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 0, 0, 0], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'349252', b'SOTON/O2 3101272', b'113806', b'233639', b'113056'],
#       dtype=object)>), ('Fare', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([ 7.8958,  7.125 , 53.1   , 13.    , 26.    ], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'', b'', b'E8', b'', b'A19'], dtype=object)>), ('Embarked', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'S', b'S', b'S', b'S', b'S'], dtype=object)>)]), <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 1, 0, 0], dtype=int32)>)
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([715, 583, 214, 711, 843], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([2, 2, 2, 1, 1], dtype=int32)>), ('Name', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'Greenberg, Mr. Samuel', b'Downton, Mr. William James',
#        b'Givard, Mr. Hans Kristensen',
#        b'Mayne, Mlle. Berthe Antonine ("Mrs de Villiers")',
#        b'Serepeca, Miss. Augusta'], dtype=object)>), ('Sex', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'male', b'male', b'male', b'female', b'female'], dtype=object)>), ('Age', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([52., 54., 30., 24., 30.], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 0, 0, 0], dtype=int32)>), ('Parch', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 0, 0, 0], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'250647', b'28403', b'250646', b'PC 17482', b'113798'],
#       dtype=object)>), ('Fare', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([13.    , 26.    , 13.    , 49.5042, 31.    ], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'', b'', b'', b'C90', b''], dtype=object)>), ('Embarked', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'S', b'S', b'S', b'C', b'C'], dtype=object)>)]), <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 0, 1, 1], dtype=int32)>)
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([636, 377, 323, 416,  16], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([2, 3, 2, 3, 2], dtype=int32)>), ('Name', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'Davis, Miss. Mary', b'Landergren, Miss. Aurora Adelia',
#        b'Slayter, Miss. Hilda Mary',
#        b'Meek, Mrs. Thomas (Annie Louise Rowley)',
#        b'Hewlett, Mrs. (Mary D Kingcome) '], dtype=object)>), ('Sex', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'female', b'female', b'female', b'female', b'female'],
#       dtype=object)>), ('Age', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([28., 22., 30.,  0., 55.], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 0, 0, 0], dtype=int32)>), ('Parch', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 0, 0, 0], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'237668', b'C 7077', b'234818', b'343095', b'248706'],
# ...
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([293, 137, 345, 696, 431], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([2, 1, 2, 2, 1], dtype=int32)>), ('Name', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'Levy, Mr. Rene Jacques', b'Newsom, Miss. Helen Monypeny',
#        b'Fox, Mr. Stanley Hubert', b'Chapman, Mr. Charles Henry',
#        b'Bjornstrom-Steffansson, Mr. Mauritz Hakan'], dtype=object)>), ('Sex', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'male', b'female', b'male', b'male', b'male'], dtype=object)>), ('Age', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([36., 19., 36., 52., 28.], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 0, 0, 0], dtype=int32)>), ('Parch', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 2, 0, 0, 0], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'SC/Paris 2163', b'11752', b'229236', b'248731', b'110564'],
#       dtype=object)>), ('Fare', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([12.875 , 26.2833, 13.    , 13.5   , 26.55  ], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'D', b'D47', b'', b'', b'C52'], dtype=object)>), ('Embarked', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'C', b'S', b'S', b'S', b'S'], dtype=object)>)]), <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 1, 0, 0, 1], dtype=int32)>)
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([840, 120, 253, 567, 558], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([1, 3, 1, 3, 1], dtype=int32)>), ('Name', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'Marechal, Mr. Pierre', b'Andersson, Miss. Ellis Anna Maria',
#        b'Stead, Mr. William Thomas', b'Stoytcheff, Mr. Ilia',
#        b'Robbins, Mr. Victor'], dtype=object)>), ('Sex', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'male', b'female', b'male', b'male', b'male'], dtype=object)>), ('Age', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([ 0.,  2., 62., 19.,  0.], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 4, 0, 0, 0], dtype=int32)>), ('Parch', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 2, 0, 0, 0], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'11774', b'347082', b'113514', b'349205', b'PC 17757'],
#       dtype=object)>), ('Fare', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([ 29.7   ,  31.275 ,  26.55  ,   7.8958, 227.525 ], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'C47', b'', b'C87', b'', b''], dtype=object)>), ('Embarked', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'C', b'S', b'S', b'S', b'C'], dtype=object)>)]), <tf.Tensor: shape=(5,), dtype=int32, numpy=array([1, 0, 0, 0, 0], dtype=int32)>)
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([281, 317, 132, 168, 859], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([3, 2, 3, 3, 3], dtype=int32)>), ('Name', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'Duane, Mr. Frank', b'Kantor, Mrs. Sinai (Miriam Sternin)',
#        b'Coelho, Mr. Domingos Fernandeo',
#        b'Skoog, Mrs. William (Anna Bernhardina Karlsson)',
#        b'Baclini, Mrs. Solomon (Latifa Qurban)'], dtype=object)>), ('Sex', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'male', b'female', b'male', b'female', b'female'], dtype=object)>), ('Age', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([65., 24., 20., 45., 24.], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 1, 0, 1, 0], dtype=int32)>), ('Parch', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 0, 4, 3], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'336439', b'244367', b'SOTON/O.Q. 3101307', b'347088', b'2666'],
#       dtype=object)>), ('Fare', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([ 7.75  , 26.    ,  7.05  , 27.9   , 19.2583], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'', b'', b'', b'', b''], dtype=object)>), ('Embarked', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'Q', b'S', b'S', b'S', b'C'], dtype=object)>)]), <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 1, 0, 0, 1], dtype=int32)>)
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([  3, 393, 731, 156, 451], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([3, 3, 1, 1, 2], dtype=int32)>), ('Name', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'Heikkinen, Miss. Laina', b'Gustafsson, Mr. Johan Birger',
#        b'Allen, Miss. Elisabeth Walton', b'Williams, Mr. Charles Duane',
#        b'West, Mr. Edwy Arthur'], dtype=object)>), ('Sex', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'female', b'male', b'female', b'male', b'male'], dtype=object)>), ('Age', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([26., 28., 29., 51., 36.], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 2, 0, 0, 1], dtype=int32)>), ('Parch', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 0, 1, 2], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'STON/O2. 3101282', b'3101277', b'24160', b'PC 17597',
#        b'C.A. 34651'], dtype=object)>), ('Fare', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([  7.925 ,   7.925 , 211.3375,  61.3792,  27.75  ], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'', b'', b'B5', b'', b''], dtype=object)>), ('Embarked', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'S', b'S', b'S', b'C', b'S'], dtype=object)>)]), <tf.Tensor: shape=(5,), dtype=int32, numpy=array([1, 0, 1, 0, 0], dtype=int32)>)
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([ 98, 729, 774, 799, 198], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([1, 2, 3, 3, 3], dtype=int32)>), ('Name', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'Greenfield, Mr. William Bertram',
#        b'Bryhl, Mr. Kurt Arnold Gottfrid', b'Elias, Mr. Dibo',
#        b'Ibrahim Shawah, Mr. Yousseff',
#        b'Olsen, Mr. Karl Siegwart Andreas'], dtype=object)>), ('Sex', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'male', b'male', b'male', b'male', b'male'], dtype=object)>), ('Age', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([23., 25.,  0., 30., 42.], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 1, 0, 0, 0], dtype=int32)>), ('Parch', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([1, 0, 0, 0, 1], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'PC 17759', b'236853', b'2674', b'2685', b'4579'], dtype=object)>), ('Fare', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([63.3583, 26.    ,  7.225 ,  7.2292,  8.4042], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'D10 D12', b'', b'', b'', b''], dtype=object)>), ('Embarked', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'C', b'S', b'C', b'C', b'S'], dtype=object)>)]), <tf.Tensor: shape=(5,), dtype=int32, numpy=array([1, 0, 0, 0, 0], dtype=int32)>)
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([479, 500, 133,  52, 418], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([3, 3, 3, 3, 2], dtype=int32)>), ('Name', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'Karlsson, Mr. Nils August', b'Svensson, Mr. Olof',
#        b'Robins, Mrs. Alexander A (Grace Charity Laury)',
#        b'Nosworthy, Mr. Richard Cater', b'Silven, Miss. Lyyli Karoliina'],
#       dtype=object)>), ('Sex', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'male', b'male', b'female', b'male', b'female'], dtype=object)>), ('Age', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([22., 24., 47., 21., 18.], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 1, 0, 0], dtype=int32)>), ('Parch', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 0, 0, 2], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'350060', b'350035', b'A/5. 3337', b'A/4. 39886', b'250652'],
#       dtype=object)>), ('Fare', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([ 7.5208,  7.7958, 14.5   ,  7.8   , 13.    ], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'', b'', b'', b'', b''], dtype=object)>), ('Embarked', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'S', b'S', b'S', b'S', b'S'], dtype=object)>)]), <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 0, 0, 1], dtype=int32)>)
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([232, 582, 801, 359,   9], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([3, 1, 2, 3, 3], dtype=int32)>), ('Name', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'Larsson, Mr. Bengt Edvin',
#        b'Thayer, Mrs. John Borland (Marian Longstreth Morris)',
#        b'Ponesell, Mr. Martin', b'McGovern, Miss. Mary',
#        b'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)'], dtype=object)>), ('Sex', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'male', b'female', b'male', b'female', b'female'], dtype=object)>), ('Age', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([29., 39., 34.,  0., 27.], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 1, 0, 0, 0], dtype=int32)>), ('Parch', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 1, 0, 0, 2], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'347067', b'17421', b'250647', b'330931', b'347742'], dtype=object)>), ('Fare', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([  7.775 , 110.8833,  13.    ,   7.8792,  11.1333], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'', b'C68', b'', b'', b''], dtype=object)>), ('Embarked', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'S', b'C', b'S', b'Q', b'S'], dtype=object)>)]), <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 1, 0, 1, 1], dtype=int32)>)
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([252, 880,  73, 651, 764], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([3, 1, 2, 3, 1], dtype=int32)>), ('Name', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'Strom, Mrs. Wilhelm (Elna Matilda Persson)',
#        b'Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)',
#        b'Hood, Mr. Ambrose Jr', b'Mitkoff, Mr. Mito',
#        b'Carter, Mrs. William Ernest (Lucile Polk)'], dtype=object)>), ('Sex', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'female', b'female', b'male', b'male', b'female'], dtype=object)>), ('Age', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([29., 56., 21.,  0., 36.], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([1, 0, 0, 0, 1], dtype=int32)>), ('Parch', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([1, 1, 0, 0, 2], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'347054', b'11767', b'S.O.C. 14879', b'349221', b'113760'],
#       dtype=object)>), ('Fare', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([ 10.4625,  83.1583,  73.5   ,   7.8958, 120.    ], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'G6', b'C50', b'', b'', b'B96 B98'], dtype=object)>), ('Embarked', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'S', b'C', b'S', b'S', b'S'], dtype=object)>)]), <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 1, 0, 0, 1], dtype=int32)>)
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([808,  80, 249,   8, 475], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([3, 3, 1, 3, 3], dtype=int32)>), ('Name', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'Pettersson, Miss. Ellen Natalia', b'Dowdell, Miss. Elizabeth',
#        b'Beckwith, Mr. Richard Leonard',
#        b'Palsson, Master. Gosta Leonard', b'Strandberg, Miss. Ida Sofia'],
#       dtype=object)>), ('Sex', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'female', b'female', b'male', b'male', b'female'], dtype=object)>), ('Age', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([18., 30., 37.,  2., 22.], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 1, 3, 0], dtype=int32)>), ('Parch', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 1, 1, 0], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'347087', b'364516', b'11751', b'349909', b'7553'], dtype=object)>), ('Fare', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([ 7.775 , 12.475 , 52.5542, 21.075 ,  9.8375], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'', b'', b'D35', b'', b''], dtype=object)>), ('Embarked', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'S', b'S', b'S', b'S', b'S'], dtype=object)>)]), <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 1, 1, 0, 0], dtype=int32)>)
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([313, 855, 417, 537, 844], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([2, 2, 2, 1, 3], dtype=int32)>), ('Name', <tf.Tensor: shape=(5,), dtype=string, numpy=
# array([b'Lahtinen, Mrs. William (Anna Sylfven)',
#        b'Carter, Mrs. Ernest Courtenay (Lilian Hughes)',
#        b'Drew, Mrs. James Vivian (Lulu Thorne Christian)',
#        b'Butt, Major. Archibald Willingham',
#        b'Lemberopolous, Mr. Peter L'], dtype=object)>), ('Sex', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'female', b'female', b'female', b'male', b'male'], dtype=object)>), ('Age', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([26. , 44. , 34. , 45. , 34.5], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([1, 1, 1, 0, 0], dtype=int32)>), ('Parch', <tf.Tensor: shape=(5,), dtype=int32, numpy=array([1, 0, 1, 0, 0], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'250651', b'244252', b'28220', b'113050', b'2683'], dtype=object)>), ('Fare', <tf.Tensor: shape=(5,), dtype=float32, numpy=array([26.    , 26.    , 32.5   , 26.55  ,  6.4375], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'', b'', b'', b'B38', b''], dtype=object)>), ('Embarked', <tf.Tensor: shape=(5,), dtype=string, numpy=array([b'S', b'S', b'S', b'S', b'C'], dtype=object)>)]), <tf.Tensor: shape=(5,), dtype=int32, numpy=array([0, 0, 1, 0, 0], dtype=int32)>)
# (OrderedDict([('PassengerId', <tf.Tensor: shape=(1,), dtype=int32, numpy=array([833], dtype=int32)>), ('Pclass', <tf.Tensor: shape=(1,), dtype=int32, numpy=array([3], dtype=int32)>), ('Name', <tf.Tensor: shape=(1,), dtype=string, numpy=array([b'Saad, Mr. Amin'], dtype=object)>), ('Sex', <tf.Tensor: shape=(1,), dtype=string, numpy=array([b'male'], dtype=object)>), ('Age', <tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>), ('SibSp', <tf.Tensor: shape=(1,), dtype=int32, numpy=array([0], dtype=int32)>), ('Parch', <tf.Tensor: shape=(1,), dtype=int32, numpy=array([0], dtype=int32)>), ('Ticket', <tf.Tensor: shape=(1,), dtype=string, numpy=array([b'2671'], dtype=object)>), ('Fare', <tf.Tensor: shape=(1,), dtype=float32, numpy=array([7.2292], dtype=float32)>), ('Cabin', <tf.Tensor: shape=(1,), dtype=string, numpy=array([b''], dtype=object)>), ('Embarked', <tf.Tensor: shape=(1,), dtype=string, numpy=array([b'C'], dtype=object)>)]), <tf.Tensor: shape=(1,), dtype=int32, numpy=array([0], dtype=int32)>)

# %%
show_batch(dataset)
# Out:
# PassengerId         : [174 103 314 102 334]
# Pclass              : [3 1 3 3 3]
# Name                : [b'Sivola, Mr. Antti Wilhelm' b'White, Mr. Richard Frasar'
#  b'Hendekovic, Mr. Ignjac' b'Petroff, Mr. Pastcho ("Pentcho")'
#  b'Vander Planke, Mr. Leo Edmondus']
# Sex                 : [b'male' b'male' b'male' b'male' b'male']
# Age                 : [21. 21. 28.  0. 16.]
# SibSp               : [0 0 0 0 2]
# Parch               : [0 1 0 0 0]
# Ticket              : [b'STON/O 2. 3101280' b'35281' b'349243' b'349215' b'345764']
# Fare                : [ 7.925  77.2875  7.8958  7.8958 18.    ]
# Cabin               : [b'' b'D26' b'' b'' b'']
# Embarked            : [b'S' b'S' b'S' b'S' b'S']

# %% [markdown]
# # Data

# %%
fashion_mnist = keras.datasets.fashion_mnist
(X_train_full, y_train_full), (X_test, y_test) = fashion_mnist.load_data()

# %%
type(X_train_full)
# Out:
# numpy.ndarray

# %%
X_valid, X_train = X_train_full[:5000] / 255.0, X_train_full[5000:] / 255.0
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]
X_test = X_test / 255.0

# %%
print(X_train.dtype)
print(X_train.shape)
# Out:
# float64
# (55000, 28, 28)

# %%
class_names = [
    "T-shirt/top", "Trouser", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"
]

# %%
class_names[y_train[0]]
# Out:
# 'Coat'

# %% [markdown]
# ### Callbacks

# %%
early_stopping_cb = keras.callbacks.EarlyStopping(
  patience=10,
  restore_best_weights=True
)
tensorboard_cb = keras.callbacks.TensorBoard(run_logdir)

# %% [markdown]
# # Model (SELU)

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[28, 28]),
    keras.layers.Dense(300, activation="selu", kernel_initializer="lecun_normal"),
    keras.layers.Dense(200, activation="selu", kernel_initializer="lecun_normal"),
    keras.layers.Dense(100, activation="selu", kernel_initializer="lecun_normal"),
    keras.layers.Dense(len(class_names), activation="softmax")
])

# First layter 784 × 300 connection weights, plus 300 bias terms, which adds up to 235,500 parameters
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_6 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 300)               235500
# _________________________________________________________________
# dense_22 (Dense)             (None, 200)               60200
# _________________________________________________________________
# dense_23 (Dense)             (None, 100)               20100
# _________________________________________________________________
# dense_24 (Dense)             (None, 10)                1010
# =================================================================
# Total params: 316,810
# Trainable params: 316,810
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Attach computation logic to the model
model.compile(
    loss="sparse_categorical_crossentropy",  # Cross entropy loss for sparse categorical labels
    optimizer=keras.optimizers.SGD(
        lr=0.01, momentum=0.9, nesterov=True # Use stochastic gradient descent with Nesterov momentum
    ),  
    metrics=["accuracy"]                     # Evaluate the model performance with accuracy.
)

# %%
history = model.fit(
    X_train, 
    y_train, 
    epochs=30, 
    validation_data=(X_valid, y_valid),
    callbacks=[
        early_stopping_cb,
        tensorboard_cb
    ]
)
# Out:
# Train on 55000 samples, validate on 5000 samples
# Epoch 1/30
# 55000/55000 [==============================] - 28s 503us/sample - loss: 0.4878 - accuracy: 0.8221 - val_loss: 0.4781 - val_accuracy: 0.8272
# Epoch 2/30
# 55000/55000 [==============================] - 20s 370us/sample - loss: 0.3932 - accuracy: 0.8575 - val_loss: 0.3872 - val_accuracy: 0.8618
# Epoch 3/30
# 55000/55000 [==============================] - 21s 385us/sample - loss: 0.3583 - accuracy: 0.8681 - val_loss: 0.3305 - val_accuracy: 0.8784
# Epoch 4/30
# 55000/55000 [==============================] - 23s 423us/sample - loss: 0.3368 - accuracy: 0.8766 - val_loss: 0.3472 - val_accuracy: 0.8726
# Epoch 5/30
# 55000/55000 [==============================] - 37s 670us/sample - loss: 0.3254 - accuracy: 0.8792 - val_loss: 0.3586 - val_accuracy: 0.8732
# Epoch 6/30
# 55000/55000 [==============================] - 28s 501us/sample - loss: 0.3122 - accuracy: 0.8852 - val_loss: 0.3177 - val_accuracy: 0.8854
# Epoch 7/30
# 55000/55000 [==============================] - 30s 543us/sample - loss: 0.2972 - accuracy: 0.8890 - val_loss: 0.3215 - val_accuracy: 0.8850
# Epoch 8/30
# 55000/55000 [==============================] - 23s 417us/sample - loss: 0.2877 - accuracy: 0.8925 - val_loss: 0.3654 - val_accuracy: 0.8650
# Epoch 9/30
# 55000/55000 [==============================] - 35s 633us/sample - loss: 0.2815 - accuracy: 0.8955 - val_loss: 0.3484 - val_accuracy: 0.8800
# Epoch 10/30
# 55000/55000 [==============================] - 36s 652us/sample - loss: 0.2721 - accuracy: 0.8978 - val_loss: 0.3736 - val_accuracy: 0.8738
# Epoch 11/30
# 55000/55000 [==============================] - 40s 723us/sample - loss: 0.2643 - accuracy: 0.9008 - val_loss: 0.3757 - val_accuracy: 0.8702
# Epoch 12/30
# 55000/55000 [==============================] - 25s 453us/sample - loss: 0.2577 - accuracy: 0.9046 - val_loss: 0.3320 - val_accuracy: 0.8840
# Epoch 13/30
# 55000/55000 [==============================] - 18s 327us/sample - loss: 0.2526 - accuracy: 0.9059 - val_loss: 0.3087 - val_accuracy: 0.8924
# Epoch 14/30
# 55000/55000 [==============================] - 17s 303us/sample - loss: 0.2488 - accuracy: 0.9066 - val_loss: 0.3714 - val_accuracy: 0.8740
# Epoch 15/30
# 55000/55000 [==============================] - 18s 320us/sample - loss: 0.2421 - accuracy: 0.9089 - val_loss: 0.3726 - val_accuracy: 0.8698
# Epoch 16/30
# 55000/55000 [==============================] - 17s 304us/sample - loss: 0.2368 - accuracy: 0.9104 - val_loss: 0.3359 - val_accuracy: 0.8914
# Epoch 17/30
# 55000/55000 [==============================] - 19s 348us/sample - loss: 0.2336 - accuracy: 0.9114 - val_loss: 0.3596 - val_accuracy: 0.8920
# Epoch 18/30
# 55000/55000 [==============================] - 21s 383us/sample - loss: 0.2267 - accuracy: 0.9151 - val_loss: 0.3647 - val_accuracy: 0.8900
# Epoch 19/30
# 55000/55000 [==============================] - 18s 329us/sample - loss: 0.2243 - accuracy: 0.9148 - val_loss: 0.3562 - val_accuracy: 0.8898
# Epoch 20/30
# 55000/55000 [==============================] - 18s 326us/sample - loss: 0.2194 - accuracy: 0.9168 - val_loss: 0.4438 - val_accuracy: 0.8720
# Epoch 21/30
# 55000/55000 [==============================] - 18s 331us/sample - loss: 0.2112 - accuracy: 0.9211 - val_loss: 0.4443 - val_accuracy: 0.8814
# Epoch 22/30
# 55000/55000 [==============================] - 18s 320us/sample - loss: 0.2114 - accuracy: 0.9202 - val_loss: 0.3612 - val_accuracy: 0.8942
# Epoch 23/30
# 55000/55000 [==============================] - 17s 314us/sample - loss: 0.2042 - accuracy: 0.9225 - val_loss: 0.3785 - val_accuracy: 0.8824

# %%
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1) # set the vertical range to [0-1]
plt.show()

# %%
model.evaluate(X_test, y_test)
# Out:
# 10000/10000 [==============================] - 3s 252us/sample - loss: 0.3559 - accuracy: 0.8799
# [0.3558882947206497, 0.8799]

# %% [markdown]
# # Model(SELU + Momentum + Batch Normalization + Drop Out)

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[28, 28]),
    
    keras.layers.Dense(300, activation="selu", kernel_initializer="lecun_normal"),

    keras.layers.BatchNormalization(),
    keras.layers.Dense(200, activation="selu", kernel_initializer="lecun_normal"),
    keras.layers.AlphaDropout(rate=0.2),
    
    keras.layers.BatchNormalization(),
    keras.layers.Dense(100, activation="selu", kernel_initializer="lecun_normal"),
    keras.layers.AlphaDropout(rate=0.2),
    
    keras.layers.BatchNormalization(),
    keras.layers.Dense(len(class_names), activation="softmax")
])

# First layter 784 × 300 connection weights, plus 300 bias terms, which adds up to 235,500 parameters
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_7 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_25 (Dense)             (None, 300)               235500
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 300)               1200
# _________________________________________________________________
# dense_26 (Dense)             (None, 200)               60200
# _________________________________________________________________
# alpha_dropout_4 (AlphaDropou (None, 200)               0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 200)               800
# _________________________________________________________________
# dense_27 (Dense)             (None, 100)               20100
# _________________________________________________________________
# alpha_dropout_5 (AlphaDropou (None, 100)               0
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 100)               400
# _________________________________________________________________
# dense_28 (Dense)             (None, 10)                1010
# =================================================================
# Total params: 319,210
# Trainable params: 318,010
# Non-trainable params: 1,200
# _________________________________________________________________

# %%
# Attach computation logic to the model
model.compile(
    loss="sparse_categorical_crossentropy",  # Cross entropy loss for sparse categorical labels
    optimizer=keras.optimizers.SGD(
        lr=0.01, momentum=0.9, nesterov=True # Use stochastic gradient descent with Nesterov momentum
    ),  
    metrics=["accuracy"]                     # Evaluate the model performance with accuracy.
)

# %%
history = model.fit(
    X_train, 
    y_train, 
    epochs=30, 
    validation_data=(X_valid, y_valid),
    callbacks=[
        early_stopping_cb,
        tensorboard_cb
    ]
)
# Out:
# Train on 55000 samples, validate on 5000 samples
# Epoch 1/30
# 55000/55000 [==============================] - 28s 514us/sample - loss: 0.5754 - accuracy: 0.7978 - val_loss: 0.5624 - val_accuracy: 0.8454
# Epoch 2/30
# 55000/55000 [==============================] - 24s 433us/sample - loss: 0.4547 - accuracy: 0.8345 - val_loss: 0.5047 - val_accuracy: 0.8478
# Epoch 3/30
# 55000/55000 [==============================] - 23s 427us/sample - loss: 0.4225 - accuracy: 0.8458 - val_loss: 0.4615 - val_accuracy: 0.8574
# Epoch 4/30
# 55000/55000 [==============================] - 31s 568us/sample - loss: 0.3955 - accuracy: 0.8553 - val_loss: 0.4427 - val_accuracy: 0.8624
# Epoch 5/30
# 55000/55000 [==============================] - 76s 1ms/sample - loss: 0.3751 - accuracy: 0.8629 - val_loss: 0.4070 - val_accuracy: 0.8770
# Epoch 6/30
# 55000/55000 [==============================] - 39s 707us/sample - loss: 0.3594 - accuracy: 0.8695 - val_loss: 0.4227 - val_accuracy: 0.8740
# Epoch 7/30
# 55000/55000 [==============================] - 39s 703us/sample - loss: 0.3442 - accuracy: 0.8735 - val_loss: 0.4221 - val_accuracy: 0.8788
# Epoch 8/30
# 55000/55000 [==============================] - 26s 472us/sample - loss: 0.3344 - accuracy: 0.8770 - val_loss: 0.4066 - val_accuracy: 0.8832
# Epoch 9/30
# 55000/55000 [==============================] - 26s 468us/sample - loss: 0.3236 - accuracy: 0.8807 - val_loss: 0.4432 - val_accuracy: 0.8868
# Epoch 10/30
# 55000/55000 [==============================] - 25s 448us/sample - loss: 0.3178 - accuracy: 0.8825 - val_loss: 0.3848 - val_accuracy: 0.8846
# Epoch 11/30
# 55000/55000 [==============================] - 27s 482us/sample - loss: 0.3081 - accuracy: 0.8854 - val_loss: 0.3985 - val_accuracy: 0.8830
# Epoch 12/30
# 55000/55000 [==============================] - 27s 493us/sample - loss: 0.2992 - accuracy: 0.8893 - val_loss: 0.3821 - val_accuracy: 0.8888
# Epoch 13/30
# 55000/55000 [==============================] - 23s 413us/sample - loss: 0.2921 - accuracy: 0.8905 - val_loss: 0.4080 - val_accuracy: 0.8788
# Epoch 14/30
# 55000/55000 [==============================] - 22s 401us/sample - loss: 0.2832 - accuracy: 0.8946 - val_loss: 0.3969 - val_accuracy: 0.8918
# Epoch 15/30
# 55000/55000 [==============================] - 23s 412us/sample - loss: 0.2775 - accuracy: 0.8955 - val_loss: 0.3777 - val_accuracy: 0.8876
# Epoch 16/30
# 55000/55000 [==============================] - 28s 515us/sample - loss: 0.2711 - accuracy: 0.8994 - val_loss: 0.3919 - val_accuracy: 0.8912
# Epoch 17/30
# 55000/55000 [==============================] - 22s 406us/sample - loss: 0.2672 - accuracy: 0.9006 - val_loss: 0.4305 - val_accuracy: 0.8798
# Epoch 18/30
# 55000/55000 [==============================] - 23s 412us/sample - loss: 0.2609 - accuracy: 0.9013 - val_loss: 0.3858 - val_accuracy: 0.8894
# Epoch 19/30
# 55000/55000 [==============================] - 38s 689us/sample - loss: 0.2558 - accuracy: 0.9047 - val_loss: 0.4026 - val_accuracy: 0.8884
# Epoch 20/30
# 55000/55000 [==============================] - 24s 439us/sample - loss: 0.2510 - accuracy: 0.9059 - val_loss: 0.3832 - val_accuracy: 0.8946
# Epoch 21/30
# 55000/55000 [==============================] - 22s 393us/sample - loss: 0.2448 - accuracy: 0.9073 - val_loss: 0.3708 - val_accuracy: 0.8982
# Epoch 22/30
# 55000/55000 [==============================] - 23s 426us/sample - loss: 0.2413 - accuracy: 0.9095 - val_loss: 0.4492 - val_accuracy: 0.8832
# Epoch 23/30
# 55000/55000 [==============================] - 23s 412us/sample - loss: 0.2349 - accuracy: 0.9123 - val_loss: 0.4505 - val_accuracy: 0.8872
# Epoch 24/30
# 55000/55000 [==============================] - 22s 402us/sample - loss: 0.2325 - accuracy: 0.9119 - val_loss: 0.4324 - val_accuracy: 0.8908
# Epoch 25/30
# 55000/55000 [==============================] - 25s 458us/sample - loss: 0.2294 - accuracy: 0.9136 - val_loss: 0.4268 - val_accuracy: 0.8950
# Epoch 26/30
# 55000/55000 [==============================] - 44s 799us/sample - loss: 0.2225 - accuracy: 0.9164 - val_loss: 0.4106 - val_accuracy: 0.8940
# Epoch 27/30
# 55000/55000 [==============================] - 25s 448us/sample - loss: 0.2184 - accuracy: 0.9183 - val_loss: 0.4247 - val_accuracy: 0.8976
# Epoch 28/30
# 55000/55000 [==============================] - 25s 456us/sample - loss: 0.2168 - accuracy: 0.9196 - val_loss: 0.4549 - val_accuracy: 0.8882
# Epoch 29/30
# 55000/55000 [==============================] - 23s 417us/sample - loss: 0.2125 - accuracy: 0.9202 - val_loss: 0.4772 - val_accuracy: 0.8890
# Epoch 30/30
# 55000/55000 [==============================] - 23s 427us/sample - loss: 0.2098 - accuracy: 0.9196 - val_loss: 0.4843 - val_accuracy: 0.8902

# %%
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1) # set the vertical range to [0-1]
plt.show()

# %%
model.evaluate(X_test, y_test)
# Out:
# 10000/10000 [==============================] - 2s 165us/sample - loss: 0.5843 - accuracy: 0.8796
# [0.584297722479701, 0.8796]

# %%
test_logdir = get_run_logdir()
writer = tf.summary.create_file_writer(test_logdir)
with writer.as_default():
    for step in range(1, 1000 + 1):
        tf.summary.scalar("my_scalar", np.sin(step / 10), step=step)
        data = (np.random.randn(100) + 2) * step / 100 # some random data
        tf.summary.histogram("my_hist", data, buckets=50, step=step)
        images = np.random.rand(2, 32, 32, 3) # random 32×32 RGB images
        tf.summary.image("my_images", images * step / 1000, step=step)
        texts = ["The step is " + str(step), "Its square is " + str(step**2)]
        tf.summary.text("my_text", texts, step=step)
        sine_wave = tf.math.sin(tf.range(12000) / 48000 * 2 * np.pi * step)
        audio = tf.reshape(tf.cast(sine_wave, tf.float32), [1, -1, 1])
        tf.summary.audio("my_audio", audio, sample_rate=48000, step=step)

# %%
# %load_ext tensorboard
# %tensorboard --logdir=./my_logs --port=6006
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 56876), started 0:20:31 ago. (Use '!kill 56876' to kill it.)
#       <iframe id="tensorboard-frame-37866a49789ab5e0" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-37866a49789ab5e0");
#           const url = new URL("/", window.location);
#           url.port = 6006;
#           frame.src = url;
#         })();
#       </script>
