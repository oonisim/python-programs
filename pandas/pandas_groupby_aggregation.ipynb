# %% [markdown]
# # Group by / Aggregation
#
# * [pandas.DataFrame.groupby](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.groupby.html)
#
# ```
# DataFrame.groupby(
#     by=None,
#     axis=0,
#     level=None,
#     as_index=True,
#     sort=True,
#     group_keys=True,
#     squeeze=NoDefault.no_default,
#     observed=False,
#     dropna=True
# )
#
# Returns: DataFrameGroupBy (a groupby object that contains information about the groups).
# ```

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.set_option('precision', 2)

# %%
df = pd.read_csv(
    "./data/titanic.csv"
)
df.head()
# Out:
#    survived  pclass                                               name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       sex   age  siblings_spouses  parents_children   fare
# 0    male  22.0                 1                 0   7.25
# 1  female  38.0                 1                 0  71.28
# 2  female  26.0                 0                 0   7.92
# 3  female  35.0                 1                 0  53.10
# 4    male  35.0                 0                 0   8.05

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887 entries, 0 to 886
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   survived          887 non-null    int64
#  1   pclass            887 non-null    int64
#  2   name              887 non-null    object
#  3   sex               887 non-null    object
#  4   age               887 non-null    float64
#  5   siblings_spouses  887 non-null    int64
#  6   parents_children  887 non-null    int64
#  7   fare              887 non-null    float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.6+ KB

# %%
df.describe()
# Out:
#        survived  pclass     age  siblings_spouses  parents_children    fare
# count    887.00  887.00  887.00            887.00            887.00  887.00
# mean       0.39    2.31   29.47              0.53              0.38   32.31
# std        0.49    0.84   14.12              1.10              0.81   49.78
# min        0.00    1.00    0.42              0.00              0.00    0.00
# 25%        0.00    2.00   20.25              0.00              0.00    7.92
# 50%        0.00    3.00   28.00              0.00              0.00   14.45
# 75%        1.00    3.00   38.00              1.00              0.00   31.14
# max        1.00    3.00   80.00              8.00              6.00  512.33

# %%
df.shape
# Out:
# (887, 8)

# %%
pd.Series(df.shape, index=['nrow', 'ncol'])
# Out:
# nrow    887
# ncol      8
# dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# # Group By passenger class
#
# ## Single Aggregation

# %%
df.groupby(['pclass']).median()
# Out:
#         survived   age  siblings_spouses  parents_children   fare
# pclass
# 1            1.0  38.5               0.0               0.0  60.29
# 2            0.0  29.0               0.0               0.0  14.25
# 3            0.0  24.0               0.0               0.0   8.05

# %%
fix, ax = plt.subplots(figsize=(10, 6))
ax.plot(x=df.index, y=)
# Out:
# RangeIndex(start=0, stop=887, step=1)

# %%
df.groupby(['pclass']).mean()
# Out:
#         survived    age  siblings_spouses  parents_children   fare
# pclass
# 1           0.63  38.79              0.42              0.36  84.15
# 2           0.47  29.87              0.40              0.38  20.66
# 3           0.24  25.19              0.62              0.40  13.71

# %%
df.groupby(['pclass']).std()
# Out:
#         survived    age  siblings_spouses  parents_children   fare
# pclass
# 1           0.48  14.18              0.61              0.69  78.38
# 2           0.50  13.76              0.60              0.69  13.42
# 3           0.43  12.10              1.38              0.89  11.82

# %% [markdown]
# ## Single aggregation on specific column

# %%
df.groupby(['pclass'])[
    ['age']
].mean()
# Out:
#           age
# pclass
# 1       38.79
# 2       29.87
# 3       25.19

# %% [markdown]
# ## Multiple Aggregations

# %%
df.groupby(['pclass']).agg(
    [np.mean, np.std, np.median]
)
# Out:
#        survived                 age               siblings_spouses        \
#            mean   std median   mean    std median             mean   std
# pclass
# 1          0.63  0.48    1.0  38.79  14.18   38.5             0.42  0.61
# 2          0.47  0.50    0.0  29.87  13.76   29.0             0.40  0.60
# 3          0.24  0.43    0.0  25.19  12.10   24.0             0.62  1.38
#
#               parents_children                fare
#        median             mean   std median   mean    std median
# pclass
# 1         0.0             0.36  0.69    0.0  84.15  78.38  60.29
# 2         0.0             0.38  0.69    0.0  20.66  13.42  14.25
# 3         0.0             0.40  0.89    0.0  13.71  11.82   8.05

# %%
df.groupby(['pclass'])[
    ['age']
].agg([np.mean, np.std, np.median])
# Out:
#           age
#          mean    std median
# pclass
# 1       38.79  14.18   38.5
# 2       29.87  13.76   29.0
# 3       25.19  12.10   24.0

# %%
df.groupby(['pclass']).agg(
    age_mean=('age', lambda x: np.mean(x)),
    fare_mean=('fare', lambda x: np.mean(x))
)
# Out:
#         age_mean  fare_mean
# pclass
# 1          38.79      84.15
# 2          29.87      20.66
# 3          25.19      13.71
