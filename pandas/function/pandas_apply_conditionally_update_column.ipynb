# %% [markdown]
# # Pandas update column conditionally
#
# * [How to Replace Values in Column Based on Condition in Pandas?](https://www.geeksforgeeks.org/how-to-replace-values-in-column-based-on-condition-in-pandas/)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Update the **supplier code** if it is NaN from the **supplier**.

# %%
df = pd.read_json("../data/recovery.json")
df
# Out:
#       facility        timeStart processTime      supplier  suppliedM3  \
# 0    Bundaberg   9/1/22 8:16 AM        4:05          Mary        5.09
# 1    Newcastle       8:29:00 AM         NaN           NaN        2.00
# 2    Newcastle       9:27:00 AM         NaN           NaN        6.80
# 3    Newcastle      11:38:00 AM         NaN           NaN        1.95
# 4    Bundaberg  9/1/22 12:34 PM        1:50  Mary Therese        3.78
# ..         ...              ...         ...           ...         ...
# 227  Newcastle      11:40:00 AM         NaN           NaN        3.70
# 228  Newcastle      12:52:00 PM         NaN           NaN        6.35
# 229  Bundaberg  9/30/22 1:48 PM        3:40  Mary Therese        4.53
# 230  Newcastle       3:02:00 PM         NaN           NaN        2.00
# 231  Newcastle       4:02:00 PM         NaN           NaN        6.30
#
#      recoveredM3       date      timeEnd supplierCode
# 0           4.13        NaT          NaN          NaN
# 1           1.55 2022-09-01   9:07:00 AM          har
# 2           4.15 2022-09-01  11:28:00 AM          dic
# 3           1.55 2022-09-01  12:21:00 PM          har
# 4           2.56        NaT          NaN          NaN
# ..           ...        ...          ...          ...
# 227         2.35 2022-09-30  12:41:00 PM          tom
# 228         4.55 2022-09-30   2:36:00 PM          dic
# 229         2.73        NaT          NaN          NaN
# 230         1.45 2022-09-30   3:42:00 PM          har
# 231         3.90 2022-09-30   6:27:00 PM          dic
#
# [232 rows x 9 columns]

# %%
df[df['supplierCode'].isnull()]
# Out:
#       facility         timeStart processTime      supplier  suppliedM3  \
# 0    Bundaberg    9/1/22 8:16 AM        4:05          Mary        5.09
# 4    Bundaberg   9/1/22 12:34 PM        1:50  Mary Therese        3.78
# 7    Bundaberg    9/1/22 2:48 PM        1:20  Mary Therese        3.55
# 9    Bundaberg    9/2/22 8:27 AM        1:25          Mary        5.02
# 10   Bundaberg   9/2/22 10:17 AM        4:00          Mary        4.95
# ..         ...               ...         ...           ...         ...
# 218  Bundaberg  9/29/22 10:53 AM        2:00     Mary Anne        2.80
# 221  Bundaberg   9/29/22 1:19 PM        3:05          Mary        5.00
# 223  Bundaberg   9/30/22 8:21 AM        2:25          Mary        4.94
# 226  Bundaberg  9/30/22 11:07 AM        2:10          Mary        5.03
# 229  Bundaberg   9/30/22 1:48 PM        3:40  Mary Therese        4.53
#
#      recoveredM3 date timeEnd supplierCode
# 0           4.13  NaT     NaN          NaN
# 4           2.56  NaT     NaN          NaN
# 7           2.59  NaT     NaN          NaN
# 9           4.13  NaT     NaN          NaN
# 10          3.58  NaT     NaN          NaN
# ..           ...  ...     ...          ...
# 218         2.31  NaT     NaN          NaN
# 221         3.31  NaT     NaN          NaN
# 223         3.77  NaT     NaN          NaN
# 226         3.47  NaT     NaN          NaN
# 229         2.73  NaT     NaN          NaN
#
# [111 rows x 9 columns]

# %% [markdown]
# ---
# # pandas.Dataframe.apply
#
# * [pandas.DataFrame.apply](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.apply.html)
# * [How to apply a function to two columns of Pandas dataframe](https://stackoverflow.com/a/13337376/4281353)

# %%
def get_code_from_supplier(supplier: str):
    supplier_to_code = {
        "mary therese": "mar",
        "mary": "mar"
    }
    return supplier_to_code.get(supplier.lower(), np.nan)
    
    
def f(row):
    # print(f"f(row): type {type(row)} value {row}")
    # print(f"supplier: {row['supplier']} code: {row['supplierCode']}")
    if row['supplier'] not in (np.nan, None):
        return get_code_from_supplier(row['supplier'])
    else:
        return row['supplierCode']

# %%
df['supplierCode'] = df.apply(func=f, axis=1)
df
# Out:
#       facility        timeStart processTime      supplier  suppliedM3  \
# 0    Bundaberg   9/1/22 8:16 AM        4:05          Mary        5.09
# 1    Newcastle       8:29:00 AM         NaN           NaN        2.00
# 2    Newcastle       9:27:00 AM         NaN           NaN        6.80
# 3    Newcastle      11:38:00 AM         NaN           NaN        1.95
# 4    Bundaberg  9/1/22 12:34 PM        1:50  Mary Therese        3.78
# ..         ...              ...         ...           ...         ...
# 227  Newcastle      11:40:00 AM         NaN           NaN        3.70
# 228  Newcastle      12:52:00 PM         NaN           NaN        6.35
# 229  Bundaberg  9/30/22 1:48 PM        3:40  Mary Therese        4.53
# 230  Newcastle       3:02:00 PM         NaN           NaN        2.00
# 231  Newcastle       4:02:00 PM         NaN           NaN        6.30
#
#      recoveredM3       date      timeEnd supplierCode
# 0           4.13        NaT          NaN          mar
# 1           1.55 2022-09-01   9:07:00 AM          har
# 2           4.15 2022-09-01  11:28:00 AM          dic
# 3           1.55 2022-09-01  12:21:00 PM          har
# 4           2.56        NaT          NaN          mar
# ..           ...        ...          ...          ...
# 227         2.35 2022-09-30  12:41:00 PM          tom
# 228         4.55 2022-09-30   2:36:00 PM          dic
# 229         2.73        NaT          NaN          mar
# 230         1.45 2022-09-30   3:42:00 PM          har
# 231         3.90 2022-09-30   6:27:00 PM          dic
#
# [232 rows x 9 columns]

# %% [markdown]
# ---
# # np.where()
#
# Same with SQL CASE WHEN logic.
#
# * [numpy.where(condition, [x, y, ])](https://numpy.org/doc/stable/reference/generated/numpy.where.html)
# * [Conditionally fill column values based on another columns value in pandas](https://stackoverflow.com/a/10726275/4281353)
#
# ## Note
#
# Cannot apply function in where as entire rows in series will be fed into it.

# %%
df = pd.read_json("../data/recovery.json")

# %%
df["supplierCode"] = np.where(
    df["supplier"] == "Mary",               # CASE WHEN supplier is Mary:
    "mar",                                  #   return supplierCode mar
    np.where(                               # ELSE 
        df['supplier'] == "Mary Therese	",  #    WHEN supplier is Mary Therese:
        "mar",                              #        return supplierCode mar
        df['supplierCode']                  #    ELSE: return supplierCode as is
   )
)

# %%
df
# Out:
#       facility        timeStart processTime      supplier  suppliedM3  \
# 0    Bundaberg   9/1/22 8:16 AM        4:05          Mary        5.09
# 1    Newcastle       8:29:00 AM         NaN           NaN        2.00
# 2    Newcastle       9:27:00 AM         NaN           NaN        6.80
# 3    Newcastle      11:38:00 AM         NaN           NaN        1.95
# 4    Bundaberg  9/1/22 12:34 PM        1:50  Mary Therese        3.78
# ..         ...              ...         ...           ...         ...
# 227  Newcastle      11:40:00 AM         NaN           NaN        3.70
# 228  Newcastle      12:52:00 PM         NaN           NaN        6.35
# 229  Bundaberg  9/30/22 1:48 PM        3:40  Mary Therese        4.53
# 230  Newcastle       3:02:00 PM         NaN           NaN        2.00
# 231  Newcastle       4:02:00 PM         NaN           NaN        6.30
#
#      recoveredM3       date      timeEnd supplierCode
# 0           4.13        NaT          NaN          mar
# 1           1.55 2022-09-01   9:07:00 AM          har
# 2           4.15 2022-09-01  11:28:00 AM          dic
# 3           1.55 2022-09-01  12:21:00 PM          har
# 4           2.56        NaT          NaN          NaN
# ..           ...        ...          ...          ...
# 227         2.35 2022-09-30  12:41:00 PM          tom
# 228         4.55 2022-09-30   2:36:00 PM          dic
# 229         2.73        NaT          NaN          NaN
# 230         1.45 2022-09-30   3:42:00 PM          har
# 231         3.90 2022-09-30   6:27:00 PM          dic
#
# [232 rows x 9 columns]
