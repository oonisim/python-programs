# %% [markdown]
# Numerical Gradient Checking

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
 
# %matplotlib inline

# %%
x = np.linspace(-3,5,100)
print(np.exp(x[-1]))

fig, ax = plt.subplots() 
ax.set_xticks(np.linspace(-2, 5, 15))
ax.set_xlim(-2, 5)
ax.set_ylim(0, 200)
ax.grid()

ax.plot(x, np.exp(x))

plt.show()
# Out:
# 148.4131591025766

# %%
import copy
from common import (
    softmax,
    cross_entropy_log_loss,
    OFFSET_FOR_DELTA,
    OFFSET_FOR_LOG
)
import pandas as pd

# %%
def gn(A, T):
    h = OFFSET_FOR_DELTA
    _A = copy.deepcopy(A)
    _A[
        ::,
        0
    ] += h
    J1 = cross_entropy_log_loss(softmax(_A), T)
    del _A
    _A = copy.deepcopy(A)
    _A[
        ::,
        0
    ] -= h
    J2 = cross_entropy_log_loss(softmax(_A), T)
    return (J1 - J2) / (2 * h)

# %%
# A1 is constant 1, increase A0 from 0 to 1 so that the p0 increase from 0 to 0.5 
N = 20+1
A0 = np.linspace(0, 1, N)
A1 = np.array([1] * N)
A = np.c_[A0, A1]
P = softmax(A)
T = np.array([0] * N)
L = cross_entropy_log_loss(P, T)
G = gn(A, T)
AG = P[
    ::,
    0
]
X = np.c_[A, P, L, G, AG]

headers = ['a0', 'a1', 'p0','p1','L', 'G', 'AG']
df = pd.DataFrame(X, columns=headers)
df
# Out:
#       a0   a1        p0        p1         L         G        AG
# 0   0.00  1.0  0.268941  0.731059  1.313258 -0.731056  0.268941
# 1   0.05  1.0  0.278885  0.721115  1.276952 -0.721112  0.278885
# 2   0.10  1.0  0.289050  0.710950  1.241150 -0.710947  0.289050
# 3   0.15  1.0  0.299433  0.700567  1.205861 -0.700565  0.299433
# 4   0.20  1.0  0.310026  0.689974  1.171097 -0.689972  0.310026
# 5   0.25  1.0  0.320821  0.679179  1.136868 -0.679176  0.320821
# 6   0.30  1.0  0.331812  0.668188  1.103183 -0.668186  0.331812
# 7   0.35  1.0  0.342990  0.657010  1.070052 -0.657008  0.342990
# 8   0.40  1.0  0.354344  0.645656  1.037485 -0.645654  0.354344
# 9   0.45  1.0  0.365864  0.634136  1.005489 -0.634134  0.365864
# 10  0.50  1.0  0.377541  0.622459  0.974074 -0.622458  0.377541
# 11  0.55  1.0  0.389361  0.610639  0.943246 -0.610638  0.389361
# 12  0.60  1.0  0.401312  0.598688  0.913013 -0.598686  0.401312
# 13  0.65  1.0  0.413382  0.586618  0.883379 -0.586616  0.413382
# 14  0.70  1.0  0.425557  0.574443  0.854353 -0.574441  0.425557
# 15  0.75  1.0  0.437823  0.562177  0.825937 -0.562175  0.437823
# 16  0.80  1.0  0.450166  0.549834  0.798136 -0.549833  0.450166
# 17  0.85  1.0  0.462570  0.537430  0.770955 -0.537429  0.462570
# 18  0.90  1.0  0.475021  0.524979  0.744394 -0.524978  0.475021
# 19  0.95  1.0  0.487503  0.512497  0.718457 -0.512496  0.487503
# 20  1.00  1.0  0.500000  0.500000  0.693145 -0.499999  0.500000

# %%
# A1 is constant 1, increase A0 from 0 to 1 so that the p0 increase from 0 to 0.5 
N = 20+1
A0 = np.linspace(0, 1, N)
A1 = np.array([1] * N)
A = np.c_[A0, A1]
P = softmax(A)
T = np.array([0] * N)
L = cross_entropy_log_loss(P, T)
G = gn(A, T)
AG = P[
    ::,
    0
]
X = np.c_[A, P, L, G, AG]

headers = ['a0', 'a1', 'p0','p1','L', 'G', 'AG']
df = pd.DataFrame(X, columns=headers)
df
# Out:
#       a0   a1        p0        p1         L         G        AG
# 0   0.00  1.0  0.268941  0.731059  1.313258 -0.731056  0.268941
# 1   0.05  1.0  0.278885  0.721115  1.276952 -0.721112  0.278885
# 2   0.10  1.0  0.289050  0.710950  1.241150 -0.710947  0.289050
# 3   0.15  1.0  0.299433  0.700567  1.205861 -0.700565  0.299433
# 4   0.20  1.0  0.310026  0.689974  1.171097 -0.689972  0.310026
# 5   0.25  1.0  0.320821  0.679179  1.136868 -0.679176  0.320821
# 6   0.30  1.0  0.331812  0.668188  1.103183 -0.668186  0.331812
# 7   0.35  1.0  0.342990  0.657010  1.070052 -0.657008  0.342990
# 8   0.40  1.0  0.354344  0.645656  1.037485 -0.645654  0.354344
# 9   0.45  1.0  0.365864  0.634136  1.005489 -0.634134  0.365864
# 10  0.50  1.0  0.377541  0.622459  0.974074 -0.622458  0.377541
# 11  0.55  1.0  0.389361  0.610639  0.943246 -0.610638  0.389361
# 12  0.60  1.0  0.401312  0.598688  0.913013 -0.598686  0.401312
# 13  0.65  1.0  0.413382  0.586618  0.883379 -0.586616  0.413382
# 14  0.70  1.0  0.425557  0.574443  0.854353 -0.574441  0.425557
# 15  0.75  1.0  0.437823  0.562177  0.825937 -0.562175  0.437823
# 16  0.80  1.0  0.450166  0.549834  0.798136 -0.549833  0.450166
# 17  0.85  1.0  0.462570  0.537430  0.770955 -0.537429  0.462570
# 18  0.90  1.0  0.475021  0.524979  0.744394 -0.524978  0.475021
# 19  0.95  1.0  0.487503  0.512497  0.718457 -0.512496  0.487503
# 20  1.00  1.0  0.500000  0.500000  0.693145 -0.499999  0.500000
