# %% [markdown]
# # Plot FFT magnitude and phrase
#
# ```np.angle(fft)``` gives the phase.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.fft import fft, fftfreq

# Generate a sample signal
fs = 1000  # Sampling frequency
T = 1.0 / fs  # Sampling interval
N = 1000  # Number of samples
t = np.linspace(0.0, N*T, N, endpoint=False)  # Time vector

# Create a signal
t = np.linspace(0.0, N*T, N)
t0 = np.pi/6   # non-zero phase of the second sine
signal = np.sin(10.0 * 2.0*np.pi*x + t0)

# Compute the FFT
signal_fft = fft(signal)
frequencies = fftfreq(N, T)

# Extract phase information
phases = np.angle(signal_fft)

# Plot the original signal
plt.figure(figsize=(12, 8))
plt.subplot(3, 1, 1)
plt.plot(t, signal)
plt.title('Original Signal')
plt.xlabel('Time [s]')
plt.ylabel('Amplitude')
plt.grid()

# Plot the magnitude spectrum
plt.subplot(3, 1, 2)
plt.plot(frequencies[:N//2], np.abs(signal_fft[:N//2]) * 2.0 / N)
plt.title('Magnitude Spectrum')
plt.xlabel('Frequency [Hz]')
plt.ylabel('Magnitude')
plt.grid()

# Plot the phase spectrum
plt.subplot(3, 1, 3)
plt.plot(frequencies[:N//2], phases[:N//2])
plt.title('Phase Spectrum')
plt.xlabel('Frequency [Hz]')
plt.ylabel('Phase [radians]')
plt.grid()
# plt.tight_layout()
plt.show()
