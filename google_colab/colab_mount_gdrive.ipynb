# %% [markdown]
# # Mount Google Drive to Colab
#
# * Colab only allows to mount the Google Drive under /content/gdrive.
# * Your Google Drive root is available at ```/content/gdrive/MyDrive``` only. Cannot change.
#
# ![image.png](attachment:image.png)

# %%
path_to_package_dir: str = "path/to/your/python/source/directory"

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
import sys
sys.path.append(f'/content/gdrive/My Drive/{path_to_package_dir}')
