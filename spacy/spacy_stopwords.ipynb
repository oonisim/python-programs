# %%
import spacy

# %%
nlp = spacy.load("zh_core_web_sm")

# %%
nlp.Defaults.stop_words
# Out:
# {'定',
#  '均',
#  '按照',
#  '如何',
#  '近',
#  '嘿',
#  '非独',
#  '各',
#  '匆匆',
#  '穷年累月',
#  '仍旧',
#  '凡是',
#  '照',
#  '造成',
#  '单',
#  '同',
#  '今天',
#  '尽早',
#  '将才',
#  '有著',
#  '会',
#  '此次',
#  '［③ｄ］',
#  '扩大',
#  '特别是',
#  '过于',
#  '别的',
#  '［①Ｄ］',
#  '迄',
#  '相应',
#  '乒',
#  '必将',
#  '具体地说',
#  '每个',
#  '凭借',
#  '便于',
#  '反倒',
#  '如此等等',
#  '如',
#  '双方',
#  '数/',
#  '本地',
#  '随著',
#  '这么些',
#  '才',
#  '"',
#  '以',
#  '与否',
#  '次第',
#  '［④ｅ］',
#  '密切',
#  '沙沙',
#  '咱',
#  '大多',
#  '帮助',
#  '极力',
#  '无',
#  '乘胜',
#  '挨家挨户',
#  '［②ｄ］',
#  '何尝',
#  '▲',
#  '［②⑤］',
#  '以期',
#  '①',
#  ';',
#  '打从',
#  '当下',
#  '9',
#  '些',
#  '比如',
#  '惟其',
#  '绝',
#  '三',
#  '不久',
#  '继而',
#  '《',
#  '这',
#  '［⑥］',
#  '此处',
#  '啊呀',
#  '［③①］',
#  '庶乎',
#  '各级',
#  '■',
#  '望',
#  '日益',
#  '虽则',
#  '正巧',
#  '表明',
#  '清楚',
#  '【',
#  '据悉',
#  '考虑',
#  '单纯',
#  '归',
#  '这点',
#  '毫无',
#  '看看',
#  '便',
#  '不但...而且',
#  '<',
#  '与其',
#  '何必',
#  '从而',
#  '后',
#  '那里',
#  '被',
#  '满',
#  '再有',
#  '全然',
#  '不得',
#  '要求',
#  '广泛',
#  '，也',
#  '仅仅',
#  '凡',
#  ',',
#  '开展',
#  '以外',
#  '砰',
#  '为什么',
#  '１．',
#  '七',
#  '几时',
#  '不曾',
#  '意思',
#  '相当',
#  '直到',
#  '乘机',
#  '恰恰',
#  '｛',
#  '［④ａ］',
#  '真正',
#  '去',
#  '应当',
#  '人',
#  '下面',
#  '啦',
#  '屡次三番',
#  '得出',
#  '顶多',
#  '局外',
#  '宁',
#  '莫若',
#  '倘然',
#  '不妨',
#  '除此之外',
#  '弹指之间',
#  '加上',
#  '俺们',
#  'Ψ',
#  '竟然',
#  '一面',
#  '较为',
#  '才能',
#  '》），',
#  '马上',
#  '难道说',
#  '移动',
#  '莫非',
#  '＝″',
#  '不比',
#  '不',
#  '部分',
#  '有的',
#  '简而言之',
#  '联系',
#  '活',
#  '以及',
#  '好在',
#  '顺',
#  '以後',
#  '呼哧',
#  '例如',
#  '相反',
#  '注意',
#  '若夫',
#  '一切',
#  '集中',
#  '乘虚',
#  '8',
#  '到底',
#  '哈哈',
#  '及其',
#  '不止一次',
#  '千',
#  '反倒是',
#  '沿着',
#  '赶快',
#  '所谓',
#  '极端',
#  '依靠',
#  '不拘',
#  '可能',
#  '也是',
#  '几经',
#  '隔日',
#  '不可',
#  '恰巧',
#  '每天',
#  '这麽',
#  '∈［',
#  '后来',
#  '介于',
#  '及至',
#  '大略',
#  '“',
#  '上来',
#  '贼死',
#  '［③Ｆ］',
#  '不论',
#  '认识',
#  '刚巧',
#  '诚然',
#  '＄',
#  '并',
#  '不仅仅',
#  '￥',
#  '≈',
#  '这个',
#  '如次',
#  '如是',
#  '———',
#  '巩固',
#  '拦腰',
#  '争取',
#  '连日',
#  '呗',
#  '极了',
#  '0',
#  '较之',
#  '小',
#  '有力',
#  '正值',
#  '藉以',
#  '什麽',
#  '并无',
#  'ｂ］',
#  '伟大',
#  '有利',
#  '接着',
#  '⑨',
#  '获得',
#  '可',
#  '人家',
#  'sup',
#  '光',
#  '⑤',
#  '第二',
#  '二话不说',
#  '直接',
#  '很多',
#  '呆呆地',
#  '８',
#  '诸如',
#  '当中',
#  '或则',
#  '［②ｂ］',
#  '已经',
#  '非特',
#  '［③ｅ］',
#  '举行',
#  '从事',
#  '从小',
#  '促进',
#  '咦',
#  '它',
#  '传闻',
#  '】',
#  '＋＋',
#  '以故',
#  '［①①］',
#  '将要',
#  '′∈',
#  '取道',
#  '仍',
#  '上下',
#  '心里',
#  '看出',
#  '到头来',
#  '积极',
#  '敢',
#  '只怕',
#  '前进',
#  '要',
#  '老是',
#  '连',
#  '认真',
#  '’‘',
#  '逢',
#  '继之',
#  '甚或',
#  '忽地',
#  '当地',
#  '一下',
#  '本人',
#  '［②ｃ］',
#  '不经意',
#  '巴',
#  '７',
#  '要不',
#  '人民',
#  '啊哈',
#  '具有',
#  '我们',
#  '使',
#  '都',
#  '何处',
#  '如下',
#  '%',
#  '③］',
#  '则甚',
#  '自从',
#  '如常',
#  '如其',
#  '从古至今',
#  '相同',
#  '乎',
#  '现代',
#  '总的来看',
#  '企图',
#  '甭',
#  '岂',
#  '不特',
#  '即若',
#  '各自',
#  '待到',
#  '然後',
#  '顺着',
#  '或是',
#  '况且',
#  '仅',
#  '年复一年',
#  '啥',
#  '何况',
#  '纵令',
#  '转动',
#  '不管怎样',
#  '奇',
#  '一.',
#  '不得了',
#  '随时',
#  '不会',
#  '当真',
#  '她是',
#  '那儿',
#  '上去',
#  '话说',
#  '：',
#  '总而言之',
#  '方才',
#  '时候',
#  '６',
#  '哪里',
#  '因为',
#  '吗',
#  '完成',
#  '哈',
#  '白白',
#  '省得',
#  '任何',
#  '还',
#  '即或',
#  '的确',
#  '傥然',
#  '大批',
#  '｜',
#  '串行',
#  '０',
#  '哼',
#  '毫无保留地',
#  '偶尔',
#  '不外',
#  '并没有',
#  '@',
#  '用来',
#  '根据',
#  '切莫',
#  '策略地',
#  '一样',
#  '……',
#  '不日',
#  '初',
#  '最后',
#  '及',
#  '反手',
#  '略',
#  '管',
#  '要不是',
#  '不成',
#  '别是',
#  '者',
#  '任务',
#  '立即',
#  '恰恰相反',
#  '交口',
#  '大多数',
#  '常言道',
#  '窃',
#  '㈧',
#  '［④］',
#  '挨个',
#  '即如',
#  '当',
#  '之类',
#  '此中',
#  '着呢',
#  '彼时',
#  '我是',
#  '各种',
#  '深入',
#  '社会主义',
#  '原来',
#  '等等',
#  '＆',
#  '不同',
#  '认为',
#  '论说',
#  '防止',
#  '［①⑦］',
#  '除非',
#  '非但',
#  '并不是',
#  '儿',
#  '否则',
#  '朝着',
#  '要不然',
#  '［①ｉ］',
#  '分期',
#  '互相',
#  '不大',
#  '从中',
#  '出去',
#  '4',
#  '多少',
#  '亲眼',
#  '总之',
#  '比照',
#  '若果',
#  '行为',
#  '在下',
#  '不能',
#  '..',
#  '从此',
#  '遭到',
#  '９',
#  '漫说',
#  '不外乎',
#  '就要',
#  'ａ］',
#  '其次',
#  '以为',
#  '怎样',
#  '据',
#  '问题',
#  '如今',
#  '〉',
#  '巨大',
#  '反应',
#  '叮当',
#  '孰知',
#  '总的来说',
#  '而又',
#  '全部',
#  '据此',
#  '概',
#  '半',
#  '呵',
#  '设若',
#  '不择手段',
#  '.日',
#  '}',
#  '且不说',
#  '为着',
#  '几番',
#  '除了',
#  '基本上',
#  '每时每刻',
#  '失去',
#  '大张旗鼓',
#  '换句话说',
#  '大约',
#  '隔夜',
#  '同一',
#  '大体上',
#  '起见',
#  '谁人',
#  '不然',
#  '皆可',
#  '──',
#  '向使',
#  '一次',
#  '几乎',
#  '让',
#  '可是',
#  '旁人',
#  '如前所述',
#  '借',
#  '这样',
#  '无宁',
#  '上述',
#  '复杂',
#  '别管',
#  '譬如',
#  '断然',
#  '个别',
#  '呀',
#  '固然',
#  '属于',
#  '八',
#  '自',
#  '［⑤ｂ］',
#  '不常',
#  '打开天窗说亮话',
#  'Δ',
#  '这么样',
#  '不时',
#  '［',
#  '`',
#  '孰料',
#  '［⑤］］',
#  '合理',
#  '够瞧的',
#  '公然',
#  '刚好',
#  '碰巧',
#  '曾经',
#  '不单',
#  '也好',
#  '不再',
#  '您',
#  '［①④］',
#  '更进一步',
#  '甚至',
#  '自各儿',
#  '明显',
#  '下',
#  '不满',
#  '就算',
#  '哼唷',
#  '多亏',
#  'φ．',
#  '怎',
#  '然则',
#  '正常',
#  '那个',
#  '相等',
#  '恰似',
#  '嗳',
#  '［③ａ］',
#  '处处',
#  '）',
#  '⑥',
#  '此',
#  '遇到',
#  '＜＜',
#  '不敢',
#  '各地',
#  '［②ａ］',
#  '跟',
#  '理当',
#  '适用',
#  '哇',
#  '喽',
#  '向',
#  '每每',
#  '种',
#  '挨门逐户',
#  '倒是',
#  '云云',
#  '附近',
#  '比方',
#  '居然',
#  '那时',
#  '要是',
#  '怎奈',
#  '那么',
#  '从',
#  '快',
#  '略加',
#  '不问',
#  '当口儿',
#  '共总',
#  '对待',
#  '极',
#  '多',
#  '［④ｄ］',
#  '遵循',
#  '啷当',
#  '先後',
#  '‘',
#  ')',
#  '并排',
#  '还是',
#  '）÷（１－',
#  '二来',
#  '理应',
#  '起先',
#  '再次',
#  '借以',
#  '决定',
#  '如上所述',
#  '总是',
#  '每',
#  '立地',
#  '趁早',
#  '更',
#  '假如',
#  '”，',
#  '尔',
#  '|',
#  '过',
#  '》',
#  '呃',
#  '然而',
#  '>>',
#  '不得已',
#  'Ａ',
#  '以至',
#  '℃',
#  '比及',
#  '－',
#  '传说',
#  '运用',
#  '方',
#  '倒不如说',
#  '近年来',
#  '周围',
#  '尽管如此',
#  '突出',
#  '［①］',
#  '·',
#  '.数',
#  '诸位',
#  '不料',
#  '臭',
#  '〕〔',
#  '昂然',
#  '纵然',
#  '这些',
#  '不仅仅是',
#  '从宽',
#  '～',
#  '［②ｅ］',
#  '两者',
#  '前此',
#  '7',
#  '存心',
#  '迅速',
#  '方能',
#  '人们',
#  '常',
#  '从今以后',
#  '不迭',
#  '倘',
#  '趁热',
#  '既是',
#  '⑧',
#  '乃至于',
#  '以便',
#  '规定',
#  '加之',
#  '不足',
#  '至若',
#  '犹自',
#  '齐',
#  '不要',
#  '多年来',
#  '即将',
#  '先后',
#  '行动',
#  '掌握',
#  '看见',
#  '设或',
#  '达旦',
#  '另',
#  '倘使',
#  '乘势',
#  '切不可',
#  '［②',
#  '必',
#  '其一',
#  '因而',
#  '切勿',
#  '难道',
#  '从优',
#  '进行',
#  '常言说得好',
#  '…………………………………………………③',
#  '目前',
#  '［①ｄ］',
#  '人人',
#  '只限',
#  '后面',
#  '归根到底',
#  '究竟',
#  '各个',
#  '继后',
#  '分头',
#  '那些',
#  '据实',
#  ':',
#  '向着',
#  '就是说',
#  '先生',
#  '凑巧',
#  '！',
#  '顷刻间',
#  '略为',
#  '→',
#  '另方面',
#  '［②ｆ］',
#  '它是',
#  '它们',
#  '彻底',
#  '论',
#  '......',
#  '可见',
#  '至今',
#  '莫',
#  '哗啦',
#  '与此同时',
#  '并没',
#  '保持',
#  '＜±',
#  '什么',
#  '饱',
#  '似的',
#  '哪',
#  '［②ｉ］',
#  '彼此',
#  '逐步',
#  '哉',
#  '且',
#  '哪儿',
#  '你们',
#  '普遍',
#  '恰好',
#  '［］',
#  '④',
#  '但凡',
#  '共',
#  '总结',
#  '再说',
#  '据我所知',
#  '暗自',
#  '而况',
#  '若是',
#  '如若',
#  '以上',
#  '］',
#  '＝｛',
#  '末##末',
#  '但是',
#  '绝对',
#  '猛然间',
#  '大举',
#  '前面',
#  '除去',
#  '啊哟',
#  '大抵',
#  '［②Ｇ］',
#  '庶几',
#  '凭',
#  '内',
#  '这会儿',
#  '＊',
#  '二',
#  '哎哟',
#  '有',
#  '精光',
#  '对应',
#  '敢于',
#  '没有',
#  '练习',
#  '当前',
#  '不得不',
#  '像',
#  '了解',
#  '屡屡',
#  '路经',
#  '——',
#  'ｆ］',
#  '一旦',
#  '一般',
#  '后者',
#  '切',
#  '立马',
#  '近几年来',
#  '［①ｆ］',
#  '我',
#  '任',
#  '依',
#  '尔等',
#  '为',
#  '互',
#  '［①⑤］',
#  '以来',
#  '敞开儿',
#  '扑通',
#  '+',
#  '多年前',
#  '即便',
#  '一番',
#  '距',
#  '０：２',
#  '俺',
#  '据称',
#  '说明',
#  '有点',
#  '一转眼',
#  '为此',
#  '千万千万',
#  '按说',
#  '不力',
#  '处在',
#  '表示',
#  'ＬＩ',
#  '哪年',
#  '格外',
#  '奋勇',
#  '自个儿',
#  '极大',
#  '没',
#  '＋',
#  '变成',
#  '在于',
#  '一一',
#  '取得',
#  '怎么办',
#  '不了',
#  '许多',
#  '为主',
#  '突然',
#  '届时',
#  '限制',
#  '您们',
#  '鉴于',
#  '＝☆',
#  '已矣',
#  '後来',
#  '从未',
#  '这般',
#  '怎么',
#  '进去',
#  '充分',
#  '没奈何',
#  '正如',
#  '充其量',
#  '偏偏',
#  '某',
#  '方面',
#  '那样',
#  '~',
#  '[',
#  '难怪',
#  '嘛',
#  '趁着',
#  '咚',
#  '绝顶',
#  '今後',
#  '何以',
#  '％',
#  '转贴',
#  '哗',
#  '准备',
#  '＝',
#  '亲口',
#  '顷刻',
#  '犹且',
#  '甚至于',
#  '唉',
#  '加以',
#  '［③ｂ］',
#  '说说',
#  '放量',
#  '毕竟',
#  '你是',
#  '一直',
#  '果然',
#  '主张',
#  '［①②］',
#  '挨着',
#  '喔唷',
#  '保险',
#  '于是',
#  '冲',
#  '明确',
#  '牢牢',
#  '嘻',
#  '迫于',
#  '岂但',
#  '设使',
#  '整个',
#  "'",
#  '来自',
#  '来不及',
#  '开始',
#  '不怎么',
#  '竟',
#  '看样子',
#  '＋ξ',
#  'ｃ］',
#  '各人',
#  '虽说',
#  '长线',
#  '一时',
#  '连声',
#  '那末',
#  '啪达',
#  '当着',
#  '之後',
#  '快要',
#  '最近',
#  '强调',
#  '除却',
#  '甫',
#  '_',
#  '反之亦然',
#  '当头',
#  '好的',
#  '［①ｏ］',
#  '不够',
#  '动不动',
#  '第',
#  '始而',
#  '归齐',
#  '(',
#  '果真',
#  '好',
#  '紧接着',
#  '加入',
#  '这就是说',
#  '之',
#  '勃然',
#  '有些',
#  '简直',
#  '用',
#  '出来',
#  '零',
#  '′｜',
#  '别人',
#  '来',
#  '召开',
#  '却不',
#  '也罢',
#  '不光',
#  '不一',
#  '岂非',
#  '［⑩］',
#  '不起',
#  '日复一日',
#  '允许',
#  ']',
#  '到了儿',
#  '叫',
#  '若',
#  '更加',
#  '赖以',
#  '临',
#  '故而',
#  '之所以',
#  '愿意',
#  'sub',
#  '陈年',
#  '过来',
#  '豁然',
#  '唯有',
#  '替代',
#  '成心',
#  '它们的',
#  '及时',
#  '显著',
#  '除此而外',
#  '#',
#  '啐',
#  '近来',
#  '呜呼',
#  '随着',
#  '日臻',
#  '来得及',
#  '再者',
#  '几',
#  '［②⑥］',
#  '屡',
#  '一何',
#  '诸',
#  '一起',
#  '姑且',
#  '全年',
#  '必定',
#  '顷刻之间',
#  '嘘',
#  '为何',
#  '尔后',
#  '同时',
#  '最後',
#  '［－',
#  '一来',
#  ...}

# %%
nlp = spacy.load("en_core_web_lg")

# %%
nlp.Defaults.stop_words
# Out:
# {"'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'could',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
#  'enough',
#  'even',
#  'ever',
#  'every',
#  'everyone',
#  'everything',
#  'everywhere',
#  'except',
#  'few',
#  'fifteen',
#  'fifty',
#  'first',
#  'five',
#  'for',
#  'former',
#  'formerly',
#  'forty',
#  'four',
#  'from',
#  'front',
#  'full',
#  'further',
#  'get',
#  'give',
#  'go',
#  'had',
#  'has',
#  'have',
#  'he',
#  'hence',
#  'her',
#  'here',
#  'hereafter',
#  'hereby',
#  'herein',
#  'hereupon',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'however',
#  'hundred',
#  'i',
#  'if',
#  'in',
#  'indeed',
#  'into',
#  'is',
#  'it',
#  'its',
#  'itself',
#  'just',
#  'keep',
#  'last',
#  'latter',
#  'latterly',
#  'least',
#  'less',
#  'made',
#  'make',
#  'many',
#  'may',
#  'me',
#  'meanwhile',
#  'might',
#  'mine',
#  'more',
#  'moreover',
#  'most',
#  'mostly',
#  'move',
#  'much',
#  'must',
#  'my',
#  'myself',
#  "n't",
#  'name',
#  'namely',
#  'neither',
#  'never',
#  'nevertheless',
#  'next',
#  'nine',
#  'no',
#  'nobody',
#  'none',
#  'noone',
#  'nor',
#  'not',
#  'nothing',
#  'now',
#  'nowhere',
#  'n‘t',
#  'n’t',
#  'of',
#  'off',
#  'often',
#  'on',
#  'once',
#  'one',
#  'only',
#  'onto',
#  'or',
#  'other',
#  'others',
#  'otherwise',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'part',
#  'per',
#  'perhaps',
#  'please',
#  'put',
#  'quite',
#  'rather',
#  're',
#  'really',
#  'regarding',
#  'same',
#  'say',
#  'see',
#  'seem',
#  'seemed',
#  'seeming',
#  'seems',
#  'serious',
#  'several',
#  'she',
#  'should',
#  'show',
#  'side',
#  'since',
#  'six',
#  'sixty',
#  'so',
#  'some',
#  'somehow',
#  'someone',
#  'something',
#  'sometime',
#  'sometimes',
#  'somewhere',
#  'still',
#  'such',
#  'take',
#  'ten',
#  'than',
#  'that',
#  'the',
#  'their',
#  'them',
#  'themselves',
#  'then',
#  'thence',
#  'there',
#  'thereafter',
#  'thereby',
#  'therefore',
#  'therein',
#  'thereupon',
#  'these',
#  'they',
#  'third',
#  'this',
#  'those',
#  'though',
#  'three',
#  'through',
#  'throughout',
#  'thru',
#  'thus',
#  'to',
#  'together',
#  'too',
#  'top',
#  'toward',
#  'towards',
#  'twelve',
#  'twenty',
#  'two',
#  'under',
#  'unless',
#  'until',
#  'up',
#  'upon',
#  'us',
#  'used',
#  'using',
#  'various',
#  'very',
#  'via',
#  'was',
#  'we',
#  'well',
#  'were',
#  'what',
#  'whatever',
#  'when',
#  'whence',
#  'whenever',
#  'where',
#  'whereafter',
#  'whereas',
#  'whereby',
#  'wherein',
#  'whereupon',
#  'wherever',
#  'whether',
#  'which',
#  'while',
#  'whither',
#  'who',
#  'whoever',
#  'whole',
#  'whom',
#  'whose',
#  'why',
#  'will',
#  'with',
#  'within',
#  'without',
#  'would',
#  'yet',
#  'you',
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  '‘d',
#  '‘ll',
#  '‘m',
#  '‘re',
#  '‘s',
#  '‘ve',
#  '’d',
#  '’ll',
#  '’m',
#  '’re',
#  '’s',
#  '’ve'}
