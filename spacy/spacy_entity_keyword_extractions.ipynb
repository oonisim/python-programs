# %% [markdown]
# # Setup
#
# ## Spacy
# * [spacy.cli.download()](https://github.com/explosion/spaCy/blob/master/spacy/cli/download.py)
#
# ```
# def download(
#     model: str,
#     direct: bool = False,
#     sdist: bool = False,
#     *pip_args,  # --target to specify the download directory
# )
# ```
#
# Internally, it is invokiing ```pip install``` in a command line.
#
# ```
# def download_model(
#     filename: str, user_pip_args: Optional[Sequence[str]] = None
# ) -> None:
#     download_url = about.__download_url__ + "/" + filename
#     pip_args = list(user_pip_args) if user_pip_args is not None else []
#     cmd = [sys.executable, "-m", "pip", "install"] + pip_args + [download_url]
#     run_command(cmd)
# ```
#
# ## NLTK
#
# * [nltk.download()](https://www.nltk.org/api/nltk.downloader.html#nltk.downloader.Downloader.download)
#
# ```
# def download(
#     info_or_id=None,
#     download_dir=None,
#     quiet=False,
#     force=False,
#     prefix="[nltk_data] ",
#     halt_on_error=True,
#     raise_on_error=False,
#     print_error_to=sys.stderr,
# )
# ```

# %%
# %%html
# <style>
# table {float:left}
# </style>
# Out:
# <style>
# table {float:left}
# </style>

# %%
# !pip install spacy textacy nltk --quiet
# Out:
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import sys
import re
import json
import pathlib
from itertools import chain

import spacy
from spacy import displacy
from spacy.cli import download
import textacy
import nltk

# %%
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/oonisim/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/oonisim/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# # PYTHONPATH

# %%
PATH_TO_LIB: str = str(pathlib.Path("../lib").resolve())
if PATH_TO_LIB not in sys.path:
    sys.path.insert(0, PATH_TO_LIB)

# %%
# %load_ext autoreload
# %autoreload 2

from util_spacy import (
    Pipeline
)

# %% [markdown]
# # Constant

# %%
LANGUAGE: str = "english"
SPACY_MODEL_NAME: str = "en_core_web_sm"

# %% [markdown]
# # Language Pipeline

# %%
pipeline: Pipeline = Pipeline(model_name=SPACY_MODEL_NAME)
nlp = pipeline.model

# %%
text = "Australian Melissa Georgiou (Melissa Georgiou) moved to Finland over a decade ago to seek happiness in one of the coldest and darkest places on Earth. “One of my favorite things about living here is that it's easy to get close to nature whether you're in a residential area or in the middle of the city,” Melissa said. Originally a teacher, 12 years ago, she switched from the beaches of Sydney to the dark winters and cold lakes of Finland, and has never looked back since. Melissa said, “For Finns, the concept of happiness is very different from the Australian concept of happiness. Finns, she said, are happy to accept portrayals of themselves as melancholy and stubborn — a popular local saying is, “People who have happiness must hide it.” “The first thing I noticed here is that you don't go to dinners or barbecues, and you don't talk about real estate. No one asks you where you live, what suburb do you live in, where your kids go to school.” The Finns seem quite happy with the status quo, and they don't always seem to want more. Melissa Georgio's Dark Night in Northern Europe Finland was named the happiest country in the world for the sixth year in a row in the “World Happiness Report” released by the United Nations. “The Nordic countries are often countries with (good) unemployment benefits, pensions, and other benefits,” explains happiness expert and researcher Frank Martela (Frank Martela). However, Frank said that Finland's position in the rankings often surprised its own people. “Finns, they're almost outraged because they don't think this can be true. We listen to sad music and hard rock.” “Therefore, happiness is not part of the Finnish self-image.” The other side of Finnish melancholy is a cultural focus on perseverance. Frank said it redefines the way Finns view happiness — a concept known as “sisu” — which is part of Finnish culture and is hard to translate directly, but can be understood as will, determination, perseverance, and reason to face adversity. This, he said, is best reflected in Finns' favorite pastime — getting warm in a sauna after taking a bath in freezing temperatures. “It's about this paradox — from one extreme to the other, and it's a pretty fun experience... because you need perseverance.” Melissa said, but Finland has many things that are great and can provide happiness for people in this country. Finland is one of the European countries least affected by the COVID-19 pandemic, and experts attribute this to a high level of trust in the government and little resistance to complying with restrictions. Trust in government, on the other hand, stems from a country's investment in its citizens. The public school system rarely tests children and is one of the best in the world. Finland also has a universal health care system with affordable childcare and strong support for parents. Melissa said, “The whole country is taking care of the child's development. This system is very well set up. So from having my son to raising him at home, to sending him to daycare, to going to school, I was very well supported in every aspect of this.” Finland vs. China, which country has the strongest sense of happiness? Since the publication of the World Happiness Report, the Nordic countries have dominated the top ten. In this year's report, Finland and its neighbors Denmark (2nd), Iceland (3rd), Sweden (6th), and Norway (7th) all scored high on happiness indicators, including healthy life expectancy, per capita GDP, low levels of corruption, social support, freedom, trust, and generosity. Other top ten countries/regions include the Netherlands (5th), Switzerland (8th), Luxembourg (9th), and New Zealand (10th). Australia ranked 12th in this report, followed by Canada (13th), Ireland (14th), and the United States (15th). In Asia, Singapore ranked 25th in the world, up two places from last year, Taiwan dropped one place from last year to 27th, Japan rose to 47th, mainland China ranked 64th, and Hong Kong ranked 82nd. Meanwhile, the polling agency Ipsos Group (Ipsos) released a survey report on the global happiness index. The results showed that out of 32 countries, the country with the highest happiness index was China (91%), followed by Saudi Arabia (86%), the Netherlands (85%), India (84%), and Brazil (83%). Australia ranked 9th in this report. According to the survey report, on average, happiness increased more significantly in middle-income countries (as defined by the World Bank) than in high-income countries."

# %% [markdown]
# # Process Document
#
# Put the text through the pretrained language pipeline.

# %%
doc = pipeline.process(text=text)

# %% [markdown]
# # Dependencies

# %%
print("{}{}{}{}{}".format(
    "Token".ljust(15), "start".ljust(7), "POS".ljust(10), "Tag".ljust(8), "Dependency".ljust(14), "Head"
))
print("-" * 80)
for token in doc:
    print(f"{token.text:15}{token.idx:<7}{token.pos_:10}{token.tag_:8}{token.dep_:14}{token.head.text}")
# Out:
# Token          start  POS       Tag     Dependency
# --------------------------------------------------------------------------------
# Australian     0      ADJ       JJ      amod          Georgiou
# Melissa        11     PROPN     NNP     compound      Georgiou
# Georgiou       19     PROPN     NNP     nsubj         moved
# (              28     PUNCT     -LRB-   punct         Georgiou
# Melissa        29     PROPN     NNP     compound      Georgiou
# Georgiou       37     PROPN     NNP     appos         Georgiou
# )              45     PUNCT     -RRB-   punct         Georgiou
# moved          47     VERB      VBD     ROOT          moved
# to             53     ADP       IN      prep          moved
# Finland        56     PROPN     NNP     pobj          to
# over           64     ADP       IN      quantmod      a
# a              69     DET       DT      det           decade
# decade         71     NOUN      NN      npadvmod      ago
# ago            78     ADV       RB      advmod        moved
# to             82     PART      TO      aux           seek
# seek           85     VERB      VB      advcl         moved
# happiness      90     NOUN      NN      dobj          seek
# in             100    ADP       IN      prep          seek
# one            103    NUM       CD      pobj          in
# of             107    ADP       IN      prep          one
# the            110    DET       DT      det           places
# coldest        114    ADJ       JJS     amod          places
# and            122    CCONJ     CC      cc            coldest
# darkest        126    ADJ       JJ      conj          coldest
# places         134    NOUN      NNS     pobj          of
# on             141    ADP       IN      prep          places
# Earth          144    PROPN     NNP     pobj          on
# .              149    PUNCT     .       punct         moved
# “              151    PUNCT     ``      punct         is
# One            152    NUM       CD      nsubj         is
# of             156    ADP       IN      prep          One
# my             159    PRON      PRP$    poss          things
# favorite       162    ADJ       JJ      amod          things
# things         171    NOUN      NNS     pobj          of
# about          178    ADP       IN      prep          things
# living         184    VERB      VBG     pcomp         about
# here           191    ADV       RB      advmod        living
# is             196    AUX       VBZ     ccomp         said
# that           199    SCONJ     IN      mark          's
# it             204    PRON      PRP     nsubj         's
# 's             206    AUX       VBZ     ccomp         is
# easy           209    ADJ       JJ      acomp         's
# to             214    PART      TO      aux           get
# get            217    VERB      VB      xcomp         's
# close          221    ADJ       JJ      acomp         get
# to             227    ADP       IN      prep          close
# nature         230    NOUN      NN      pobj          to
# whether        237    SCONJ     IN      mark          're
# you            245    PRON      PRP     nsubj         're
# 're            248    AUX       VBP     ccomp         get
# in             252    ADP       IN      prep          're
# a              255    DET       DT      det           area
# residential    257    ADJ       JJ      amod          area
# area           269    NOUN      NN      pobj          in
# or             274    CCONJ     CC      cc            in
# in             277    ADP       IN      conj          in
# the            280    DET       DT      det           middle
# middle         284    NOUN      NN      pobj          in
# of             291    ADP       IN      prep          middle
# the            294    DET       DT      det           city
# city           298    NOUN      NN      pobj          of
# ,              302    PUNCT     ,       punct         said
# ”              303    PUNCT     ''      punct         said
# Melissa        305    PROPN     NNP     nsubj         said
# said           313    VERB      VBD     ROOT          said
# .              317    PUNCT     .       punct         said
# Originally     319    ADV       RB      advmod        teacher
# a              330    DET       DT      det           teacher
# teacher        332    NOUN      NN      npadvmod      switched
# ,              339    PUNCT     ,       punct         teacher
# 12             341    NUM       CD      nummod        years
# years          344    NOUN      NNS     npadvmod      ago
# ago            350    ADV       RB      advmod        switched
# ,              353    PUNCT     ,       punct         switched
# she            355    PRON      PRP     nsubj         switched
# switched       359    VERB      VBD     ROOT          switched
# from           368    ADP       IN      prep          switched
# the            373    DET       DT      det           beaches
# beaches        377    NOUN      NNS     pobj          from
# of             385    ADP       IN      prep          beaches
# Sydney         388    PROPN     NNP     pobj          of
# to             395    ADP       IN      prep          switched
# the            398    DET       DT      det           winters
# dark           402    ADJ       JJ      amod          winters
# winters        407    NOUN      NNS     pobj          to
# and            415    CCONJ     CC      cc            winters
# cold           419    ADJ       JJ      amod          lakes
# lakes          424    NOUN      NNS     conj          winters
# of             430    ADP       IN      prep          lakes
# Finland        433    PROPN     NNP     pobj          of
# ,              440    PUNCT     ,       punct         switched
# and            442    CCONJ     CC      cc            switched
# has            446    AUX       VBZ     aux           looked
# never          450    ADV       RB      neg           looked
# looked         456    VERB      VBN     conj          switched
# back           463    ADV       RB      advmod        looked
# since          468    ADV       RB      advmod        looked
# .              473    PUNCT     .       punct         switched
# Melissa        475    PROPN     NNP     nsubj         said
# said           483    VERB      VBD     ROOT          said
# ,              487    PUNCT     ,       punct         said
# “              489    PUNCT     ``      punct         said
# For            490    ADP       IN      prep          is
# Finns          494    PROPN     NNP     pobj          For
# ,              499    PUNCT     ,       punct         is
# the            501    DET       DT      det           concept
# concept        505    NOUN      NN      nsubj         is
# of             513    ADP       IN      prep          concept
# happiness      516    NOUN      NN      pobj          of
# is             526    AUX       VBZ     ccomp         said
# very           529    ADV       RB      advmod        different
# different      534    ADJ       JJ      acomp         is
# from           544    ADP       IN      prep          different
# the            549    DET       DT      det           concept
# Australian     553    ADJ       JJ      amod          concept
# concept        564    NOUN      NN      pobj          from
# of             572    ADP       IN      prep          concept
# happiness      575    NOUN      NN      pobj          of
# .              584    PUNCT     .       punct         said
# Finns          586    ADV       RB      nsubj         are
# ,              591    PUNCT     ,       punct         said
# she            593    PRON      PRP     nsubj         said
# said           597    VERB      VBD     parataxis     are
# ,              601    PUNCT     ,       punct         said
# are            603    AUX       VBP     ROOT          are
# happy          607    ADJ       JJ      acomp         are
# to             613    PART      TO      aux           accept
# accept         616    VERB      VB      xcomp         happy
# portrayals     623    NOUN      NNS     dobj          accept
# of             634    ADP       IN      prep          portrayals
# themselves     637    PRON      PRP     pobj          of
# as             648    ADP       IN      prep          portrayals
# melancholy     651    ADJ       JJ      amod          as
# and            662    CCONJ     CC      cc            melancholy
# stubborn       666    ADJ       JJ      conj          melancholy
# —              675    PUNCT     :       punct         portrayals
# a              677    DET       DT      det           saying
# popular        679    ADJ       JJ      amod          saying
# local          687    ADJ       JJ      amod          saying
# saying         693    NOUN      NN      nsubj         is
# is             700    AUX       VBZ     conj          are
# ,              702    PUNCT     ,       punct         is
# “              704    PUNCT     ``      punct         is
# People         705    NOUN      NNS     nsubj         hide
# who            712    PRON      WP      nsubj         have
# have           716    VERB      VBP     relcl         People
# happiness      721    NOUN      NN      dobj          have
# must           731    AUX       MD      aux           hide
# hide           736    VERB      VB      ccomp         is
# it             741    PRON      PRP     dobj          hide
# .              743    PUNCT     .       punct         are
# ”              744    PUNCT     ''      punct         are
# “              746    PUNCT     ``      punct         is
# The            747    DET       DT      det           thing
# first          751    ADJ       JJ      amod          thing
# thing          757    NOUN      NN      nsubj         is
# I              763    PRON      PRP     nsubj         noticed
# noticed        765    VERB      VBD     relcl         thing
# here           773    ADV       RB      advmod        noticed
# is             778    AUX       VBZ     ROOT          is
# that           781    SCONJ     IN      mark          go
# you            786    PRON      PRP     nsubj         go
# do             790    AUX       VBP     aux           go
# n't            792    PART      RB      neg           go
# go             796    VERB      VB      ccomp         is
# to             799    ADP       IN      prep          go
# dinners        802    NOUN      NNS     pobj          to
# or             810    CCONJ     CC      cc            dinners
# barbecues      813    NOUN      NNS     conj          dinners
# ,              822    PUNCT     ,       punct         is
# and            824    CCONJ     CC      cc            is
# you            828    PRON      PRP     nsubj         talk
# do             832    AUX       VBP     aux           talk
# n't            834    PART      RB      neg           talk
# talk           838    VERB      VB      conj          is
# about          843    ADP       IN      prep          talk
# real           849    ADJ       JJ      amod          estate
# estate         854    NOUN      NN      pobj          about
# .              860    PUNCT     .       punct         talk
# No             862    DET       DT      det           one
# one            865    NOUN      NN      nsubj         asks
# asks           869    VERB      VBZ     ROOT          asks
# you            874    PRON      PRP     dobj          asks
# where          878    SCONJ     WRB     advmod        live
# you            884    PRON      PRP     nsubj         live
# live           888    VERB      VBP     ccomp         asks
# ,              892    PUNCT     ,       punct         live
# what           894    DET       WDT     det           suburb
# suburb         899    NOUN      NN      pobj          in
# do             906    AUX       VBP     aux           live
# you            909    PRON      PRP     nsubj         live
# live           913    VERB      VB      ccomp         asks
# in             918    ADP       IN      prep          live
# ,              920    PUNCT     ,       punct         live
# where          922    SCONJ     WRB     advmod        go
# your           928    PRON      PRP$    poss          kids
# kids           933    NOUN      NNS     nsubj         go
# go             938    VERB      VBP     advcl         live
# to             941    ADP       IN      prep          go
# school         944    NOUN      NN      pobj          to
# .              950    PUNCT     .       punct         asks
# ”              951    PUNCT     ''      punct         asks
# The            953    DET       DT      det           Finns
# Finns          957    PROPN     NNPS    nsubj         seem
# seem           963    VERB      VBP     ROOT          seem
# quite          968    ADV       RB      advmod        happy
# happy          974    ADJ       JJ      oprd          seem
# with           980    ADP       IN      prep          happy
# the            985    DET       DT      det           quo
# status         989    NOUN      NN      compound      quo
# quo            996    NOUN      NN      pobj          with
# ,              999    PUNCT     ,       punct         seem
# and            1001   CCONJ     CC      cc            seem
# they           1005   PRON      PRP     nsubj         seem
# do             1010   AUX       VBP     aux           seem
# n't            1012   PART      RB      neg           seem
# always         1016   ADV       RB      advmod        seem
# seem           1023   VERB      VB      conj          seem
# to             1028   PART      TO      aux           want
# want           1031   VERB      VB      xcomp         seem
# more           1036   ADJ       JJR     dobj          want
# .              1040   PUNCT     .       punct         seem
# Melissa        1042   PROPN     NNP     compound      Georgio
# Georgio        1050   PROPN     NNP     poss          Night
# 's             1057   PART      POS     case          Georgio
# Dark           1060   PROPN     NNP     compound      Night
# Night          1065   PROPN     NNP     nsubjpass     named
# in             1071   ADP       IN      prep          Night
# Northern       1074   PROPN     NNP     compound      Europe
# Europe         1083   PROPN     NNP     compound      Finland
# Finland        1090   PROPN     NNP     pobj          in
# was            1098   AUX       VBD     auxpass       named
# named          1102   VERB      VBN     ROOT          named
# the            1108   DET       DT      det           country
# happiest       1112   ADJ       JJS     amod          country
# country        1121   NOUN      NN      oprd          named
# in             1129   ADP       IN      prep          country
# the            1132   DET       DT      det           world
# world          1136   NOUN      NN      pobj          in
# for            1142   ADP       IN      prep          named
# the            1146   DET       DT      det           year
# sixth          1150   ADJ       JJ      amod          year
# year           1156   NOUN      NN      pobj          for
# in             1161   ADP       IN      prep          year
# a              1164   DET       DT      det           row
# row            1166   NOUN      NN      pobj          in
# in             1170   ADP       IN      prep          row
# the            1173   DET       DT      det           Report
# “              1177   PUNCT     ``      punct         Report
# World          1178   PROPN     NNP     compound      Happiness
# Happiness      1184   PROPN     NNP     compound      Report
# Report         1194   PROPN     NNP     pobj          in
# ”              1200   PUNCT     ''      punct         Report
# released       1202   VERB      VBN     acl           Report
# by             1211   ADP       IN      agent         released
# the            1214   DET       DT      det           Nations
# United         1218   PROPN     NNP     compound      Nations
# Nations        1225   PROPN     NNP     pobj          by
# .              1232   PUNCT     .       punct         named
# “              1234   PUNCT     ``      punct         are
# The            1235   DET       DT      det           countries
# Nordic         1239   ADJ       JJ      amod          countries
# countries      1246   NOUN      NNS     nsubj         are
# are            1256   AUX       VBP     ccomp         explains
# often          1260   ADV       RB      advmod        are
# countries      1266   NOUN      NNS     attr          are
# with           1276   ADP       IN      prep          countries
# (              1281   PUNCT     -LRB-   punct         with
# good           1282   ADJ       JJ      amod          benefits
# )              1286   PUNCT     -RRB-   punct         good
# unemployment   1288   NOUN      NN      compound      benefits
# benefits       1301   NOUN      NNS     pobj          with
# ,              1309   PUNCT     ,       punct         benefits
# pensions       1311   NOUN      NNS     conj          benefits
# ,              1319   PUNCT     ,       punct         pensions
# and            1321   CCONJ     CC      cc            pensions
# other          1325   ADJ       JJ      amod          benefits
# benefits       1331   NOUN      NNS     conj          pensions
# ,              1339   PUNCT     ,       punct         explains
# ”              1340   PUNCT     ''      punct         explains
# explains       1342   VERB      VBZ     ROOT          explains
# happiness      1351   NOUN      NN      compound      expert
# expert         1361   NOUN      NN      nsubj         explains
# and            1368   CCONJ     CC      cc            expert
# researcher     1372   NOUN      NN      compound      Martela
# Frank          1383   PROPN     NNP     compound      Martela
# Martela        1389   PROPN     NNP     conj          expert
# (              1397   PUNCT     -LRB-   punct         Martela
# Frank          1398   PROPN     NNP     compound      Martela
# Martela        1404   PROPN     NNP     appos         Martela
# )              1411   PUNCT     -RRB-   punct         Martela
# .              1412   PUNCT     .       punct         explains
# However        1414   ADV       RB      advmod        said
# ,              1421   PUNCT     ,       punct         said
# Frank          1423   PROPN     NNP     nsubj         said
# said           1429   VERB      VBD     ROOT          said
# that           1434   SCONJ     IN      mark          surprised
# Finland        1439   PROPN     NNP     poss          position
# 's             1446   PART      POS     case          Finland
# position       1449   NOUN      NN      nsubj         surprised
# in             1458   ADP       IN      prep          position
# the            1461   DET       DT      det           rankings
# rankings       1465   NOUN      NNS     pobj          in
# often          1474   ADV       RB      advmod        surprised
# surprised      1480   VERB      VBD     ccomp         said
# its            1490   PRON      PRP$    poss          people
# own            1494   ADJ       JJ      amod          people
# people         1498   NOUN      NNS     dobj          surprised
# .              1504   PUNCT     .       punct         said
# “              1506   PUNCT     ``      punct         're
# Finns          1507   PROPN     NNP     advmod        're
# ,              1512   PUNCT     ,       punct         're
# they           1514   PRON      PRP     nsubj         're
# 're            1518   AUX       VBP     ROOT          're
# almost         1522   ADV       RB      advmod        outraged
# outraged       1529   ADJ       JJ      acomp         're
# because        1538   SCONJ     IN      mark          think
# they           1546   PRON      PRP     nsubj         think
# do             1551   AUX       VBP     aux           think
# n't            1553   PART      RB      neg           think
# think          1557   VERB      VB      advcl         're
# this           1563   PRON      DT      nsubj         be
# can            1568   AUX       MD      aux           be
# be             1572   AUX       VB      ccomp         think
# true           1575   ADJ       JJ      acomp         be
# .              1579   PUNCT     .       punct         're
# We             1581   PRON      PRP     nsubj         listen
# listen         1584   VERB      VBP     ROOT          listen
# to             1591   ADP       IN      prep          listen
# sad            1594   ADJ       JJ      amod          music
# music          1598   NOUN      NN      pobj          to
# and            1604   CCONJ     CC      cc            music
# hard           1608   ADJ       JJ      amod          rock
# rock           1613   NOUN      NN      conj          music
# .              1617   PUNCT     .       punct         listen
# ”              1618   PUNCT     ''      punct         listen
# “              1620   PUNCT     ``      punct         is
# Therefore      1621   ADV       RB      advmod        is
# ,              1630   PUNCT     ,       punct         is
# happiness      1632   NOUN      NN      nsubj         is
# is             1642   AUX       VBZ     ROOT          is
# not            1645   PART      RB      neg           is
# part           1649   NOUN      NN      attr          is
# of             1654   ADP       IN      prep          part
# the            1657   DET       DT      det           image
# Finnish        1661   ADJ       JJ      amod          image
# self           1669   NOUN      NN      compound      image
# -              1673   PUNCT     HYPH    punct         image
# image          1674   NOUN      NN      pobj          of
# .              1679   PUNCT     .       punct         is
# ”              1680   PUNCT     ''      punct         is
# The            1682   DET       DT      det           side
# other          1686   ADJ       JJ      amod          side
# side           1692   NOUN      NN      nsubj         is
# of             1697   ADP       IN      prep          side
# Finnish        1700   ADJ       JJ      amod          melancholy
# melancholy     1708   NOUN      NN      pobj          of
# is             1719   AUX       VBZ     ROOT          is
# a              1722   DET       DT      det           focus
# cultural       1724   ADJ       JJ      amod          focus
# focus          1733   NOUN      NN      attr          is
# on             1739   ADP       IN      prep          focus
# perseverance   1742   NOUN      NN      pobj          on
# .              1754   PUNCT     .       punct         is
# Frank          1756   PROPN     NNP     nsubj         said
# said           1762   VERB      VBD     ROOT          said
# it             1767   PRON      PRP     nsubj         redefines
# redefines      1770   VERB      VBZ     ccomp         said
# the            1780   DET       DT      det           way
# way            1784   NOUN      NN      npadvmod      redefines
# Finns          1788   PROPN     NNP     nsubj         view
# view           1794   VERB      VBP     relcl         way
# happiness      1799   NOUN      NN      dobj          view
# —              1809   PUNCT     :       punct         way
# a              1811   DET       DT      det           concept
# concept        1813   NOUN      NN      appos         way
# known          1821   VERB      VBN     acl           concept
# as             1827   ADP       IN      prep          known
# “              1830   PUNCT     ``      punct         sisu
# sisu           1831   NOUN      NN      pobj          as
# ”              1835   PUNCT     ''      punct         sisu
# —              1837   PUNCT     :       punct         concept
# which          1839   PRON      WDT     nsubj         is
# is             1845   AUX       VBZ     relcl         concept
# part           1848   NOUN      NN      attr          is
# of             1853   ADP       IN      prep          part
# Finnish        1856   ADJ       JJ      amod          culture
# culture        1864   NOUN      NN      pobj          of
# and            1872   CCONJ     CC      cc            is
# is             1876   AUX       VBZ     conj          is
# hard           1879   ADJ       JJ      acomp         is
# to             1884   PART      TO      aux           translate
# translate      1887   VERB      VB      xcomp         hard
# directly       1897   ADV       RB      advmod        translate
# ,              1905   PUNCT     ,       punct         said
# but            1907   CCONJ     CC      cc            said
# can            1911   AUX       MD      aux           understood
# be             1915   AUX       VB      auxpass       understood
# understood     1918   VERB      VBN     conj          said
# as             1929   ADP       IN      prep          understood
# will           1932   NOUN      NN      pobj          as
# ,              1936   PUNCT     ,       punct         will
# determination  1938   NOUN      NN      conj          will
# ,              1951   PUNCT     ,       punct         determination
# perseverance   1953   NOUN      NN      conj          determination
# ,              1965   PUNCT     ,       punct         perseverance
# and            1967   CCONJ     CC      cc            perseverance
# reason         1971   NOUN      NN      conj          perseverance
# to             1978   PART      TO      aux           face
# face           1981   VERB      VB      relcl         reason
# adversity      1986   NOUN      NN      dobj          face
# .              1995   PUNCT     .       punct         said
# This           1997   PRON      DT      nsubjpass     reflected
# ,              2001   PUNCT     ,       punct         said
# he             2003   PRON      PRP     nsubj         said
# said           2006   VERB      VBD     parataxis     reflected
# ,              2010   PUNCT     ,       punct         said
# is             2012   AUX       VBZ     auxpass       reflected
# best           2015   ADV       RBS     advmod        reflected
# reflected      2020   VERB      VBN     ROOT          reflected
# in             2030   ADP       IN      prep          reflected
# Finns          2033   PROPN     NNP     poss          pastime
# '              2038   PART      POS     case          Finns
# favorite       2040   ADJ       JJ      amod          pastime
# pastime        2049   NOUN      NN      pobj          in
# —              2057   PUNCT     :       punct         pastime
# getting        2059   VERB      VBG     acl           pastime
# warm           2067   ADJ       JJ      acomp         getting
# in             2072   ADP       IN      prep          getting
# a              2075   DET       DT      det           sauna
# sauna          2077   NOUN      NN      pobj          in
# after          2083   ADP       IN      prep          getting
# taking         2089   VERB      VBG     pcomp         after
# a              2096   DET       DT      det           bath
# bath           2098   NOUN      NN      dobj          taking
# in             2103   ADP       IN      prep          bath
# freezing       2106   VERB      VBG     amod          temperatures
# temperatures   2115   NOUN      NNS     pobj          in
# .              2127   PUNCT     .       punct         reflected
# “              2129   PUNCT     ``      punct         's
# It             2130   PRON      PRP     nsubj         's
# 's             2132   AUX       VBZ     ROOT          's
# about          2135   ADP       IN      prep          's
# this           2141   DET       DT      det           paradox
# paradox        2146   NOUN      NN      pobj          about
# —              2154   PUNCT     :       punct         paradox
# from           2156   ADP       IN      prep          's
# one            2161   NUM       CD      nummod        extreme
# extreme        2165   NOUN      NN      pobj          from
# to             2173   ADP       IN      prep          extreme
# the            2176   DET       DT      det           other
# other          2180   ADJ       JJ      pobj          to
# ,              2185   PUNCT     ,       punct         's
# and            2187   CCONJ     CC      cc            's
# it             2191   PRON      PRP     nsubj         's
# 's             2193   AUX       VBZ     conj          's
# a              2196   DET       DT      det           experience
# pretty         2198   ADV       RB      advmod        fun
# fun            2205   NOUN      NN      amod          experience
# experience     2209   NOUN      NN      attr          's
# ...            2219   PUNCT     :       punct         's
# because        2223   SCONJ     IN      mark          need
# you            2231   PRON      PRP     nsubj         need
# need           2235   VERB      VBP     advcl         's
# perseverance   2240   NOUN      NN      dobj          need
# .              2252   PUNCT     .       punct         's
# ”              2253   PUNCT     ''      punct         's
# Melissa        2255   PROPN     NNP     nsubj         said
# said           2263   VERB      VBD     ROOT          said
# ,              2267   PUNCT     ,       punct         said
# but            2269   CCONJ     CC      cc            said
# Finland        2273   PROPN     NNP     nsubj         has
# has            2281   VERB      VBZ     conj          said
# many           2285   ADJ       JJ      amod          things
# things         2290   NOUN      NNS     dobj          has
# that           2297   PRON      WDT     nsubj         are
# are            2302   AUX       VBP     relcl         things
# great          2306   ADJ       JJ      acomp         are
# and            2312   CCONJ     CC      cc            has
# can            2316   AUX       MD      aux           provide
# provide        2320   VERB      VB      conj          has
# happiness      2328   NOUN      NN      dobj          provide
# for            2338   ADP       IN      prep          provide
# people         2342   NOUN      NNS     pobj          for
# in             2349   ADP       IN      prep          people
# this           2352   DET       DT      det           country
# country        2357   NOUN      NN      pobj          in
# .              2364   PUNCT     .       punct         said
# Finland        2366   PROPN     NNP     nsubj         is
# is             2374   AUX       VBZ     ROOT          is
# one            2377   NUM       CD      attr          is
# of             2381   ADP       IN      prep          one
# the            2384   DET       DT      det           countries
# European       2388   ADJ       JJ      amod          countries
# countries      2397   NOUN      NNS     pobj          of
# least          2407   ADV       RBS     advmod        affected
# affected       2413   VERB      VBN     acl           countries
# by             2422   ADP       IN      agent         affected
# the            2425   DET       DT      det           COVID-19
# COVID-19       2429   PROPN     NNP     pobj          by
# pandemic       2438   ADJ       JJ      amod          COVID-19
# ,              2446   PUNCT     ,       punct         is
# and            2448   CCONJ     CC      cc            is
# experts        2452   NOUN      NNS     nsubj         attribute
# attribute      2460   VERB      VBP     conj          is
# this           2470   PRON      DT      dobj          attribute
# to             2475   ADP       IN      prep          attribute
# a              2478   DET       DT      det           level
# high           2480   ADJ       JJ      amod          level
# level          2485   NOUN      NN      pobj          to
# of             2491   ADP       IN      prep          level
# trust          2494   NOUN      NN      pobj          of
# in             2500   ADP       IN      prep          trust
# the            2503   DET       DT      det           government
# government     2507   NOUN      NN      pobj          in
# and            2518   CCONJ     CC      cc            government
# little         2522   ADJ       JJ      amod          resistance
# resistance     2529   NOUN      NN      conj          government
# to             2540   ADP       IN      prep          resistance
# complying      2543   VERB      VBG     pcomp         to
# with           2553   ADP       IN      prep          complying
# restrictions   2558   NOUN      NNS     pobj          with
# .              2570   PUNCT     .       punct         attribute
# Trust          2572   NOUN      NN      nsubj         stems
# in             2578   ADP       IN      prep          Trust
# government     2581   NOUN      NN      pobj          in
# ,              2591   PUNCT     ,       punct         stems
# on             2593   ADP       IN      prep          stems
# the            2596   DET       DT      det           hand
# other          2600   ADJ       JJ      amod          hand
# hand           2606   NOUN      NN      pobj          on
# ,              2610   PUNCT     ,       punct         stems
# stems          2612   VERB      VBZ     ROOT          stems
# from           2618   ADP       IN      prep          stems
# a              2623   DET       DT      det           country
# country        2625   NOUN      NN      poss          investment
# 's             2632   PART      POS     case          country
# investment     2635   NOUN      NN      pobj          from
# in             2646   ADP       IN      prep          investment
# its            2649   PRON      PRP$    poss          citizens
# citizens       2653   NOUN      NNS     pobj          in
# .              2661   PUNCT     .       punct         stems
# The            2663   DET       DT      det           system
# public         2667   ADJ       JJ      amod          school
# school         2674   NOUN      NN      compound      system
# system         2681   NOUN      NN      nsubj         tests
# rarely         2688   ADV       RB      advmod        tests
# tests          2695   VERB      VBZ     ROOT          tests
# children       2701   NOUN      NNS     dobj          tests
# and            2710   CCONJ     CC      cc            tests
# is             2714   AUX       VBZ     conj          tests
# one            2717   NUM       CD      attr          is
# of             2721   ADP       IN      prep          one
# the            2724   DET       DT      det           best
# best           2728   ADJ       JJS     pobj          of
# in             2733   ADP       IN      prep          best
# the            2736   DET       DT      det           world
# world          2740   NOUN      NN      pobj          in
# .              2745   PUNCT     .       punct         tests
# Finland        2747   PROPN     NNP     nsubj         has
# also           2755   ADV       RB      advmod        has
# has            2760   VERB      VBZ     ROOT          has
# a              2764   DET       DT      det           system
# universal      2766   ADJ       JJ      amod          system
# health         2776   NOUN      NN      compound      care
# care           2783   NOUN      NN      compound      system
# system         2788   NOUN      NN      dobj          has
# with           2795   ADP       IN      prep          system
# affordable     2800   ADJ       JJ      amod          childcare
# childcare      2811   NOUN      NN      pobj          with
# and            2821   CCONJ     CC      cc            childcare
# strong         2825   ADJ       JJ      amod          support
# support        2832   NOUN      NN      conj          childcare
# for            2840   ADP       IN      prep          support
# parents        2844   NOUN      NNS     pobj          for
# .              2851   PUNCT     .       punct         has
# Melissa        2853   PROPN     NNP     nsubj         said
# said           2861   VERB      VBD     ROOT          said
# ,              2865   PUNCT     ,       punct         said
# “              2867   PUNCT     ``      punct         said
# The            2868   DET       DT      det           country
# whole          2872   ADJ       JJ      amod          country
# country        2878   NOUN      NN      nsubj         taking
# is             2886   AUX       VBZ     aux           taking
# taking         2889   VERB      VBG     ccomp         said
# care           2896   NOUN      NN      dobj          taking
# of             2901   ADP       IN      prep          taking
# the            2904   DET       DT      det           child
# child          2908   NOUN      NN      poss          development
# 's             2913   PART      POS     case          child
# development    2916   NOUN      NN      pobj          of
# .              2927   PUNCT     .       punct         said
# This           2929   DET       DT      det           system
# system         2934   NOUN      NN      nsubjpass     set
# is             2941   AUX       VBZ     auxpass       set
# very           2944   ADV       RB      advmod        well
# well           2949   ADV       RB      advmod        set
# set            2954   VERB      VBN     ROOT          set
# up             2958   ADP       RP      prt           set
# .              2960   PUNCT     .       punct         set
# So             2962   ADV       RB      advmod        supported
# from           2965   ADP       IN      prep          supported
# having         2970   VERB      VBG     pcomp         from
# my             2977   PRON      PRP$    poss          son
# son            2980   NOUN      NN      dobj          having
# to             2984   ADP       IN      prep          having
# raising        2987   VERB      VBG     pcomp         to
# him            2995   PRON      PRP     dobj          raising
# at             2999   ADP       IN      prep          raising
# home           3002   NOUN      NN      pobj          at
# ,              3006   PUNCT     ,       punct         raising
# to             3008   ADP       IN      prep          from
# sending        3011   VERB      VBG     pcomp         to
# him            3019   PRON      PRP     dobj          sending
# to             3023   ADP       IN      prep          sending
# daycare        3026   PROPN     NNP     pobj          to
# ,              3033   PUNCT     ,       punct         sending
# to             3035   ADP       IN      prep          sending
# going          3038   VERB      VBG     pcomp         to
# to             3044   ADP       IN      prep          going
# school         3047   NOUN      NN      pobj          to
# ,              3053   PUNCT     ,       punct         supported
# I              3055   PRON      PRP     nsubjpass     supported
# was            3057   AUX       VBD     auxpass       supported
# very           3061   ADV       RB      advmod        well
# well           3066   ADV       RB      advmod        supported
# supported      3071   VERB      VBN     ROOT          supported
# in             3081   ADP       IN      prep          supported
# every          3084   DET       DT      det           aspect
# aspect         3090   NOUN      NN      pobj          in
# of             3097   ADP       IN      prep          aspect
# this           3100   PRON      DT      pobj          of
# .              3104   PUNCT     .       punct         supported
# ”              3105   PUNCT     ''      punct         supported
# Finland        3107   PROPN     NNP     ROOT          Finland
# vs.            3115   ADP       IN      prep          Finland
# China          3119   PROPN     NNP     pobj          vs.
# ,              3124   PUNCT     ,       punct         China
# which          3126   DET       WDT     det           country
# country        3132   NOUN      NN      nsubj         has
# has            3140   VERB      VBZ     relcl         China
# the            3144   DET       DT      det           sense
# strongest      3148   ADJ       JJS     amod          sense
# sense          3158   NOUN      NN      dobj          has
# of             3164   ADP       IN      prep          sense
# happiness      3167   NOUN      NN      pobj          of
# ?              3176   PUNCT     .       punct         Finland
# Since          3178   SCONJ     IN      prep          dominated
# the            3184   DET       DT      det           publication
# publication    3188   NOUN      NN      pobj          Since
# of             3200   ADP       IN      prep          publication
# the            3203   DET       DT      det           Report
# World          3207   PROPN     NNP     compound      Happiness
# Happiness      3213   PROPN     NNP     compound      Report
# Report         3223   PROPN     NNP     pobj          of
# ,              3229   PUNCT     ,       punct         dominated
# the            3231   DET       DT      det           countries
# Nordic         3235   ADJ       JJ      amod          countries
# countries      3242   NOUN      NNS     nsubj         dominated
# have           3252   AUX       VBP     aux           dominated
# dominated      3257   VERB      VBN     ROOT          dominated
# the            3267   DET       DT      det           ten
# top            3271   ADJ       JJ      amod          ten
# ten            3275   NUM       CD      dobj          dominated
# .              3278   PUNCT     .       punct         dominated
# In             3280   ADP       IN      prep          scored
# this           3283   DET       DT      det           year
# year           3288   NOUN      NN      poss          report
# 's             3292   PART      POS     case          year
# report         3295   NOUN      NN      pobj          In
# ,              3301   PUNCT     ,       punct         report
# Finland        3303   PROPN     NNP     appos         report
# and            3311   CCONJ     CC      cc            Finland
# its            3315   PRON      PRP$    poss          neighbors
# neighbors      3319   NOUN      NNS     conj          Finland
# Denmark        3329   PROPN     NNP     appos         neighbors
# (              3337   PUNCT     -LRB-   punct         2nd
# 2nd            3338   ADJ       JJ      appos         Denmark
# )              3341   PUNCT     -RRB-   punct         2nd
# ,              3342   PUNCT     ,       punct         Denmark
# Iceland        3344   PROPN     NNP     appos         neighbors
# (              3352   PUNCT     -LRB-   punct         Iceland
# 3rd            3353   NOUN      NN      appos         Iceland
# )              3356   PUNCT     -RRB-   punct         Iceland
# ,              3357   PUNCT     ,       punct         Iceland
# Sweden         3359   PROPN     NNP     conj          Iceland
# (              3366   PUNCT     -LRB-   punct         6th
# 6th            3367   NOUN      NN      appos         Sweden
# )              3370   PUNCT     -RRB-   punct         Sweden
# ,              3371   PUNCT     ,       punct         Iceland
# and            3373   CCONJ     CC      cc            Iceland
# Norway         3377   PROPN     NNP     conj          Iceland
# (              3384   PUNCT     -LRB-   punct         7th
# 7th            3385   PROPN     NNP     appos         Norway
# )              3388   PUNCT     -RRB-   punct         7th
# all            3390   PRON      DT      appos         neighbors
# scored         3394   VERB      VBD     ROOT          scored
# high           3401   ADJ       JJ      advmod        scored
# on             3406   ADP       IN      prep          scored
# happiness      3409   NOUN      NN      compound      indicators
# indicators     3419   NOUN      NNS     pobj          on
# ,              3429   PUNCT     ,       punct         scored
# including      3431   VERB      VBG     prep          scored
# healthy        3441   ADJ       JJ      amod          expectancy
# life           3449   NOUN      NN      compound      expectancy
# expectancy     3454   NOUN      NN      pobj          including
# ,              3464   PUNCT     ,       punct         expectancy
# per            3466   ADP       IN      nmod          GDP
# capita         3470   X         FW      pobj          per
# GDP            3477   PROPN     NNP     appos         expectancy
# ,              3480   PUNCT     ,       punct         GDP
# low            3482   ADJ       JJ      amod          levels
# levels         3486   NOUN      NNS     conj          GDP
# of             3493   ADP       IN      prep          levels
# corruption     3496   NOUN      NN      pobj          of
# ,              3506   PUNCT     ,       punct         corruption
# social         3508   ADJ       JJ      amod          support
# support        3515   NOUN      NN      conj          corruption
# ,              3522   PUNCT     ,       punct         support
# freedom        3524   NOUN      NN      conj          support
# ,              3531   PUNCT     ,       punct         freedom
# trust          3533   NOUN      NN      conj          freedom
# ,              3538   PUNCT     ,       punct         trust
# and            3540   CCONJ     CC      cc            trust
# generosity     3544   NOUN      NN      conj          trust
# .              3554   PUNCT     .       punct         scored
# Other          3556   ADJ       JJ      amod          regions
# top            3562   ADJ       JJ      amod          regions
# ten            3566   NUM       CD      nummod        countries
# countries      3570   NOUN      NNS     nmod          regions
# /              3579   SYM       SYM     punct         regions
# regions        3580   NOUN      NNS     nsubj         include
# include        3588   VERB      VBP     ROOT          include
# the            3596   DET       DT      det           Netherlands
# Netherlands    3600   PROPN     NNP     dobj          include
# (              3612   PUNCT     -LRB-   punct         Netherlands
# 5th            3613   NOUN      NN      appos         Netherlands
# )              3616   PUNCT     -RRB-   punct         Netherlands
# ,              3617   PUNCT     ,       punct         Netherlands
# Switzerland    3619   PROPN     NNP     appos         Netherlands
# (              3631   PUNCT     -LRB-   punct         8th
# 8th            3632   NOUN      NN      appos         Switzerland
# )              3635   PUNCT     -RRB-   punct         8th
# ,              3636   PUNCT     ,       punct         Switzerland
# Luxembourg     3638   PROPN     NNP     conj          Switzerland
# (              3649   PUNCT     -LRB-   punct         9th
# 9th            3650   NOUN      NN      appos         Luxembourg
# )              3653   PUNCT     -RRB-   punct         9th
# ,              3654   PUNCT     ,       punct         Luxembourg
# and            3656   CCONJ     CC      cc            Luxembourg
# New            3660   PROPN     NNP     compound      Zealand
# Zealand        3664   PROPN     NNP     conj          Luxembourg
# (              3672   PUNCT     -LRB-   punct         10th
# 10th           3673   PROPN     NNP     appos         Zealand
# )              3677   PUNCT     -RRB-   punct         Zealand
# .              3678   PUNCT     .       punct         include
# Australia      3680   PROPN     NNP     nsubj         ranked
# ranked         3690   VERB      VBD     ROOT          ranked
# 12th           3697   NOUN      NN      dobj          ranked
# in             3702   ADP       IN      prep          ranked
# this           3705   DET       DT      det           report
# report         3710   NOUN      NN      pobj          in
# ,              3716   PUNCT     ,       punct         ranked
# followed       3718   VERB      VBN     advcl         ranked
# by             3727   ADP       IN      agent         followed
# Canada         3730   PROPN     NNP     pobj          by
# (              3737   PUNCT     -LRB-   punct         Canada
# 13th           3738   PROPN     NNP     appos         Canada
# )              3742   PUNCT     -RRB-   punct         Canada
# ,              3743   PUNCT     ,       punct         Canada
# Ireland        3745   PROPN     NNP     appos         Canada
# (              3753   PUNCT     -LRB-   punct         Ireland
# 14th           3754   NUM       CD      appos         Ireland
# )              3758   PUNCT     -RRB-   punct         Ireland
# ,              3759   PUNCT     ,       punct         Ireland
# and            3761   CCONJ     CC      cc            Ireland
# the            3765   DET       DT      det           States
# United         3769   PROPN     NNP     compound      States
# States         3776   PROPN     NNP     conj          Ireland
# (              3783   PUNCT     -LRB-   punct         States
# 15th           3784   NOUN      NN      appos         States
# )              3788   PUNCT     -RRB-   punct         States
# .              3789   PUNCT     .       punct         ranked
# In             3791   ADP       IN      prep          ranked
# Asia           3794   PROPN     NNP     pobj          In
# ,              3798   PUNCT     ,       punct         ranked
# Singapore      3800   PROPN     NNP     nsubj         ranked
# ranked         3810   VERB      VBD     advcl         dropped
# 25th           3817   NOUN      NN      advmod        ranked
# in             3822   ADP       IN      prep          ranked
# the            3825   DET       DT      det           world
# world          3829   NOUN      NN      pobj          in
# ,              3834   PUNCT     ,       punct         ranked
# up             3836   ADV       RB      advmod        ranked
# two            3839   NUM       CD      nummod        places
# places         3843   NOUN      NNS     npadvmod      up
# from           3850   ADP       IN      prep          up
# last           3855   ADJ       JJ      amod          year
# year           3860   NOUN      NN      pobj          from
# ,              3864   PUNCT     ,       punct         dropped
# Taiwan         3866   PROPN     NNP     nsubj         dropped
# dropped        3873   VERB      VBD     ccomp         rose
# one            3881   NUM       CD      nummod        place
# place          3885   NOUN      NN      dobj          dropped
# from           3891   ADP       IN      prep          dropped
# last           3896   ADJ       JJ      amod          year
# year           3901   NOUN      NN      pobj          from
# to             3906   ADP       IN      prep          dropped
# 27th           3909   NOUN      NN      pobj          to
# ,              3913   PUNCT     ,       punct         rose
# Japan          3915   PROPN     NNP     nsubj         rose
# rose           3921   VERB      VBD     ROOT          rose
# to             3926   ADP       IN      prep          rose
# 47th           3929   ADJ       JJ      pobj          to
# ,              3933   PUNCT     ,       punct         ranked
# mainland       3935   NOUN      NN      compound      China
# China          3944   PROPN     NNP     nsubj         ranked
# ranked         3950   VERB      VBD     conj          rose
# 64th           3957   NOUN      NN      npadvmod      ranked
# ,              3961   PUNCT     ,       punct         ranked
# and            3963   CCONJ     CC      cc            ranked
# Hong           3967   PROPN     NNP     compound      Kong
# Kong           3972   PROPN     NNP     nsubj         ranked
# ranked         3977   VERB      VBD     conj          ranked
# 82nd           3984   NOUN      NN      dobj          ranked
# .              3988   PUNCT     .       punct         ranked
# Meanwhile      3990   ADV       RB      advmod        released
# ,              3999   PUNCT     ,       punct         released
# the            4001   DET       DT      det           agency
# polling        4005   NOUN      NN      compound      agency
# agency         4013   NOUN      NN      nsubj         released
# Ipsos          4020   PROPN     NNP     compound      Group
# Group          4026   PROPN     NNP     appos         agency
# (              4032   PUNCT     -LRB-   punct         Group
# Ipsos          4033   PROPN     NNP     appos         Group
# )              4038   PUNCT     -RRB-   punct         Group
# released       4040   VERB      VBD     ROOT          released
# a              4049   DET       DT      det           report
# survey         4051   NOUN      NN      compound      report
# report         4058   NOUN      NN      dobj          released
# on             4065   ADP       IN      prep          report
# the            4068   DET       DT      det           index
# global         4072   ADJ       JJ      amod          happiness
# happiness      4079   NOUN      NN      compound      index
# index          4089   NOUN      NN      pobj          on
# .              4094   PUNCT     .       punct         released
# The            4096   DET       DT      det           results
# results        4100   NOUN      NNS     nsubj         showed
# showed         4108   VERB      VBD     ROOT          showed
# that           4115   SCONJ     IN      mark          was
# out            4120   ADP       IN      prep          was
# of             4124   ADP       IN      prep          out
# 32             4127   NUM       CD      nummod        countries
# countries      4130   NOUN      NNS     pobj          of
# ,              4139   PUNCT     ,       punct         was
# the            4141   DET       DT      det           country
# country        4145   NOUN      NN      nsubj         was
# with           4153   ADP       IN      prep          country
# the            4158   DET       DT      det           index
# highest        4162   ADJ       JJS     amod          happiness
# happiness      4170   NOUN      NN      compound      index
# index          4180   NOUN      NN      pobj          with
# was            4186   AUX       VBD     ccomp         showed
# China          4190   PROPN     NNP     attr          was
# (              4196   PUNCT     -LRB-   punct         China
# 91             4197   NUM       CD      nummod        %
# %              4199   NOUN      NN      appos         China
# )              4200   PUNCT     -RRB-   punct         China
# ,              4201   PUNCT     ,       punct         China
# followed       4203   VERB      VBN     acl           China
# by             4212   ADP       IN      agent         followed
# Saudi          4215   PROPN     NNP     compound      Arabia
# Arabia         4221   PROPN     NNP     pobj          by
# (              4228   PUNCT     -LRB-   punct         Arabia
# 86             4229   NUM       CD      nummod        %
# %              4231   NOUN      NN      appos         Arabia
# )              4232   PUNCT     -RRB-   punct         Arabia
# ,              4233   PUNCT     ,       punct         Arabia
# the            4235   DET       DT      det           Netherlands
# Netherlands    4239   PROPN     NNP     conj          Arabia
# (              4251   PUNCT     -LRB-   punct         Netherlands
# 85             4252   NUM       CD      nummod        %
# %              4254   NOUN      NN      appos         Netherlands
# )              4255   PUNCT     -RRB-   punct         Netherlands
# ,              4256   PUNCT     ,       punct         Netherlands
# India          4258   PROPN     NNP     appos         Netherlands
# (              4264   PUNCT     -LRB-   punct         India
# 84             4265   NUM       CD      nummod        %
# %              4267   NOUN      NN      appos         India
# )              4268   PUNCT     -RRB-   punct         India
# ,              4269   PUNCT     ,       punct         Netherlands
# and            4271   CCONJ     CC      cc            Netherlands
# Brazil         4275   PROPN     NNP     conj          Netherlands
# (              4282   PUNCT     -LRB-   punct         Brazil
# 83             4283   NUM       CD      nummod        %
# %              4285   NOUN      NN      appos         Brazil
# )              4286   PUNCT     -RRB-   punct         Netherlands
# .              4287   PUNCT     .       punct         showed
# Australia      4289   PROPN     NNP     nsubj         ranked
# ranked         4299   VERB      VBD     ROOT          ranked
# 9th            4306   NOUN      NN      dobj          ranked
# in             4310   ADP       IN      prep          ranked
# this           4313   DET       DT      det           report
# report         4318   NOUN      NN      pobj          in
# .              4324   PUNCT     .       punct         ranked
# According      4326   VERB      VBG     prep          increased
# to             4336   ADP       IN      prep          According
# the            4339   DET       DT      det           report
# survey         4343   NOUN      NN      compound      report
# report         4350   NOUN      NN      pobj          to
# ,              4356   PUNCT     ,       punct         increased
# on             4358   ADP       IN      prep          increased
# average        4361   ADJ       JJ      amod          on
# ,              4368   PUNCT     ,       punct         increased
# happiness      4370   NOUN      NN      nsubj         increased
# increased      4380   VERB      VBD     ROOT          increased
# more           4390   ADV       RBR     advmod        significantly
# significantly  4395   ADV       RB      advmod        increased
# in             4409   ADP       IN      prep          increased
# middle         4412   ADJ       JJ      amod          income
# -              4418   PUNCT     HYPH    punct         income
# income         4419   NOUN      NN      compound      countries
# countries      4426   NOUN      NNS     pobj          in
# (              4436   PUNCT     -LRB-   punct         countries
# as             4437   SCONJ     IN      mark          defined
# defined        4440   VERB      VBN     advcl         increased
# by             4448   ADP       IN      agent         defined
# the            4451   DET       DT      det           Bank
# World          4455   PROPN     NNP     compound      Bank
# Bank           4461   PROPN     NNP     pobj          by
# )              4465   PUNCT     -RRB-   punct         defined
# than           4467   ADP       IN      prep          increased
# in             4472   ADP       IN      prep          than
# high           4475   ADJ       JJ      amod          income
# -              4479   PUNCT     HYPH    punct         income
# income         4480   NOUN      NN      compound      countries
# countries      4487   NOUN      NNS     pobj          in
# .              4496   PUNCT     .       punct         increased

# %%
displacy.serve(doc, style="dep", auto_select_port=True, page=False)
# Out:
# /Users/oonisim/venv/tf/lib/python3.9/site-packages/spacy/util.py:1785: UserWarning: [W124] 0.0.0.0:5000 is already in use, using the nearest available port 5001 as an alternative.
#   warnings.warn(Warnings.W124.format(host=host, port=start, serve_port=port))
# /Users/oonisim/venv/tf/lib/python3.9/site-packages/spacy/displacy/__init__.py:108: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="60ffb1db9b7b497e943423abebefcb0d-0" class="displacy" width="132350" height="749.5" direction="ltr" style="max-width: none; height: 749.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Australian</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Melissa</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">Georgiou (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">Melissa</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">Georgiou)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">moved</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">Finland</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">over</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">decade</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">ago</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">seek</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">happiness</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">one</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">coldest</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">darkest</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">places</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">Earth. “</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">One</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">my</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">favorite</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">things</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">about</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="curr
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5001 ...
#
# Shutting down server on port 5001.

# %% [markdown]
# ----
# # Entities
#
# Named Entities have been identified by NER in the document object.
#
# * [Named Entities](https://spacy.io/usage/spacy-101#annotations-ner)
#
# ### Entity Labels
# ```
# PERSON:      People, including fictional.
# NORP:        Nationalities or religious or political groups.
# FAC:         Buildings, airports, highways, bridges, etc.
# ORG:         Companies, agencies, institutions, etc.
# GPE:         Countries, cities, states.
# LOC:         Non-GPE locations, mountain ranges, bodies of water.
# PRODUCT:     Objects, vehicles, foods, etc. (Not services.)
# EVENT:       Named hurricanes, battles, wars, sports events, etc.
# WORK_OF_ART: Titles of books, songs, etc.
# LAW:         Named documents made into laws.
# LANGUAGE:    Any named language.
# DATE:        Absolute or relative dates or periods.
# TIME:        Times smaller than a day.
# PERCENT:     Percentage, including ”%“.
# MONEY:       Monetary values, including unit.
# QUANTITY:    Measurements, as of weight or distance.
# ORDINAL:     “first”, “second”, etc.
# CARDINAL:    Numerals that do not fall under another type.
# ```

# %%
pipeline.named_entity_labels
# Out:
# ('CARDINAL',
#  'DATE',
#  'EVENT',
#  'FAC',
#  'GPE',
#  'LANGUAGE',
#  'LAW',
#  'LOC',
#  'MONEY',
#  'NORP',
#  'ORDINAL',
#  'ORG',
#  'PERCENT',
#  'PERSON',
#  'PRODUCT',
#  'QUANTITY',
#  'TIME',
#  'WORK_OF_ART')

# %%
displacy.serve(doc, style="ent", auto_select_port=True, page=False)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Australian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Melissa Georgiou
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  (
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Melissa Georgiou
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ) moved to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Finland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a decade ago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  to seek happiness in
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of the coldest and darkest places on
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Earth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# . “
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     One
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of my favorite things about living here is that it's easy to get close to nature whether you're in a residential area or in the middle of the city,”
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Melissa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said. Originally a teacher,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     12 years ago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , she switched from the beaches of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sydney
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  to the dark
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     winters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and cold lakes of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Finland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , and has never looked back since.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Melissa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said, “For
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Finns
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# , the concept of happiness is very different from the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Australian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  concept of happiness. Finns, she said, are happy to accept portrayals of themselves as melancholy and stubborn — a popular local saying is, “People who have happiness must hide it.” “The first thing I noticed here is that you don't go to dinners or barbecues, and you don't talk about real estate. No one asks you where you live, what suburb do you live in, where your kids go to school.” The
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Finns
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  seem quite happy with the status quo, and they don't always seem to want more.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Melissa Georgio's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dark Night
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  in
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Northern Europe Finland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  was named the happiest country in the world for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the sixth year in a row
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  in the “
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     World Happiness Report
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# ” released by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United Nations
#     <span style="font-
# Using the 'ent' visualizer
# Serving on http://0.0.0.0:5001 ...
#
# Shutting down server on port 5001.

# %%
print("{}{}{}{}".format(
    "Entity".ljust(50), "Start".ljust(7), "End".ljust(7), "Label".ljust(10)
))
print("-" * 80)
for ent in doc.ents:
    print(f"{ent.text:50}{ent.start_char:<7}{ent.end_char:<7}{ent.label_:10}")
# Out:
# Entity                                            Start  End    Label
# --------------------------------------------------------------------------------
# Australian                                        0      10     NORP
# Melissa Georgiou                                  11     27     PERSON
# Melissa Georgiou                                  29     45     PERSON
# Finland                                           56     63     GPE
# a decade ago                                      69     81     DATE
# one                                               103    106    CARDINAL
# Earth                                             144    149    LOC
# One                                               152    155    CARDINAL
# Melissa                                           305    312    PERSON
# 12 years ago                                      341    353    DATE
# Sydney                                            388    394    GPE
# winters                                           407    414    DATE
# Finland                                           433    440    GPE
# Melissa                                           475    482    PERSON
# Finns                                             494    499    NORP
# Australian                                        553    563    NORP
# Finns                                             957    962    NORP
# Melissa Georgio's                                 1042   1059   PERSON
# Dark Night                                        1060   1070   WORK_OF_ART
# Northern Europe Finland                           1074   1097   LOC
# the sixth year in a row                           1146   1169   DATE
# World Happiness Report                            1178   1200   WORK_OF_ART
# the United Nations                                1214   1232   ORG
# Nordic                                            1239   1245   GPE
# Frank Martela                                     1383   1396   PERSON
# Frank Martela                                     1398   1411   PERSON
# Frank                                             1423   1428   PERSON
# Finland                                           1439   1446   GPE
# Finnish                                           1661   1668   NORP
# Finnish                                           1700   1707   NORP
# Frank                                             1756   1761   PERSON
# Finns                                             1788   1793   NORP
# Finnish                                           1856   1863   NORP
# Finns                                             2033   2038   NORP
# one                                               2161   2164   CARDINAL
# Melissa                                           2255   2262   PERSON
# Finland                                           2273   2280   GPE
# Finland                                           2366   2373   GPE
# one                                               2377   2380   CARDINAL
# European                                          2388   2396   NORP
# COVID-19                                          2429   2437   ORG
# Finland                                           2747   2754   GPE
# Melissa                                           2853   2860   PERSON
# Finland                                           3107   3114   GPE
# China                                             3119   3124   GPE
# the World Happiness Report                        3203   3229   ORG
# Nordic                                            3235   3241   GPE
# ten                                               3275   3278   CARDINAL
# year                                              3288   3292   DATE
# Finland                                           3303   3310   GPE
# Denmark                                           3329   3336   GPE
# 2nd                                               3338   3341   ORDINAL
# Iceland                                           3344   3351   GPE
# 3rd                                               3353   3356   ORDINAL
# Sweden                                            3359   3365   GPE
# 6th                                               3367   3370   ORDINAL
# Norway                                            3377   3383   GPE
# 7th                                               3385   3388   ORDINAL
# ten                                               3566   3569   CARDINAL
# Netherlands                                       3600   3611   GPE
# 5th                                               3613   3616   ORDINAL
# Switzerland                                       3619   3630   GPE
# 8th                                               3632   3635   ORDINAL
# Luxembourg                                        3638   3648   GPE
# 9th                                               3650   3653   ORDINAL
# New Zealand                                       3660   3671   GPE
# 10th                                              3673   3677   ORDINAL
# Australia                                         3680   3689   GPE
# Canada                                            3730   3736   GPE
# Ireland                                           3745   3752   GPE
# 14th                                              3754   3758   ORDINAL
# the United States                                 3765   3782   GPE
# 15th                                              3784   3788   ORDINAL
# Asia                                              3794   3798   LOC
# Singapore                                         3800   3809   GPE
# 25th                                              3817   3821   ORDINAL
# two                                               3839   3842   CARDINAL
# last year                                         3855   3864   DATE
# Taiwan                                            3866   3872   GPE
# one                                               3881   3884   CARDINAL
# last year to 27th                                 3896   3913   DATE
# Japan                                             3915   3920   GPE
# 47th                                              3929   3933   ORDINAL
# China                                             3944   3949   GPE
# 64th                                              3957   3961   ORDINAL
# Hong Kong                                         3967   3976   GPE
# Ipsos Group                                       4020   4031   ORG
# Ipsos                                             4033   4038   NORP
# 32                                                4127   4129   CARDINAL
# China                                             4190   4195   GPE
# 91%                                               4197   4200   PERCENT
# Saudi Arabia                                      4215   4227   GPE
# 86%                                               4229   4232   PERCENT
# Netherlands                                       4239   4250   GPE
# 85%                                               4252   4255   PERCENT
# India                                             4258   4263   GPE
# 84%                                               4265   4268   PERCENT
# Brazil                                            4275   4281   GPE
# 83%                                               4283   4286   PERCENT
# Australia                                         4289   4298   GPE
# 9th                                               4306   4309   ORDINAL
# the World Bank                                    4451   4465   ORG

# %% [markdown]
# ## Entities per label

# %%
print(json.dumps(
    pipeline.get_named_entities_from_text(
        text=text, 
        excludes=["ORDINAL", "CARDINAL", "PERCENT", "DATE", "time", "QUANTITY", "MONEY"],
        remove_special_characters=True,
        return_value_only=True,
        remove_similarity_threshold=0.9,
        include_noun_phrases=False,
        include_keywords=False
    ), 
    indent=4, 
    default=str
))
# Out:
# {
#     "EVENT": [],
#     "FAC": [],
#     "GPE": [
#         "Sweden",
#         "United States",
#         "Sydney",
#         "Taiwan",
#         "Iceland",
#         "Luxembourg",
#         "Australia",
#         "Denmark",
#         "Switzerland",
#         "India",
#         "Hong Kong",
#         "Finland",
#         "Saudi Arabia",
#         "China",
#         "Nordic",
#         "Netherlands",
#         "Japan",
#         "New Zealand",
#         "Canada",
#         "Norway",
#         "Singapore",
#         "Ireland",
#         "Brazil"
#     ],
#     "LANGUAGE": [],
#     "LAW": [],
#     "LOC": [
#         "Northern Europe Finland",
#         "Earth",
#         "Asia"
#     ],
#     "NORP": [
#         "Australian",
#         "Finns",
#         "European",
#         "Finnish",
#         "Ipsos"
#     ],
#     "ORG": [
#         "Ipsos Group",
#         "COVID19",
#         "World Happiness Report",
#         "United Nations",
#         "World Bank"
#     ],
#     "PERSON": [
#         "Frank Martela",
#         "Melissa Georgiou",
#         "Frank",
#         "Melissa"
#     ],
#     "PRODUCT": [],
#     "WORK_OF_ART": [
#         "World Happiness Report",
#         "Dark Night"
#     ]
# }

# %% [markdown]
# ---
# # Noun Phrases
#
# * [Noun chunks](https://spacy.io/usage/linguistic-features#noun-chunks)
#
# > **Noun chunks** are “base noun phrases” – flat phrases that **have a noun as their head**. You can think of noun chunks as a noun plus the words describing the noun – for example, “the lavish green grass” or “the world’s largest tech fund”.

# %%
phrases = doc.noun_chunks

for sentence in doc.sents:
    print("-" * 80)
    print(sentence)
    print("-" * 80)
    
    phrase = next(phrases)
    while phrase.root.sent == sentence:
        print(
            f"phrase:[{phrase.text:30}] "\
            f"root:[{phrase.root.text:12}] "\
            f"type:[{phrase.root.dep_:6}] "\
            f"parent:[{phrase.root.head}]" 
        )
        try:
            phrase = next(phrases)
        except StopIteration:
            break
            
del phrases
# Out:
# --------------------------------------------------------------------------------
# Australian Melissa Georgiou (Melissa Georgiou) moved to Finland over a decade ago to seek happiness in one of the coldest and darkest places on Earth.
# --------------------------------------------------------------------------------
# phrase:[Australian Melissa Georgiou   ] root:[Georgiou    ] type:[nsubj ] parent:[moved]
# phrase:[Melissa Georgiou              ] root:[Georgiou    ] type:[appos ] parent:[Georgiou]
# phrase:[Finland                       ] root:[Finland     ] type:[pobj  ] parent:[to]
# phrase:[happiness                     ] root:[happiness   ] type:[dobj  ] parent:[seek]
# phrase:[the coldest and darkest places] root:[places      ] type:[pobj  ] parent:[of]
# phrase:[Earth                         ] root:[Earth       ] type:[pobj  ] parent:[on]
# --------------------------------------------------------------------------------
# “One of my favorite things about living here is that it's easy to get close to nature whether you're in a residential area or in the middle of the city,” Melissa said.
# --------------------------------------------------------------------------------
# phrase:[it                            ] root:[it          ] type:[nsubj ] parent:['s]
# phrase:[nature                        ] root:[nature      ] type:[pobj  ] parent:[to]
# phrase:[you                           ] root:[you         ] type:[nsubj ] parent:['re]
# phrase:[a residential area            ] root:[area        ] type:[pobj  ] parent:[in]
# phrase:[the middle                    ] root:[middle      ] type:[pobj  ] parent:[in]
# phrase:[the city                      ] root:[city        ] type:[pobj  ] parent:[of]
# phrase:[Melissa                       ] root:[Melissa     ] type:[nsubj ] parent:[said]
# --------------------------------------------------------------------------------
# Originally a teacher, 12 years ago, she switched from the beaches of Sydney to the dark winters and cold lakes of Finland, and has never looked back since.
# --------------------------------------------------------------------------------
# phrase:[the beaches                   ] root:[beaches     ] type:[pobj  ] parent:[from]
# phrase:[Sydney                        ] root:[Sydney      ] type:[pobj  ] parent:[of]
# phrase:[the dark winters              ] root:[winters     ] type:[pobj  ] parent:[to]
# phrase:[cold lakes                    ] root:[lakes       ] type:[conj  ] parent:[winters]
# phrase:[Finland                       ] root:[Finland     ] type:[pobj  ] parent:[of]
# --------------------------------------------------------------------------------
# Melissa said, “For Finns, the concept of happiness is very different from the Australian concept of happiness.
# --------------------------------------------------------------------------------
# phrase:[Finns                         ] root:[Finns       ] type:[pobj  ] parent:[For]
# phrase:[the concept                   ] root:[concept     ] type:[nsubj ] parent:[is]
# phrase:[happiness                     ] root:[happiness   ] type:[pobj  ] parent:[of]
# phrase:[the Australian concept        ] root:[concept     ] type:[pobj  ] parent:[from]
# phrase:[happiness                     ] root:[happiness   ] type:[pobj  ] parent:[of]
# --------------------------------------------------------------------------------
# Finns, she said, are happy to accept portrayals of themselves as melancholy and stubborn — a popular local saying is, “People who have happiness must hide it.”
# --------------------------------------------------------------------------------
# phrase:[portrayals                    ] root:[portrayals  ] type:[dobj  ] parent:[accept]
# phrase:[themselves                    ] root:[themselves  ] type:[pobj  ] parent:[of]
# phrase:[a popular local saying        ] root:[saying      ] type:[nsubj ] parent:[is]
# phrase:[People                        ] root:[People      ] type:[nsubj ] parent:[hide]
# phrase:[who                           ] root:[who         ] type:[nsubj ] parent:[have]
# phrase:[happiness                     ] root:[happiness   ] type:[dobj  ] parent:[have]
# phrase:[it                            ] root:[it          ] type:[dobj  ] parent:[hide]
# --------------------------------------------------------------------------------
# “The first thing I noticed here is that you don't go to dinners or barbecues, and you don't talk about real estate.
# --------------------------------------------------------------------------------
# phrase:[I                             ] root:[I           ] type:[nsubj ] parent:[noticed]
# phrase:[you                           ] root:[you         ] type:[nsubj ] parent:[go]
# phrase:[dinners                       ] root:[dinners     ] type:[pobj  ] parent:[to]
# phrase:[barbecues                     ] root:[barbecues   ] type:[conj  ] parent:[dinners]
# phrase:[you                           ] root:[you         ] type:[nsubj ] parent:[talk]
# phrase:[real estate                   ] root:[estate      ] type:[pobj  ] parent:[about]
# --------------------------------------------------------------------------------
# No one asks you where you live, what suburb do you live in, where your kids go to school.”
# --------------------------------------------------------------------------------
# phrase:[you                           ] root:[you         ] type:[dobj  ] parent:[asks]
# phrase:[you                           ] root:[you         ] type:[nsubj ] parent:[live]
# phrase:[what suburb                   ] root:[suburb      ] type:[pobj  ] parent:[in]
# phrase:[you                           ] root:[you         ] type:[nsubj ] parent:[live]
# phrase:[your kids                     ] root:[kids        ] type:[nsubj ] parent:[go]
# phrase:[school                        ] root:[school      ] type:[pobj  ] parent:[to]
# --------------------------------------------------------------------------------
# The Finns seem quite happy with the status quo, and they don't always seem to want more.
# --------------------------------------------------------------------------------
# phrase:[the status quo                ] root:[quo         ] type:[pobj  ] parent:[with]
# phrase:[they                          ] root:[they        ] type:[nsubj ] parent:[seem]
# --------------------------------------------------------------------------------
# Melissa Georgio's Dark Night in Northern Europe Finland was named the happiest country in the world for the sixth year in a row in the “World Happiness Report” released by the United Nations.
# --------------------------------------------------------------------------------
# phrase:[Northern Europe Finland       ] root:[Finland     ] type:[pobj  ] parent:[in]
# phrase:[the happiest country          ] root:[country     ] type:[oprd  ] parent:[named]
# phrase:[the world                     ] root:[world       ] type:[pobj  ] parent:[in]
# phrase:[the sixth year                ] root:[year        ] type:[pobj  ] parent:[for]
# phrase:[a row                         ] root:[row         ] type:[pobj  ] parent:[in]
# phrase:[the “World Happiness Report   ] root:[Report      ] type:[pobj  ] parent:[in]
# phrase:[the United Nations            ] root:[Nations     ] type:[pobj  ] parent:[by]
# --------------------------------------------------------------------------------
# “The Nordic countries are often countries with (good) unemployment benefits, pensions, and other benefits,” explains happiness expert and researcher Frank Martela (Frank Martela).
# --------------------------------------------------------------------------------
# phrase:[countries                     ] root:[countries   ] type:[attr  ] parent:[are]
# phrase:[good) unemployment benefits   ] root:[benefits    ] type:[pobj  ] parent:[with]
# phrase:[pensions                      ] root:[pensions    ] type:[conj  ] parent:[benefits]
# phrase:[other benefits                ] root:[benefits    ] type:[conj  ] parent:[pensions]
# phrase:[happiness expert              ] root:[expert      ] type:[nsubj ] parent:[explains]
# phrase:[researcher Frank Martela      ] root:[Martela     ] type:[conj  ] parent:[expert]
# phrase:[Frank Martela                 ] root:[Martela     ] type:[appos ] parent:[Martela]
# --------------------------------------------------------------------------------
# However, Frank said that Finland's position in the rankings often surprised its own people.
# --------------------------------------------------------------------------------
# phrase:[Finland's position            ] root:[position    ] type:[nsubj ] parent:[surprised]
# phrase:[the rankings                  ] root:[rankings    ] type:[pobj  ] parent:[in]
# phrase:[its own people                ] root:[people      ] type:[dobj  ] parent:[surprised]
# --------------------------------------------------------------------------------
# “Finns, they're almost outraged because they don't think this can be true.
# --------------------------------------------------------------------------------
# phrase:[they                          ] root:[they        ] type:[nsubj ] parent:[think]
# phrase:[this                          ] root:[this        ] type:[nsubj ] parent:[be]
# --------------------------------------------------------------------------------
# We listen to sad music and hard rock.”
# --------------------------------------------------------------------------------
# phrase:[sad music                     ] root:[music       ] type:[pobj  ] parent:[to]
# phrase:[hard rock                     ] root:[rock        ] type:[conj  ] parent:[music]
# --------------------------------------------------------------------------------
# “Therefore, happiness is not part of the Finnish self-image.”
# --------------------------------------------------------------------------------
# phrase:[part                          ] root:[part        ] type:[attr  ] parent:[is]
# phrase:[the Finnish self-image        ] root:[image       ] type:[pobj  ] parent:[of]
# --------------------------------------------------------------------------------
# The other side of Finnish melancholy is a cultural focus on perseverance.
# --------------------------------------------------------------------------------
# phrase:[Finnish melancholy            ] root:[melancholy  ] type:[pobj  ] parent:[of]
# phrase:[a cultural focus              ] root:[focus       ] type:[attr  ] parent:[is]
# phrase:[perseverance                  ] root:[perseverance] type:[pobj  ] parent:[on]
# --------------------------------------------------------------------------------
# Frank said it redefines the way Finns view happiness — a concept known as “sisu” — which is part of Finnish culture and is hard to translate directly, but can be understood as will, determination, perseverance, and reason to face adversity.
# --------------------------------------------------------------------------------
# phrase:[it                            ] root:[it          ] type:[nsubj ] parent:[redefines]
# phrase:[Finns                         ] root:[Finns       ] type:[nsubj ] parent:[view]
# phrase:[happiness                     ] root:[happiness   ] type:[dobj  ] parent:[view]
# phrase:[a concept                     ] root:[concept     ] type:[appos ] parent:[way]
# phrase:[“sisu                         ] root:[sisu        ] type:[pobj  ] parent:[as]
# phrase:[which                         ] root:[which       ] type:[nsubj ] parent:[is]
# phrase:[part                          ] root:[part        ] type:[attr  ] parent:[is]
# phrase:[Finnish culture               ] root:[culture     ] type:[pobj  ] parent:[of]
# phrase:[will                          ] root:[will        ] type:[pobj  ] parent:[as]
# phrase:[determination                 ] root:[determination] type:[conj  ] parent:[will]
# phrase:[perseverance                  ] root:[perseverance] type:[conj  ] parent:[determination]
# phrase:[reason                        ] root:[reason      ] type:[conj  ] parent:[perseverance]
# phrase:[adversity                     ] root:[adversity   ] type:[dobj  ] parent:[face]
# --------------------------------------------------------------------------------
# This, he said, is best reflected in Finns' favorite pastime — getting warm in a sauna after taking a bath in freezing temperatures.
# --------------------------------------------------------------------------------
# phrase:[he                            ] root:[he          ] type:[nsubj ] parent:[said]
# phrase:[Finns' favorite pastime       ] root:[pastime     ] type:[pobj  ] parent:[in]
# phrase:[a sauna                       ] root:[sauna       ] type:[pobj  ] parent:[in]
# phrase:[a bath                        ] root:[bath        ] type:[dobj  ] parent:[taking]
# phrase:[freezing temperatures         ] root:[temperatures] type:[pobj  ] parent:[in]
# --------------------------------------------------------------------------------
# “It's about this paradox — from one extreme to the other, and it's a pretty fun experience... because you need perseverance.”
# --------------------------------------------------------------------------------
# phrase:[this paradox                  ] root:[paradox     ] type:[pobj  ] parent:[about]
# phrase:[one extreme                   ] root:[extreme     ] type:[pobj  ] parent:[from]
# phrase:[it                            ] root:[it          ] type:[nsubj ] parent:['s]
# phrase:[a pretty fun experience       ] root:[experience  ] type:[attr  ] parent:['s]
# phrase:[you                           ] root:[you         ] type:[nsubj ] parent:[need]
# phrase:[perseverance                  ] root:[perseverance] type:[dobj  ] parent:[need]
# --------------------------------------------------------------------------------
# Melissa said, but Finland has many things that are great and can provide happiness for people in this country.
# --------------------------------------------------------------------------------
# phrase:[Finland                       ] root:[Finland     ] type:[nsubj ] parent:[has]
# phrase:[many things                   ] root:[things      ] type:[dobj  ] parent:[has]
# phrase:[that                          ] root:[that        ] type:[nsubj ] parent:[are]
# phrase:[happiness                     ] root:[happiness   ] type:[dobj  ] parent:[provide]
# phrase:[people                        ] root:[people      ] type:[pobj  ] parent:[for]
# phrase:[this country                  ] root:[country     ] type:[pobj  ] parent:[in]
# --------------------------------------------------------------------------------
# Finland is one of the European countries least affected by the COVID-19 pandemic, and experts attribute this to a high level of trust in the government and little resistance to complying with restrictions.
# --------------------------------------------------------------------------------
# phrase:[the European countries        ] root:[countries   ] type:[pobj  ] parent:[of]
# phrase:[the COVID-19                  ] root:[COVID-19    ] type:[pobj  ] parent:[by]
# phrase:[experts                       ] root:[experts     ] type:[nsubj ] parent:[attribute]
# phrase:[this                          ] root:[this        ] type:[dobj  ] parent:[attribute]
# phrase:[a high level                  ] root:[level       ] type:[pobj  ] parent:[to]
# phrase:[trust                         ] root:[trust       ] type:[pobj  ] parent:[of]
# phrase:[the government                ] root:[government  ] type:[pobj  ] parent:[in]
# phrase:[little resistance             ] root:[resistance  ] type:[conj  ] parent:[government]
# phrase:[restrictions                  ] root:[restrictions] type:[pobj  ] parent:[with]
# --------------------------------------------------------------------------------
# Trust in government, on the other hand, stems from a country's investment in its citizens.
# --------------------------------------------------------------------------------
# phrase:[government                    ] root:[government  ] type:[pobj  ] parent:[in]
# phrase:[the other hand                ] root:[hand        ] type:[pobj  ] parent:[on]
# phrase:[a country's investment        ] root:[investment  ] type:[pobj  ] parent:[from]
# phrase:[its citizens                  ] root:[citizens    ] type:[pobj  ] parent:[in]
# --------------------------------------------------------------------------------
# The public school system rarely tests children and is one of the best in the world.
# --------------------------------------------------------------------------------
# phrase:[children                      ] root:[children    ] type:[dobj  ] parent:[tests]
# phrase:[the world                     ] root:[world       ] type:[pobj  ] parent:[in]
# --------------------------------------------------------------------------------
# Finland also has a universal health care system with affordable childcare and strong support for parents.
# --------------------------------------------------------------------------------
# phrase:[a universal health care system] root:[system      ] type:[dobj  ] parent:[has]
# phrase:[affordable childcare          ] root:[childcare   ] type:[pobj  ] parent:[with]
# phrase:[strong support                ] root:[support     ] type:[conj  ] parent:[childcare]
# phrase:[parents                       ] root:[parents     ] type:[pobj  ] parent:[for]
# --------------------------------------------------------------------------------
# Melissa said, “The whole country is taking care of the child's development.
# --------------------------------------------------------------------------------
# phrase:[The whole country             ] root:[country     ] type:[nsubj ] parent:[taking]
# phrase:[care                          ] root:[care        ] type:[dobj  ] parent:[taking]
# phrase:[the child's development       ] root:[development ] type:[pobj  ] parent:[of]
# --------------------------------------------------------------------------------
# This system is very well set up.
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# So from having my son to raising him at home, to sending him to daycare, to going to school, I was very well supported in every aspect of this.”
# --------------------------------------------------------------------------------
# phrase:[him                           ] root:[him         ] type:[dobj  ] parent:[raising]
# phrase:[home                          ] root:[home        ] type:[pobj  ] parent:[at]
# phrase:[him                           ] root:[him         ] type:[dobj  ] parent:[sending]
# phrase:[daycare                       ] root:[daycare     ] type:[pobj  ] parent:[to]
# phrase:[school                        ] root:[school      ] type:[pobj  ] parent:[to]
# phrase:[I                             ] root:[I           ] type:[nsubjpass] parent:[supported]
# phrase:[every aspect                  ] root:[aspect      ] type:[pobj  ] parent:[in]
# phrase:[this                          ] root:[this        ] type:[pobj  ] parent:[of]
# --------------------------------------------------------------------------------
# Finland vs. China, which country has the strongest sense of happiness?
# --------------------------------------------------------------------------------
# phrase:[China                         ] root:[China       ] type:[pobj  ] parent:[vs.]
# phrase:[which country                 ] root:[country     ] type:[nsubj ] parent:[has]
# phrase:[the strongest sense           ] root:[sense       ] type:[dobj  ] parent:[has]
# phrase:[happiness                     ] root:[happiness   ] type:[pobj  ] parent:[of]
# --------------------------------------------------------------------------------
# Since the publication of the World Happiness Report, the Nordic countries have dominated the top ten.
# --------------------------------------------------------------------------------
# phrase:[the World Happiness Report    ] root:[Report      ] type:[pobj  ] parent:[of]
# phrase:[the Nordic countries          ] root:[countries   ] type:[nsubj ] parent:[dominated]
# --------------------------------------------------------------------------------
# In this year's report, Finland and its neighbors Denmark (2nd), Iceland (3rd), Sweden (6th), and Norway (7th) all scored high on happiness indicators, including healthy life expectancy, per capita GDP, low levels of corruption, social support, freedom, trust, and generosity.
# --------------------------------------------------------------------------------
# phrase:[Finland                       ] root:[Finland     ] type:[appos ] parent:[report]
# phrase:[its neighbors                 ] root:[neighbors   ] type:[conj  ] parent:[Finland]
# phrase:[Denmark                       ] root:[Denmark     ] type:[appos ] parent:[neighbors]
# phrase:[Iceland                       ] root:[Iceland     ] type:[appos ] parent:[neighbors]
# phrase:[3rd                           ] root:[3rd         ] type:[appos ] parent:[Iceland]
# phrase:[Sweden                        ] root:[Sweden      ] type:[conj  ] parent:[Iceland]
# phrase:[(6th                          ] root:[6th         ] type:[appos ] parent:[Sweden]
# phrase:[Norway                        ] root:[Norway      ] type:[conj  ] parent:[Iceland]
# phrase:[(7th                          ] root:[7th         ] type:[appos ] parent:[Norway]
# phrase:[all                           ] root:[all         ] type:[appos ] parent:[neighbors]
# phrase:[happiness indicators          ] root:[indicators  ] type:[pobj  ] parent:[on]
# phrase:[healthy life expectancy       ] root:[expectancy  ] type:[pobj  ] parent:[including]
# phrase:[per capita GDP                ] root:[GDP         ] type:[appos ] parent:[expectancy]
# phrase:[low levels                    ] root:[levels      ] type:[conj  ] parent:[GDP]
# phrase:[corruption                    ] root:[corruption  ] type:[pobj  ] parent:[of]
# phrase:[social support                ] root:[support     ] type:[conj  ] parent:[corruption]
# phrase:[freedom                       ] root:[freedom     ] type:[conj  ] parent:[support]
# phrase:[trust                         ] root:[trust       ] type:[conj  ] parent:[freedom]
# phrase:[generosity                    ] root:[generosity  ] type:[conj  ] parent:[trust]
# --------------------------------------------------------------------------------
# Other top ten countries/regions include the Netherlands (5th), Switzerland (8th), Luxembourg (9th), and New Zealand (10th).
# --------------------------------------------------------------------------------
# phrase:[the Netherlands               ] root:[Netherlands ] type:[dobj  ] parent:[include]
# phrase:[5th                           ] root:[5th         ] type:[appos ] parent:[Netherlands]
# phrase:[Switzerland                   ] root:[Switzerland ] type:[appos ] parent:[Netherlands]
# phrase:[(8th                          ] root:[8th         ] type:[appos ] parent:[Switzerland]
# phrase:[Luxembourg                    ] root:[Luxembourg  ] type:[conj  ] parent:[Switzerland]
# phrase:[(9th                          ] root:[9th         ] type:[appos ] parent:[Luxembourg]
# phrase:[New Zealand                   ] root:[Zealand     ] type:[conj  ] parent:[Luxembourg]
# phrase:[(10th                         ] root:[10th        ] type:[appos ] parent:[Zealand]
# --------------------------------------------------------------------------------
# Australia ranked 12th in this report, followed by Canada (13th), Ireland (14th), and the United States (15th).
# --------------------------------------------------------------------------------
# phrase:[12th                          ] root:[12th        ] type:[dobj  ] parent:[ranked]
# phrase:[this report                   ] root:[report      ] type:[pobj  ] parent:[in]
# phrase:[Canada                        ] root:[Canada      ] type:[pobj  ] parent:[by]
# phrase:[13th                          ] root:[13th        ] type:[appos ] parent:[Canada]
# phrase:[Ireland                       ] root:[Ireland     ] type:[appos ] parent:[Canada]
# phrase:[the United States             ] root:[States      ] type:[conj  ] parent:[Ireland]
# phrase:[15th                          ] root:[15th        ] type:[appos ] parent:[States]
# --------------------------------------------------------------------------------
# In Asia, Singapore ranked 25th in the world, up two places from last year, Taiwan dropped one place from last year to 27th, Japan rose to 47th, mainland China ranked 64th, and Hong Kong ranked 82nd.
# --------------------------------------------------------------------------------
# phrase:[Singapore                     ] root:[Singapore   ] type:[nsubj ] parent:[ranked]
# phrase:[the world                     ] root:[world       ] type:[pobj  ] parent:[in]
# phrase:[last year                     ] root:[year        ] type:[pobj  ] parent:[from]
# phrase:[Taiwan                        ] root:[Taiwan      ] type:[nsubj ] parent:[dropped]
# phrase:[one place                     ] root:[place       ] type:[dobj  ] parent:[dropped]
# phrase:[last year                     ] root:[year        ] type:[pobj  ] parent:[from]
# phrase:[27th                          ] root:[27th        ] type:[pobj  ] parent:[to]
# phrase:[Japan                         ] root:[Japan       ] type:[nsubj ] parent:[rose]
# phrase:[mainland China                ] root:[China       ] type:[nsubj ] parent:[ranked]
# phrase:[Hong Kong                     ] root:[Kong        ] type:[nsubj ] parent:[ranked]
# phrase:[82nd                          ] root:[82nd        ] type:[dobj  ] parent:[ranked]
# --------------------------------------------------------------------------------
# Meanwhile, the polling agency Ipsos Group (Ipsos) released a survey report on the global happiness index.
# --------------------------------------------------------------------------------
# phrase:[Ipsos Group                   ] root:[Group       ] type:[appos ] parent:[agency]
# phrase:[Ipsos                         ] root:[Ipsos       ] type:[appos ] parent:[Group]
# phrase:[a survey report               ] root:[report      ] type:[dobj  ] parent:[released]
# phrase:[the global happiness index    ] root:[index       ] type:[pobj  ] parent:[on]
# --------------------------------------------------------------------------------
# The results showed that out of 32 countries, the country with the highest happiness index was China (91%), followed by Saudi Arabia (86%), the Netherlands (85%), India (84%), and Brazil (83%).
# --------------------------------------------------------------------------------
# phrase:[32 countries                  ] root:[countries   ] type:[pobj  ] parent:[of]
# phrase:[the country                   ] root:[country     ] type:[nsubj ] parent:[was]
# phrase:[the highest happiness index   ] root:[index       ] type:[pobj  ] parent:[with]
# phrase:[China                         ] root:[China       ] type:[attr  ] parent:[was]
# phrase:[91%                           ] root:[%           ] type:[appos ] parent:[China]
# phrase:[Saudi Arabia                  ] root:[Arabia      ] type:[pobj  ] parent:[by]
# phrase:[86%                           ] root:[%           ] type:[appos ] parent:[Arabia]
# phrase:[the Netherlands               ] root:[Netherlands ] type:[conj  ] parent:[Arabia]
# phrase:[85%                           ] root:[%           ] type:[appos ] parent:[Netherlands]
# phrase:[India                         ] root:[India       ] type:[appos ] parent:[Netherlands]
# phrase:[84%                           ] root:[%           ] type:[appos ] parent:[India]
# phrase:[Brazil                        ] root:[Brazil      ] type:[conj  ] parent:[Netherlands]
# phrase:[83%                           ] root:[%           ] type:[appos ] parent:[Brazil]
# --------------------------------------------------------------------------------
# Australia ranked 9th in this report.
# --------------------------------------------------------------------------------
# phrase:[9th                           ] root:[9th         ] type:[dobj  ] parent:[ranked]
# phrase:[this report                   ] root:[report      ] type:[pobj  ] parent:[in]
# --------------------------------------------------------------------------------
# According to the survey report, on average, happiness increased more significantly in middle-income countries (as defined by the World Bank) than in high-income countries.
# --------------------------------------------------------------------------------
# phrase:[happiness                     ] root:[happiness   ] type:[nsubj ] parent:[increased]
# phrase:[middle-income countries       ] root:[countries   ] type:[pobj  ] parent:[in]
# phrase:[the World Bank                ] root:[Bank        ] type:[pobj  ] parent:[by]
# phrase:[high-income countries         ] root:[countries   ] type:[pobj  ] parent:[in]

# %%
for chunk in doc.noun_chunks:
    print(
        f"{chunk.text:32} " \
        f"tag:{chunk.root.dep_:10} " \
        f"root:{chunk.root.head.text:10} " \
#        sentence:{chunk.root.sent} " \
        f"children:{list(chunk.root.children)}"
    )
# Out:
# Australian Melissa Georgiou      tag:nsubj      root:moved      children:[Australian, Melissa, (, Georgiou, )]
# Melissa Georgiou                 tag:appos      root:Georgiou   children:[Melissa]
# Finland                          tag:pobj       root:to         children:[]
# happiness                        tag:dobj       root:seek       children:[]
# the coldest and darkest places   tag:pobj       root:of         children:[the, coldest, on]
# Earth                            tag:pobj       root:on         children:[]
# my favorite things               tag:pobj       root:of         children:[my, favorite, about]
# it                               tag:nsubj      root:'s         children:[]
# nature                           tag:pobj       root:to         children:[]
# you                              tag:nsubj      root:'re        children:[]
# a residential area               tag:pobj       root:in         children:[a, residential]
# the middle                       tag:pobj       root:in         children:[the, of]
# the city                         tag:pobj       root:of         children:[the]
# Melissa                          tag:nsubj      root:said       children:[]
# she                              tag:nsubj      root:switched   children:[]
# the beaches                      tag:pobj       root:from       children:[the, of]
# Sydney                           tag:pobj       root:of         children:[]
# the dark winters                 tag:pobj       root:to         children:[the, dark, and, lakes]
# cold lakes                       tag:conj       root:winters    children:[cold, of]
# Finland                          tag:pobj       root:of         children:[]
# Melissa                          tag:nsubj      root:said       children:[]
# Finns                            tag:pobj       root:For        children:[]
# the concept                      tag:nsubj      root:is         children:[the, of]
# happiness                        tag:pobj       root:of         children:[]
# the Australian concept           tag:pobj       root:from       children:[the, Australian, of]
# happiness                        tag:pobj       root:of         children:[]
# she                              tag:nsubj      root:said       children:[]
# portrayals                       tag:dobj       root:accept     children:[of, as, —]
# themselves                       tag:pobj       root:of         children:[]
# a popular local saying           tag:nsubj      root:is         children:[a, popular, local]
# People                           tag:nsubj      root:hide       children:[have]
# who                              tag:nsubj      root:have       children:[]
# happiness                        tag:dobj       root:have       children:[]
# it                               tag:dobj       root:hide       children:[]
# The first thing                  tag:nsubj      root:is         children:[The, first, noticed]
# I                                tag:nsubj      root:noticed    children:[]
# you                              tag:nsubj      root:go         children:[]
# dinners                          tag:pobj       root:to         children:[or, barbecues]
# barbecues                        tag:conj       root:dinners    children:[]
# you                              tag:nsubj      root:talk       children:[]
# real estate                      tag:pobj       root:about      children:[real]
# No one                           tag:nsubj      root:asks       children:[No]
# you                              tag:dobj       root:asks       children:[]
# you                              tag:nsubj      root:live       children:[]
# what suburb                      tag:pobj       root:in         children:[what]
# you                              tag:nsubj      root:live       children:[]
# your kids                        tag:nsubj      root:go         children:[your]
# school                           tag:pobj       root:to         children:[]
# The Finns                        tag:nsubj      root:seem       children:[The]
# the status quo                   tag:pobj       root:with       children:[the, status]
# they                             tag:nsubj      root:seem       children:[]
# Melissa Georgio's Dark Night     tag:nsubjpass  root:named      children:[Georgio, Dark, in]
# Northern Europe Finland          tag:pobj       root:in         children:[Europe]
# the happiest country             tag:oprd       root:named      children:[the, happiest, in]
# the world                        tag:pobj       root:in         children:[the]
# the sixth year                   tag:pobj       root:for        children:[the, sixth, in]
# a row                            tag:pobj       root:in         children:[a, in]
# the “World Happiness Report      tag:pobj       root:in         children:[the, “, Happiness, ”, released]
# the United Nations               tag:pobj       root:by         children:[the, United]
# The Nordic countries             tag:nsubj      root:are        children:[The, Nordic]
# countries                        tag:attr       root:are        children:[with]
# good) unemployment benefits      tag:pobj       root:with       children:[good, unemployment, ,, pensions]
# pensions                         tag:conj       root:benefits   children:[,, and, benefits]
# other benefits                   tag:conj       root:pensions   children:[other]
# happiness expert                 tag:nsubj      root:explains   children:[happiness, and, Martela]
# researcher Frank Martela         tag:conj       root:expert     children:[researcher, Frank, (, Martela, )]
# Frank Martela                    tag:appos      root:Martela    children:[Frank]
# Frank                            tag:nsubj      root:said       children:[]
# Finland's position               tag:nsubj      root:surprised  children:[Finland, in]
# the rankings                     tag:pobj       root:in         children:[the]
# its own people                   tag:dobj       root:surprised  children:[its, own]
# they                             tag:nsubj      root:'re        children:[]
# they                             tag:nsubj      root:think      children:[]
# this                             tag:nsubj      root:be         children:[]
# We                               tag:nsubj      root:listen     children:[]
# sad music                        tag:pobj       root:to         children:[sad, and, rock]
# hard rock                        tag:conj       root:music      children:[hard]
# happiness                        tag:nsubj      root:is         children:[]
# part                             tag:attr       root:is         children:[of]
# the Finnish self-image           tag:pobj       root:of         children:[the, Finnish, self, -]
# The other side                   tag:nsubj      root:is         children:[The, other, of]
# Finnish melancholy               tag:pobj       root:of         children:[Finnish]
# a cultural focus                 tag:attr       root:is         children:[a, cultural, on]
# perseverance                     tag:pobj       root:on         children:[]
# Frank                            tag:nsubj      root:said       children:[]
# it                               tag:nsubj      root:redefines  children:[]
# Finns                            tag:nsubj      root:view       children:[]
# happiness                        tag:dobj       root:view       children:[]
# a concept                        tag:appos      root:way        children:[a, known, —, is]
# “sisu                            tag:pobj       root:as         children:[“, ”]
# which                            tag:nsubj      root:is         children:[]
# part                             tag:attr       root:is         children:[of]
# Finnish culture                  tag:pobj       root:of         children:[Finnish]
# will                             tag:pobj       root:as         children:[,, determination]
# determination                    tag:conj       root:will       children:[,, perseverance]
# perseverance                     tag:conj       root:determination children:[,, and, reason]
# reason                           tag:conj       root:perseverance children:[face]
# adversity                        tag:dobj       root:face       children:[]
# This                             tag:nsubjpass  root:reflected  children:[]
# he                               tag:nsubj      root:said       children:[]
# Finns' favorite pastime          tag:pobj       root:in         children:[Finns, favorite, —, getting]
# a sauna                          tag:pobj       root:in         children:[a]
# a bath                           tag:dobj       root:taking     children:[a, in]
# freezing temperatures            tag:pobj       root:in         children:[freezing]
# It                               tag:nsubj      root:'s         children:[]
# this paradox                     tag:pobj       root:about      children:[this, —]
# one extreme                      tag:pobj       root:from       children:[one, to]
# it                               tag:nsubj      root:'s         children:[]
# a pretty fun experience          tag:attr       root:'s         children:[a, fun]
# you                              tag:nsubj      root:need       children:[]
# perseverance                     tag:dobj       root:need       children:[]
# Melissa                          tag:nsubj      root:said       children:[]
# Finland                          tag:nsubj      root:has        children:[]
# many things                      tag:dobj       root:has        children:[many, are]
# that                             tag:nsubj      root:are        children:[]
# happiness                        tag:dobj       root:provide    children:[]
# people                           tag:pobj       root:for        children:[in]
# this country                     tag:pobj       root:in         children:[this]
# Finland                          tag:nsubj      root:is         children:[]
# the European countries           tag:pobj       root:of         children:[the, European, affected]
# the COVID-19                     tag:pobj       root:by         children:[the, pandemic]
# experts                          tag:nsubj      root:attribute  children:[]
# this                             tag:dobj       root:attribute  children:[]
# a high level                     tag:pobj       root:to         children:[a, high, of]
# trust                            tag:pobj       root:of         children:[in]
# the government                   tag:pobj       root:in         children:[the, and, resistance]
# little resistance                tag:conj       root:government children:[little, to]
# restrictions                     tag:pobj       root:with       children:[]
# Trust                            tag:nsubj      root:stems      children:[in]
# government                       tag:pobj       root:in         children:[]
# the other hand                   tag:pobj       root:on         children:[the, other]
# a country's investment           tag:pobj       root:from       children:[country, in]
# its citizens                     tag:pobj       root:in         children:[its]
# The public school system         tag:nsubj      root:tests      children:[The, school]
# children                         tag:dobj       root:tests      children:[]
# the world                        tag:pobj       root:in         children:[the]
# Finland                          tag:nsubj      root:has        children:[]
# a universal health care system   tag:dobj       root:has        children:[a, universal, care, with]
# affordable childcare             tag:pobj       root:with       children:[affordable, and, support]
# strong support                   tag:conj       root:childcare  children:[strong, for]
# parents                          tag:pobj       root:for        children:[]
# Melissa                          tag:nsubj      root:said       children:[]
# The whole country                tag:nsubj      root:taking     children:[The, whole]
# care                             tag:dobj       root:taking     children:[]
# the child's development          tag:pobj       root:of         children:[child]
# This system                      tag:nsubjpass  root:set        children:[This]
# my son                           tag:dobj       root:having     children:[my]
# him                              tag:dobj       root:raising    children:[]
# home                             tag:pobj       root:at         children:[]
# him                              tag:dobj       root:sending    children:[]
# daycare                          tag:pobj       root:to         children:[]
# school                           tag:pobj       root:to         children:[]
# I                                tag:nsubjpass  root:supported  children:[]
# every aspect                     tag:pobj       root:in         children:[every, of]
# this                             tag:pobj       root:of         children:[]
# Finland                          tag:ROOT       root:Finland    children:[vs., ?]
# China                            tag:pobj       root:vs.        children:[,, has]
# which country                    tag:nsubj      root:has        children:[which]
# the strongest sense              tag:dobj       root:has        children:[the, strongest, of]
# happiness                        tag:pobj       root:of         children:[]
# the publication                  tag:pobj       root:Since      children:[the, of]
# the World Happiness Report       tag:pobj       root:of         children:[the, Happiness]
# the Nordic countries             tag:nsubj      root:dominated  children:[the, Nordic]
# this year's report               tag:pobj       root:In         children:[year, ,, Finland]
# Finland                          tag:appos      root:report     children:[and, neighbors]
# its neighbors                    tag:conj       root:Finland    children:[its, Denmark, Iceland, all]
# Denmark                          tag:appos      root:neighbors  children:[2nd, ,]
# Iceland                          tag:appos      root:neighbors  children:[(, 3rd, ), ,, Sweden, ,, and, Norway]
# 3rd                              tag:appos      root:Iceland    children:[]
# Sweden                           tag:conj       root:Iceland    children:[6th, )]
# (6th                             tag:appos      root:Sweden     children:[(]
# Norway                           tag:conj       root:Iceland    children:[7th]
# (7th                             tag:appos      root:Norway     children:[(, )]
# all                              tag:appos      root:neighbors  children:[]
# happiness indicators             tag:pobj       root:on         children:[happiness]
# healthy life expectancy          tag:pobj       root:including  children:[healthy, life, ,, GDP]
# per capita GDP                   tag:appos      root:expectancy children:[per, ,, levels]
# low levels                       tag:conj       root:GDP        children:[low, of]
# corruption                       tag:pobj       root:of         children:[,, support]
# social support                   tag:conj       root:corruption children:[social, ,, freedom]
# freedom                          tag:conj       root:support    children:[,, trust]
# trust                            tag:conj       root:freedom    children:[,, and, generosity]
# generosity                       tag:conj       root:trust      children:[]
# Other top ten countries/regions  tag:nsubj      root:include    children:[Other, top, countries, /]
# the Netherlands                  tag:dobj       root:include    children:[the, (, 5th, ), ,, Switzerland]
# 5th                              tag:appos      root:Netherlands children:[]
# Switzerland                      tag:appos      root:Netherlands children:[8th, ,, Luxembourg]
# (8th                             tag:appos      root:Switzerland children:[(, )]
# Luxembourg                       tag:conj       root:Switzerland children:[9th, ,, and, Zealand]
# (9th                             tag:appos      root:Luxembourg children:[(, )]
# New Zealand                      tag:conj       root:Luxembourg children:[New, 10th, )]
# (10th                            tag:appos      root:Zealand    children:[(]
# Australia                        tag:nsubj      root:ranked     children:[]
# 12th                             tag:dobj       root:ranked     children:[]
# this report                      tag:pobj       root:in         children:[this]
# Canada                           tag:pobj       root:by         children:[(, 13th, ), ,, Ireland]
# 13th                             tag:appos      root:Canada     children:[]
# Ireland                          tag:appos      root:Canada     children:[(, 14th, ), ,, and, States]
# the United States                tag:conj       root:Ireland    children:[the, United, (, 15th, )]
# 15th                             tag:appos      root:States     children:[]
# Asia                             tag:pobj       root:In         children:[]
# Singapore                        tag:nsubj      root:ranked     children:[]
# the world                        tag:pobj       root:in         children:[the]
# last year                        tag:pobj       root:from       children:[last]
# Taiwan                           tag:nsubj      root:dropped    children:[]
# one place                        tag:dobj       root:dropped    children:[one]
# last year                        tag:pobj       root:from       children:[last]
# 27th                             tag:pobj       root:to         children:[]
# Japan                            tag:nsubj      root:rose       children:[]
# mainland China                   tag:nsubj      root:ranked     children:[mainland]
# Hong Kong                        tag:nsubj      root:ranked     children:[Hong]
# 82nd                             tag:dobj       root:ranked     children:[]
# the polling agency               tag:nsubj      root:released   children:[the, polling, Group]
# Ipsos Group                      tag:appos      root:agency     children:[Ipsos, (, Ipsos, )]
# Ipsos                            tag:appos      root:Group      children:[]
# a survey report                  tag:dobj       root:released   children:[a, survey, on]
# the global happiness index       tag:pobj       root:on         children:[the, happiness]
# The results                      tag:nsubj      root:showed     children:[The]
# 32 countries                     tag:pobj       root:of         children:[32]
# the country                      tag:nsubj      root:was        children:[the, with]
# the highest happiness index      tag:pobj       root:with       children:[the, happiness]
# China                            tag:attr       root:was        children:[(, %, ), ,, followed]
# 91%                              tag:appos      root:China      children:[91]
# Saudi Arabia                     tag:pobj       root:by         children:[Saudi, (, %, ), ,, Netherlands]
# 86%                              tag:appos      root:Arabia     children:[86]
# the Netherlands                  tag:conj       root:Arabia     children:[the, (, %, ), ,, India, ,, and, Brazil, )]
# 85%                              tag:appos      root:Netherlands children:[85]
# India                            tag:appos      root:Netherlands children:[(, %, )]
# 84%                              tag:appos      root:India      children:[84]
# Brazil                           tag:conj       root:Netherlands children:[(, %]
# 83%                              tag:appos      root:Brazil     children:[83]
# Australia                        tag:nsubj      root:ranked     children:[]
# 9th                              tag:dobj       root:ranked     children:[]
# this report                      tag:pobj       root:in         children:[this]
# the survey report                tag:pobj       root:to         children:[the, survey]
# happiness                        tag:nsubj      root:increased  children:[]
# middle-income countries          tag:pobj       root:in         children:[income, (]
# the World Bank                   tag:pobj       root:by         children:[the, World]
# high-income countries            tag:pobj       root:in         children:[income]

# %%
print("{}{}{}{}{}{}".format(
    "Token".ljust(15), "Lemma".ljust(15), "POS".ljust(10), "Tag".ljust(8), "Dependency".ljust(14), "StopWord"
))
print("-" * 80)
for token in doc:
    if (not token.is_stop) and len(token.text) > 1:
        print(f"{token.text:15}{token.lemma_:15}{token.pos_:10}{token.tag_:8}{token.dep_:14}{token.is_stop:}")
# Out:
# Token          Lemma          POS       Tag     Dependency    StopWord
# --------------------------------------------------------------------------------
# Australian     australian     ADJ       JJ      amod          False
# Melissa        Melissa        PROPN     NNP     compound      False
# Georgiou       Georgiou       PROPN     NNP     nsubj         False
# Melissa        Melissa        PROPN     NNP     compound      False
# Georgiou       Georgiou       PROPN     NNP     appos         False
# moved          move           VERB      VBD     ROOT          False
# Finland        Finland        PROPN     NNP     pobj          False
# decade         decade         NOUN      NN      npadvmod      False
# ago            ago            ADV       RB      advmod        False
# seek           seek           VERB      VB      advcl         False
# happiness      happiness      NOUN      NN      dobj          False
# coldest        cold           ADJ       JJS     amod          False
# darkest        darkest        ADJ       JJ      conj          False
# places         place          NOUN      NNS     pobj          False
# Earth          Earth          PROPN     NNP     pobj          False
# favorite       favorite       ADJ       JJ      amod          False
# things         thing          NOUN      NNS     pobj          False
# living         live           VERB      VBG     pcomp         False
# easy           easy           ADJ       JJ      acomp         False
# close          close          ADJ       JJ      acomp         False
# nature         nature         NOUN      NN      pobj          False
# residential    residential    ADJ       JJ      amod          False
# area           area           NOUN      NN      pobj          False
# middle         middle         NOUN      NN      pobj          False
# city           city           NOUN      NN      pobj          False
# Melissa        Melissa        PROPN     NNP     nsubj         False
# said           say            VERB      VBD     ROOT          False
# Originally     originally     ADV       RB      advmod        False
# teacher        teacher        NOUN      NN      npadvmod      False
# 12             12             NUM       CD      nummod        False
# years          year           NOUN      NNS     npadvmod      False
# ago            ago            ADV       RB      advmod        False
# switched       switch         VERB      VBD     ROOT          False
# beaches        beach          NOUN      NNS     pobj          False
# Sydney         Sydney         PROPN     NNP     pobj          False
# dark           dark           ADJ       JJ      amod          False
# winters        winter         NOUN      NNS     pobj          False
# cold           cold           ADJ       JJ      amod          False
# lakes          lake           NOUN      NNS     conj          False
# Finland        Finland        PROPN     NNP     pobj          False
# looked         look           VERB      VBN     conj          False
# Melissa        Melissa        PROPN     NNP     nsubj         False
# said           say            VERB      VBD     ROOT          False
# Finns          Finns          PROPN     NNP     pobj          False
# concept        concept        NOUN      NN      nsubj         False
# happiness      happiness      NOUN      NN      pobj          False
# different      different      ADJ       JJ      acomp         False
# Australian     australian     ADJ       JJ      amod          False
# concept        concept        NOUN      NN      pobj          False
# happiness      happiness      NOUN      NN      pobj          False
# Finns          finns          ADV       RB      nsubj         False
# said           say            VERB      VBD     parataxis     False
# happy          happy          ADJ       JJ      acomp         False
# accept         accept         VERB      VB      xcomp         False
# portrayals     portrayal      NOUN      NNS     dobj          False
# melancholy     melancholy     ADJ       JJ      amod          False
# stubborn       stubborn       ADJ       JJ      conj          False
# popular        popular        ADJ       JJ      amod          False
# local          local          ADJ       JJ      amod          False
# saying         saying         NOUN      NN      nsubj         False
# People         People         NOUN      NNS     nsubj         False
# happiness      happiness      NOUN      NN      dobj          False
# hide           hide           VERB      VB      ccomp         False
# thing          thing          NOUN      NN      nsubj         False
# noticed        notice         VERB      VBD     relcl         False
# dinners        dinner         NOUN      NNS     pobj          False
# barbecues      barbecue       NOUN      NNS     conj          False
# talk           talk           VERB      VB      conj          False
# real           real           ADJ       JJ      amod          False
# estate         estate         NOUN      NN      pobj          False
# asks           ask            VERB      VBZ     ROOT          False
# live           live           VERB      VBP     ccomp         False
# suburb         suburb         NOUN      NN      pobj          False
# live           live           VERB      VB      ccomp         False
# kids           kid            NOUN      NNS     nsubj         False
# school         school         NOUN      NN      pobj          False
# Finns          Finns          PROPN     NNPS    nsubj         False
# happy          happy          ADJ       JJ      oprd          False
# status         status         NOUN      NN      compound      False
# quo            quo            NOUN      NN      pobj          False
# want           want           VERB      VB      xcomp         False
# Melissa        Melissa        PROPN     NNP     compound      False
# Georgio        Georgio        PROPN     NNP     poss          False
# Dark           Dark           PROPN     NNP     compound      False
# Night          Night          PROPN     NNP     nsubjpass     False
# Northern       Northern       PROPN     NNP     compound      False
# Europe         Europe         PROPN     NNP     compound      False
# Finland        Finland        PROPN     NNP     pobj          False
# named          name           VERB      VBN     ROOT          False
# happiest       happy          ADJ       JJS     amod          False
# country        country        NOUN      NN      oprd          False
# world          world          NOUN      NN      pobj          False
# sixth          sixth          ADJ       JJ      amod          False
# year           year           NOUN      NN      pobj          False
# row            row            NOUN      NN      pobj          False
# World          World          PROPN     NNP     compound      False
# Happiness      Happiness      PROPN     NNP     compound      False
# Report         Report         PROPN     NNP     pobj          False
# released       release        VERB      VBN     acl           False
# United         United         PROPN     NNP     compound      False
# Nations        Nations        PROPN     NNP     pobj          False
# Nordic         nordic         ADJ       JJ      amod          False
# countries      country        NOUN      NNS     nsubj         False
# countries      country        NOUN      NNS     attr          False
# good           good           ADJ       JJ      amod          False
# unemployment   unemployment   NOUN      NN      compound      False
# benefits       benefit        NOUN      NNS     pobj          False
# pensions       pension        NOUN      NNS     conj          False
# benefits       benefit        NOUN      NNS     conj          False
# explains       explain        VERB      VBZ     ROOT          False
# happiness      happiness      NOUN      NN      compound      False
# expert         expert         NOUN      NN      nsubj         False
# researcher     researcher     NOUN      NN      compound      False
# Frank          Frank          PROPN     NNP     compound      False
# Martela        Martela        PROPN     NNP     conj          False
# Frank          Frank          PROPN     NNP     compound      False
# Martela        Martela        PROPN     NNP     appos         False
# Frank          Frank          PROPN     NNP     nsubj         False
# said           say            VERB      VBD     ROOT          False
# Finland        Finland        PROPN     NNP     poss          False
# position       position       NOUN      NN      nsubj         False
# rankings       ranking        NOUN      NNS     pobj          False
# surprised      surprise       VERB      VBD     ccomp         False
# people         people         NOUN      NNS     dobj          False
# Finns          Finns          PROPN     NNP     advmod        False
# outraged       outraged       ADJ       JJ      acomp         False
# think          think          VERB      VB      advcl         False
# true           true           ADJ       JJ      acomp         False
# listen         listen         VERB      VBP     ROOT          False
# sad            sad            ADJ       JJ      amod          False
# music          music          NOUN      NN      pobj          False
# hard           hard           ADJ       JJ      amod          False
# rock           rock           NOUN      NN      conj          False
# happiness      happiness      NOUN      NN      nsubj         False
# Finnish        finnish        ADJ       JJ      amod          False
# self           self           NOUN      NN      compound      False
# image          image          NOUN      NN      pobj          False
# Finnish        finnish        ADJ       JJ      amod          False
# melancholy     melancholy     NOUN      NN      pobj          False
# cultural       cultural       ADJ       JJ      amod          False
# focus          focus          NOUN      NN      attr          False
# perseverance   perseverance   NOUN      NN      pobj          False
# Frank          Frank          PROPN     NNP     nsubj         False
# said           say            VERB      VBD     ROOT          False
# redefines      redefine       VERB      VBZ     ccomp         False
# way            way            NOUN      NN      npadvmod      False
# Finns          Finns          PROPN     NNP     nsubj         False
# view           view           VERB      VBP     relcl         False
# happiness      happiness      NOUN      NN      dobj          False
# concept        concept        NOUN      NN      appos         False
# known          know           VERB      VBN     acl           False
# sisu           sisu           NOUN      NN      pobj          False
# Finnish        finnish        ADJ       JJ      amod          False
# culture        culture        NOUN      NN      pobj          False
# hard           hard           ADJ       JJ      acomp         False
# translate      translate      VERB      VB      xcomp         False
# directly       directly       ADV       RB      advmod        False
# understood     understand     VERB      VBN     conj          False
# determination  determination  NOUN      NN      conj          False
# perseverance   perseverance   NOUN      NN      conj          False
# reason         reason         NOUN      NN      conj          False
# face           face           VERB      VB      relcl         False
# adversity      adversity      NOUN      NN      dobj          False
# said           say            VERB      VBD     parataxis     False
# best           well           ADV       RBS     advmod        False
# reflected      reflect        VERB      VBN     ROOT          False
# Finns          Finns          PROPN     NNP     poss          False
# favorite       favorite       ADJ       JJ      amod          False
# pastime        pastime        NOUN      NN      pobj          False
# getting        get            VERB      VBG     acl           False
# warm           warm           ADJ       JJ      acomp         False
# sauna          sauna          NOUN      NN      pobj          False
# taking         take           VERB      VBG     pcomp         False
# bath           bath           NOUN      NN      dobj          False
# freezing       freeze         VERB      VBG     amod          False
# temperatures   temperature    NOUN      NNS     pobj          False
# paradox        paradox        NOUN      NN      pobj          False
# extreme        extreme        NOUN      NN      pobj          False
# pretty         pretty         ADV       RB      advmod        False
# fun            fun            NOUN      NN      amod          False
# experience     experience     NOUN      NN      attr          False
# ...            ...            PUNCT     :       punct         False
# need           need           VERB      VBP     advcl         False
# perseverance   perseverance   NOUN      NN      dobj          False
# Melissa        Melissa        PROPN     NNP     nsubj         False
# said           say            VERB      VBD     ROOT          False
# Finland        Finland        PROPN     NNP     nsubj         False
# things         thing          NOUN      NNS     dobj          False
# great          great          ADJ       JJ      acomp         False
# provide        provide        VERB      VB      conj          False
# happiness      happiness      NOUN      NN      dobj          False
# people         people         NOUN      NNS     pobj          False
# country        country        NOUN      NN      pobj          False
# Finland        Finland        PROPN     NNP     nsubj         False
# European       european       ADJ       JJ      amod          False
# countries      country        NOUN      NNS     pobj          False
# affected       affect         VERB      VBN     acl           False
# COVID-19       COVID-19       PROPN     NNP     pobj          False
# pandemic       pandemic       ADJ       JJ      amod          False
# experts        expert         NOUN      NNS     nsubj         False
# attribute      attribute      VERB      VBP     conj          False
# high           high           ADJ       JJ      amod          False
# level          level          NOUN      NN      pobj          False
# trust          trust          NOUN      NN      pobj          False
# government     government     NOUN      NN      pobj          False
# little         little         ADJ       JJ      amod          False
# resistance     resistance     NOUN      NN      conj          False
# complying      comply         VERB      VBG     pcomp         False
# restrictions   restriction    NOUN      NNS     pobj          False
# Trust          trust          NOUN      NN      nsubj         False
# government     government     NOUN      NN      pobj          False
# hand           hand           NOUN      NN      pobj          False
# stems          stem           VERB      VBZ     ROOT          False
# country        country        NOUN      NN      poss          False
# investment     investment     NOUN      NN      pobj          False
# citizens       citizen        NOUN      NNS     pobj          False
# public         public         ADJ       JJ      amod          False
# school         school         NOUN      NN      compound      False
# system         system         NOUN      NN      nsubj         False
# rarely         rarely         ADV       RB      advmod        False
# tests          test           VERB      VBZ     ROOT          False
# children       child          NOUN      NNS     dobj          False
# best           good           ADJ       JJS     pobj          False
# world          world          NOUN      NN      pobj          False
# Finland        Finland        PROPN     NNP     nsubj         False
# universal      universal      ADJ       JJ      amod          False
# health         health         NOUN      NN      compound      False
# care           care           NOUN      NN      compound      False
# system         system         NOUN      NN      dobj          False
# affordable     affordable     ADJ       JJ      amod          False
# childcare      childcare      NOUN      NN      pobj          False
# strong         strong         ADJ       JJ      amod          False
# support        support        NOUN      NN      conj          False
# parents        parent         NOUN      NNS     pobj          False
# Melissa        Melissa        PROPN     NNP     nsubj         False
# said           say            VERB      VBD     ROOT          False
# country        country        NOUN      NN      nsubj         False
# taking         take           VERB      VBG     ccomp         False
# care           care           NOUN      NN      dobj          False
# child          child          NOUN      NN      poss          False
# development    development    NOUN      NN      pobj          False
# system         system         NOUN      NN      nsubjpass     False
# set            set            VERB      VBN     ROOT          False
# having         have           VERB      VBG     pcomp         False
# son            son            NOUN      NN      dobj          False
# raising        raise          VERB      VBG     pcomp         False
# home           home           NOUN      NN      pobj          False
# sending        send           VERB      VBG     pcomp         False
# daycare        daycare        PROPN     NNP     pobj          False
# going          go             VERB      VBG     pcomp         False
# school         school         NOUN      NN      pobj          False
# supported      support        VERB      VBN     ROOT          False
# aspect         aspect         NOUN      NN      pobj          False
# Finland        Finland        PROPN     NNP     ROOT          False
# vs.            vs.            ADP       IN      prep          False
# China          China          PROPN     NNP     pobj          False
# country        country        NOUN      NN      nsubj         False
# strongest      strong         ADJ       JJS     amod          False
# sense          sense          NOUN      NN      dobj          False
# happiness      happiness      NOUN      NN      pobj          False
# publication    publication    NOUN      NN      pobj          False
# World          World          PROPN     NNP     compound      False
# Happiness      Happiness      PROPN     NNP     compound      False
# Report         Report         PROPN     NNP     pobj          False
# Nordic         nordic         ADJ       JJ      amod          False
# countries      country        NOUN      NNS     nsubj         False
# dominated      dominate       VERB      VBN     ROOT          False
# year           year           NOUN      NN      poss          False
# report         report         NOUN      NN      pobj          False
# Finland        Finland        PROPN     NNP     appos         False
# neighbors      neighbor       NOUN      NNS     conj          False
# Denmark        Denmark        PROPN     NNP     appos         False
# 2nd            2nd            ADJ       JJ      appos         False
# Iceland        Iceland        PROPN     NNP     appos         False
# 3rd            3rd            NOUN      NN      appos         False
# Sweden         Sweden         PROPN     NNP     conj          False
# 6th            6th            NOUN      NN      appos         False
# Norway         Norway         PROPN     NNP     conj          False
# 7th            7th            PROPN     NNP     appos         False
# scored         score          VERB      VBD     ROOT          False
# high           high           ADJ       JJ      advmod        False
# happiness      happiness      NOUN      NN      compound      False
# indicators     indicator      NOUN      NNS     pobj          False
# including      include        VERB      VBG     prep          False
# healthy        healthy        ADJ       JJ      amod          False
# life           life           NOUN      NN      compound      False
# expectancy     expectancy     NOUN      NN      pobj          False
# capita         capita         X         FW      pobj          False
# GDP            GDP            PROPN     NNP     appos         False
# low            low            ADJ       JJ      amod          False
# levels         level          NOUN      NNS     conj          False
# corruption     corruption     NOUN      NN      pobj          False
# social         social         ADJ       JJ      amod          False
# support        support        NOUN      NN      conj          False
# freedom        freedom        NOUN      NN      conj          False
# trust          trust          NOUN      NN      conj          False
# generosity     generosity     NOUN      NN      conj          False
# countries      country        NOUN      NNS     nmod          False
# regions        region         NOUN      NNS     nsubj         False
# include        include        VERB      VBP     ROOT          False
# Netherlands    Netherlands    PROPN     NNP     dobj          False
# 5th            5th            NOUN      NN      appos         False
# Switzerland    Switzerland    PROPN     NNP     appos         False
# 8th            8th            NOUN      NN      appos         False
# Luxembourg     Luxembourg     PROPN     NNP     conj          False
# 9th            9th            NOUN      NN      appos         False
# New            New            PROPN     NNP     compound      False
# Zealand        Zealand        PROPN     NNP     conj          False
# 10th           10th           PROPN     NNP     appos         False
# Australia      Australia      PROPN     NNP     nsubj         False
# ranked         rank           VERB      VBD     ROOT          False
# 12th           12th           NOUN      NN      dobj          False
# report         report         NOUN      NN      pobj          False
# followed       follow         VERB      VBN     advcl         False
# Canada         Canada         PROPN     NNP     pobj          False
# 13th           13th           PROPN     NNP     appos         False
# Ireland        Ireland        PROPN     NNP     appos         False
# 14th           14th           NUM       CD      appos         False
# United         United         PROPN     NNP     compound      False
# States         States         PROPN     NNP     conj          False
# 15th           15th           NOUN      NN      appos         False
# Asia           Asia           PROPN     NNP     pobj          False
# Singapore      Singapore      PROPN     NNP     nsubj         False
# ranked         rank           VERB      VBD     advcl         False
# 25th           25th           NOUN      NN      advmod        False
# world          world          NOUN      NN      pobj          False
# places         place          NOUN      NNS     npadvmod      False
# year           year           NOUN      NN      pobj          False
# Taiwan         Taiwan         PROPN     NNP     nsubj         False
# dropped        drop           VERB      VBD     ccomp         False
# place          place          NOUN      NN      dobj          False
# year           year           NOUN      NN      pobj          False
# 27th           27th           NOUN      NN      pobj          False
# Japan          Japan          PROPN     NNP     nsubj         False
# rose           rise           VERB      VBD     ROOT          False
# 47th           47th           ADJ       JJ      pobj          False
# mainland       mainland       NOUN      NN      compound      False
# China          China          PROPN     NNP     nsubj         False
# ranked         rank           VERB      VBD     conj          False
# 64th           64th           NOUN      NN      npadvmod      False
# Hong           Hong           PROPN     NNP     compound      False
# Kong           Kong           PROPN     NNP     nsubj         False
# ranked         rank           VERB      VBD     conj          False
# 82nd           82nd           NOUN      NN      dobj          False
# polling        polling        NOUN      NN      compound      False
# agency         agency         NOUN      NN      nsubj         False
# Ipsos          Ipsos          PROPN     NNP     compound      False
# Group          Group          PROPN     NNP     appos         False
# Ipsos          Ipsos          PROPN     NNP     appos         False
# released       release        VERB      VBD     ROOT          False
# survey         survey         NOUN      NN      compound      False
# report         report         NOUN      NN      dobj          False
# global         global         ADJ       JJ      amod          False
# happiness      happiness      NOUN      NN      compound      False
# index          index          NOUN      NN      pobj          False
# results        result         NOUN      NNS     nsubj         False
# showed         show           VERB      VBD     ROOT          False
# 32             32             NUM       CD      nummod        False
# countries      country        NOUN      NNS     pobj          False
# country        country        NOUN      NN      nsubj         False
# highest        high           ADJ       JJS     amod          False
# happiness      happiness      NOUN      NN      compound      False
# index          index          NOUN      NN      pobj          False
# China          China          PROPN     NNP     attr          False
# 91             91             NUM       CD      nummod        False
# followed       follow         VERB      VBN     acl           False
# Saudi          Saudi          PROPN     NNP     compound      False
# Arabia         Arabia         PROPN     NNP     pobj          False
# 86             86             NUM       CD      nummod        False
# Netherlands    Netherlands    PROPN     NNP     conj          False
# 85             85             NUM       CD      nummod        False
# India          India          PROPN     NNP     appos         False
# 84             84             NUM       CD      nummod        False
# Brazil         Brazil         PROPN     NNP     conj          False
# 83             83             NUM       CD      nummod        False
# Australia      Australia      PROPN     NNP     nsubj         False
# ranked         rank           VERB      VBD     ROOT          False
# 9th            9th            NOUN      NN      dobj          False
# report         report         NOUN      NN      pobj          False
# According      accord         VERB      VBG     prep          False
# survey         survey         NOUN      NN      compound      False
# report         report         NOUN      NN      pobj          False
# average        average        ADJ       JJ      amod          False
# happiness      happiness      NOUN      NN      nsubj         False
# increased      increase       VERB      VBD     ROOT          False
# significantly  significantly  ADV       RB      advmod        False
# middle         middle         ADJ       JJ      amod          False
# income         income         NOUN      NN      compound      False
# countries      country        NOUN      NNS     pobj          False
# defined        define         VERB      VBN     advcl         False
# World          World          PROPN     NNP     compound      False
# Bank           Bank           PROPN     NNP     pobj          False
# high           high           ADJ       JJ      amod          False
# income         income         NOUN      NN      compound      False
# countries      country        NOUN      NNS     pobj          False

# %% [markdown]
# ---

# %%
pipeline.get_noun_phrases_from_document(
    doc=doc,
    remove_special_characters=False,
    remove_stopwords=False,
)
# Out:
# ['Australian Melissa Georgiou',
#  'Melissa Georgiou',
#  'the coldest and darkest places',
#  'my favorite things',
#  'a residential area',
#  'the middle',
#  'the city',
#  'the beaches',
#  'the dark winters',
#  'cold lakes',
#  'the concept',
#  'the Australian concept',
#  'a popular local saying',
#  'The first thing',
#  'real estate',
#  'No one',
#  'what suburb',
#  'your kids',
#  'The Finns',
#  'the status quo',
#  "Melissa Georgio's Dark Night",
#  'Northern Europe Finland',
#  'the happiest country',
#  'the world',
#  'the sixth year',
#  'a row',
#  'the “World Happiness Report',
#  'the United Nations',
#  'The Nordic countries',
#  'good) unemployment benefits',
#  'other benefits',
#  'happiness expert',
#  'researcher Frank Martela',
#  'Frank Martela',
#  "Finland's position",
#  'the rankings',
#  'its own people',
#  'sad music',
#  'hard rock',
#  'the Finnish self-image',
#  'The other side',
#  'Finnish melancholy',
#  'a cultural focus',
#  'a concept',
#  'Finnish culture',
#  "Finns' favorite pastime",
#  'a sauna',
#  'a bath',
#  'freezing temperatures',
#  'this paradox',
#  'one extreme',
#  'a pretty fun experience',
#  'many things',
#  'this country',
#  'the European countries',
#  'the COVID-19',
#  'a high level',
#  'the government',
#  'little resistance',
#  'the other hand',
#  "a country's investment",
#  'its citizens',
#  'The public school system',
#  'the world',
#  'a universal health care system',
#  'affordable childcare',
#  'strong support',
#  'The whole country',
#  "the child's development",
#  'This system',
#  'my son',
#  'every aspect',
#  'which country',
#  'the strongest sense',
#  'the publication',
#  'the World Happiness Report',
#  'the Nordic countries',
#  "this year's report",
#  'its neighbors',
#  'happiness indicators',
#  'healthy life expectancy',
#  'per capita GDP',
#  'low levels',
#  'social support',
#  'Other top ten countries/regions',
#  'the Netherlands',
#  'New Zealand',
#  'this report',
#  'the United States',
#  'the world',
#  'last year',
#  'one place',
#  'last year',
#  'mainland China',
#  'Hong Kong',
#  'the polling agency',
#  'Ipsos Group',
#  'a survey report',
#  'the global happiness index',
#  'The results',
#  '32 countries',
#  'the country',
#  'the highest happiness index',
#  'Saudi Arabia',
#  'the Netherlands',
#  'this report',
#  'the survey report',
#  'middle-income countries',
#  'the World Bank',
#  'high-income countries']

# %% [markdown]
# # Noun Phrase Entities
#
# Find a phrase that includes an identified named entity.

# %%
print(json.dumps(
    pipeline.get_named_entities_from_text(
        text=text, 
        excludes=["ORDINAL", "CARDINAL", "PERCENT", "DATE", "time", "QUANTITY", "MONEY"],
        remove_special_characters=True,
        return_value_only=True,
        remove_similarity_threshold=0.9,
        include_noun_phrases=True,
        include_keywords=False
    ), 
    indent=4, 
    default=str
))
# Out:
# {
#     "EVENT": [],
#     "FAC": [],
#     "GPE": [
#         "Sweden",
#         "United States",
#         "Sydney",
#         "Taiwan",
#         "Iceland",
#         "Luxembourg",
#         "Australia",
#         "Denmark",
#         "Switzerland",
#         "India",
#         "Hong Kong",
#         "Finland",
#         "Saudi Arabia",
#         "China",
#         "Nordic",
#         "Netherlands",
#         "Japan",
#         "New Zealand",
#         "Canada",
#         "Norway",
#         "Singapore",
#         "Ireland",
#         "Brazil",
#         "Northern Europe Finland"
#     ],
#     "LANGUAGE": [],
#     "LAW": [],
#     "LOC": [
#         "Northern Europe Finland",
#         "Earth",
#         "Asia"
#     ],
#     "NORP": [
#         "Australian",
#         "Finns",
#         "European",
#         "Finnish",
#         "Ipsos"
#     ],
#     "ORG": [
#         "Ipsos Group",
#         "COVID19",
#         "World Happiness Report",
#         "United Nations",
#         "World Bank",
#         "the United Nations"
#     ],
#     "PERSON": [
#         "Frank Martela",
#         "Melissa Georgiou",
#         "Frank",
#         "Melissa",
#         "Australian Melissa Georgiou"
#     ],
#     "PRODUCT": [],
#     "WORK_OF_ART": [
#         "World Happiness Report",
#         "Dark Night"
#     ]
# }

# %% [markdown]
# ---
# # Keyword Extraction
#
# * [textacy - Information Extraction](https://textacy.readthedocs.io/en/latest/api_reference/extract.html)

# %%
print(json.dumps(
    pipeline.get_named_entities_from_text(
        text=text, 
        excludes=["ORDINAL", "CARDINAL", "PERCENT", "DATE", "time", "QUANTITY", "MONEY"],
        remove_special_characters=True,
        return_value_only=True,
        remove_similarity_threshold=0.9,
        include_noun_phrases=False,
        include_keywords=True
    ), 
    indent=4, 
    default=str
))
# Out:
# {
#     "EVENT": [],
#     "FAC": [],
#     "GPE": [
#         "Sweden",
#         "United States",
#         "Sydney",
#         "Taiwan",
#         "Iceland",
#         "Luxembourg",
#         "Australia",
#         "Denmark",
#         "Switzerland",
#         "India",
#         "Hong Kong",
#         "Finland",
#         "Saudi Arabia",
#         "China",
#         "Nordic",
#         "Netherlands",
#         "Japan",
#         "New Zealand",
#         "Canada",
#         "Norway",
#         "Singapore",
#         "Ireland",
#         "Brazil"
#     ],
#     "LANGUAGE": [],
#     "LAW": [],
#     "LOC": [
#         "Northern Europe Finland",
#         "Earth",
#         "Asia"
#     ],
#     "NORP": [
#         "Australian",
#         "Finns",
#         "European",
#         "Finnish",
#         "Ipsos"
#     ],
#     "ORG": [
#         "Ipsos Group",
#         "COVID19",
#         "World Happiness Report",
#         "United Nations",
#         "World Bank"
#     ],
#     "PERSON": [
#         "Frank Martela",
#         "Melissa Georgiou",
#         "Frank",
#         "Melissa"
#     ],
#     "PRODUCT": [],
#     "WORK_OF_ART": [
#         "World Happiness Report",
#         "Dark Night"
#     ],
#     "KEYWORDS": [
#         "high happiness index",
#         "global happiness index",
#         "happiness expert",
#         "happy country",
#         "happiness indicator",
#         "Northern Europe Finland",
#         "nordic country",
#         "european country",
#         "income country",
#         "australian Melissa Georgiou"
#     ]
# }

# %% [markdown]
# ---
# # Synonyms

# %%
del pipeline, doc

from nltk.corpus import (
    wordnet
)

# %%
def get_synonyms(text: str, pos=None):
    """Get synonym of the POS type. 
    
    "speed" can be verb and noun. To get the synonyms for verb, set pos='v'
    
    Args:
        text: text to find the synonyms
        pos: part of speech tag (n=noun, v=verb, a=adjective, r=adverb)
    Returns: set of synonyms
    """
    text = "_".join(text.split())
    synonyms = wordnet.synsets(text, pos=pos)
    lemmas = set(chain.from_iterable([word.lemma_names() for word in synonyms]))
    return lemmas - {text}

# %%
get_synonyms(text="speed", pos="v")
# Out:
# {'accelerate',
#  'belt_along',
#  'bucket_along',
#  'cannonball_along',
#  'hasten',
#  'hie',
#  'hotfoot',
#  'hurry',
#  'pelt_along',
#  'quicken',
#  'race',
#  'rush',
#  'rush_along',
#  'speed_up',
#  'step_on_it',
#  'travel_rapidly',
#  'zip'}

# %% [markdown]
# ## Conversion
#
# happy -> hapiness
# speedy -> speed

# %%
# Just to make it a bit more readable
WN_NOUN = 'n'
WN_VERB = 'v'
WN_ADJECTIVE = 'a'
WN_ADJECTIVE_SATELLITE = 's'
WN_ADVERB = 'r'


def convert(word, from_pos, to_pos):    
    """ Transform words given from/to POS tags """
    synsets = wordnet.synsets(word, pos=from_pos)

    # Word not found
    if not synsets:
        return []

    # Get all lemmas of the word (consider 'a'and 's' equivalent)
    lemmas = []
    for s in synsets:
        for l in s.lemmas():
            if s.name().split('.')[1] == from_pos or from_pos in (WN_ADJECTIVE, WN_ADJECTIVE_SATELLITE) and s.name().split('.')[1] in (WN_ADJECTIVE, WN_ADJECTIVE_SATELLITE):
                lemmas += [l]

    # Get related forms
    derivationally_related_forms = [(l, l.derivationally_related_forms()) for l in lemmas]

    # filter only the desired pos (consider 'a' and 's' equivalent)
    related_noun_lemmas = []

    for drf in derivationally_related_forms:
        for l in drf[1]:
            if l.synset().name().split('.')[1] == to_pos or to_pos in (WN_ADJECTIVE, WN_ADJECTIVE_SATELLITE) and l.synset().name().split('.')[1] in (WN_ADJECTIVE, WN_ADJECTIVE_SATELLITE):
                related_noun_lemmas += [l]

    # Extract the words from the lemmas
    words = [l.name() for l in related_noun_lemmas]
    len_words = len(words)

    # Build the result in the form of a list containing tuples (word, probability)
    result = [(w, float(words.count(w)) / len_words) for w in set(words)]
    result.sort(key=lambda w:-w[1])

    # return all the possibilities sorted by probability
    return result

# %%
convert("happy", "a", "n")
# Out:
# [('happiness', 0.6), ('felicity', 0.2), ('felicitousness', 0.2)]

# %%
convert("happy", "a", "r")
# Out:
# []

# %%
convert("speedy", "a", "n")
# Out:
# [('speed', 0.375),
#  ('speediness', 0.25),
#  ('quickness', 0.125),
#  ('rapidity', 0.125),
#  ('rapidness', 0.125)]

# %%
convert("speedy", "a", "r")
# Out:
# []
