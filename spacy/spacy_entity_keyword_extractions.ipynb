# %% [markdown]
# # Setup
#
# ## Spacy
# * [spacy.cli.download()](https://github.com/explosion/spaCy/blob/master/spacy/cli/download.py)
#
# ```
# def download(
#     model: str,
#     direct: bool = False,
#     sdist: bool = False,
#     *pip_args,  # --target to specify the download directory
# )
# ```
#
# Internally, it is invokiing ```pip install``` in a command line.
#
# ```
# def download_model(
#     filename: str, user_pip_args: Optional[Sequence[str]] = None
# ) -> None:
#     download_url = about.__download_url__ + "/" + filename
#     pip_args = list(user_pip_args) if user_pip_args is not None else []
#     cmd = [sys.executable, "-m", "pip", "install"] + pip_args + [download_url]
#     run_command(cmd)
# ```
#
# ## NLTK
#
# * [nltk.download()](https://www.nltk.org/api/nltk.downloader.html#nltk.downloader.Downloader.download)
#
# ```
# def download(
#     info_or_id=None,
#     download_dir=None,
#     quiet=False,
#     force=False,
#     prefix="[nltk_data] ",
#     halt_on_error=True,
#     raise_on_error=False,
#     print_error_to=sys.stderr,
# )
# ```

# %%
# %%html
# <style>
# table {float:left}
# </style>
# Out:
# <style>
# table {float:left}
# </style>

# %%
# !pip install spacy textacy nltk --quiet
# Out:
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import sys
import re
import json
import pathlib
from itertools import chain

import spacy
from spacy import displacy
from spacy.cli import download
import textacy
import nltk

# %%
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/oonisim/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/oonisim/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# # PYTHONPATH

# %%
PATH_TO_LIB: str = str(pathlib.Path("../lib").resolve())
if PATH_TO_LIB not in sys.path:
    sys.path.insert(0, PATH_TO_LIB)

# %%
# %load_ext autoreload
# %autoreload 2

from util_spacy import (
    Pipeline
)

# %% [markdown]
# # Constant

# %%
LANGUAGE: str = "english"
SPACY_MODEL_NAME: str = "en_core_web_sm"

# %% [markdown]
# # Language Pipeline

# %%
pipeline: Pipeline = Pipeline(model_name=SPACY_MODEL_NAME)
nlp = pipeline.model

# %%
# text = "Australian Melissa Georgiou (Melissa Georgiou) moved to Finland over a decade ago to seek happiness in one of the coldest and darkest places on Earth. “One of my favorite things about living here is that it's easy to get close to nature whether you're in a residential area or in the middle of the city,” Melissa said. Originally a teacher, 12 years ago, she switched from the beaches of Sydney to the dark winters and cold lakes of Finland, and has never looked back since. Melissa said, “For Finns, the concept of happiness is very different from the Australian concept of happiness. Finns, she said, are happy to accept portrayals of themselves as melancholy and stubborn — a popular local saying is, “People who have happiness must hide it.” “The first thing I noticed here is that you don't go to dinners or barbecues, and you don't talk about real estate. No one asks you where you live, what suburb do you live in, where your kids go to school.” The Finns seem quite happy with the status quo, and they don't always seem to want more. Melissa Georgio's Dark Night in Northern Europe Finland was named the happiest country in the world for the sixth year in a row in the “World Happiness Report” released by the United Nations. “The Nordic countries are often countries with (good) unemployment benefits, pensions, and other benefits,” explains happiness expert and researcher Frank Martela (Frank Martela). However, Frank said that Finland's position in the rankings often surprised its own people. “Finns, they're almost outraged because they don't think this can be true. We listen to sad music and hard rock.” “Therefore, happiness is not part of the Finnish self-image.” The other side of Finnish melancholy is a cultural focus on perseverance. Frank said it redefines the way Finns view happiness — a concept known as “sisu” — which is part of Finnish culture and is hard to translate directly, but can be understood as will, determination, perseverance, and reason to face adversity. This, he said, is best reflected in Finns' favorite pastime — getting warm in a sauna after taking a bath in freezing temperatures. “It's about this paradox — from one extreme to the other, and it's a pretty fun experience... because you need perseverance.” Melissa said, but Finland has many things that are great and can provide happiness for people in this country. Finland is one of the European countries least affected by the COVID-19 pandemic, and experts attribute this to a high level of trust in the government and little resistance to complying with restrictions. Trust in government, on the other hand, stems from a country's investment in its citizens. The public school system rarely tests children and is one of the best in the world. Finland also has a universal health care system with affordable childcare and strong support for parents. Melissa said, “The whole country is taking care of the child's development. This system is very well set up. So from having my son to raising him at home, to sending him to daycare, to going to school, I was very well supported in every aspect of this.” Finland vs. China, which country has the strongest sense of happiness? Since the publication of the World Happiness Report, the Nordic countries have dominated the top ten. In this year's report, Finland and its neighbors Denmark (2nd), Iceland (3rd), Sweden (6th), and Norway (7th) all scored high on happiness indicators, including healthy life expectancy, per capita GDP, low levels of corruption, social support, freedom, trust, and generosity. Other top ten countries/regions include the Netherlands (5th), Switzerland (8th), Luxembourg (9th), and New Zealand (10th). Australia ranked 12th in this report, followed by Canada (13th), Ireland (14th), and the United States (15th). In Asia, Singapore ranked 25th in the world, up two places from last year, Taiwan dropped one place from last year to 27th, Japan rose to 47th, mainland China ranked 64th, and Hong Kong ranked 82nd. Meanwhile, the polling agency Ipsos Group (Ipsos) released a survey report on the global happiness index. The results showed that out of 32 countries, the country with the highest happiness index was China (91%), followed by Saudi Arabia (86%), the Netherlands (85%), India (84%), and Brazil (83%). Australia ranked 9th in this report. According to the survey report, on average, happiness increased more significantly in middle-income countries (as defined by the World Bank) than in high-income countries."
text = """
Millions of Turks are headed to the polls Sunday in what is set to be Turkey’s most consequential election in two decades, and one whose results will have implications far beyond its own borders.

The country of 85 million holds both its presidential and parliamentary elections on May 14. For the presidency — which is expected to be close — if no candidate wins more than 50%, the vote goes to a run-off two weeks later.

Incumbent President Recep Tayyip Erdogan is facing his toughest test yet after two decades in power, grappling with public anger over worsening economic conditions and the slow government response to a series of devastating earthquakes in February that killed more than 50,000 people.

His primary opponent, 74-year-old Kemal Kilicdaroglu of the center-left Republican People’s Party (CHP), is running as a unity candidate representing six different parties that all want to see Erdogan out of power.  

In a possibly game-changing development, one of the four presidential candidates, Muharrem Ince, pulled out of the race Thursday. A former CHP member, he had been under heavy criticism for splitting the opposition vote in a way that would hurt Kilicdaroglu’s chances.

Now, with Ince out of the race, his votes may go to Erdogan’s top challenger Kilicdaroglu, helping him tremendously and spelling more trouble for the 69-year-old Erdogan.

Another crucial factor will be turnout: More than 5 million young Turks will be voting for the first time, and the greater the youth turnout, the better for the challenger candidate and the worse for the incumbent, election analysts say.

With such a high-stakes contest, many inside and out of the country are asking whether Erdogan may dispute the result if he does not win.

“The most likely tactics that he’s going to use to try to tip the vote will be to use influence in the electoral board (the YSK), courts, and media to build a narrative that either elections should be re-run or that they are illegitimate,” said Ryan Bohl, a senior Middle East and North Africa analyst at Rane. Erdogan did this in 2019 when his party narrowly lost the Istanbul mayoral race, only to lose again by a greater margin after demanding a re-run.

Some even fear violence and instability if the result is disputed, which would bring more volatility to Turkey’s already damaged economy. Turkish and foreign analysts and rights activists have for years been sounding the alarm over increasingly autocratic governance coming from Erdogan’s administration.

CNBC has reached out to the Turkish Presidency’s office for comment.

‘So much at stake’
The election’s outcome and its impact on stability in the country, which sits as a crossroads between Europe and Asia and is home to NATO’s second-largest military, is of paramount importance both domestically and internationally.

“There is so much at stake for President Erdogan and his AKP (Justice and Development Party) for the first time, as his 20-year rule over Türkiye may come to an end given the unified opposition has managed to maintain a strong alliance and stay on a hope-building positive campaign,” said Hakan Akbas, managing director of consulting firm Strategic Advisory Services based between Istanbul and Washington.

This is similar, he noted, to “what Istanbul Mayor Emrak Imamoglu did to win twice against Erdogan’s AKP candidate in the mayoral election in 2019.”

Imamoglu, a popular figure who was widely expected to run for the presidency as a formidable opponent to Erdogan, was in December sentenced to nearly three years in prison and barred from politics for what a court described as insulting the judges of the Supreme Election Council (YSK). Imamoglu and his supporters say the charges are purely political and were influenced by Erdogan and his party to sabotage his political ambitions. 
"""

# %%
text = re.sub(r'[\s"“]+', ' ', text).strip()
text
# Out:
# 'Millions of Turks are headed to the polls Sunday in what is set to be Turkey’s most consequential election in two decades, and one whose results will have implications far beyond its own borders. The country of 85 million holds both its presidential and parliamentary elections on May 14. For the presidency — which is expected to be close — if no candidate wins more than 50%, the vote goes to a run-off two weeks later. Incumbent President Recep Tayyip Erdogan is facing his toughest test yet after two decades in power, grappling with public anger over worsening economic conditions and the slow government response to a series of devastating earthquakes in February that killed more than 50,000 people. His primary opponent, 74-year-old Kemal Kilicdaroglu of the center-left Republican People’s Party (CHP), is running as a unity candidate representing six different parties that all want to see Erdogan out of power. In a possibly game-changing development, one of the four presidential candidates, Muharrem Ince, pulled out of the race Thursday. A former CHP member, he had been under heavy criticism for splitting the opposition vote in a way that would hurt Kilicdaroglu’s chances. Now, with Ince out of the race, his votes may go to Erdogan’s top challenger Kilicdaroglu, helping him tremendously and spelling more trouble for the 69-year-old Erdogan. Another crucial factor will be turnout: More than 5 million young Turks will be voting for the first time, and the greater the youth turnout, the better for the challenger candidate and the worse for the incumbent, election analysts say. With such a high-stakes contest, many inside and out of the country are asking whether Erdogan may dispute the result if he does not win. The most likely tactics that he’s going to use to try to tip the vote will be to use influence in the electoral board (the YSK), courts, and media to build a narrative that either elections should be re-run or that they are illegitimate,” said Ryan Bohl, a senior Middle East and North Africa analyst at Rane. Erdogan did this in 2019 when his party narrowly lost the Istanbul mayoral race, only to lose again by a greater margin after demanding a re-run. Some even fear violence and instability if the result is disputed, which would bring more volatility to Turkey’s already damaged economy. Turkish and foreign analysts and rights activists have for years been sounding the alarm over increasingly autocratic governance coming from Erdogan’s administration. CNBC has reached out to the Turkish Presidency’s office for comment. ‘So much at stake’ The election’s outcome and its impact on stability in the country, which sits as a crossroads between Europe and Asia and is home to NATO’s second-largest military, is of paramount importance both domestically and internationally. There is so much at stake for President Erdogan and his AKP (Justice and Development Party) for the first time, as his 20-year rule over Türkiye may come to an end given the unified opposition has managed to maintain a strong alliance and stay on a hope-building positive campaign,” said Hakan Akbas, managing director of consulting firm Strategic Advisory Services based between Istanbul and Washington. This is similar, he noted, to what Istanbul Mayor Emrak Imamoglu did to win twice against Erdogan’s AKP candidate in the mayoral election in 2019.” Imamoglu, a popular figure who was widely expected to run for the presidency as a formidable opponent to Erdogan, was in December sentenced to nearly three years in prison and barred from politics for what a court described as insulting the judges of the Supreme Election Council (YSK). Imamoglu and his supporters say the charges are purely political and were influenced by Erdogan and his party to sabotage his political ambitions.'

# %% [markdown]
# # Process Document
#
# Put the text through the pretrained language pipeline.

# %%
doc = pipeline.process(text=text)

# %% [markdown]
# # Dependencies

# %%
print("{}{}{}{}{}".format(
    "Token".ljust(15), "start".ljust(7), "POS".ljust(10), "Tag".ljust(8), "Dependency".ljust(14), "Head"
))
print("-" * 80)
for token in doc:
    print(f"{token.text:15}{token.idx:<7}{token.pos_:10}{token.tag_:8}{token.dep_:14}{token.head.text}")
# Out:
# Token          start  POS       Tag     Dependency
# --------------------------------------------------------------------------------
# Millions       0      NOUN      NNS     nsubjpass     headed
# of             9      ADP       IN      prep          Millions
# Turks          12     PROPN     NNPS    pobj          of
# are            18     AUX       VBP     auxpass       headed
# headed         22     VERB      VBN     ROOT          headed
# to             29     ADP       IN      prep          headed
# the            32     DET       DT      det           polls
# polls          36     NOUN      NNS     pobj          to
# Sunday         42     PROPN     NNP     npadvmod      headed
# in             49     ADP       IN      prep          headed
# what           52     PRON      WP      nsubjpass     set
# is             57     AUX       VBZ     auxpass       set
# set            60     VERB      VBN     pcomp         in
# to             64     PART      TO      aux           be
# be             67     AUX       VB      xcomp         set
# Turkey         70     PROPN     NNP     poss          election
# ’s             76     PART      POS     case          Turkey
# most           79     ADV       RBS     advmod        consequential
# consequential  84     ADJ       JJ      amod          election
# election       98     NOUN      NN      attr          be
# in             107    ADP       IN      prep          election
# two            110    NUM       CD      nummod        decades
# decades        114    NOUN      NNS     pobj          in
# ,              121    PUNCT     ,       punct         headed
# and            123    CCONJ     CC      cc            headed
# one            127    NUM       CD      conj          headed
# whose          131    DET       WP$     poss          results
# results        137    NOUN      NNS     nsubj         have
# will           145    AUX       MD      aux           have
# have           150    VERB      VB      relcl         one
# implications   155    NOUN      NNS     dobj          have
# far            168    ADV       RB      advmod        beyond
# beyond         172    ADP       IN      prep          implications
# its            179    PRON      PRP$    poss          borders
# own            183    ADJ       JJ      amod          borders
# borders        187    NOUN      NNS     pobj          beyond
# .              194    PUNCT     .       punct         headed
# The            196    DET       DT      det           country
# country        200    NOUN      NN      nsubj         holds
# of             208    ADP       IN      prep          country
# 85             211    NUM       CD      compound      million
# million        214    NUM       CD      pobj          of
# holds          222    VERB      VBZ     ROOT          holds
# both           228    CCONJ     CC      preconj       elections
# its            233    PRON      PRP$    poss          elections
# presidential   237    ADJ       JJ      amod          elections
# and            250    CCONJ     CC      cc            presidential
# parliamentary  254    ADJ       JJ      conj          presidential
# elections      268    NOUN      NNS     dobj          holds
# on             278    ADP       IN      prep          holds
# May            281    PROPN     NNP     pobj          on
# 14             285    NUM       CD      nummod        May
# .              287    PUNCT     .       punct         holds
# For            289    ADP       IN      prep          expected
# the            293    DET       DT      det           presidency
# presidency     297    NOUN      NN      pobj          For
# —              308    PUNCT     :       punct         expected
# which          310    PRON      WDT     nsubjpass     expected
# is             316    AUX       VBZ     auxpass       expected
# expected       319    VERB      VBN     advcl         goes
# to             328    PART      TO      aux           be
# be             331    AUX       VB      xcomp         expected
# close          334    ADJ       JJ      acomp         be
# —              340    PUNCT     :       punct         be
# if             342    SCONJ     IN      mark          wins
# no             345    DET       DT      det           candidate
# candidate      348    NOUN      NN      nsubj         wins
# wins           358    VERB      VBZ     advcl         goes
# more           363    ADJ       JJR     amod          50
# than           368    ADP       IN      quantmod      50
# 50             373    NUM       CD      nummod        %
# %              375    NOUN      NN      dobj          wins
# ,              376    PUNCT     ,       punct         goes
# the            378    DET       DT      det           vote
# vote           382    NOUN      NN      nsubj         goes
# goes           387    VERB      VBZ     ROOT          goes
# to             392    ADP       IN      prep          goes
# a              395    DET       DT      det           weeks
# run            397    VERB      VB      amod          weeks
# -              400    PUNCT     HYPH    punct         run
# off            401    ADP       RP      prt           run
# two            405    NUM       CD      nummod        weeks
# weeks          409    NOUN      NNS     npadvmod      later
# later          415    ADV       RB      advmod        goes
# .              420    PUNCT     .       punct         goes
# Incumbent      422    ADJ       JJ      amod          President
# President      432    PROPN     NNP     compound      Erdogan
# Recep          442    PROPN     NNP     compound      Erdogan
# Tayyip         448    PROPN     NNP     compound      Erdogan
# Erdogan        455    PROPN     NNP     nsubj         facing
# is             463    AUX       VBZ     aux           facing
# facing         466    VERB      VBG     ROOT          facing
# his            473    PRON      PRP$    poss          test
# toughest       477    ADJ       JJS     amod          test
# test           486    NOUN      NN      dobj          facing
# yet            491    ADV       RB      advmod        facing
# after          495    ADP       IN      prep          facing
# two            501    NUM       CD      nummod        decades
# decades        505    NOUN      NNS     pobj          after
# in             513    ADP       IN      prep          decades
# power          516    NOUN      NN      pobj          in
# ,              521    PUNCT     ,       punct         facing
# grappling      523    VERB      VBG     advcl         facing
# with           533    ADP       IN      prep          grappling
# public         538    ADJ       JJ      amod          anger
# anger          545    NOUN      NN      pobj          with
# over           551    ADP       IN      prep          anger
# worsening      556    VERB      VBG     pcomp         over
# economic       566    ADJ       JJ      amod          conditions
# conditions     575    NOUN      NNS     dobj          worsening
# and            586    CCONJ     CC      cc            anger
# the            590    DET       DT      det           response
# slow           594    ADJ       JJ      amod          response
# government     599    NOUN      NN      compound      response
# response       610    NOUN      NN      dobj          grappling
# to             619    ADP       IN      prep          response
# a              622    DET       DT      det           series
# series         624    NOUN      NN      pobj          to
# of             631    ADP       IN      prep          series
# devastating    634    ADJ       JJ      amod          earthquakes
# earthquakes    646    NOUN      NNS     pobj          of
# in             658    ADP       IN      prep          series
# February       661    PROPN     NNP     pobj          in
# that           670    PRON      WDT     nsubj         killed
# killed         675    VERB      VBD     relcl         series
# more           682    ADJ       JJR     amod          50,000
# than           687    ADP       IN      quantmod      50,000
# 50,000         692    NUM       CD      nummod        people
# people         699    NOUN      NNS     dobj          killed
# .              705    PUNCT     .       punct         facing
# His            707    PRON      PRP$    poss          opponent
# primary        711    ADJ       JJ      amod          opponent
# opponent       719    NOUN      NN      nsubj         running
# ,              727    PUNCT     ,       punct         opponent
# 74             729    NUM       CD      nummod        year
# -              731    PUNCT     HYPH    punct         year
# year           732    NOUN      NN      npadvmod      old
# -              736    PUNCT     HYPH    punct         old
# old            737    ADJ       JJ      amod          Kilicdaroglu
# Kemal          741    PROPN     NNP     compound      Kilicdaroglu
# Kilicdaroglu   747    PROPN     NNP     appos         opponent
# of             760    ADP       IN      prep          Kilicdaroglu
# the            763    DET       DT      det           Party
# center         767    NOUN      NN      npadvmod      left
# -              773    PUNCT     HYPH    punct         left
# left           774    VERB      VBN     amod          Party
# Republican     779    PROPN     NNP     compound      People
# People         790    PROPN     NNPS    poss          Party
# ’s             796    PART      POS     case          People
# Party          799    PROPN     NNP     pobj          of
# (              805    PUNCT     -LRB-   punct         Party
# CHP            806    PROPN     NNP     appos         Party
# )              809    PUNCT     -RRB-   punct         Party
# ,              810    PUNCT     ,       punct         opponent
# is             812    AUX       VBZ     aux           running
# running        815    VERB      VBG     ROOT          running
# as             823    ADP       IN      prep          running
# a              826    DET       DT      det           candidate
# unity          828    NOUN      NN      compound      candidate
# candidate      834    NOUN      NN      pobj          as
# representing   844    VERB      VBG     acl           candidate
# six            857    NUM       CD      nummod        parties
# different      861    ADJ       JJ      amod          parties
# parties        871    NOUN      NNS     dobj          representing
# that           879    PRON      WDT     nsubj         want
# all            884    PRON      DT      nsubj         want
# want           888    VERB      VBP     relcl         parties
# to             893    PART      TO      aux           see
# see            896    VERB      VB      xcomp         want
# Erdogan        900    PROPN     NNP     dobj          see
# out            908    ADP       IN      prep          see
# of             912    ADP       IN      prep          out
# power          915    NOUN      NN      pobj          of
# .              920    PUNCT     .       punct         running
# In             922    ADP       IN      prep          pulled
# a              925    DET       DT      det           development
# possibly       927    ADV       RB      advmod        changing
# game           936    NOUN      NN      npadvmod      changing
# -              940    PUNCT     HYPH    punct         changing
# changing       941    VERB      VBG     amod          development
# development    950    NOUN      NN      pobj          In
# ,              961    PUNCT     ,       punct         pulled
# one            963    NUM       CD      nsubj         pulled
# of             967    ADP       IN      prep          one
# the            970    DET       DT      det           candidates
# four           974    NUM       CD      nummod        candidates
# presidential   979    ADJ       JJ      amod          candidates
# candidates     992    NOUN      NNS     pobj          of
# ,              1002   PUNCT     ,       punct         one
# Muharrem       1004   PROPN     NNP     compound      Ince
# Ince           1013   PROPN     NNP     appos         one
# ,              1017   PUNCT     ,       punct         one
# pulled         1019   VERB      VBD     ROOT          pulled
# out            1026   ADP       IN      prep          pulled
# of             1030   ADP       IN      prep          out
# the            1033   DET       DT      det           race
# race           1037   NOUN      NN      pobj          of
# Thursday       1042   PROPN     NNP     npadvmod      pulled
# .              1050   PUNCT     .       punct         pulled
# A              1052   DET       DT      det           member
# former         1054   ADJ       JJ      amod          member
# CHP            1061   PROPN     NNP     compound      member
# member         1065   NOUN      NN      advcl         been
# ,              1071   PUNCT     ,       punct         been
# he             1073   PRON      PRP     nsubj         been
# had            1076   AUX       VBD     aux           been
# been           1080   AUX       VBN     ROOT          been
# under          1085   ADP       IN      prep          been
# heavy          1091   ADJ       JJ      amod          criticism
# criticism      1097   NOUN      NN      pobj          under
# for            1107   ADP       IN      prep          criticism
# splitting      1111   VERB      VBG     pcomp         for
# the            1121   DET       DT      det           vote
# opposition     1125   NOUN      NN      compound      vote
# vote           1136   NOUN      NN      dobj          splitting
# in             1141   ADP       IN      prep          splitting
# a              1144   DET       DT      det           way
# way            1146   NOUN      NN      pobj          in
# that           1150   PRON      WDT     nsubj         hurt
# would          1155   AUX       MD      aux           hurt
# hurt           1161   VERB      VB      relcl         way
# Kilicdaroglu   1166   PROPN     NNP     poss          chances
# ’s             1178   PART      POS     case          Kilicdaroglu
# chances        1181   NOUN      NNS     dobj          hurt
# .              1188   PUNCT     .       punct         been
# Now            1190   ADV       RB      advmod        go
# ,              1193   PUNCT     ,       punct         go
# with           1195   ADP       IN      prep          go
# Ince           1200   PROPN     NNP     pobj          with
# out            1205   ADP       IN      prep          Ince
# of             1209   ADP       IN      prep          out
# the            1212   DET       DT      det           race
# race           1216   NOUN      NN      pobj          of
# ,              1220   PUNCT     ,       punct         go
# his            1222   PRON      PRP$    poss          votes
# votes          1226   NOUN      NNS     nsubj         go
# may            1232   AUX       MD      aux           go
# go             1236   VERB      VB      ROOT          go
# to             1239   ADP       IN      prep          go
# Erdogan        1242   PROPN     NNP     poss          Kilicdaroglu
# ’s             1249   PART      POS     case          Erdogan
# top            1252   ADJ       JJ      amod          challenger
# challenger     1256   NOUN      NN      compound      Kilicdaroglu
# Kilicdaroglu   1267   PROPN     NNP     pobj          to
# ,              1279   PUNCT     ,       punct         go
# helping        1281   VERB      VBG     advcl         go
# him            1289   PRON      PRP     dobj          helping
# tremendously   1293   ADV       RB      advmod        helping
# and            1306   CCONJ     CC      cc            helping
# spelling       1310   VERB      VBG     conj          helping
# more           1319   ADJ       JJR     amod          trouble
# trouble        1324   NOUN      NN      dobj          spelling
# for            1332   ADP       IN      prep          trouble
# the            1336   DET       DT      det           Erdogan
# 69             1340   NUM       CD      nummod        year
# -              1342   PUNCT     HYPH    punct         year
# year           1343   NOUN      NN      npadvmod      old
# -              1347   PUNCT     HYPH    punct         old
# old            1348   ADJ       JJ      amod          Erdogan
# Erdogan        1352   PROPN     NNP     pobj          for
# .              1359   PUNCT     .       punct         go
# Another        1361   DET       DT      det           factor
# crucial        1369   ADJ       JJ      amod          factor
# factor         1377   NOUN      NN      nsubj         be
# will           1384   AUX       MD      aux           be
# be             1389   AUX       VB      ccomp         voting
# turnout        1392   ADJ       JJ      acomp         be
# :              1399   PUNCT     :       punct         voting
# More           1401   ADJ       JJR     amod          million
# than           1406   ADP       IN      quantmod      million
# 5              1411   NUM       CD      compound      million
# million        1413   NUM       CD      nummod        Turks
# young          1421   ADJ       JJ      amod          Turks
# Turks          1427   PROPN     NNPS    nsubj         voting
# will           1433   AUX       MD      aux           voting
# be             1438   AUX       VB      aux           voting
# voting         1441   VERB      VBG     ccomp         say
# for            1448   ADP       IN      prep          voting
# the            1452   DET       DT      det           time
# first          1456   ADJ       JJ      amod          time
# time           1462   NOUN      NN      pobj          for
# ,              1466   PUNCT     ,       punct         voting
# and            1468   CCONJ     CC      cc            voting
# the            1472   DET       DT      det           turnout
# greater        1476   ADJ       JJR     amod          turnout
# the            1484   DET       DT      det           turnout
# youth          1488   NOUN      NN      compound      turnout
# turnout        1494   NOUN      NN      conj          voting
# ,              1501   PUNCT     ,       punct         turnout
# the            1503   PRON      DT      advmod        better
# better         1507   ADJ       JJR     appos         turnout
# for            1514   ADP       IN      prep          better
# the            1518   DET       DT      det           candidate
# challenger     1522   NOUN      NN      compound      candidate
# candidate      1533   NOUN      NN      pobj          for
# and            1543   CCONJ     CC      cc            candidate
# the            1547   DET       DT      det           worse
# worse          1551   ADJ       JJR     conj          candidate
# for            1557   ADP       IN      prep          worse
# the            1561   DET       DT      det           incumbent
# incumbent      1565   NOUN      NN      pobj          for
# ,              1574   PUNCT     ,       punct         say
# election       1576   NOUN      NN      compound      analysts
# analysts       1585   NOUN      NNS     nsubj         say
# say            1594   VERB      VBP     ROOT          say
# .              1597   PUNCT     .       punct         say
# With           1599   ADP       IN      prep          asking
# such           1604   DET       PDT     predet        contest
# a              1609   DET       DT      det           contest
# high           1611   ADJ       JJ      amod          stakes
# -              1615   PUNCT     HYPH    punct         stakes
# stakes         1616   NOUN      NNS     compound      contest
# contest        1623   NOUN      NN      pobj          With
# ,              1630   PUNCT     ,       punct         asking
# many           1632   ADJ       JJ      nsubj         asking
# inside         1637   ADV       RB      advmod        many
# and            1644   CCONJ     CC      cc            inside
# out            1648   ADP       IN      conj          inside
# of             1652   ADP       IN      prep          out
# the            1655   DET       DT      det           country
# country        1659   NOUN      NN      pobj          of
# are            1667   AUX       VBP     aux           asking
# asking         1671   VERB      VBG     ROOT          asking
# whether        1678   SCONJ     IN      mark          dispute
# Erdogan        1686   PROPN     NNP     nsubj         dispute
# may            1694   AUX       MD      aux           dispute
# dispute        1698   VERB      VB      ccomp         asking
# the            1706   DET       DT      det           result
# result         1710   NOUN      NN      dobj          dispute
# if             1717   SCONJ     IN      mark          win
# he             1720   PRON      PRP     nsubj         win
# does           1723   AUX       VBZ     aux           win
# not            1728   PART      RB      neg           win
# win            1732   VERB      VB      advcl         dispute
# .              1735   PUNCT     .       punct         asking
# The            1737   DET       DT      det           tactics
# most           1741   ADV       RBS     advmod        likely
# likely         1746   ADJ       JJ      amod          tactics
# tactics        1753   NOUN      NNS     nsubj         be
# that           1761   PRON      WDT     dobj          use
# he             1766   PRON      PRP     nsubj         going
# ’s             1768   AUX       VBZ     aux           going
# going          1771   VERB      VBG     relcl         tactics
# to             1777   PART      TO      aux           use
# use            1780   VERB      VB      xcomp         going
# to             1784   PART      TO      aux           try
# try            1787   VERB      VB      xcomp         use
# to             1791   PART      TO      aux           tip
# tip            1794   VERB      VB      xcomp         try
# the            1798   DET       DT      det           vote
# vote           1802   NOUN      NN      dobj          tip
# will           1807   AUX       MD      aux           be
# be             1812   AUX       VB      ccomp         said
# to             1815   PART      TO      aux           use
# use            1818   VERB      VB      xcomp         be
# influence      1822   NOUN      NN      dobj          use
# in             1832   ADP       IN      prep          influence
# the            1835   DET       DT      det           board
# electoral      1839   PROPN     NNP     compound      board
# board          1849   PROPN     NNP     pobj          in
# (              1855   PUNCT     -LRB-   punct         board
# the            1856   DET       DT      det           YSK
# YSK            1860   PROPN     NNP     appos         board
# )              1863   PUNCT     -RRB-   punct         YSK
# ,              1864   PUNCT     ,       punct         YSK
# courts         1866   NOUN      NNS     conj          YSK
# ,              1872   PUNCT     ,       punct         courts
# and            1874   CCONJ     CC      cc            courts
# media          1878   NOUN      NNS     conj          courts
# to             1884   PART      TO      aux           build
# build          1887   VERB      VB      xcomp         use
# a              1893   DET       DT      det           narrative
# narrative      1895   NOUN      NN      dobj          build
# that           1905   SCONJ     IN      mark          be
# either         1910   DET       DT      det           elections
# elections      1917   NOUN      NNS     nsubj         be
# should         1927   AUX       MD      aux           be
# be             1934   AUX       VB      ccomp         build
# re             1937   VERB      VBN     acomp         be
# -              1939   VERB      VB      acomp         be
# run            1940   VERB      VB      acomp         be
# or             1944   CCONJ     CC      cc            be
# that           1947   SCONJ     IN      mark          are
# they           1952   PRON      PRP     nsubj         are
# are            1957   AUX       VBP     conj          be
# illegitimate   1961   ADJ       JJ      acomp         are
# ,              1973   PUNCT     ,       punct         said
# ”              1974   PUNCT     ''      punct         said
# said           1976   VERB      VBD     ROOT          said
# Ryan           1981   PROPN     NNP     compound      Bohl
# Bohl           1986   PROPN     NNP     nsubj         said
# ,              1990   PUNCT     ,       punct         Bohl
# a              1992   DET       DT      det           East
# senior         1994   ADJ       JJ      amod          East
# Middle         2001   PROPN     NNP     compound      East
# East           2008   PROPN     NNP     nmod          analyst
# and            2013   CCONJ     CC      cc            East
# North          2017   PROPN     NNP     compound      Africa
# Africa         2023   PROPN     NNP     conj          East
# analyst        2030   NOUN      NN      appos         Bohl
# at             2038   ADP       IN      prep          analyst
# Rane           2041   PROPN     NNP     pobj          at
# .              2045   PUNCT     .       punct         said
# Erdogan        2047   PROPN     NNP     nsubj         did
# did            2055   VERB      VBD     ROOT          did
# this           2059   PRON      DT      dobj          did
# in             2064   ADP       IN      prep          did
# 2019           2067   NUM       CD      pobj          in
# when           2072   SCONJ     WRB     advmod        lost
# his            2077   PRON      PRP$    poss          party
# party          2081   NOUN      NN      nsubj         lost
# narrowly       2087   ADV       RB      advmod        lost
# lost           2096   VERB      VBD     advcl         did
# the            2101   DET       DT      det           race
# Istanbul       2105   PROPN     NNP     nmod          race
# mayoral        2114   ADJ       JJ      amod          race
# race           2122   NOUN      NN      dobj          lost
# ,              2126   PUNCT     ,       punct         lost
# only           2128   ADV       RB      advmod        lose
# to             2133   PART      TO      aux           lose
# lose           2136   VERB      VB      advcl         lost
# again          2141   ADV       RB      advmod        lose
# by             2147   ADP       IN      agent         lose
# a              2150   DET       DT      det           margin
# greater        2152   ADJ       JJR     amod          margin
# margin         2160   NOUN      NN      pobj          by
# after          2167   ADP       IN      prep          lose
# demanding      2173   VERB      VBG     pcomp         after
# a              2183   DET       DT      det           re
# re             2185   NOUN      NN      dobj          demanding
# -              2187   NOUN      NN      dobj          demanding
# run            2188   NOUN      NN      dobj          demanding
# .              2191   PUNCT     .       punct         did
# Some           2193   PRON      DT      nsubj         fear
# even           2198   ADV       RB      advmod        fear
# fear           2203   VERB      VBP     ROOT          fear
# violence       2208   NOUN      NN      dobj          fear
# and            2217   CCONJ     CC      cc            violence
# instability    2221   NOUN      NN      conj          violence
# if             2233   SCONJ     IN      mark          disputed
# the            2236   DET       DT      det           result
# result         2240   NOUN      NN      nsubjpass     disputed
# is             2247   AUX       VBZ     auxpass       disputed
# disputed       2250   VERB      VBN     advcl         fear
# ,              2258   PUNCT     ,       punct         fear
# which          2260   PRON      WDT     nsubj         bring
# would          2266   AUX       MD      aux           bring
# bring          2272   VERB      VB      advcl         fear
# more           2278   ADJ       JJR     amod          volatility
# volatility     2283   NOUN      NN      dobj          bring
# to             2294   ADP       IN      prep          bring
# Turkey         2297   PROPN     NNP     poss          economy
# ’s             2303   PART      POS     case          Turkey
# already        2306   ADV       RB      advmod        damaged
# damaged        2314   VERB      VBN     amod          economy
# economy        2322   NOUN      NN      pobj          to
# .              2329   PUNCT     .       punct         fear
# Turkish        2331   ADJ       JJ      amod          analysts
# and            2339   CCONJ     CC      cc            Turkish
# foreign        2343   ADJ       JJ      conj          Turkish
# analysts       2351   NOUN      NNS     nsubj         sounding
# and            2360   CCONJ     CC      cc            analysts
# rights         2364   NOUN      NNS     compound      activists
# activists      2371   NOUN      NNS     conj          analysts
# have           2381   AUX       VBP     aux           sounding
# for            2386   ADP       IN      prep          have
# years          2390   NOUN      NNS     pobj          for
# been           2396   AUX       VBN     aux           sounding
# sounding       2401   VERB      VBG     ROOT          sounding
# the            2410   DET       DT      det           alarm
# alarm          2414   NOUN      NN      dobj          sounding
# over           2420   ADP       IN      prep          sounding
# increasingly   2425   ADV       RB      advmod        autocratic
# autocratic     2438   ADJ       JJ      amod          governance
# governance     2449   NOUN      NN      pobj          over
# coming         2460   VERB      VBG     acl           governance
# from           2467   ADP       IN      prep          coming
# Erdogan        2472   PROPN     NNP     poss          administration
# ’s             2479   PART      POS     case          Erdogan
# administration 2482   NOUN      NN      pobj          from
# .              2496   PUNCT     .       punct         sounding
# CNBC           2498   PROPN     NNP     nsubj         reached
# has            2503   AUX       VBZ     aux           reached
# reached        2507   VERB      VBN     ROOT          reached
# out            2515   ADP       RP      prt           reached
# to             2519   ADP       IN      prep          reached
# the            2522   DET       DT      det           Presidency
# Turkish        2526   PROPN     NNP     compound      Presidency
# Presidency     2534   PROPN     NNP     poss          office
# ’s             2544   PART      POS     case          Presidency
# office         2547   NOUN      NN      pobj          to
# for            2554   ADP       IN      prep          office
# comment        2558   NOUN      NN      pobj          for
# .              2565   PUNCT     .       punct         reached
# ‘              2567   PUNCT     ``      punct         is
# So             2568   ADV       RB      advmod        much
# much           2571   ADJ       JJ      advmod        at
# at             2576   ADP       IN      prep          is
# stake          2579   NOUN      NN      pobj          at
# ’              2584   PUNCT     ''      punct         at
# The            2586   DET       DT      det           election
# election       2590   NOUN      NN      poss          outcome
# ’s             2598   PART      POS     case          election
# outcome        2601   NOUN      NN      pobj          at
# and            2609   CCONJ     CC      cc            outcome
# its            2613   PRON      PRP$    poss          impact
# impact         2617   NOUN      NN      conj          outcome
# on             2624   ADP       IN      prep          impact
# stability      2627   NOUN      NN      pobj          on
# in             2637   ADP       IN      prep          stability
# the            2640   DET       DT      det           country
# country        2644   NOUN      NN      pobj          in
# ,              2651   PUNCT     ,       punct         country
# which          2653   PRON      WDT     nsubj         sits
# sits           2659   VERB      VBZ     relcl         country
# as             2664   ADP       IN      prep          sits
# a              2667   DET       DT      det           crossroads
# crossroads     2669   NOUN      NNS     pobj          as
# between        2680   ADP       IN      prep          crossroads
# Europe         2688   PROPN     NNP     pobj          between
# and            2695   CCONJ     CC      cc            Europe
# Asia           2699   PROPN     NNP     conj          Europe
# and            2704   CCONJ     CC      cc            sits
# is             2708   AUX       VBZ     conj          sits
# home           2711   NOUN      NN      attr          is
# to             2716   ADP       IN      prep          home
# NATO           2719   PROPN     NNP     poss          military
# ’s             2723   PART      POS     case          NATO
# second         2726   ADV       RB      advmod        largest
# -              2732   PUNCT     HYPH    punct         largest
# largest        2733   ADJ       JJS     amod          military
# military       2741   NOUN      NN      pobj          to
# ,              2749   PUNCT     ,       punct         is
# is             2751   AUX       VBZ     ROOT          is
# of             2754   ADP       IN      prep          is
# paramount      2757   ADJ       JJ      amod          importance
# importance     2767   NOUN      NN      pobj          of
# both           2778   CCONJ     CC      preconj       domestically
# domestically   2783   ADV       RB      advmod        is
# and            2796   CCONJ     CC      cc            domestically
# internationally2800   ADV       RB      conj          domestically
# .              2815   PUNCT     .       punct         is
# There          2817   PRON      EX      expl          is
# is             2823   VERB      VBZ     ccomp         said
# so             2826   ADV       RB      advmod        much
# much           2829   ADJ       JJ      attr          is
# at             2834   ADP       IN      prep          is
# stake          2837   NOUN      NN      pobj          at
# for            2843   ADP       IN      prep          stake
# President      2847   PROPN     NNP     compound      Erdogan
# Erdogan        2857   PROPN     NNP     pobj          for
# and            2865   CCONJ     CC      cc            Erdogan
# his            2869   PRON      PRP$    poss          AKP
# AKP            2873   PROPN     NNP     conj          Erdogan
# (              2877   PUNCT     -LRB-   punct         Party
# Justice        2878   PROPN     NNP     nmod          Party
# and            2886   CCONJ     CC      cc            Justice
# Development    2890   PROPN     NNP     conj          Justice
# Party          2902   PROPN     NNP     appos         AKP
# )              2907   PUNCT     -RRB-   punct         Party
# for            2909   ADP       IN      prep          is
# the            2913   DET       DT      det           time
# first          2917   ADJ       JJ      amod          time
# time           2923   NOUN      NN      pobj          for
# ,              2927   PUNCT     ,       punct         is
# as             2929   SCONJ     IN      mark          come
# his            2932   PRON      PRP$    poss          rule
# 20             2936   NUM       CD      nummod        year
# -              2938   PUNCT     HYPH    punct         year
# year           2939   NOUN      NN      compound      rule
# rule           2944   NOUN      NN      nsubj         come
# over           2949   ADP       IN      prep          rule
# Türkiye        2954   PROPN     NNP     pobj          over
# may            2962   AUX       MD      aux           come
# come           2966   VERB      VB      advcl         is
# to             2971   ADP       IN      prep          come
# an             2974   DET       DT      det           end
# end            2977   NOUN      NN      pobj          to
# given          2981   VERB      VBN     prep          come
# the            2987   DET       DT      det           opposition
# unified        2991   ADJ       JJ      amod          opposition
# opposition     2999   NOUN      NN      pobj          given
# has            3010   AUX       VBZ     aux           managed
# managed        3014   VERB      VBN     conj          is
# to             3022   PART      TO      aux           maintain
# maintain       3025   VERB      VB      xcomp         managed
# a              3034   DET       DT      det           alliance
# strong         3036   ADJ       JJ      amod          alliance
# alliance       3043   NOUN      NN      dobj          maintain
# and            3052   CCONJ     CC      cc            maintain
# stay           3056   VERB      VB      conj          maintain
# on             3061   ADP       IN      prep          stay
# a              3064   DET       DT      det           campaign
# hope           3066   NOUN      NN      npadvmod      building
# -              3070   PUNCT     HYPH    punct         building
# building       3071   NOUN      NN      nmod          campaign
# positive       3080   ADJ       JJ      amod          campaign
# campaign       3089   NOUN      NN      pobj          on
# ,              3097   PUNCT     ,       punct         said
# ”              3098   PUNCT     ''      punct         said
# said           3100   VERB      VBD     ROOT          said
# Hakan          3105   PROPN     NNP     compound      Akbas
# Akbas          3111   PROPN     NNP     nsubj         said
# ,              3116   PUNCT     ,       punct         Akbas
# managing       3118   VERB      VBG     amod          director
# director       3127   NOUN      NN      appos         Akbas
# of             3136   ADP       IN      prep          director
# consulting     3139   VERB      VBG     amod          firm
# firm           3150   NOUN      NN      compound      Services
# Strategic      3155   PROPN     NNP     compound      Services
# Advisory       3165   PROPN     NNP     compound      Services
# Services       3174   PROPN     NNPS    pobj          of
# based          3183   VERB      VBN     acl           Akbas
# between        3189   ADP       IN      prep          based
# Istanbul       3197   PROPN     NNP     pobj          between
# and            3206   CCONJ     CC      cc            Istanbul
# Washington     3210   PROPN     NNP     conj          Istanbul
# .              3220   PUNCT     .       punct         said
# This           3222   PRON      DT      nsubj         is
# is             3227   AUX       VBZ     ROOT          is
# similar        3230   ADJ       JJ      acomp         is
# ,              3237   PUNCT     ,       punct         noted
# he             3239   PRON      PRP     nsubj         noted
# noted          3242   VERB      VBD     parataxis     is
# ,              3247   PUNCT     ,       punct         noted
# to             3249   ADP       IN      prep          noted
# what           3252   PRON      WP      dobj          did
# Istanbul       3257   PROPN     NNP     compound      Mayor
# Mayor          3266   PROPN     NNP     compound      Imamoglu
# Emrak          3272   PROPN     NNP     compound      Imamoglu
# Imamoglu       3278   PROPN     NNP     nsubj         did
# did            3287   AUX       VBD     pcomp         to
# to             3291   PART      TO      aux           win
# win            3294   VERB      VB      xcomp         did
# twice          3298   ADV       RB      advmod        win
# against        3304   ADP       IN      prep          win
# Erdogan        3312   PROPN     NNP     poss          candidate
# ’s             3319   PART      POS     case          Erdogan
# AKP            3322   PROPN     NNP     compound      candidate
# candidate      3326   NOUN      NN      pobj          against
# in             3336   ADP       IN      prep          win
# the            3339   DET       DT      det           election
# mayoral        3343   ADJ       JJ      amod          election
# election       3351   NOUN      NN      pobj          in
# in             3360   ADP       IN      prep          win
# 2019           3363   NUM       CD      pobj          in
# .              3367   PUNCT     .       punct         is
# ”              3368   PUNCT     ''      punct         is
# Imamoglu       3370   PROPN     NNP     nsubj         was
# ,              3378   PUNCT     ,       punct         Imamoglu
# a              3380   DET       DT      det           figure
# popular        3382   ADJ       JJ      amod          figure
# figure         3390   NOUN      NN      appos         Imamoglu
# who            3397   PRON      WP      nsubjpass     expected
# was            3401   AUX       VBD     auxpass       expected
# widely         3405   ADV       RB      advmod        expected
# expected       3412   VERB      VBN     relcl         figure
# to             3421   PART      TO      aux           run
# run            3424   VERB      VB      xcomp         expected
# for            3428   ADP       IN      prep          run
# the            3432   DET       DT      det           presidency
# presidency     3436   NOUN      NN      pobj          for
# as             3447   ADP       IN      prep          run
# a              3450   DET       DT      det           opponent
# formidable     3452   ADJ       JJ      amod          opponent
# opponent       3463   NOUN      NN      pobj          as
# to             3472   ADP       IN      prep          opponent
# Erdogan        3475   PROPN     NNP     pobj          to
# ,              3482   PUNCT     ,       punct         Imamoglu
# was            3484   AUX       VBD     ROOT          was
# in             3488   ADP       IN      prep          was
# December       3491   PROPN     NNP     pobj          in
# sentenced      3500   VERB      VBN     advcl         was
# to             3510   ADP       IN      prep          sentenced
# nearly         3513   ADV       RB      advmod        three
# three          3520   NUM       CD      nummod        years
# years          3526   NOUN      NNS     pobj          to
# in             3532   ADP       IN      prep          years
# prison         3535   NOUN      NN      pobj          in
# and            3542   CCONJ     CC      cc            sentenced
# barred         3546   VERB      VBN     conj          sentenced
# from           3553   ADP       IN      prep          barred
# politics       3558   NOUN      NNS     pobj          from
# for            3567   ADP       IN      prep          barred
# what           3571   PRON      WP      dobj          described
# a              3576   DET       DT      det           court
# court          3578   NOUN      NN      nsubj         described
# described      3584   VERB      VBD     pcomp         for
# as             3594   ADP       IN      prep          described
# insulting      3597   VERB      VBG     pcomp         as
# the            3607   DET       DT      det           judges
# judges         3611   NOUN      NNS     dobj          insulting
# of             3618   ADP       IN      prep          judges
# the            3621   DET       DT      det           Council
# Supreme        3625   PROPN     NNP     compound      Council
# Election       3633   PROPN     NNP     compound      Council
# Council        3642   PROPN     NNP     pobj          of
# (              3650   PUNCT     -LRB-   punct         YSK
# YSK            3651   PROPN     NNP     appos         Council
# )              3654   PUNCT     -RRB-   punct         Council
# .              3655   PUNCT     .       punct         was
# Imamoglu       3657   PROPN     NNP     nsubj         say
# and            3666   CCONJ     CC      cc            Imamoglu
# his            3670   PRON      PRP$    poss          supporters
# supporters     3674   NOUN      NNS     conj          Imamoglu
# say            3685   VERB      VBP     ROOT          say
# the            3689   DET       DT      det           charges
# charges        3693   NOUN      NNS     nsubj         are
# are            3701   AUX       VBP     ccomp         say
# purely         3705   ADV       RB      advmod        are
# political      3712   ADJ       JJ      acomp         are
# and            3722   CCONJ     CC      cc            are
# were           3726   AUX       VBD     auxpass       influenced
# influenced     3731   VERB      VBN     conj          are
# by             3742   ADP       IN      agent         influenced
# Erdogan        3745   PROPN     NNP     pobj          by
# and            3753   CCONJ     CC      cc            Erdogan
# his            3757   PRON      PRP$    poss          party
# party          3761   NOUN      NN      conj          Erdogan
# to             3767   PART      TO      aux           sabotage
# sabotage       3770   VERB      VB      xcomp         influenced
# his            3779   PRON      PRP$    poss          ambitions
# political      3783   ADJ       JJ      amod          ambitions
# ambitions      3793   NOUN      NNS     dobj          sabotage
# .              3802   PUNCT     .       punct         say

# %%
displacy.serve(doc, style="dep", auto_select_port=True, page=False)
# Out:
# /Users/oonisim/venv/tf/lib/python3.9/site-packages/spacy/util.py:1785: UserWarning: [W124] 0.0.0.0:5000 is already in use, using the nearest available port 5001 as an alternative.
#   warnings.warn(Warnings.W124.format(host=host, port=start, serve_port=port))
# /Users/oonisim/venv/tf/lib/python3.9/site-packages/spacy/displacy/__init__.py:108: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="7f81ffec380f464ca159136bd55415b8-0" class="displacy" width="112750" height="837.0" direction="ltr" style="max-width: none; height: 837.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Millions</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">Turks</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">headed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">polls</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">Sunday</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">what</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">set</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">be</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">Turkey</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">’s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">most</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">consequential</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">election</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">two</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">decades,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">one</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">whose</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">results</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">will</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">have</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">implications</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">far</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="53
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5001 ...
#
# Shutting down server on port 5001.

# %% [markdown]
# ----
# # Entities
#
# Named Entities have been identified by NER in the document object.
#
# * [Named Entities](https://spacy.io/usage/spacy-101#annotations-ner)
#
# ### Entity Labels
# ```
# PERSON:      People, including fictional.
# NORP:        Nationalities or religious or political groups.
# FAC:         Buildings, airports, highways, bridges, etc.
# ORG:         Companies, agencies, institutions, etc.
# GPE:         Countries, cities, states.
# LOC:         Non-GPE locations, mountain ranges, bodies of water.
# PRODUCT:     Objects, vehicles, foods, etc. (Not services.)
# EVENT:       Named hurricanes, battles, wars, sports events, etc.
# WORK_OF_ART: Titles of books, songs, etc.
# LAW:         Named documents made into laws.
# LANGUAGE:    Any named language.
# DATE:        Absolute or relative dates or periods.
# TIME:        Times smaller than a day.
# PERCENT:     Percentage, including ”%“.
# MONEY:       Monetary values, including unit.
# QUANTITY:    Measurements, as of weight or distance.
# ORDINAL:     “first”, “second”, etc.
# CARDINAL:    Numerals that do not fall under another type.
# ```

# %%
pipeline.named_entity_labels
# Out:
# ('CARDINAL',
#  'DATE',
#  'EVENT',
#  'FAC',
#  'GPE',
#  'LANGUAGE',
#  'LAW',
#  'LOC',
#  'MONEY',
#  'NORP',
#  'ORDINAL',
#  'ORG',
#  'PERCENT',
#  'PERSON',
#  'PRODUCT',
#  'QUANTITY',
#  'TIME',
#  'WORK_OF_ART')

# %%
displacy.serve(doc, style="ent", auto_select_port=True, page=False)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Millions
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Turks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  are headed to the polls
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sunday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  in what is set to be
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Turkey
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ’s most consequential election in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two decades
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , and one whose results will have implications far beyond its own borders. The country of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     85 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  holds both its presidential and parliamentary elections on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     May 14
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . For the presidency — which is expected to be close — if no candidate wins
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     more than 50%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
# , the vote goes to a run-off
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two weeks later
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . Incumbent President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Recep Tayyip Erdogan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is facing his toughest test yet after
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two decades
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  in power, grappling with public anger over worsening economic conditions and the slow government response to a series of devastating earthquakes in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     February
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  that killed
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     more than 50,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  people. His primary opponent,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     74-year-old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kemal Kilicdaroglu
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  of the center-left
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Republican People’s Party
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CHP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ), is running as a unity candidate representing
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     six
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  different parties that all want to see
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Erdogan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  out of power. In a possibly game-changing development,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     four
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  presidential candidates,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Muharrem Ince
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , pulled out of the race
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Thursday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . A former
# <mark class="entity" style="b
# Using the 'ent' visualizer
# Serving on http://0.0.0.0:5001 ...
#
# Shutting down server on port 5001.

# %%
print("{}{}{}{}".format(
    "Entity".ljust(50), "Start".ljust(7), "End".ljust(7), "Label".ljust(10)
))
print("-" * 80)
for ent in doc.ents:
    print(f"{ent.text:50}{ent.start_char:<7}{ent.end_char:<7}{ent.label_:10}")
# Out:
# Entity                                            Start  End    Label
# --------------------------------------------------------------------------------
# Millions                                          0      8      CARDINAL
# Turks                                             12     17     NORP
# Sunday                                            42     48     DATE
# Turkey                                            70     76     GPE
# two decades                                       110    121    DATE
# 85 million                                        211    221    CARDINAL
# May 14                                            281    287    DATE
# more than 50%                                     363    376    PERCENT
# two weeks later                                   405    420    DATE
# Recep Tayyip Erdogan                              442    462    PERSON
# two decades                                       501    512    DATE
# February                                          661    669    DATE
# more than 50,000                                  682    698    CARDINAL
# 74-year-old                                       729    740    DATE
# Kemal Kilicdaroglu                                741    759    PERSON
# Republican People’s Party                         779    804    ORG
# CHP                                               806    809    ORG
# six                                               857    860    CARDINAL
# Erdogan                                           900    907    PERSON
# one                                               963    966    CARDINAL
# four                                              974    978    CARDINAL
# Muharrem Ince                                     1004   1017   PERSON
# Thursday                                          1042   1050   DATE
# CHP                                               1061   1064   ORG
# Kilicdaroglu                                      1166   1178   ORG
# Erdogan                                           1242   1249   PERSON
# Kilicdaroglu                                      1267   1279   GPE
# 69-year-old                                       1340   1351   DATE
# Erdogan                                           1352   1359   PERSON
# More than 5 million                               1401   1420   CARDINAL
# Turks                                             1427   1432   NORP
# first                                             1456   1461   ORDINAL
# Erdogan                                           1686   1693   PERSON
# the electoral board                               1835   1854   ORG
# Ryan Bohl                                         1981   1990   PERSON
# Middle East                                       2001   2012   LOC
# North Africa                                      2017   2029   GPE
# Rane                                              2041   2045   PERSON
# Erdogan                                           2047   2054   PERSON
# 2019                                              2067   2071   DATE
# Istanbul                                          2105   2113   GPE
# Turkey                                            2297   2303   GPE
# Turkish                                           2331   2338   NORP
# years                                             2390   2395   DATE
# Erdogan                                           2472   2479   ORG
# CNBC                                              2498   2502   ORG
# Turkish                                           2526   2533   NORP
# Europe                                            2688   2694   LOC
# Asia                                              2699   2703   LOC
# NATO                                              2719   2723   ORG
# second                                            2726   2732   ORDINAL
# Erdogan                                           2857   2864   PERSON
# AKP                                               2873   2876   ORG
# Justice                                           2878   2885   ORG
# Development Party                                 2890   2907   ORG
# first                                             2917   2922   ORDINAL
# 20-year                                           2936   2943   DATE
# Türkiye                                           2954   2961   GPE
# Hakan Akbas                                       3105   3116   PERSON
# Strategic Advisory Services                       3155   3182   ORG
# Istanbul                                          3197   3205   GPE
# Washington                                        3210   3220   GPE
# Istanbul                                          3257   3265   GPE
# Emrak Imamoglu                                    3272   3286   PERSON
# Erdogan                                           3312   3319   ORG
# AKP                                               3322   3325   ORG
# 2019                                              3363   3367   DATE
# Imamoglu                                          3370   3378   PERSON
# Erdogan                                           3475   3482   PERSON
# December                                          3491   3499   DATE
# nearly three years                                3513   3531   DATE
# the Supreme Election Council                      3621   3649   ORG
# Imamoglu                                          3657   3665   PERSON
# Erdogan                                           3745   3752   PERSON

# %% [markdown]
# ## Entities per label

# %%
print(json.dumps(
    pipeline.get_named_entities_from_text(
        text=text, 
        excludes=["ORDINAL", "CARDINAL", "PERCENT", "DATE", "time", "QUANTITY", "MONEY"],
        remove_special_characters=True,
        return_value_only=True,
        remove_similarity_threshold=0.9,
        include_noun_phrases=False,
        include_keywords=False
    ), 
    indent=4, 
    default=str,
    ensure_ascii=False
))
# Out:
# {
#     "EVENT": [],
#     "FAC": [],
#     "GPE": [
#         "Turkey",
#         "Washington",
#         "Kilicdaroglu",
#         "Türkiye",
#         "Istanbul",
#         "North Africa"
#     ],
#     "LANGUAGE": [],
#     "LAW": [],
#     "LOC": [
#         "Asia",
#         "Middle East",
#         "Europe"
#     ],
#     "NORP": [
#         "Turkish",
#         "Turks"
#     ],
#     "ORG": [
#         "AKP",
#         "CHP",
#         "Supreme Election Council",
#         "Kilicdaroglu",
#         "electoral board",
#         "Development Party",
#         "NATO",
#         "Republican Peoples Party",
#         "Justice",
#         "Erdogan",
#         "CNBC",
#         "Strategic Advisory Services"
#     ],
#     "PERSON": [
#         "Ryan Bohl",
#         "Kemal Kilicdaroglu",
#         "Recep Tayyip Erdogan",
#         "Imamoglu",
#         "Hakan Akbas",
#         "Emrak Imamoglu",
#         "Rane",
#         "Erdogan",
#         "Muharrem Ince"
#     ],
#     "PRODUCT": [],
#     "WORK_OF_ART": []
# }

# %% [markdown]
# ---
# # Noun Phrases
#
# * [Noun chunks](https://spacy.io/usage/linguistic-features#noun-chunks)
#
# > **Noun chunks** are “base noun phrases” – flat phrases that **have a noun as their head**. You can think of noun chunks as a noun plus the words describing the noun – for example, “the lavish green grass” or “the world’s largest tech fund”.

# %%
phrases = doc.noun_chunks

for sentence in doc.sents:
    print("-" * 80)
    print(sentence)
    print("-" * 80)
    
    phrase = next(phrases)
    while phrase.root.sent == sentence:
        print(
            f"phrase:[{phrase.text:30}] "\
            f"root:[{phrase.root.text:12}] "\
            f"type:[{phrase.root.dep_:6}] "\
            f"parent:[{phrase.root.head}]" 
        )
        try:
            phrase = next(phrases)
        except StopIteration:
            break
            
del phrases
# Out:
# --------------------------------------------------------------------------------
# Millions of Turks are headed to the polls Sunday in what is set to be Turkey’s most consequential election in two decades, and one whose results will have implications far beyond its own borders.
# --------------------------------------------------------------------------------
# phrase:[Millions                      ] root:[Millions    ] type:[nsubjpass] parent:[headed]
# phrase:[Turks                         ] root:[Turks       ] type:[pobj  ] parent:[of]
# phrase:[the polls                     ] root:[polls       ] type:[pobj  ] parent:[to]
# phrase:[what                          ] root:[what        ] type:[nsubjpass] parent:[set]
# phrase:[Turkey’s most consequential election] root:[election    ] type:[attr  ] parent:[be]
# phrase:[two decades                   ] root:[decades     ] type:[pobj  ] parent:[in]
# phrase:[whose results                 ] root:[results     ] type:[nsubj ] parent:[have]
# phrase:[implications                  ] root:[implications] type:[dobj  ] parent:[have]
# phrase:[its own borders               ] root:[borders     ] type:[pobj  ] parent:[beyond]
# --------------------------------------------------------------------------------
# The country of 85 million holds both its presidential and parliamentary elections on May 14.
# --------------------------------------------------------------------------------
# phrase:[both its presidential and parliamentary elections] root:[elections   ] type:[dobj  ] parent:[holds]
# phrase:[May                           ] root:[May         ] type:[pobj  ] parent:[on]
# --------------------------------------------------------------------------------
# For the presidency — which is expected to be close — if no candidate wins more than 50%, the vote goes to a run-off two weeks later.
# --------------------------------------------------------------------------------
# phrase:[which                         ] root:[which       ] type:[nsubjpass] parent:[expected]
# phrase:[no candidate                  ] root:[candidate   ] type:[nsubj ] parent:[wins]
# phrase:[more than 50%                 ] root:[%           ] type:[dobj  ] parent:[wins]
# phrase:[the vote                      ] root:[vote        ] type:[nsubj ] parent:[goes]
# --------------------------------------------------------------------------------
# Incumbent President Recep Tayyip Erdogan is facing his toughest test yet after two decades in power, grappling with public anger over worsening economic conditions and the slow government response to a series of devastating earthquakes in February that killed more than 50,000 people.
# --------------------------------------------------------------------------------
# phrase:[his toughest test             ] root:[test        ] type:[dobj  ] parent:[facing]
# phrase:[two decades                   ] root:[decades     ] type:[pobj  ] parent:[after]
# phrase:[power                         ] root:[power       ] type:[pobj  ] parent:[in]
# phrase:[public anger                  ] root:[anger       ] type:[pobj  ] parent:[with]
# phrase:[economic conditions           ] root:[conditions  ] type:[dobj  ] parent:[worsening]
# phrase:[the slow government response  ] root:[response    ] type:[dobj  ] parent:[grappling]
# phrase:[a series                      ] root:[series      ] type:[pobj  ] parent:[to]
# phrase:[devastating earthquakes       ] root:[earthquakes ] type:[pobj  ] parent:[of]
# phrase:[February                      ] root:[February    ] type:[pobj  ] parent:[in]
# phrase:[that                          ] root:[that        ] type:[nsubj ] parent:[killed]
# phrase:[more than 50,000 people       ] root:[people      ] type:[dobj  ] parent:[killed]
# --------------------------------------------------------------------------------
# His primary opponent, 74-year-old Kemal Kilicdaroglu of the center-left Republican People’s Party (CHP), is running as a unity candidate representing six different parties that all want to see Erdogan out of power.
# --------------------------------------------------------------------------------
# phrase:[74-year-old Kemal Kilicdaroglu] root:[Kilicdaroglu] type:[appos ] parent:[opponent]
# phrase:[the center-left Republican People’s Party] root:[Party       ] type:[pobj  ] parent:[of]
# phrase:[CHP                           ] root:[CHP         ] type:[appos ] parent:[Party]
# phrase:[a unity candidate             ] root:[candidate   ] type:[pobj  ] parent:[as]
# phrase:[six different parties         ] root:[parties     ] type:[dobj  ] parent:[representing]
# phrase:[that                          ] root:[that        ] type:[nsubj ] parent:[want]
# phrase:[all                           ] root:[all         ] type:[nsubj ] parent:[want]
# phrase:[Erdogan                       ] root:[Erdogan     ] type:[dobj  ] parent:[see]
# phrase:[power                         ] root:[power       ] type:[pobj  ] parent:[of]
# --------------------------------------------------------------------------------
# In a possibly game-changing development, one of the four presidential candidates, Muharrem Ince, pulled out of the race Thursday.
# --------------------------------------------------------------------------------
# phrase:[the four presidential candidates] root:[candidates  ] type:[pobj  ] parent:[of]
# phrase:[Muharrem Ince                 ] root:[Ince        ] type:[appos ] parent:[one]
# phrase:[the race                      ] root:[race        ] type:[pobj  ] parent:[of]
# --------------------------------------------------------------------------------
# A former CHP member, he had been under heavy criticism for splitting the opposition vote in a way that would hurt Kilicdaroglu’s chances.
# --------------------------------------------------------------------------------
# phrase:[heavy criticism               ] root:[criticism   ] type:[pobj  ] parent:[under]
# phrase:[the opposition vote           ] root:[vote        ] type:[dobj  ] parent:[splitting]
# phrase:[a way                         ] root:[way         ] type:[pobj  ] parent:[in]
# phrase:[that                          ] root:[that        ] type:[nsubj ] parent:[hurt]
# phrase:[Kilicdaroglu’s chances        ] root:[chances     ] type:[dobj  ] parent:[hurt]
# --------------------------------------------------------------------------------
# Now, with Ince out of the race, his votes may go to Erdogan’s top challenger Kilicdaroglu, helping him tremendously and spelling more trouble for the 69-year-old Erdogan.
# --------------------------------------------------------------------------------
# phrase:[the race                      ] root:[race        ] type:[pobj  ] parent:[of]
# phrase:[his votes                     ] root:[votes       ] type:[nsubj ] parent:[go]
# phrase:[Erdogan’s top challenger Kilicdaroglu] root:[Kilicdaroglu] type:[pobj  ] parent:[to]
# phrase:[him                           ] root:[him         ] type:[dobj  ] parent:[helping]
# phrase:[more trouble                  ] root:[trouble     ] type:[dobj  ] parent:[spelling]
# phrase:[the 69-year-old Erdogan       ] root:[Erdogan     ] type:[pobj  ] parent:[for]
# --------------------------------------------------------------------------------
# Another crucial factor will be turnout: More than 5 million young Turks will be voting for the first time, and the greater the youth turnout, the better for the challenger candidate and the worse for the incumbent, election analysts say.
# --------------------------------------------------------------------------------
# phrase:[More than 5 million young Turks] root:[Turks       ] type:[nsubj ] parent:[voting]
# phrase:[the first time                ] root:[time        ] type:[pobj  ] parent:[for]
# phrase:[the challenger candidate      ] root:[candidate   ] type:[pobj  ] parent:[for]
# phrase:[the incumbent                 ] root:[incumbent   ] type:[pobj  ] parent:[for]
# phrase:[election analysts             ] root:[analysts    ] type:[nsubj ] parent:[say]
# --------------------------------------------------------------------------------
# With such a high-stakes contest, many inside and out of the country are asking whether Erdogan may dispute the result if he does not win.
# --------------------------------------------------------------------------------
# phrase:[the country                   ] root:[country     ] type:[pobj  ] parent:[of]
# phrase:[Erdogan                       ] root:[Erdogan     ] type:[nsubj ] parent:[dispute]
# phrase:[the result                    ] root:[result      ] type:[dobj  ] parent:[dispute]
# phrase:[he                            ] root:[he          ] type:[nsubj ] parent:[win]
# --------------------------------------------------------------------------------
# The most likely tactics that he’s going to use to try to tip the vote will be to use influence in the electoral board (the YSK), courts, and media to build a narrative that either elections should be re-run or that they are illegitimate,” said Ryan Bohl, a senior Middle East and North Africa analyst at Rane.
# --------------------------------------------------------------------------------
# phrase:[that                          ] root:[that        ] type:[dobj  ] parent:[use]
# phrase:[he                            ] root:[he          ] type:[nsubj ] parent:[going]
# phrase:[the vote                      ] root:[vote        ] type:[dobj  ] parent:[tip]
# phrase:[influence                     ] root:[influence   ] type:[dobj  ] parent:[use]
# phrase:[the electoral board           ] root:[board       ] type:[pobj  ] parent:[in]
# phrase:[the YSK                       ] root:[YSK         ] type:[appos ] parent:[board]
# phrase:[courts                        ] root:[courts      ] type:[conj  ] parent:[YSK]
# phrase:[media                         ] root:[media       ] type:[conj  ] parent:[courts]
# phrase:[a narrative                   ] root:[narrative   ] type:[dobj  ] parent:[build]
# phrase:[either elections              ] root:[elections   ] type:[nsubj ] parent:[be]
# phrase:[they                          ] root:[they        ] type:[nsubj ] parent:[are]
# phrase:[Ryan Bohl                     ] root:[Bohl        ] type:[nsubj ] parent:[said]
# phrase:[a senior Middle East and North Africa analyst] root:[analyst     ] type:[appos ] parent:[Bohl]
# phrase:[Rane                          ] root:[Rane        ] type:[pobj  ] parent:[at]
# --------------------------------------------------------------------------------
# Erdogan did this in 2019 when his party narrowly lost the Istanbul mayoral race, only to lose again by a greater margin after demanding a re-run.
# --------------------------------------------------------------------------------
# phrase:[this                          ] root:[this        ] type:[dobj  ] parent:[did]
# phrase:[his party                     ] root:[party       ] type:[nsubj ] parent:[lost]
# phrase:[the Istanbul mayoral race     ] root:[race        ] type:[dobj  ] parent:[lost]
# phrase:[a greater margin              ] root:[margin      ] type:[pobj  ] parent:[by]
# phrase:[a re                          ] root:[re          ] type:[dobj  ] parent:[demanding]
# phrase:[-                             ] root:[-           ] type:[dobj  ] parent:[demanding]
# phrase:[run                           ] root:[run         ] type:[dobj  ] parent:[demanding]
# --------------------------------------------------------------------------------
# Some even fear violence and instability if the result is disputed, which would bring more volatility to Turkey’s already damaged economy.
# --------------------------------------------------------------------------------
# phrase:[violence                      ] root:[violence    ] type:[dobj  ] parent:[fear]
# phrase:[instability                   ] root:[instability ] type:[conj  ] parent:[violence]
# phrase:[the result                    ] root:[result      ] type:[nsubjpass] parent:[disputed]
# phrase:[which                         ] root:[which       ] type:[nsubj ] parent:[bring]
# phrase:[more volatility               ] root:[volatility  ] type:[dobj  ] parent:[bring]
# phrase:[Turkey’s already damaged economy] root:[economy     ] type:[pobj  ] parent:[to]
# --------------------------------------------------------------------------------
# Turkish and foreign analysts and rights activists have for years been sounding the alarm over increasingly autocratic governance coming from Erdogan’s administration.
# --------------------------------------------------------------------------------
# phrase:[rights activists              ] root:[activists   ] type:[conj  ] parent:[analysts]
# phrase:[years                         ] root:[years       ] type:[pobj  ] parent:[for]
# phrase:[the alarm                     ] root:[alarm       ] type:[dobj  ] parent:[sounding]
# phrase:[increasingly autocratic governance] root:[governance  ] type:[pobj  ] parent:[over]
# phrase:[Erdogan’s administration      ] root:[administration] type:[pobj  ] parent:[from]
# --------------------------------------------------------------------------------
# CNBC has reached out to the Turkish Presidency’s office for comment.
# --------------------------------------------------------------------------------
# phrase:[the Turkish Presidency’s office] root:[office      ] type:[pobj  ] parent:[to]
# phrase:[comment                       ] root:[comment     ] type:[pobj  ] parent:[for]
# --------------------------------------------------------------------------------
# ‘So much at stake’ The election’s outcome and its impact on stability in the country, which sits as a crossroads between Europe and Asia and is home to NATO’s second-largest military, is of paramount importance both domestically and internationally.
# --------------------------------------------------------------------------------
# phrase:[The election’s outcome        ] root:[outcome     ] type:[pobj  ] parent:[at]
# phrase:[its impact                    ] root:[impact      ] type:[conj  ] parent:[outcome]
# phrase:[stability                     ] root:[stability   ] type:[pobj  ] parent:[on]
# phrase:[the country                   ] root:[country     ] type:[pobj  ] parent:[in]
# phrase:[which                         ] root:[which       ] type:[nsubj ] parent:[sits]
# phrase:[a crossroads                  ] root:[crossroads  ] type:[pobj  ] parent:[as]
# phrase:[Europe                        ] root:[Europe      ] type:[pobj  ] parent:[between]
# phrase:[Asia                          ] root:[Asia        ] type:[conj  ] parent:[Europe]
# phrase:[home                          ] root:[home        ] type:[attr  ] parent:[is]
# phrase:[NATO’s second-largest military] root:[military    ] type:[pobj  ] parent:[to]
# phrase:[paramount importance          ] root:[importance  ] type:[pobj  ] parent:[of]
# --------------------------------------------------------------------------------
# There is so much at stake for President Erdogan and his AKP (Justice and Development Party) for the first time, as his 20-year rule over Türkiye may come to an end given the unified opposition has managed to maintain a strong alliance and stay on a hope-building positive campaign,” said Hakan Akbas, managing director of consulting firm Strategic Advisory Services based between Istanbul and Washington.
# --------------------------------------------------------------------------------
# phrase:[President Erdogan             ] root:[Erdogan     ] type:[pobj  ] parent:[for]
# phrase:[his AKP                       ] root:[AKP         ] type:[conj  ] parent:[Erdogan]
# phrase:[(Justice and Development Party] root:[Party       ] type:[appos ] parent:[AKP]
# phrase:[the first time                ] root:[time        ] type:[pobj  ] parent:[for]
# phrase:[his 20-year rule              ] root:[rule        ] type:[nsubj ] parent:[come]
# phrase:[Türkiye                       ] root:[Türkiye     ] type:[pobj  ] parent:[over]
# phrase:[an end                        ] root:[end         ] type:[pobj  ] parent:[to]
# phrase:[the unified opposition        ] root:[opposition  ] type:[pobj  ] parent:[given]
# phrase:[a strong alliance             ] root:[alliance    ] type:[dobj  ] parent:[maintain]
# phrase:[a hope-building positive campaign] root:[campaign    ] type:[pobj  ] parent:[on]
# phrase:[Hakan Akbas                   ] root:[Akbas       ] type:[nsubj ] parent:[said]
# phrase:[managing director             ] root:[director    ] type:[appos ] parent:[Akbas]
# phrase:[consulting firm Strategic Advisory Services] root:[Services    ] type:[pobj  ] parent:[of]
# phrase:[Istanbul                      ] root:[Istanbul    ] type:[pobj  ] parent:[between]
# phrase:[Washington                    ] root:[Washington  ] type:[conj  ] parent:[Istanbul]
# --------------------------------------------------------------------------------
# This is similar, he noted, to what Istanbul Mayor Emrak Imamoglu did to win twice against Erdogan’s AKP candidate in the mayoral election in 2019.”
# --------------------------------------------------------------------------------
# phrase:[he                            ] root:[he          ] type:[nsubj ] parent:[noted]
# phrase:[what                          ] root:[what        ] type:[dobj  ] parent:[did]
# phrase:[Istanbul Mayor Emrak Imamoglu ] root:[Imamoglu    ] type:[nsubj ] parent:[did]
# phrase:[Erdogan’s AKP candidate       ] root:[candidate   ] type:[pobj  ] parent:[against]
# phrase:[the mayoral election          ] root:[election    ] type:[pobj  ] parent:[in]
# --------------------------------------------------------------------------------
# Imamoglu, a popular figure who was widely expected to run for the presidency as a formidable opponent to Erdogan, was in December sentenced to nearly three years in prison and barred from politics for what a court described as insulting the judges of the Supreme Election Council (YSK).
# --------------------------------------------------------------------------------
# phrase:[a popular figure              ] root:[figure      ] type:[appos ] parent:[Imamoglu]
# phrase:[who                           ] root:[who         ] type:[nsubjpass] parent:[expected]
# phrase:[the presidency                ] root:[presidency  ] type:[pobj  ] parent:[for]
# phrase:[a formidable opponent         ] root:[opponent    ] type:[pobj  ] parent:[as]
# phrase:[Erdogan                       ] root:[Erdogan     ] type:[pobj  ] parent:[to]
# phrase:[December                      ] root:[December    ] type:[pobj  ] parent:[in]
# phrase:[nearly three years            ] root:[years       ] type:[pobj  ] parent:[to]
# phrase:[prison                        ] root:[prison      ] type:[pobj  ] parent:[in]
# phrase:[politics                      ] root:[politics    ] type:[pobj  ] parent:[from]
# phrase:[what                          ] root:[what        ] type:[dobj  ] parent:[described]
# phrase:[a court                       ] root:[court       ] type:[nsubj ] parent:[described]
# phrase:[the judges                    ] root:[judges      ] type:[dobj  ] parent:[insulting]
# phrase:[the Supreme Election Council  ] root:[Council     ] type:[pobj  ] parent:[of]
# phrase:[(YSK                          ] root:[YSK         ] type:[appos ] parent:[Council]
# --------------------------------------------------------------------------------
# Imamoglu and his supporters say the charges are purely political and were influenced by Erdogan and his party to sabotage his political ambitions.
# --------------------------------------------------------------------------------
# phrase:[his supporters                ] root:[supporters  ] type:[conj  ] parent:[Imamoglu]
# phrase:[the charges                   ] root:[charges     ] type:[nsubj ] parent:[are]
# phrase:[Erdogan                       ] root:[Erdogan     ] type:[pobj  ] parent:[by]
# phrase:[his party                     ] root:[party       ] type:[conj  ] parent:[Erdogan]
# phrase:[his political ambitions       ] root:[ambitions   ] type:[dobj  ] parent:[sabotage]

# %%
for chunk in doc.noun_chunks:
    print(
        f"{chunk.text:32} " \
        f"tag:{chunk.root.dep_:10} " \
        f"root:{chunk.root.head.text:10} " \
#        sentence:{chunk.root.sent} " \
        f"children:{list(chunk.root.children)}"
    )
# Out:
# Millions                         tag:nsubjpass  root:headed     children:[of]
# Turks                            tag:pobj       root:of         children:[]
# the polls                        tag:pobj       root:to         children:[the]
# what                             tag:nsubjpass  root:set        children:[]
# Turkey’s most consequential election tag:attr       root:be         children:[Turkey, consequential, in]
# two decades                      tag:pobj       root:in         children:[two]
# whose results                    tag:nsubj      root:have       children:[whose]
# implications                     tag:dobj       root:have       children:[beyond]
# its own borders                  tag:pobj       root:beyond     children:[its, own]
# The country                      tag:nsubj      root:holds      children:[The, of]
# both its presidential and parliamentary elections tag:dobj       root:holds      children:[both, its, presidential]
# May                              tag:pobj       root:on         children:[14]
# the presidency                   tag:pobj       root:For        children:[the]
# which                            tag:nsubjpass  root:expected   children:[]
# no candidate                     tag:nsubj      root:wins       children:[no]
# more than 50%                    tag:dobj       root:wins       children:[50]
# the vote                         tag:nsubj      root:goes       children:[the]
# Incumbent President Recep Tayyip Erdogan tag:nsubj      root:facing     children:[President, Recep, Tayyip]
# his toughest test                tag:dobj       root:facing     children:[his, toughest]
# two decades                      tag:pobj       root:after      children:[two, in]
# power                            tag:pobj       root:in         children:[]
# public anger                     tag:pobj       root:with       children:[public, over, and]
# economic conditions              tag:dobj       root:worsening  children:[economic]
# the slow government response     tag:dobj       root:grappling  children:[the, slow, government, to]
# a series                         tag:pobj       root:to         children:[a, of, in, killed]
# devastating earthquakes          tag:pobj       root:of         children:[devastating]
# February                         tag:pobj       root:in         children:[]
# that                             tag:nsubj      root:killed     children:[]
# more than 50,000 people          tag:dobj       root:killed     children:[50,000]
# His primary opponent             tag:nsubj      root:running    children:[His, primary, ,, Kilicdaroglu, ,]
# 74-year-old Kemal Kilicdaroglu   tag:appos      root:opponent   children:[old, Kemal, of]
# the center-left Republican People’s Party tag:pobj       root:of         children:[the, left, People, (, CHP, )]
# CHP                              tag:appos      root:Party      children:[]
# a unity candidate                tag:pobj       root:as         children:[a, unity, representing]
# six different parties            tag:dobj       root:representing children:[six, different, want]
# that                             tag:nsubj      root:want       children:[]
# all                              tag:nsubj      root:want       children:[]
# Erdogan                          tag:dobj       root:see        children:[]
# power                            tag:pobj       root:of         children:[]
# a possibly game-changing development tag:pobj       root:In         children:[a, changing]
# the four presidential candidates tag:pobj       root:of         children:[the, four, presidential]
# Muharrem Ince                    tag:appos      root:one        children:[Muharrem]
# the race                         tag:pobj       root:of         children:[the]
# he                               tag:nsubj      root:been       children:[]
# heavy criticism                  tag:pobj       root:under      children:[heavy, for]
# the opposition vote              tag:dobj       root:splitting  children:[the, opposition]
# a way                            tag:pobj       root:in         children:[a, hurt]
# that                             tag:nsubj      root:hurt       children:[]
# Kilicdaroglu’s chances           tag:dobj       root:hurt       children:[Kilicdaroglu]
# Ince                             tag:pobj       root:with       children:[out]
# the race                         tag:pobj       root:of         children:[the]
# his votes                        tag:nsubj      root:go         children:[his]
# Erdogan’s top challenger Kilicdaroglu tag:pobj       root:to         children:[Erdogan, challenger]
# him                              tag:dobj       root:helping    children:[]
# more trouble                     tag:dobj       root:spelling   children:[more, for]
# the 69-year-old Erdogan          tag:pobj       root:for        children:[the, old]
# Another crucial factor           tag:nsubj      root:be         children:[Another, crucial]
# More than 5 million young Turks  tag:nsubj      root:voting     children:[million, young]
# the first time                   tag:pobj       root:for        children:[the, first]
# the challenger candidate         tag:pobj       root:for        children:[the, challenger, and, worse]
# the incumbent                    tag:pobj       root:for        children:[the]
# election analysts                tag:nsubj      root:say        children:[election]
# such a high-stakes contest       tag:pobj       root:With       children:[such, a, stakes]
# the country                      tag:pobj       root:of         children:[the]
# Erdogan                          tag:nsubj      root:dispute    children:[]
# the result                       tag:dobj       root:dispute    children:[the]
# he                               tag:nsubj      root:win        children:[]
# The most likely tactics          tag:nsubj      root:be         children:[The, likely, going]
# that                             tag:dobj       root:use        children:[]
# he                               tag:nsubj      root:going      children:[]
# the vote                         tag:dobj       root:tip        children:[the]
# influence                        tag:dobj       root:use        children:[in]
# the electoral board              tag:pobj       root:in         children:[the, electoral, (, YSK]
# the YSK                          tag:appos      root:board      children:[the, ), ,, courts]
# courts                           tag:conj       root:YSK        children:[,, and, media]
# media                            tag:conj       root:courts     children:[]
# a narrative                      tag:dobj       root:build      children:[a]
# either elections                 tag:nsubj      root:be         children:[either]
# they                             tag:nsubj      root:are        children:[]
# Ryan Bohl                        tag:nsubj      root:said       children:[Ryan, ,, analyst]
# a senior Middle East and North Africa analyst tag:appos      root:Bohl       children:[East, at]
# Rane                             tag:pobj       root:at         children:[]
# Erdogan                          tag:nsubj      root:did        children:[]
# this                             tag:dobj       root:did        children:[]
# his party                        tag:nsubj      root:lost       children:[his]
# the Istanbul mayoral race        tag:dobj       root:lost       children:[the, Istanbul, mayoral]
# a greater margin                 tag:pobj       root:by         children:[a, greater]
# a re                             tag:dobj       root:demanding  children:[a]
# -                                tag:dobj       root:demanding  children:[]
# run                              tag:dobj       root:demanding  children:[]
# Some                             tag:nsubj      root:fear       children:[]
# violence                         tag:dobj       root:fear       children:[and, instability]
# instability                      tag:conj       root:violence   children:[]
# the result                       tag:nsubjpass  root:disputed   children:[the]
# which                            tag:nsubj      root:bring      children:[]
# more volatility                  tag:dobj       root:bring      children:[more]
# Turkey’s already damaged economy tag:pobj       root:to         children:[Turkey, damaged]
# Turkish and foreign analysts     tag:nsubj      root:sounding   children:[Turkish, and, activists]
# rights activists                 tag:conj       root:analysts   children:[rights]
# years                            tag:pobj       root:for        children:[]
# the alarm                        tag:dobj       root:sounding   children:[the]
# increasingly autocratic governance tag:pobj       root:over       children:[autocratic, coming]
# Erdogan’s administration         tag:pobj       root:from       children:[Erdogan]
# CNBC                             tag:nsubj      root:reached    children:[]
# the Turkish Presidency’s office  tag:pobj       root:to         children:[Presidency, for]
# comment                          tag:pobj       root:for        children:[]
# stake                            tag:pobj       root:at         children:[]
# The election’s outcome           tag:pobj       root:at         children:[election, and, impact]
# its impact                       tag:conj       root:outcome    children:[its, on]
# stability                        tag:pobj       root:on         children:[in]
# the country                      tag:pobj       root:in         children:[the, ,, sits]
# which                            tag:nsubj      root:sits       children:[]
# a crossroads                     tag:pobj       root:as         children:[a, between]
# Europe                           tag:pobj       root:between    children:[and, Asia]
# Asia                             tag:conj       root:Europe     children:[]
# home                             tag:attr       root:is         children:[to]
# NATO’s second-largest military   tag:pobj       root:to         children:[NATO, largest]
# paramount importance             tag:pobj       root:of         children:[paramount]
# stake                            tag:pobj       root:at         children:[for]
# President Erdogan                tag:pobj       root:for        children:[President, and, AKP]
# his AKP                          tag:conj       root:Erdogan    children:[his, Party]
# (Justice and Development Party   tag:appos      root:AKP        children:[(, Justice, )]
# the first time                   tag:pobj       root:for        children:[the, first]
# his 20-year rule                 tag:nsubj      root:come       children:[his, year, over]
# Türkiye                          tag:pobj       root:over       children:[]
# an end                           tag:pobj       root:to         children:[an]
# the unified opposition           tag:pobj       root:given      children:[the, unified]
# a strong alliance                tag:dobj       root:maintain   children:[a, strong]
# a hope-building positive campaign tag:pobj       root:on         children:[a, building, positive]
# Hakan Akbas                      tag:nsubj      root:said       children:[Hakan, ,, director, based]
# managing director                tag:appos      root:Akbas      children:[managing, of]
# consulting firm Strategic Advisory Services tag:pobj       root:of         children:[firm, Strategic, Advisory]
# Istanbul                         tag:pobj       root:between    children:[and, Washington]
# Washington                       tag:conj       root:Istanbul   children:[]
# This                             tag:nsubj      root:is         children:[]
# he                               tag:nsubj      root:noted      children:[]
# what                             tag:dobj       root:did        children:[]
# Istanbul Mayor Emrak Imamoglu    tag:nsubj      root:did        children:[Mayor, Emrak]
# Erdogan’s AKP candidate          tag:pobj       root:against    children:[Erdogan, AKP]
# the mayoral election             tag:pobj       root:in         children:[the, mayoral]
# Imamoglu                         tag:nsubj      root:was        children:[,, figure, ,]
# a popular figure                 tag:appos      root:Imamoglu   children:[a, popular, expected]
# who                              tag:nsubjpass  root:expected   children:[]
# the presidency                   tag:pobj       root:for        children:[the]
# a formidable opponent            tag:pobj       root:as         children:[a, formidable, to]
# Erdogan                          tag:pobj       root:to         children:[]
# December                         tag:pobj       root:in         children:[]
# nearly three years               tag:pobj       root:to         children:[three, in]
# prison                           tag:pobj       root:in         children:[]
# politics                         tag:pobj       root:from       children:[]
# what                             tag:dobj       root:described  children:[]
# a court                          tag:nsubj      root:described  children:[a]
# the judges                       tag:dobj       root:insulting  children:[the, of]
# the Supreme Election Council     tag:pobj       root:of         children:[the, Supreme, Election, YSK, )]
# (YSK                             tag:appos      root:Council    children:[(]
# Imamoglu                         tag:nsubj      root:say        children:[and, supporters]
# his supporters                   tag:conj       root:Imamoglu   children:[his]
# the charges                      tag:nsubj      root:are        children:[the]
# Erdogan                          tag:pobj       root:by         children:[and, party]
# his party                        tag:conj       root:Erdogan    children:[his]
# his political ambitions          tag:dobj       root:sabotage   children:[his, political]

# %%
print("{}{}{}{}{}{}".format(
    "Token".ljust(15), "Lemma".ljust(15), "POS".ljust(10), "Tag".ljust(8), "Dependency".ljust(14), "StopWord"
))
print("-" * 80)
for token in doc:
    if (not token.is_stop) and len(token.text) > 1:
        print(f"{token.text:15}{token.lemma_:15}{token.pos_:10}{token.tag_:8}{token.dep_:14}{token.is_stop:}")
# Out:
# Token          Lemma          POS       Tag     Dependency    StopWord
# --------------------------------------------------------------------------------
# Millions       million        NOUN      NNS     nsubjpass     False
# Turks          Turks          PROPN     NNPS    pobj          False
# headed         head           VERB      VBN     ROOT          False
# polls          poll           NOUN      NNS     pobj          False
# Sunday         Sunday         PROPN     NNP     npadvmod      False
# set            set            VERB      VBN     pcomp         False
# Turkey         Turkey         PROPN     NNP     poss          False
# consequential  consequential  ADJ       JJ      amod          False
# election       election       NOUN      NN      attr          False
# decades        decade         NOUN      NNS     pobj          False
# results        result         NOUN      NNS     nsubj         False
# implications   implication    NOUN      NNS     dobj          False
# far            far            ADV       RB      advmod        False
# borders        border         NOUN      NNS     pobj          False
# country        country        NOUN      NN      nsubj         False
# 85             85             NUM       CD      compound      False
# million        million        NUM       CD      pobj          False
# holds          hold           VERB      VBZ     ROOT          False
# presidential   presidential   ADJ       JJ      amod          False
# parliamentary  parliamentary  ADJ       JJ      conj          False
# elections      election       NOUN      NNS     dobj          False
# 14             14             NUM       CD      nummod        False
# presidency     presidency     NOUN      NN      pobj          False
# expected       expect         VERB      VBN     advcl         False
# close          close          ADJ       JJ      acomp         False
# candidate      candidate      NOUN      NN      nsubj         False
# wins           win            VERB      VBZ     advcl         False
# 50             50             NUM       CD      nummod        False
# vote           vote           NOUN      NN      nsubj         False
# goes           go             VERB      VBZ     ROOT          False
# run            run            VERB      VB      amod          False
# weeks          week           NOUN      NNS     npadvmod      False
# later          later          ADV       RB      advmod        False
# Incumbent      incumbent      ADJ       JJ      amod          False
# President      President      PROPN     NNP     compound      False
# Recep          Recep          PROPN     NNP     compound      False
# Tayyip         Tayyip         PROPN     NNP     compound      False
# Erdogan        Erdogan        PROPN     NNP     nsubj         False
# facing         face           VERB      VBG     ROOT          False
# toughest       tough          ADJ       JJS     amod          False
# test           test           NOUN      NN      dobj          False
# decades        decade         NOUN      NNS     pobj          False
# power          power          NOUN      NN      pobj          False
# grappling      grapple        VERB      VBG     advcl         False
# public         public         ADJ       JJ      amod          False
# anger          anger          NOUN      NN      pobj          False
# worsening      worsen         VERB      VBG     pcomp         False
# economic       economic       ADJ       JJ      amod          False
# conditions     condition      NOUN      NNS     dobj          False
# slow           slow           ADJ       JJ      amod          False
# government     government     NOUN      NN      compound      False
# response       response       NOUN      NN      dobj          False
# series         series         NOUN      NN      pobj          False
# devastating    devastating    ADJ       JJ      amod          False
# earthquakes    earthquake     NOUN      NNS     pobj          False
# February       February       PROPN     NNP     pobj          False
# killed         kill           VERB      VBD     relcl         False
# 50,000         50,000         NUM       CD      nummod        False
# people         people         NOUN      NNS     dobj          False
# primary        primary        ADJ       JJ      amod          False
# opponent       opponent       NOUN      NN      nsubj         False
# 74             74             NUM       CD      nummod        False
# year           year           NOUN      NN      npadvmod      False
# old            old            ADJ       JJ      amod          False
# Kemal          Kemal          PROPN     NNP     compound      False
# Kilicdaroglu   Kilicdaroglu   PROPN     NNP     appos         False
# center         center         NOUN      NN      npadvmod      False
# left           leave          VERB      VBN     amod          False
# Republican     Republican     PROPN     NNP     compound      False
# People         People         PROPN     NNPS    poss          False
# Party          Party          PROPN     NNP     pobj          False
# CHP            CHP            PROPN     NNP     appos         False
# running        run            VERB      VBG     ROOT          False
# unity          unity          NOUN      NN      compound      False
# candidate      candidate      NOUN      NN      pobj          False
# representing   represent      VERB      VBG     acl           False
# different      different      ADJ       JJ      amod          False
# parties        party          NOUN      NNS     dobj          False
# want           want           VERB      VBP     relcl         False
# Erdogan        Erdogan        PROPN     NNP     dobj          False
# power          power          NOUN      NN      pobj          False
# possibly       possibly       ADV       RB      advmod        False
# game           game           NOUN      NN      npadvmod      False
# changing       change         VERB      VBG     amod          False
# development    development    NOUN      NN      pobj          False
# presidential   presidential   ADJ       JJ      amod          False
# candidates     candidate      NOUN      NNS     pobj          False
# Muharrem       Muharrem       PROPN     NNP     compound      False
# Ince           Ince           PROPN     NNP     appos         False
# pulled         pull           VERB      VBD     ROOT          False
# race           race           NOUN      NN      pobj          False
# Thursday       Thursday       PROPN     NNP     npadvmod      False
# CHP            CHP            PROPN     NNP     compound      False
# member         member         NOUN      NN      advcl         False
# heavy          heavy          ADJ       JJ      amod          False
# criticism      criticism      NOUN      NN      pobj          False
# splitting      split          VERB      VBG     pcomp         False
# opposition     opposition     NOUN      NN      compound      False
# vote           vote           NOUN      NN      dobj          False
# way            way            NOUN      NN      pobj          False
# hurt           hurt           VERB      VB      relcl         False
# Kilicdaroglu   Kilicdaroglu   PROPN     NNP     poss          False
# chances        chance         NOUN      NNS     dobj          False
# Ince           Ince           PROPN     NNP     pobj          False
# race           race           NOUN      NN      pobj          False
# votes          vote           NOUN      NNS     nsubj         False
# Erdogan        Erdogan        PROPN     NNP     poss          False
# challenger     challenger     NOUN      NN      compound      False
# Kilicdaroglu   Kilicdaroglu   PROPN     NNP     pobj          False
# helping        help           VERB      VBG     advcl         False
# tremendously   tremendously   ADV       RB      advmod        False
# spelling       spell          VERB      VBG     conj          False
# trouble        trouble        NOUN      NN      dobj          False
# 69             69             NUM       CD      nummod        False
# year           year           NOUN      NN      npadvmod      False
# old            old            ADJ       JJ      amod          False
# Erdogan        Erdogan        PROPN     NNP     pobj          False
# crucial        crucial        ADJ       JJ      amod          False
# factor         factor         NOUN      NN      nsubj         False
# turnout        turnout        ADJ       JJ      acomp         False
# million        million        NUM       CD      nummod        False
# young          young          ADJ       JJ      amod          False
# Turks          Turks          PROPN     NNPS    nsubj         False
# voting         vote           VERB      VBG     ccomp         False
# time           time           NOUN      NN      pobj          False
# greater        great          ADJ       JJR     amod          False
# youth          youth          NOUN      NN      compound      False
# turnout        turnout        NOUN      NN      conj          False
# better         well           ADJ       JJR     appos         False
# challenger     challenger     NOUN      NN      compound      False
# candidate      candidate      NOUN      NN      pobj          False
# worse          bad            ADJ       JJR     conj          False
# incumbent      incumbent      NOUN      NN      pobj          False
# election       election       NOUN      NN      compound      False
# analysts       analyst        NOUN      NNS     nsubj         False
# high           high           ADJ       JJ      amod          False
# stakes         stake          NOUN      NNS     compound      False
# contest        contest        NOUN      NN      pobj          False
# inside         inside         ADV       RB      advmod        False
# country        country        NOUN      NN      pobj          False
# asking         ask            VERB      VBG     ROOT          False
# Erdogan        Erdogan        PROPN     NNP     nsubj         False
# dispute        dispute        VERB      VB      ccomp         False
# result         result         NOUN      NN      dobj          False
# win            win            VERB      VB      advcl         False
# likely         likely         ADJ       JJ      amod          False
# tactics        tactic         NOUN      NNS     nsubj         False
# going          go             VERB      VBG     relcl         False
# use            use            VERB      VB      xcomp         False
# try            try            VERB      VB      xcomp         False
# tip            tip            VERB      VB      xcomp         False
# vote           vote           NOUN      NN      dobj          False
# use            use            VERB      VB      xcomp         False
# influence      influence      NOUN      NN      dobj          False
# electoral      electoral      PROPN     NNP     compound      False
# board          board          PROPN     NNP     pobj          False
# YSK            YSK            PROPN     NNP     appos         False
# courts         court          NOUN      NNS     conj          False
# media          medium         NOUN      NNS     conj          False
# build          build          VERB      VB      xcomp         False
# narrative      narrative      NOUN      NN      dobj          False
# elections      election       NOUN      NNS     nsubj         False
# run            run            VERB      VB      acomp         False
# illegitimate   illegitimate   ADJ       JJ      acomp         False
# said           say            VERB      VBD     ROOT          False
# Ryan           Ryan           PROPN     NNP     compound      False
# Bohl           Bohl           PROPN     NNP     nsubj         False
# senior         senior         ADJ       JJ      amod          False
# Middle         Middle         PROPN     NNP     compound      False
# East           East           PROPN     NNP     nmod          False
# North          North          PROPN     NNP     compound      False
# Africa         Africa         PROPN     NNP     conj          False
# analyst        analyst        NOUN      NN      appos         False
# Rane           Rane           PROPN     NNP     pobj          False
# Erdogan        Erdogan        PROPN     NNP     nsubj         False
# 2019           2019           NUM       CD      pobj          False
# party          party          NOUN      NN      nsubj         False
# narrowly       narrowly       ADV       RB      advmod        False
# lost           lose           VERB      VBD     advcl         False
# Istanbul       Istanbul       PROPN     NNP     nmod          False
# mayoral        mayoral        ADJ       JJ      amod          False
# race           race           NOUN      NN      dobj          False
# lose           lose           VERB      VB      advcl         False
# greater        great          ADJ       JJR     amod          False
# margin         margin         NOUN      NN      pobj          False
# demanding      demand         VERB      VBG     pcomp         False
# run            run            NOUN      NN      dobj          False
# fear           fear           VERB      VBP     ROOT          False
# violence       violence       NOUN      NN      dobj          False
# instability    instability    NOUN      NN      conj          False
# result         result         NOUN      NN      nsubjpass     False
# disputed       dispute        VERB      VBN     advcl         False
# bring          bring          VERB      VB      advcl         False
# volatility     volatility     NOUN      NN      dobj          False
# Turkey         Turkey         PROPN     NNP     poss          False
# damaged        damage         VERB      VBN     amod          False
# economy        economy        NOUN      NN      pobj          False
# Turkish        turkish        ADJ       JJ      amod          False
# foreign        foreign        ADJ       JJ      conj          False
# analysts       analyst        NOUN      NNS     nsubj         False
# rights         right          NOUN      NNS     compound      False
# activists      activist       NOUN      NNS     conj          False
# years          year           NOUN      NNS     pobj          False
# sounding       sound          VERB      VBG     ROOT          False
# alarm          alarm          NOUN      NN      dobj          False
# increasingly   increasingly   ADV       RB      advmod        False
# autocratic     autocratic     ADJ       JJ      amod          False
# governance     governance     NOUN      NN      pobj          False
# coming         come           VERB      VBG     acl           False
# Erdogan        Erdogan        PROPN     NNP     poss          False
# administration administration NOUN      NN      pobj          False
# CNBC           CNBC           PROPN     NNP     nsubj         False
# reached        reach          VERB      VBN     ROOT          False
# Turkish        Turkish        PROPN     NNP     compound      False
# Presidency     Presidency     PROPN     NNP     poss          False
# office         office         NOUN      NN      pobj          False
# comment        comment        NOUN      NN      pobj          False
# stake          stake          NOUN      NN      pobj          False
# election       election       NOUN      NN      poss          False
# outcome        outcome        NOUN      NN      pobj          False
# impact         impact         NOUN      NN      conj          False
# stability      stability      NOUN      NN      pobj          False
# country        country        NOUN      NN      pobj          False
# sits           sit            VERB      VBZ     relcl         False
# crossroads     crossroad      NOUN      NNS     pobj          False
# Europe         Europe         PROPN     NNP     pobj          False
# Asia           Asia           PROPN     NNP     conj          False
# home           home           NOUN      NN      attr          False
# NATO           NATO           PROPN     NNP     poss          False
# second         second         ADV       RB      advmod        False
# largest        large          ADJ       JJS     amod          False
# military       military       NOUN      NN      pobj          False
# paramount      paramount      ADJ       JJ      amod          False
# importance     importance     NOUN      NN      pobj          False
# domestically   domestically   ADV       RB      advmod        False
# internationallyinternationallyADV       RB      conj          False
# stake          stake          NOUN      NN      pobj          False
# President      President      PROPN     NNP     compound      False
# Erdogan        Erdogan        PROPN     NNP     pobj          False
# AKP            AKP            PROPN     NNP     conj          False
# Justice        Justice        PROPN     NNP     nmod          False
# Development    Development    PROPN     NNP     conj          False
# Party          Party          PROPN     NNP     appos         False
# time           time           NOUN      NN      pobj          False
# 20             20             NUM       CD      nummod        False
# year           year           NOUN      NN      compound      False
# rule           rule           NOUN      NN      nsubj         False
# Türkiye        Türkiye        PROPN     NNP     pobj          False
# come           come           VERB      VB      advcl         False
# end            end            NOUN      NN      pobj          False
# given          give           VERB      VBN     prep          False
# unified        unified        ADJ       JJ      amod          False
# opposition     opposition     NOUN      NN      pobj          False
# managed        manage         VERB      VBN     conj          False
# maintain       maintain       VERB      VB      xcomp         False
# strong         strong         ADJ       JJ      amod          False
# alliance       alliance       NOUN      NN      dobj          False
# stay           stay           VERB      VB      conj          False
# hope           hope           NOUN      NN      npadvmod      False
# building       building       NOUN      NN      nmod          False
# positive       positive       ADJ       JJ      amod          False
# campaign       campaign       NOUN      NN      pobj          False
# said           say            VERB      VBD     ROOT          False
# Hakan          Hakan          PROPN     NNP     compound      False
# Akbas          Akbas          PROPN     NNP     nsubj         False
# managing       manage         VERB      VBG     amod          False
# director       director       NOUN      NN      appos         False
# consulting     consult        VERB      VBG     amod          False
# firm           firm           NOUN      NN      compound      False
# Strategic      Strategic      PROPN     NNP     compound      False
# Advisory       Advisory       PROPN     NNP     compound      False
# Services       Services       PROPN     NNPS    pobj          False
# based          base           VERB      VBN     acl           False
# Istanbul       Istanbul       PROPN     NNP     pobj          False
# Washington     Washington     PROPN     NNP     conj          False
# similar        similar        ADJ       JJ      acomp         False
# noted          note           VERB      VBD     parataxis     False
# Istanbul       Istanbul       PROPN     NNP     compound      False
# Mayor          Mayor          PROPN     NNP     compound      False
# Emrak          Emrak          PROPN     NNP     compound      False
# Imamoglu       Imamoglu       PROPN     NNP     nsubj         False
# win            win            VERB      VB      xcomp         False
# twice          twice          ADV       RB      advmod        False
# Erdogan        Erdogan        PROPN     NNP     poss          False
# AKP            AKP            PROPN     NNP     compound      False
# candidate      candidate      NOUN      NN      pobj          False
# mayoral        mayoral        ADJ       JJ      amod          False
# election       election       NOUN      NN      pobj          False
# 2019           2019           NUM       CD      pobj          False
# Imamoglu       Imamoglu       PROPN     NNP     nsubj         False
# popular        popular        ADJ       JJ      amod          False
# figure         figure         NOUN      NN      appos         False
# widely         widely         ADV       RB      advmod        False
# expected       expect         VERB      VBN     relcl         False
# run            run            VERB      VB      xcomp         False
# presidency     presidency     NOUN      NN      pobj          False
# formidable     formidable     ADJ       JJ      amod          False
# opponent       opponent       NOUN      NN      pobj          False
# Erdogan        Erdogan        PROPN     NNP     pobj          False
# December       December       PROPN     NNP     pobj          False
# sentenced      sentence       VERB      VBN     advcl         False
# nearly         nearly         ADV       RB      advmod        False
# years          year           NOUN      NNS     pobj          False
# prison         prison         NOUN      NN      pobj          False
# barred         bar            VERB      VBN     conj          False
# politics       politic        NOUN      NNS     pobj          False
# court          court          NOUN      NN      nsubj         False
# described      describe       VERB      VBD     pcomp         False
# insulting      insult         VERB      VBG     pcomp         False
# judges         judge          NOUN      NNS     dobj          False
# Supreme        Supreme        PROPN     NNP     compound      False
# Election       Election       PROPN     NNP     compound      False
# Council        Council        PROPN     NNP     pobj          False
# YSK            YSK            PROPN     NNP     appos         False
# Imamoglu       Imamoglu       PROPN     NNP     nsubj         False
# supporters     supporter      NOUN      NNS     conj          False
# charges        charge         NOUN      NNS     nsubj         False
# purely         purely         ADV       RB      advmod        False
# political      political      ADJ       JJ      acomp         False
# influenced     influence      VERB      VBN     conj          False
# Erdogan        Erdogan        PROPN     NNP     pobj          False
# party          party          NOUN      NN      conj          False
# sabotage       sabotage       VERB      VB      xcomp         False
# political      political      ADJ       JJ      amod          False
# ambitions      ambition       NOUN      NNS     dobj          False

# %% [markdown]
# ---

# %%
pipeline.get_noun_phrases_from_document(
    doc=doc,
    remove_special_characters=False,
    remove_stopwords=False,
)
# Out:
# ['the polls',
#  'Turkey’s most consequential election',
#  'two decades',
#  'whose results',
#  'its own borders',
#  'The country',
#  'both its presidential and parliamentary elections',
#  'the presidency',
#  'no candidate',
#  'more than 50%',
#  'the vote',
#  'Incumbent President Recep Tayyip Erdogan',
#  'his toughest test',
#  'two decades',
#  'public anger',
#  'economic conditions',
#  'the slow government response',
#  'a series',
#  'devastating earthquakes',
#  'more than 50,000 people',
#  'His primary opponent',
#  '74-year-old Kemal Kilicdaroglu',
#  'the center-left Republican People’s Party',
#  'a unity candidate',
#  'six different parties',
#  'a possibly game-changing development',
#  'the four presidential candidates',
#  'Muharrem Ince',
#  'the race',
#  'heavy criticism',
#  'the opposition vote',
#  'a way',
#  'Kilicdaroglu’s chances',
#  'the race',
#  'his votes',
#  'Erdogan’s top challenger Kilicdaroglu',
#  'more trouble',
#  'the 69-year-old Erdogan',
#  'Another crucial factor',
#  'More than 5 million young Turks',
#  'the first time',
#  'the challenger candidate',
#  'the incumbent',
#  'election analysts',
#  'such a high-stakes contest',
#  'the country',
#  'the result',
#  'The most likely tactics',
#  'the vote',
#  'the electoral board',
#  'the YSK',
#  'a narrative',
#  'either elections',
#  'Ryan Bohl',
#  'a senior Middle East and North Africa analyst',
#  'his party',
#  'the Istanbul mayoral race',
#  'a greater margin',
#  'a re',
#  'the result',
#  'more volatility',
#  'Turkey’s already damaged economy',
#  'Turkish and foreign analysts',
#  'rights activists',
#  'the alarm',
#  'increasingly autocratic governance',
#  'Erdogan’s administration',
#  'the Turkish Presidency’s office',
#  'The election’s outcome',
#  'its impact',
#  'the country',
#  'a crossroads',
#  'NATO’s second-largest military',
#  'paramount importance',
#  'President Erdogan',
#  'his AKP',
#  '(Justice and Development Party',
#  'the first time',
#  'his 20-year rule',
#  'an end',
#  'the unified opposition',
#  'a strong alliance',
#  'a hope-building positive campaign',
#  'Hakan Akbas',
#  'managing director',
#  'consulting firm Strategic Advisory Services',
#  'Istanbul Mayor Emrak Imamoglu',
#  'Erdogan’s AKP candidate',
#  'the mayoral election',
#  'a popular figure',
#  'the presidency',
#  'a formidable opponent',
#  'nearly three years',
#  'a court',
#  'the judges',
#  'the Supreme Election Council',
#  'his supporters',
#  'the charges',
#  'his party',
#  'his political ambitions']

# %% [markdown]
# # Noun Phrase Entities
#
# Find a phrase that includes an identified named entity.

# %%
print(json.dumps(
    pipeline.get_named_entities_from_text(
        text=text, 
        excludes=["ORDINAL", "CARDINAL", "PERCENT", "DATE", "time", "QUANTITY", "MONEY"],
        remove_special_characters=True,
        return_value_only=True,
        remove_similarity_threshold=0.9,
        include_noun_phrases=True,
        include_keywords=False
    ), 
    indent=4, 
    default=str,
    ensure_ascii=False
))
# Out:
# {
#     "EVENT": [],
#     "FAC": [],
#     "GPE": [
#         "Turkey",
#         "Washington",
#         "Kilicdaroglu",
#         "Türkiye",
#         "Istanbul",
#         "North Africa"
#     ],
#     "LANGUAGE": [],
#     "LAW": [],
#     "LOC": [
#         "Asia",
#         "Middle East",
#         "Europe"
#     ],
#     "NORP": [
#         "Turkish",
#         "Turks"
#     ],
#     "ORG": [
#         "AKP",
#         "CHP",
#         "Supreme Election Council",
#         "Kilicdaroglu",
#         "electoral board",
#         "Development Party",
#         "NATO",
#         "Republican Peoples Party",
#         "Justice",
#         "Erdogan",
#         "CNBC",
#         "Strategic Advisory Services",
#         "the electoral board"
#     ],
#     "PERSON": [
#         "Ryan Bohl",
#         "Kemal Kilicdaroglu",
#         "Recep Tayyip Erdogan",
#         "Imamoglu",
#         "Hakan Akbas",
#         "Emrak Imamoglu",
#         "Rane",
#         "Erdogan",
#         "Muharrem Ince",
#         "Incumbent President Recep Tayyip Erdogan"
#     ],
#     "PRODUCT": [],
#     "WORK_OF_ART": []
# }

# %% [markdown]
# ---
# # Keyword Extraction
#
# * [textacy - Information Extraction](https://textacy.readthedocs.io/en/latest/api_reference/extract.html)

# %%
print(json.dumps(
    pipeline.get_named_entities_from_text(
        text=text, 
        excludes=["ORDINAL", "CARDINAL", "PERCENT", "DATE", "time", "QUANTITY", "MONEY"],
        remove_special_characters=True,
        return_value_only=True,
        remove_similarity_threshold=0.9,
        include_noun_phrases=False,
        include_keywords=True
    ), 
    indent=4, 
    default=str,
    ensure_ascii=False
))
# Out:
# {
#     "EVENT": [],
#     "FAC": [],
#     "GPE": [
#         "Turkey",
#         "Washington",
#         "Kilicdaroglu",
#         "Türkiye",
#         "Istanbul",
#         "North Africa"
#     ],
#     "LANGUAGE": [],
#     "LAW": [],
#     "LOC": [
#         "Asia",
#         "Middle East",
#         "Europe"
#     ],
#     "NORP": [
#         "Turkish",
#         "Turks"
#     ],
#     "ORG": [
#         "AKP",
#         "CHP",
#         "Supreme Election Council",
#         "Kilicdaroglu",
#         "electoral board",
#         "Development Party",
#         "NATO",
#         "Republican Peoples Party",
#         "Justice",
#         "Erdogan",
#         "CNBC",
#         "Strategic Advisory Services"
#     ],
#     "PERSON": [
#         "Ryan Bohl",
#         "Kemal Kilicdaroglu",
#         "Recep Tayyip Erdogan",
#         "Imamoglu",
#         "Hakan Akbas",
#         "Emrak Imamoglu",
#         "Rane",
#         "Erdogan",
#         "Muharrem Ince"
#     ],
#     "PRODUCT": [],
#     "WORK_OF_ART": [],
#     "KEYWORDS": [
#         "incumbent President Recep Tayyip Erdogan",
#         "President Erdogan",
#         "old Erdogan",
#         "Istanbul Mayor Emrak Imamoglu",
#         "Istanbul mayoral race",
#         "election analyst",
#         "mayoral election",
#         "old Kemal Kilicdaroglu",
#         "AKP candidate",
#         "North Africa analyst"
#     ]
# }

# %% [markdown]
# ---
# # Synonyms

# %%
del pipeline, doc

from nltk.corpus import (
    wordnet
)

# %%
def get_synonyms(text: str, pos=None):
    """Get synonym of the POS type. 
    
    "speed" can be verb and noun. To get the synonyms for verb, set pos='v'
    
    Args:
        text: text to find the synonyms
        pos: part of speech tag (n=noun, v=verb, a=adjective, r=adverb)
    Returns: set of synonyms
    """
    text = "_".join(text.split())
    synonyms = wordnet.synsets(text, pos=pos)
    lemmas = set(chain.from_iterable([word.lemma_names() for word in synonyms]))
    return lemmas - {text}

# %%
get_synonyms(text="speed", pos="v")
# Out:
# {'accelerate',
#  'belt_along',
#  'bucket_along',
#  'cannonball_along',
#  'hasten',
#  'hie',
#  'hotfoot',
#  'hurry',
#  'pelt_along',
#  'quicken',
#  'race',
#  'rush',
#  'rush_along',
#  'speed_up',
#  'step_on_it',
#  'travel_rapidly',
#  'zip'}

# %% [markdown]
# ## Conversion
#
# happy -> hapiness
# speedy -> speed

# %%
# Just to make it a bit more readable
WN_NOUN = 'n'
WN_VERB = 'v'
WN_ADJECTIVE = 'a'
WN_ADJECTIVE_SATELLITE = 's'
WN_ADVERB = 'r'


def convert(word, from_pos, to_pos):    
    """ Transform words given from/to POS tags """
    synsets = wordnet.synsets(word, pos=from_pos)

    # Word not found
    if not synsets:
        return []

    # Get all lemmas of the word (consider 'a'and 's' equivalent)
    lemmas = []
    for s in synsets:
        for l in s.lemmas():
            if s.name().split('.')[1] == from_pos or from_pos in (WN_ADJECTIVE, WN_ADJECTIVE_SATELLITE) and s.name().split('.')[1] in (WN_ADJECTIVE, WN_ADJECTIVE_SATELLITE):
                lemmas += [l]

    # Get related forms
    derivationally_related_forms = [(l, l.derivationally_related_forms()) for l in lemmas]

    # filter only the desired pos (consider 'a' and 's' equivalent)
    related_noun_lemmas = []

    for drf in derivationally_related_forms:
        for l in drf[1]:
            if l.synset().name().split('.')[1] == to_pos or to_pos in (WN_ADJECTIVE, WN_ADJECTIVE_SATELLITE) and l.synset().name().split('.')[1] in (WN_ADJECTIVE, WN_ADJECTIVE_SATELLITE):
                related_noun_lemmas += [l]

    # Extract the words from the lemmas
    words = [l.name() for l in related_noun_lemmas]
    len_words = len(words)

    # Build the result in the form of a list containing tuples (word, probability)
    result = [(w, float(words.count(w)) / len_words) for w in set(words)]
    result.sort(key=lambda w:-w[1])

    # return all the possibilities sorted by probability
    return result

# %%
convert("happy", "a", "n")
# Out:
# [('happiness', 0.6), ('felicitousness', 0.2), ('felicity', 0.2)]

# %%
convert("incumbent", "a", "n")
# Out:
# [('incumbency', 1.0)]

# %%
convert("speedy", "a", "n")
# Out:
# [('speed', 0.375),
#  ('speediness', 0.25),
#  ('quickness', 0.125),
#  ('rapidity', 0.125),
#  ('rapidness', 0.125)]

# %%
convert("speedy", "a", "r")
# Out:
# []
