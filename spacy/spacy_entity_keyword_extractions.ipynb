# %%
import re
import spacy
from spacy import displacy

# %%
# %%html
# <style>
# table {float:left}
# </style>
# Out:
# <style>
# table {float:left}
# </style>

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/oonisim/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopwords = nltk.corpus.stopwords.words('english')

# %% [markdown]
# # Language Pipeline

# %%
# By convention "nlp" is the pipeline instance name
nlp = spacy.load("en_core_web_trf")

# %%
text = "Australian Melissa Georgiou (Melissa Georgiou) moved to Finland over a decade ago to seek happiness in one of the coldest and darkest places on Earth. “One of my favorite things about living here is that it's easy to get close to nature whether you're in a residential area or in the middle of the city,” Melissa said. Originally a teacher, 12 years ago, she switched from the beaches of Sydney to the dark winters and cold lakes of Finland, and has never looked back since. Melissa said, “For Finns, the concept of happiness is very different from the Australian concept of happiness. Finns, she said, are happy to accept portrayals of themselves as melancholy and stubborn — a popular local saying is, “People who have happiness must hide it.” “The first thing I noticed here is that you don't go to dinners or barbecues, and you don't talk about real estate. No one asks you where you live, what suburb do you live in, where your kids go to school.” The Finns seem quite happy with the status quo, and they don't always seem to want more. Melissa Georgio's Dark Night in Northern Europe Finland was named the happiest country in the world for the sixth year in a row in the “World Happiness Report” released by the United Nations. “The Nordic countries are often countries with (good) unemployment benefits, pensions, and other benefits,” explains happiness expert and researcher Frank Martela (Frank Martela). However, Frank said that Finland's position in the rankings often surprised its own people. “Finns, they're almost outraged because they don't think this can be true. We listen to sad music and hard rock.” “Therefore, happiness is not part of the Finnish self-image.” The other side of Finnish melancholy is a cultural focus on perseverance. Frank said it redefines the way Finns view happiness — a concept known as “sisu” — which is part of Finnish culture and is hard to translate directly, but can be understood as will, determination, perseverance, and reason to face adversity. This, he said, is best reflected in Finns' favorite pastime — getting warm in a sauna after taking a bath in freezing temperatures. “It's about this paradox — from one extreme to the other, and it's a pretty fun experience... because you need perseverance.” Melissa said, but Finland has many things that are great and can provide happiness for people in this country. Finland is one of the European countries least affected by the COVID-19 pandemic, and experts attribute this to a high level of trust in the government and little resistance to complying with restrictions. Trust in government, on the other hand, stems from a country's investment in its citizens. The public school system rarely tests children and is one of the best in the world. Finland also has a universal health care system with affordable childcare and strong support for parents. Melissa said, “The whole country is taking care of the child's development. This system is very well set up. So from having my son to raising him at home, to sending him to daycare, to going to school, I was very well supported in every aspect of this.” Finland vs. China, which country has the strongest sense of happiness? Since the publication of the World Happiness Report, the Nordic countries have dominated the top ten. In this year's report, Finland and its neighbors Denmark (2nd), Iceland (3rd), Sweden (6th), and Norway (7th) all scored high on happiness indicators, including healthy life expectancy, per capita GDP, low levels of corruption, social support, freedom, trust, and generosity. Other top ten countries/regions include the Netherlands (5th), Switzerland (8th), Luxembourg (9th), and New Zealand (10th). Australia ranked 12th in this report, followed by Canada (13th), Ireland (14th), and the United States (15th). In Asia, Singapore ranked 25th in the world, up two places from last year, Taiwan dropped one place from last year to 27th, Japan rose to 47th, mainland China ranked 64th, and Hong Kong ranked 82nd. Meanwhile, the polling agency Ipsos Group (Ipsos) released a survey report on the global happiness index. The results showed that out of 32 countries, the country with the highest happiness index was China (91%), followed by Saudi Arabia (86%), the Netherlands (85%), India (84%), and Brazil (83%). Australia ranked 9th in this report. According to the survey report, on average, happiness increased more significantly in middle-income countries (as defined by the World Bank) than in high-income countries."

# %%
# text = "Australian Melissa Georgiou moved to Finland over a decade ago to seek happiness in one of the coldest and darkest places on Earth."

# %% [markdown]
# # Processed Document

# %%
doc = nlp(text)

# %% [markdown]
# # Dependencies

# %%
print("{}{}{}{}{}".format(
    "Token".ljust(15), "POS".ljust(10), "Tag".ljust(8), "Dependency".ljust(14), "Head"
))
print("-" * 80)
for token in doc:
    print(f"{token.text:15}{token.pos_:10}{token.tag_:8}{token.dep_:14}{token.head.text}")
# Out:
# Token          POS       Tag     Dependency    Head
# --------------------------------------------------------------------------------
# Australian     PROPN     NNP     compound      Georgiou
# Melissa        PROPN     NNP     compound      Georgiou
# Georgiou       PROPN     NNP     nsubj         moved
# (              PUNCT     -LRB-   punct         Georgiou
# Melissa        PROPN     NNP     compound      Georgiou
# Georgiou       PROPN     NNP     appos         Georgiou
# )              PUNCT     -RRB-   punct         Georgiou
# moved          VERB      VBD     ROOT          moved
# to             ADP       IN      prep          moved
# Finland        PROPN     NNP     pobj          to
# over           ADP       IN      nmod          decade
# a              DET       DT      det           decade
# decade         NOUN      NN      npadvmod      ago
# ago            ADV       RB      advmod        moved
# to             PART      TO      aux           seek
# seek           VERB      VB      advcl         moved
# happiness      NOUN      NN      dobj          seek
# in             ADP       IN      prep          seek
# one            NUM       CD      pobj          in
# of             ADP       IN      prep          one
# the            DET       DT      det           places
# coldest        ADJ       JJS     amod          places
# and            CCONJ     CC      cc            coldest
# darkest        ADJ       JJS     conj          coldest
# places         NOUN      NNS     pobj          of
# on             ADP       IN      prep          places
# Earth          PROPN     NNP     pobj          on
# .              PUNCT     .       punct         moved
# “              PUNCT     ``      punct         said
# One            NUM       CD      nsubj         is
# of             ADP       IN      prep          One
# my             PRON      PRP$    poss          things
# favorite       ADJ       JJ      amod          things
# things         NOUN      NNS     pobj          of
# about          ADP       IN      prep          things
# living         VERB      VBG     pcomp         about
# here           ADV       RB      advmod        living
# is             AUX       VBZ     ccomp         said
# that           SCONJ     IN      mark          's
# it             PRON      PRP     nsubj         's
# 's             AUX       VBZ     ccomp         is
# easy           ADJ       JJ      acomp         's
# to             PART      TO      aux           get
# get            VERB      VB      xcomp         's
# close          ADV       RB      advmod        get
# to             ADP       IN      prep          close
# nature         NOUN      NN      pobj          to
# whether        SCONJ     IN      mark          're
# you            PRON      PRP     nsubj         're
# 're            AUX       VBP     advcl         's
# in             ADP       IN      prep          're
# a              DET       DT      det           area
# residential    ADJ       JJ      amod          area
# area           NOUN      NN      pobj          in
# or             CCONJ     CC      cc            in
# in             ADP       IN      conj          in
# the            DET       DT      det           middle
# middle         NOUN      NN      pobj          in
# of             ADP       IN      prep          middle
# the            DET       DT      det           city
# city           NOUN      NN      pobj          of
# ,              PUNCT     ,       punct         said
# ”              PUNCT     ''      punct         said
# Melissa        PROPN     NNP     nsubj         said
# said           VERB      VBD     ROOT          said
# .              PUNCT     .       punct         said
# Originally     ADV       RB      advmod        teacher
# a              DET       DT      det           teacher
# teacher        NOUN      NN      advcl         switched
# ,              PUNCT     ,       punct         switched
# 12             NUM       CD      nummod        years
# years          NOUN      NNS     npadvmod      ago
# ago            ADV       RB      advmod        switched
# ,              PUNCT     ,       punct         switched
# she            PRON      PRP     nsubj         switched
# switched       VERB      VBD     ROOT          switched
# from           ADP       IN      prep          switched
# the            DET       DT      det           beaches
# beaches        NOUN      NNS     pobj          from
# of             ADP       IN      prep          beaches
# Sydney         PROPN     NNP     pobj          of
# to             ADP       IN      prep          switched
# the            DET       DT      det           winters
# dark           ADJ       JJ      amod          winters
# winters        NOUN      NNS     pobj          to
# and            CCONJ     CC      cc            winters
# cold           ADJ       JJ      amod          lakes
# lakes          NOUN      NNS     conj          winters
# of             ADP       IN      prep          winters
# Finland        PROPN     NNP     pobj          of
# ,              PUNCT     ,       punct         switched
# and            CCONJ     CC      cc            switched
# has            AUX       VBZ     aux           looked
# never          ADV       RB      neg           looked
# looked         VERB      VBN     conj          switched
# back           ADV       RB      advmod        looked
# since          ADV       RB      advmod        looked
# .              PUNCT     .       punct         switched
# Melissa        PROPN     NNP     nsubj         said
# said           VERB      VBD     ROOT          said
# ,              PUNCT     ,       punct         said
# “              PUNCT     ``      punct         is
# For            ADP       IN      prep          is
# Finns          PROPN     NNPS    pobj          For
# ,              PUNCT     ,       punct         is
# the            DET       DT      det           concept
# concept        NOUN      NN      nsubj         is
# of             ADP       IN      prep          concept
# happiness      NOUN      NN      pobj          of
# is             AUX       VBZ     ccomp         said
# very           ADV       RB      advmod        different
# different      ADJ       JJ      acomp         is
# from           ADP       IN      prep          different
# the            DET       DT      det           concept
# Australian     ADJ       JJ      amod          concept
# concept        NOUN      NN      pobj          from
# of             ADP       IN      prep          concept
# happiness      NOUN      NN      pobj          of
# .              PUNCT     .       punct         said
# Finns          PROPN     NNPS    nsubj         are
# ,              PUNCT     ,       punct         said
# she            PRON      PRP     nsubj         said
# said           VERB      VBD     parataxis     are
# ,              PUNCT     ,       punct         said
# are            AUX       VBP     ccomp         is
# happy          ADJ       JJ      acomp         are
# to             PART      TO      aux           accept
# accept         VERB      VB      xcomp         happy
# portrayals     NOUN      NNS     dobj          accept
# of             ADP       IN      prep          portrayals
# themselves     PRON      PRP     pobj          of
# as             ADP       IN      prep          portrayals
# melancholy     ADJ       JJ      amod          as
# and            CCONJ     CC      cc            melancholy
# stubborn       ADJ       JJ      conj          melancholy
# —              PUNCT     :       punct         is
# a              DET       DT      det           saying
# popular        ADJ       JJ      amod          saying
# local          ADJ       JJ      amod          saying
# saying         NOUN      NN      nsubj         is
# is             AUX       VBZ     ROOT          is
# ,              PUNCT     ,       punct         is
# “              PUNCT     ``      punct         is
# People         NOUN      NNS     nsubj         hide
# who            PRON      WP      nsubj         have
# have           VERB      VBP     relcl         People
# happiness      NOUN      NN      dobj          have
# must           AUX       MD      aux           hide
# hide           VERB      VB      ccomp         is
# it             PRON      PRP     dobj          hide
# .              PUNCT     .       punct         is
# ”              PUNCT     ''      punct         is
# “              PUNCT     ``      punct         is
# The            DET       DT      det           thing
# first          ADJ       JJ      amod          thing
# thing          NOUN      NN      nsubj         is
# I              PRON      PRP     nsubj         noticed
# noticed        VERB      VBD     relcl         thing
# here           ADV       RB      advmod        noticed
# is             AUX       VBZ     ROOT          is
# that           SCONJ     IN      mark          go
# you            PRON      PRP     nsubj         go
# do             AUX       VBP     aux           go
# n't            PART      RB      neg           go
# go             VERB      VB      ccomp         is
# to             ADP       IN      prep          go
# dinners        NOUN      NNS     pobj          to
# or             CCONJ     CC      cc            dinners
# barbecues      NOUN      NNS     conj          dinners
# ,              PUNCT     ,       punct         go
# and            CCONJ     CC      cc            go
# you            PRON      PRP     nsubj         talk
# do             AUX       VBP     aux           talk
# n't            PART      RB      neg           talk
# talk           VERB      VB      conj          go
# about          ADP       IN      prep          talk
# real           ADJ       JJ      amod          estate
# estate         NOUN      NN      pobj          about
# .              PUNCT     .       punct         is
# No             DET       DT      det           one
# one            NOUN      NN      nsubj         asks
# asks           VERB      VBZ     ROOT          asks
# you            PRON      PRP     dobj          asks
# where          SCONJ     WRB     advmod        live
# you            PRON      PRP     nsubj         live
# live           VERB      VBP     advcl         go
# ,              PUNCT     ,       punct         go
# what           PRON      WP      det           suburb
# suburb         NOUN      NN      pobj          in
# do             AUX       VBP     aux           live
# you            PRON      PRP     nsubj         live
# live           VERB      VB      dep           go
# in             ADP       IN      prep          live
# ,              PUNCT     ,       punct         live
# where          SCONJ     WRB     advmod        go
# your           PRON      PRP$    poss          kids
# kids           NOUN      NNS     nsubj         go
# go             VERB      VBP     ccomp         asks
# to             ADP       IN      prep          go
# school         NOUN      NN      pobj          to
# .              PUNCT     .       punct         asks
# ”              PUNCT     ''      punct         asks
# The            DET       DT      det           Finns
# Finns          PROPN     NNPS    nsubj         seem
# seem           VERB      VBP     ROOT          seem
# quite          ADV       RB      advmod        happy
# happy          ADJ       JJ      oprd          seem
# with           ADP       IN      prep          happy
# the            DET       DT      det           quo
# status         NOUN      NN      compound      quo
# quo            NOUN      NN      pobj          with
# ,              PUNCT     ,       punct         seem
# and            CCONJ     CC      cc            seem
# they           PRON      PRP     nsubj         seem
# do             AUX       VBP     aux           seem
# n't            PART      RB      neg           seem
# always         ADV       RB      advmod        seem
# seem           VERB      VB      conj          seem
# to             PART      TO      aux           want
# want           VERB      VB      xcomp         seem
# more           ADJ       JJR     dobj          want
# .              PUNCT     .       punct         seem
# Melissa        PROPN     NNP     compound      Georgio
# Georgio        PROPN     NNP     poss          Night
# 's             PART      POS     case          Georgio
# Dark           PROPN     NNP     compound      Night
# Night          PROPN     NNP     nsubjpass     named
# in             ADP       IN      prep          Night
# Northern       PROPN     NNP     compound      Europe
# Europe         PROPN     NNP     pobj          in
# Finland        PROPN     NNP     appos         Night
# was            AUX       VBD     auxpass       named
# named          VERB      VBN     ROOT          named
# the            DET       DT      det           country
# happiest       ADJ       JJS     amod          country
# country        NOUN      NN      oprd          named
# in             ADP       IN      prep          country
# the            DET       DT      det           world
# world          NOUN      NN      pobj          in
# for            ADP       IN      prep          named
# the            DET       DT      det           year
# sixth          ADJ       JJ      amod          year
# year           NOUN      NN      pobj          for
# in             ADP       IN      prep          year
# a              DET       DT      det           row
# row            NOUN      NN      pobj          in
# in             ADP       IN      prep          named
# the            DET       DT      det           Report
# “              PUNCT     ``      punct         Report
# World          PROPN     NNP     compound      Report
# Happiness      PROPN     NNP     compound      Report
# Report         PROPN     NNP     pobj          in
# ”              PUNCT     ''      punct         Report
# released       VERB      VBN     acl           Report
# by             ADP       IN      agent         released
# the            DET       DT      det           Nations
# United         PROPN     NNP     compound      Nations
# Nations        PROPN     NNP     pobj          by
# .              PUNCT     .       punct         named
# “              PUNCT     ``      punct         explains
# The            DET       DT      det           countries
# Nordic         ADJ       JJ      amod          countries
# countries      NOUN      NNS     nsubj         are
# are            AUX       VBP     ccomp         explains
# often          ADV       RB      advmod        are
# countries      NOUN      NNS     attr          are
# with           ADP       IN      prep          countries
# (              PUNCT     -LRB-   punct         benefits
# good           ADJ       JJ      amod          benefits
# )              PUNCT     -RRB-   punct         benefits
# unemployment   NOUN      NN      compound      benefits
# benefits       NOUN      NNS     pobj          with
# ,              PUNCT     ,       punct         benefits
# pensions       NOUN      NNS     conj          benefits
# ,              PUNCT     ,       punct         pensions
# and            CCONJ     CC      cc            pensions
# other          ADJ       JJ      amod          benefits
# benefits       NOUN      NNS     conj          pensions
# ,              PUNCT     ,       punct         explains
# ”              PUNCT     ''      punct         explains
# explains       VERB      VBZ     ROOT          explains
# happiness      NOUN      NN      compound      expert
# expert         NOUN      NN      nmod          Martela
# and            CCONJ     CC      cc            expert
# researcher     NOUN      NN      conj          expert
# Frank          PROPN     NNP     compound      Martela
# Martela        PROPN     NNP     nsubj         explains
# (              PUNCT     -LRB-   punct         Martela
# Frank          PROPN     NNP     compound      Martela
# Martela        PROPN     NNP     appos         Martela
# )              PUNCT     -RRB-   punct         Martela
# .              PUNCT     -RRB-   punct         explains
# However        ADV       RB      advmod        said
# ,              PUNCT     ,       punct         said
# Frank          PROPN     NNP     nsubj         said
# said           VERB      VBD     ROOT          said
# that           SCONJ     IN      mark          surprised
# Finland        PROPN     NNP     poss          position
# 's             PART      POS     case          Finland
# position       NOUN      NN      nsubj         surprised
# in             ADP       IN      prep          position
# the            DET       DT      det           rankings
# rankings       NOUN      NNS     pobj          in
# often          ADV       RB      advmod        surprised
# surprised      VERB      VBD     ccomp         said
# its            PRON      PRP$    poss          people
# own            ADJ       JJ      amod          people
# people         NOUN      NNS     dobj          surprised
# .              PUNCT     .       punct         said
# “              PUNCT     ``      punct         're
# Finns          PROPN     NNPS    npadvmod      're
# ,              PUNCT     ,       punct         're
# they           PRON      PRP     nsubj         're
# 're            AUX       VBP     ROOT          're
# almost         ADV       RB      advmod        outraged
# outraged       ADJ       JJ      acomp         're
# because        SCONJ     IN      mark          think
# they           PRON      PRP     nsubj         think
# do             AUX       VBP     aux           think
# n't            PART      RB      neg           think
# think          VERB      VB      advcl         're
# this           PRON      DT      nsubj         be
# can            AUX       MD      aux           be
# be             AUX       VB      ccomp         think
# true           ADJ       JJ      acomp         be
# .              PUNCT     .       punct         're
# We             PRON      PRP     nsubj         listen
# listen         VERB      VBP     ROOT          listen
# to             ADP       IN      prep          listen
# sad            ADJ       JJ      amod          music
# music          NOUN      NN      pobj          to
# and            CCONJ     CC      cc            music
# hard           ADJ       JJ      amod          rock
# rock           NOUN      NN      conj          music
# .              PUNCT     .       punct         listen
# ”              PUNCT     ''      punct         listen
# “              PUNCT     ``      punct         is
# Therefore      ADV       RB      advmod        is
# ,              PUNCT     ,       punct         is
# happiness      NOUN      NN      nsubj         is
# is             AUX       VBZ     ROOT          is
# not            PART      RB      neg           is
# part           NOUN      NN      attr          is
# of             ADP       IN      prep          part
# the            DET       DT      det           image
# Finnish        ADJ       JJ      amod          image
# self           NOUN      NN      compound      image
# -              PUNCT     HYPH    punct         image
# image          NOUN      NN      pobj          of
# .              PUNCT     .       punct         is
# ”              PUNCT     ''      punct         is
# The            DET       DT      det           side
# other          ADJ       JJ      amod          side
# side           NOUN      NN      nsubj         is
# of             ADP       IN      prep          side
# Finnish        ADJ       JJ      amod          melancholy
# melancholy     NOUN      NN      pobj          of
# is             AUX       VBZ     ROOT          is
# a              DET       DT      det           focus
# cultural       ADJ       JJ      amod          focus
# focus          NOUN      NN      attr          is
# on             ADP       IN      prep          focus
# perseverance   NOUN      NN      pobj          on
# .              PUNCT     .       punct         is
# Frank          PROPN     NNP     nsubj         said
# said           VERB      VBD     ROOT          said
# it             PRON      PRP     nsubj         redefines
# redefines      VERB      VBZ     ccomp         said
# the            DET       DT      det           way
# way            NOUN      NN      dobj          redefines
# Finns          PROPN     NNPS    nsubj         view
# view           VERB      VBP     relcl         way
# happiness      NOUN      NN      dobj          view
# —              PUNCT     :       punct         happiness
# a              DET       DT      det           concept
# concept        NOUN      NN      appos         happiness
# known          VERB      VBN     acl           concept
# as             ADP       IN      prep          known
# “              PUNCT     ``      punct         sisu
# sisu           NOUN      NN      pobj          as
# ”              PUNCT     ''      punct         sisu
# —              PUNCT     :       punct         as
# which          PRON      WDT     nsubj         is
# is             AUX       VBZ     relcl         concept
# part           NOUN      NN      attr          is
# of             ADP       IN      prep          part
# Finnish        ADJ       JJ      amod          culture
# culture        NOUN      NN      pobj          of
# and            CCONJ     CC      cc            is
# is             AUX       VBZ     conj          is
# hard           ADJ       JJ      acomp         is
# to             PART      TO      aux           translate
# translate      VERB      VB      xcomp         hard
# directly       ADV       RB      advmod        translate
# ,              PUNCT     ,       punct         is
# but            CCONJ     CC      cc            is
# can            AUX       MD      aux           understood
# be             AUX       VB      auxpass       understood
# understood     VERB      VBN     conj          is
# as             ADP       IN      prep          understood
# will           NOUN      NN      pobj          as
# ,              PUNCT     ,       punct         will
# determination  NOUN      NN      conj          will
# ,              PUNCT     ,       punct         determination
# perseverance   NOUN      NN      conj          determination
# ,              PUNCT     ,       punct         perseverance
# and            CCONJ     CC      cc            perseverance
# reason         NOUN      NN      conj          perseverance
# to             PART      TO      aux           face
# face           VERB      VB      relcl         reason
# adversity      NOUN      NN      dobj          face
# .              PUNCT     .       punct         said
# This           PRON      DT      nsubjpass     reflected
# ,              PUNCT     ,       punct         said
# he             PRON      PRP     nsubj         said
# said           VERB      VBD     parataxis     reflected
# ,              PUNCT     ,       punct         said
# is             AUX       VBZ     auxpass       reflected
# best           ADV       RBS     advmod        reflected
# reflected      VERB      VBN     ROOT          reflected
# in             ADP       IN      prep          reflected
# Finns          PROPN     NNPS    poss          pastime
# '              PART      POS     case          Finns
# favorite       ADJ       JJ      amod          pastime
# pastime        NOUN      NN      pobj          in
# —              PUNCT     :       punct         pastime
# getting        VERB      VBG     acl           pastime
# warm           ADJ       JJ      acomp         getting
# in             ADP       IN      prep          getting
# a              DET       DT      det           sauna
# sauna          NOUN      NN      pobj          in
# after          ADP       IN      prep          getting
# taking         VERB      VBG     pcomp         after
# a              DET       DT      det           bath
# bath           NOUN      NN      dobj          taking
# in             ADP       IN      prep          taking
# freezing       ADJ       JJ      amod          temperatures
# temperatures   NOUN      NNS     pobj          in
# .              PUNCT     .       punct         reflected
# “              PUNCT     ``      punct         's
# It             PRON      PRP     nsubj         's
# 's             AUX       VBZ     ROOT          's
# about          ADP       IN      prep          's
# this           DET       DT      det           paradox
# paradox        NOUN      NN      pobj          about
# —              PUNCT     :       punct         paradox
# from           ADP       IN      prep          paradox
# one            NUM       CD      nummod        extreme
# extreme        NOUN      NN      pobj          from
# to             ADP       IN      prep          from
# the            DET       DT      det           other
# other          ADJ       JJ      pobj          to
# ,              PUNCT     ,       punct         's
# and            CCONJ     CC      cc            's
# it             PRON      PRP     nsubj         's
# 's             AUX       VBZ     conj          's
# a              DET       DT      det           experience
# pretty         ADV       RB      advmod        fun
# fun            ADJ       JJ      amod          experience
# experience     NOUN      NN      attr          's
# ...            PUNCT     :       punct         's
# because        SCONJ     IN      mark          need
# you            PRON      PRP     nsubj         need
# need           VERB      VBP     advcl         's
# perseverance   NOUN      NN      dobj          need
# .              PUNCT     .       punct         's
# ”              PUNCT     ''      punct         's
# Melissa        PROPN     NNP     nsubj         said
# said           VERB      VBD     ROOT          said
# ,              PUNCT     ,       punct         said
# but            CCONJ     CC      cc            said
# Finland        PROPN     NNP     nsubj         has
# has            VERB      VBZ     conj          said
# many           ADJ       JJ      amod          things
# things         NOUN      NNS     dobj          has
# that           PRON      WDT     nsubj         are
# are            AUX       VBP     relcl         things
# great          ADJ       JJ      acomp         are
# and            CCONJ     CC      cc            are
# can            AUX       MD      aux           provide
# provide        VERB      VB      conj          are
# happiness      NOUN      NN      dobj          provide
# for            ADP       IN      prep          provide
# people         NOUN      NNS     pobj          for
# in             ADP       IN      prep          people
# this           DET       DT      det           country
# country        NOUN      NN      pobj          in
# .              PUNCT     .       punct         has
# Finland        PROPN     NNP     nsubj         is
# is             AUX       VBZ     ROOT          is
# one            NUM       CD      attr          is
# of             ADP       IN      prep          one
# the            DET       DT      det           countries
# European       ADJ       JJ      amod          countries
# countries      NOUN      NNS     pobj          of
# least          ADV       RBS     advmod        affected
# affected       VERB      VBN     acl           countries
# by             ADP       IN      agent         affected
# the            DET       DT      det           pandemic
# COVID-19       PROPN     NNP     nmod          pandemic
# pandemic       NOUN      NN      pobj          by
# ,              PUNCT     ,       punct         is
# and            CCONJ     CC      cc            is
# experts        NOUN      NNS     nsubj         attribute
# attribute      VERB      VBP     conj          is
# this           PRON      DT      dobj          attribute
# to             ADP       IN      prep          attribute
# a              DET       DT      det           level
# high           ADJ       JJ      amod          level
# level          NOUN      NN      pobj          to
# of             ADP       IN      prep          level
# trust          NOUN      NN      pobj          of
# in             ADP       IN      prep          trust
# the            DET       DT      det           government
# government     NOUN      NN      pobj          in
# and            CCONJ     CC      cc            level
# little         ADJ       JJ      amod          resistance
# resistance     NOUN      NN      conj          level
# to             ADP       IN      prep          resistance
# complying      VERB      VBG     pcomp         to
# with           ADP       IN      prep          complying
# restrictions   NOUN      NNS     pobj          with
# .              PUNCT     .       punct         attribute
# Trust          NOUN      NN      nsubj         stems
# in             ADP       IN      prep          Trust
# government     NOUN      NN      pobj          in
# ,              PUNCT     ,       punct         stems
# on             ADP       IN      prep          stems
# the            DET       DT      det           hand
# other          ADJ       JJ      amod          hand
# hand           NOUN      NN      pobj          on
# ,              PUNCT     ,       punct         stems
# stems          VERB      VBZ     ROOT          stems
# from           ADP       IN      prep          stems
# a              DET       DT      det           country
# country        NOUN      NN      poss          investment
# 's             PART      POS     case          country
# investment     NOUN      NN      pobj          from
# in             ADP       IN      prep          investment
# its            PRON      PRP$    poss          citizens
# citizens       NOUN      NNS     pobj          in
# .              PUNCT     .       punct         stems
# The            DET       DT      det           system
# public         ADJ       JJ      amod          system
# school         NOUN      NN      compound      system
# system         NOUN      NN      nsubj         tests
# rarely         ADV       RB      advmod        tests
# tests          VERB      VBZ     ROOT          tests
# children       NOUN      NNS     dobj          tests
# and            CCONJ     CC      cc            tests
# is             AUX       VBZ     conj          tests
# one            NUM       CD      attr          is
# of             ADP       IN      prep          one
# the            DET       DT      det           best
# best           ADJ       JJS     pobj          of
# in             ADP       IN      prep          best
# the            DET       DT      det           world
# world          NOUN      NN      pobj          in
# .              PUNCT     .       punct         tests
# Finland        PROPN     NNP     nsubj         has
# also           ADV       RB      advmod        has
# has            VERB      VBZ     ROOT          has
# a              DET       DT      det           system
# universal      ADJ       JJ      amod          system
# health         NOUN      NN      compound      care
# care           NOUN      NN      compound      system
# system         NOUN      NN      dobj          has
# with           ADP       IN      prep          system
# affordable     ADJ       JJ      amod          childcare
# childcare      NOUN      NN      pobj          with
# and            CCONJ     CC      cc            childcare
# strong         ADJ       JJ      amod          support
# support        NOUN      NN      conj          childcare
# for            ADP       IN      prep          support
# parents        NOUN      NNS     pobj          for
# .              PUNCT     .       punct         has
# Melissa        PROPN     NNP     nsubj         said
# said           VERB      VBD     ROOT          said
# ,              PUNCT     ,       punct         said
# “              PUNCT     ``      punct         said
# The            DET       DT      det           country
# whole          ADJ       JJ      amod          country
# country        NOUN      NN      nsubj         taking
# is             AUX       VBZ     aux           taking
# taking         VERB      VBG     ccomp         said
# care           NOUN      NN      dobj          taking
# of             ADP       IN      prep          taking
# the            DET       DT      det           child
# child          NOUN      NN      poss          development
# 's             PART      POS     case          child
# development    NOUN      NN      pobj          of
# .              PUNCT     .       punct         said
# This           DET       DT      det           system
# system         NOUN      NN      nsubjpass     set
# is             AUX       VBZ     auxpass       set
# very           ADV       RB      advmod        well
# well           ADV       RB      advmod        set
# set            VERB      VBN     ROOT          set
# up             ADP       RP      prt           set
# .              PUNCT     .       punct         set
# So             ADV       RB      advmod        supported
# from           ADP       IN      prep          supported
# having         VERB      VBG     pcomp         from
# my             PRON      PRP$    poss          son
# son            NOUN      NN      dobj          having
# to             ADP       IN      prep          from
# raising        VERB      VBG     pcomp         to
# him            PRON      PRP     dobj          raising
# at             ADP       IN      prep          raising
# home           NOUN      NN      pobj          at
# ,              PUNCT     ,       punct         from
# to             ADP       IN      prep          from
# sending        VERB      VBG     pcomp         to
# him            PRON      PRP     dobj          sending
# to             ADP       IN      prep          sending
# daycare        NOUN      NN      pobj          to
# ,              PUNCT     ,       punct         from
# to             ADP       IN      prep          from
# going          VERB      VBG     pcomp         to
# to             ADP       IN      prep          going
# school         NOUN      NN      pobj          to
# ,              PUNCT     ,       punct         supported
# I              PRON      PRP     nsubjpass     supported
# was            AUX       VBD     auxpass       supported
# very           ADV       RB      advmod        well
# well           ADV       RB      advmod        supported
# supported      VERB      VBN     ROOT          supported
# in             ADP       IN      prep          supported
# every          DET       DT      det           aspect
# aspect         NOUN      NN      pobj          in
# of             ADP       IN      prep          aspect
# this           PRON      DT      pobj          of
# .              PUNCT     .       punct         supported
# ”              PUNCT     ''      punct         supported
# Finland        PROPN     NNP     dep           has
# vs.            ADP       IN      prep          Finland
# China          PROPN     NNP     pobj          vs.
# ,              PUNCT     ,       punct         has
# which          DET       WDT     det           country
# country        NOUN      NN      nsubj         has
# has            VERB      VBZ     ROOT          has
# the            DET       DT      det           sense
# strongest      ADJ       JJS     amod          sense
# sense          NOUN      NN      dobj          has
# of             ADP       IN      prep          sense
# happiness      NOUN      NN      pobj          of
# ?              PUNCT     .       punct         has
# Since          SCONJ     IN      prep          dominated
# the            DET       DT      det           publication
# publication    NOUN      NN      pobj          Since
# of             ADP       IN      prep          publication
# the            DET       DT      det           Report
# World          PROPN     NNP     compound      Happiness
# Happiness      PROPN     NNP     compound      Report
# Report         PROPN     NNP     pobj          of
# ,              PUNCT     ,       punct         dominated
# the            DET       DT      det           countries
# Nordic         ADJ       JJ      amod          countries
# countries      NOUN      NNS     nsubj         dominated
# have           AUX       VBP     aux           dominated
# dominated      VERB      VBN     ROOT          dominated
# the            DET       DT      det           ten
# top            ADJ       JJ      amod          ten
# ten            NUM       CD      dobj          dominated
# .              PUNCT     .       punct         dominated
# In             ADP       IN      prep          scored
# this           DET       DT      det           year
# year           NOUN      NN      poss          report
# 's             PART      POS     case          year
# report         NOUN      NN      pobj          In
# ,              PUNCT     ,       punct         scored
# Finland        PROPN     NNP     nsubj         scored
# and            CCONJ     CC      cc            Finland
# its            PRON      PRP$    poss          neighbors
# neighbors      NOUN      NNS     conj          Finland
# Denmark        PROPN     NNP     appos         neighbors
# (              PUNCT     -LRB-   punct         Denmark
# 2nd            ADJ       JJ      amod          Denmark
# )              PUNCT     -RRB-   punct         Denmark
# ,              PUNCT     -RRB-   punct         Denmark
# Iceland        PROPN     NNP     conj          Denmark
# (              PUNCT     -LRB-   punct         Iceland
# 3rd            ADJ       JJ      npadvmod      Iceland
# )              PUNCT     -RRB-   punct         Iceland
# ,              PUNCT     -RRB-   punct         Iceland
# Sweden         PROPN     NNP     conj          Iceland
# (              PUNCT     -LRB-   punct         Sweden
# 6th            ADJ       JJ      amod          Sweden
# )              PUNCT     -RRB-   punct         Sweden
# ,              PUNCT     -RRB-   punct         Sweden
# and            CCONJ     CC      cc            Sweden
# Norway         PROPN     NNP     conj          Sweden
# (              PUNCT     -LRB-   punct         Norway
# 7th            ADJ       JJ      npadvmod      Norway
# )              PUNCT     -RRB-   punct         Norway
# all            PRON      DT      dep           scored
# scored         VERB      VBD     ROOT          scored
# high           ADV       RB      advmod        scored
# on             ADP       IN      prep          scored
# happiness      NOUN      NN      compound      indicators
# indicators     NOUN      NNS     pobj          on
# ,              PUNCT     ,       punct         indicators
# including      VERB      VBG     prep          indicators
# healthy        ADJ       JJ      amod          expectancy
# life           NOUN      NN      compound      expectancy
# expectancy     NOUN      NN      pobj          including
# ,              PUNCT     ,       punct         expectancy
# per            ADP       IN      nmod          GDP
# capita         X         FW      pobj          per
# GDP            NOUN      NN      conj          expectancy
# ,              PUNCT     ,       punct         GDP
# low            ADJ       JJ      amod          levels
# levels         NOUN      NNS     conj          GDP
# of             ADP       IN      prep          levels
# corruption     NOUN      NN      pobj          of
# ,              PUNCT     ,       punct         levels
# social         ADJ       JJ      amod          support
# support        NOUN      NN      conj          levels
# ,              PUNCT     ,       punct         support
# freedom        NOUN      NN      conj          support
# ,              PUNCT     ,       punct         freedom
# trust          NOUN      NN      conj          freedom
# ,              PUNCT     ,       punct         trust
# and            CCONJ     CC      cc            trust
# generosity     NOUN      NN      conj          trust
# .              PUNCT     .       punct         scored
# Other          ADJ       JJ      amod          regions
# top            ADJ       JJ      amod          regions
# ten            NUM       CD      nummod        countries
# countries      NOUN      NNS     nmod          regions
# /              SYM       SYM     punct         regions
# regions        NOUN      NNS     nsubj         include
# include        VERB      VBP     ROOT          include
# the            DET       DT      det           Netherlands
# Netherlands    PROPN     NNPS    dobj          include
# (              PUNCT     -LRB-   punct         Netherlands
# 5th            ADJ       JJ      npadvmod      Netherlands
# )              PUNCT     -RRB-   punct         Netherlands
# ,              PUNCT     -RRB-   punct         Netherlands
# Switzerland    PROPN     NNP     conj          Netherlands
# (              PUNCT     -LRB-   punct         Switzerland
# 8th            ADJ       JJ      npadvmod      Switzerland
# )              PUNCT     -RRB-   punct         Switzerland
# ,              PUNCT     -RRB-   punct         Switzerland
# Luxembourg     PROPN     NNP     conj          Switzerland
# (              PUNCT     -LRB-   punct         Luxembourg
# 9th            ADJ       JJ      amod          Luxembourg
# )              PUNCT     -RRB-   punct         Luxembourg
# ,              PUNCT     -RRB-   punct         Luxembourg
# and            CCONJ     CC      cc            Luxembourg
# New            PROPN     NNP     compound      Zealand
# Zealand        PROPN     NNP     conj          Luxembourg
# (              PUNCT     -LRB-   punct         Zealand
# 10th           NOUN      NN      npadvmod      Zealand
# )              PUNCT     .       punct         Zealand
# .              PUNCT     .       punct         include
# Australia      PROPN     NNP     nsubj         ranked
# ranked         VERB      VBD     ROOT          ranked
# 12th           ADV       RB      advmod        ranked
# in             ADP       IN      prep          ranked
# this           DET       DT      det           report
# report         NOUN      NN      pobj          in
# ,              PUNCT     ,       punct         ranked
# followed       VERB      VBN     advcl         ranked
# by             ADP       IN      prep          followed
# Canada         PROPN     NNP     pobj          by
# (              PUNCT     -LRB-   punct         Canada
# 13th           ADJ       JJ      amod          Canada
# )              PUNCT     -RRB-   punct         Canada
# ,              PUNCT     -RRB-   punct         Canada
# Ireland        PROPN     NNP     conj          Canada
# (              PUNCT     -LRB-   punct         Ireland
# 14th           ADJ       JJ      npadvmod      Ireland
# )              PUNCT     -RRB-   punct         Ireland
# ,              PUNCT     -RRB-   punct         Ireland
# and            CCONJ     CC      cc            Ireland
# the            DET       DT      det           States
# United         PROPN     NNP     compound      States
# States         PROPN     NNP     conj          Ireland
# (              PUNCT     -LRB-   punct         States
# 15th           ADJ       JJ      appos         States
# )              PUNCT     .       punct         Canada
# .              PUNCT     .       punct         ranked
# In             ADP       IN      prep          ranked
# Asia           PROPN     NNP     pobj          In
# ,              PUNCT     ,       punct         ranked
# Singapore      PROPN     NNP     nsubj         ranked
# ranked         VERB      VBD     ROOT          ranked
# 25th           ADV       RB      advmod        ranked
# in             ADP       IN      prep          ranked
# the            DET       DT      det           world
# world          NOUN      NN      pobj          in
# ,              PUNCT     ,       punct         ranked
# up             ADV       RB      advmod        ranked
# two            NUM       CD      nummod        places
# places         NOUN      NNS     npadvmod      up
# from           ADP       IN      prep          up
# last           ADJ       JJ      amod          year
# year           NOUN      NN      npadvmod      from
# ,              PUNCT     ,       punct         ranked
# Taiwan         PROPN     NNP     nsubj         dropped
# dropped        VERB      VBD     conj          ranked
# one            NUM       CD      nummod        place
# place          NOUN      NN      npadvmod      dropped
# from           ADP       IN      prep          dropped
# last           ADJ       JJ      amod          year
# year           NOUN      NN      pobj          from
# to             ADP       IN      prep          dropped
# 27th           ADV       RB      pobj          to
# ,              PUNCT     ,       punct         dropped
# Japan          PROPN     NNP     nsubj         rose
# rose           VERB      VBD     conj          dropped
# to             ADP       IN      prep          rose
# 47th           ADV       RB      pobj          to
# ,              PUNCT     ,       punct         rose
# mainland       NOUN      NN      compound      China
# China          PROPN     NNP     nsubj         ranked
# ranked         VERB      VBD     conj          rose
# 64th           ADV       RB      advmod        ranked
# ,              PUNCT     ,       punct         ranked
# and            CCONJ     CC      cc            ranked
# Hong           PROPN     NNP     compound      Kong
# Kong           PROPN     NNP     nsubj         ranked
# ranked         VERB      VBD     conj          ranked
# 82nd           ADV       RB      advmod        ranked
# .              PUNCT     .       punct         ranked
# Meanwhile      ADV       RB      advmod        released
# ,              PUNCT     ,       punct         released
# the            DET       DT      det           agency
# polling        NOUN      NN      compound      agency
# agency         NOUN      NN      nsubj         released
# Ipsos          PROPN     NNP     compound      Group
# Group          PROPN     NNP     appos         agency
# (              PUNCT     -LRB-   punct         Group
# Ipsos          PROPN     NNP     appos         Group
# )              PUNCT     -RRB-   punct         Group
# released       VERB      VBD     ROOT          released
# a              DET       DT      det           report
# survey         NOUN      NN      compound      report
# report         NOUN      NN      dobj          released
# on             ADP       IN      prep          report
# the            DET       DT      det           index
# global         ADJ       JJ      amod          index
# happiness      NOUN      NN      compound      index
# index          NOUN      NN      pobj          on
# .              PUNCT     .       punct         released
# The            DET       DT      det           results
# results        NOUN      NNS     nsubj         showed
# showed         VERB      VBD     ROOT          showed
# that           SCONJ     IN      mark          was
# out            ADP       IN      prep          was
# of             ADP       IN      prep          out
# 32             NUM       CD      nummod        countries
# countries      NOUN      NNS     pobj          of
# ,              PUNCT     ,       punct         was
# the            DET       DT      det           country
# country        NOUN      NN      nsubj         was
# with           ADP       IN      prep          country
# the            DET       DT      det           index
# highest        ADJ       JJS     amod          index
# happiness      NOUN      NN      compound      index
# index          NOUN      NN      pobj          with
# was            AUX       VBD     ccomp         showed
# China          PROPN     NNP     attr          was
# (              PUNCT     -LRB-   punct         China
# 91             NUM       CD      nummod        %
# %              PUNCT     ,       appos         China
# )              PUNCT     ,       punct         China
# ,              PUNCT     ,       punct         China
# followed       VERB      VBN     acl           China
# by             ADP       IN      agent         followed
# Saudi          PROPN     NNP     compound      Arabia
# Arabia         PROPN     NNP     pobj          by
# (              PUNCT     -LRB-   punct         Arabia
# 86             NUM       CD      nummod        %
# %              PUNCT     ,       appos         Arabia
# )              PUNCT     ,       punct         Arabia
# ,              PUNCT     ,       punct         Arabia
# the            DET       DT      det           Netherlands
# Netherlands    PROPN     NNP     conj          Arabia
# (              PUNCT     -LRB-   punct         Netherlands
# 85             NUM       CD      nummod        %
# %              PUNCT     ,       appos         Netherlands
# )              PUNCT     ,       punct         Netherlands
# ,              PUNCT     ,       punct         Netherlands
# India          PROPN     NNP     conj          Netherlands
# (              PUNCT     -LRB-   punct         India
# 84             NUM       CD      nummod        %
# %              NOUN      NN      appos         India
# )              NOUN      NN      punct         India
# ,              NOUN      NN      punct         India
# and            CCONJ     CC      cc            India
# Brazil         PROPN     NNP     conj          India
# (              PUNCT     -LRB-   punct         Brazil
# 83             NUM       CD      nummod        %
# %              NOUN      NN      appos         Brazil
# )              PUNCT     .       punct         Brazil
# .              PUNCT     .       punct         Arabia
# Australia      PROPN     NNP     nsubj         ranked
# ranked         VERB      VBD     ROOT          ranked
# 9th            ADV       RB      advmod        ranked
# in             ADP       IN      prep          ranked
# this           DET       DT      det           report
# report         NOUN      NN      pobj          in
# .              PUNCT     .       punct         ranked
# According      VERB      VBG     prep          increased
# to             ADP       IN      prep          According
# the            DET       DT      det           report
# survey         NOUN      NN      compound      report
# report         NOUN      NN      pobj          to
# ,              PUNCT     ,       punct         increased
# on             ADP       IN      prep          increased
# average        ADJ       JJ      amod          on
# ,              PUNCT     ,       punct         increased
# happiness      NOUN      NN      nsubj         increased
# increased      VERB      VBD     ROOT          increased
# more           ADV       RBR     advmod        significantly
# significantly  ADV       RB      advmod        increased
# in             ADP       IN      prep          increased
# middle         ADJ       JJ      amod          income
# -              PUNCT     HYPH    punct         income
# income         NOUN      NN      compound      countries
# countries      NOUN      NNS     pobj          in
# (              PUNCT     -LRB-   punct         in
# as             SCONJ     IN      mark          defined
# defined        VERB      VBN     advcl         in
# by             ADP       IN      agent         defined
# the            DET       DT      det           Bank
# World          PROPN     NNP     compound      Bank
# Bank           PROPN     NNP     pobj          by
# )              PUNCT     -RRB-   punct         in
# than           ADP       IN      prep          increased
# in             ADP       IN      prep          than
# high           ADJ       JJ      amod          income
# -              PUNCT     HYPH    punct         income
# income         NOUN      NN      compound      countries
# countries      NOUN      NNS     pobj          in
# .              PUNCT     .       punct         increased

# %%
displacy.serve(doc, style="dep", auto_select_port=True, page=False)
# Out:
# /Users/oonisim/venv/tf/lib/python3.9/site-packages/spacy/util.py:1785: UserWarning: [W124] 0.0.0.0:5000 is already in use, using the nearest available port 5001 as an alternative.
#   warnings.warn(Warnings.W124.format(host=host, port=start, serve_port=port))
# /Users/oonisim/venv/tf/lib/python3.9/site-packages/spacy/displacy/__init__.py:108: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="c7a1a36325374ce29d808bf1abc97ef6-0" class="displacy" width="132350" height="837.0" direction="ltr" style="max-width: none; height: 837.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Australian</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Melissa</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">Georgiou (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">Melissa</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">Georgiou)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">moved</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">Finland</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">over</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">decade</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">ago</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">seek</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">happiness</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">one</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">coldest</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">darkest</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">places</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">Earth. “</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">One</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">my</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">favorite</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">things</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">about</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="cu
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5001 ...
#
# Shutting down server on port 5001.

# %% [markdown]
# ----
# # Entities
#
# Named Entities have been identified by NER in the document object.
#
# * [Named Entities](https://spacy.io/usage/spacy-101#annotations-ner)
#
# ### Entity Labels
# ```
# PERSON:      People, including fictional.
# NORP:        Nationalities or religious or political groups.
# FAC:         Buildings, airports, highways, bridges, etc.
# ORG:         Companies, agencies, institutions, etc.
# GPE:         Countries, cities, states.
# LOC:         Non-GPE locations, mountain ranges, bodies of water.
# PRODUCT:     Objects, vehicles, foods, etc. (Not services.)
# EVENT:       Named hurricanes, battles, wars, sports events, etc.
# WORK_OF_ART: Titles of books, songs, etc.
# LAW:         Named documents made into laws.
# LANGUAGE:    Any named language.
# DATE:        Absolute or relative dates or periods.
# TIME:        Times smaller than a day.
# PERCENT:     Percentage, including ”%“.
# MONEY:       Monetary values, including unit.
# QUANTITY:    Measurements, as of weight or distance.
# ORDINAL:     “first”, “second”, etc.
# CARDINAL:    Numerals that do not fall under another type.
# ```

# %%
displacy.serve(doc, style="ent", auto_select_port=True, page=False)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Australian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Melissa Georgiou
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  (
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Melissa Georgiou
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ) moved to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Finland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     over a decade ago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  to seek happiness in one of the coldest and darkest places on
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Earth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# . “One of my favorite things about living here is that it's easy to get close to nature whether you're in a residential area or in the middle of the city,”
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Melissa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said. Originally a teacher,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     12 years ago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , she switched from the beaches of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sydney
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  to the dark winters and cold lakes of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Finland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , and has never looked back since.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Melissa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said, “For
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Finns
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# , the concept of happiness is very different from the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Australian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  concept of happiness.
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Finns
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# , she said, are happy to accept portrayals of themselves as melancholy and stubborn — a popular local saying is, “People who have happiness must hide it.” “The first thing I noticed here is that you don't go to dinners or barbecues, and you don't talk about real estate. No one asks you where you live, what suburb do you live in, where your kids go to school.” The
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Finns
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  seem quite happy with the status quo, and they don't always seem to want more.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Melissa Georgio's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dark Night
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  in
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Northern Europe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Finland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  was named the happiest country in the world for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the sixth year in a row
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  in
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the “World Happiness Report”
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  released by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United Nations
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . “The
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nordic
#     <span style="fo
# Using the 'ent' visualizer
# Serving on http://0.0.0.0:5001 ...
#
# Shutting down server on port 5001.

# %%
print("{}{}{}{}".format(
    "Entity".ljust(50), "Start".ljust(7), "End".ljust(7), "Label".ljust(10)
))
print("-" * 80)
for ent in doc.ents:
    print(f"{ent.text:50}{ent.start_char:<7}{ent.end_char:<7}{ent.label_:10}")
# Out:
# Entity                                            Start  End    Label
# --------------------------------------------------------------------------------
# Australian                                        0      10     NORP
# Melissa Georgiou                                  11     27     PERSON
# Melissa Georgiou                                  29     45     PERSON
# Finland                                           56     63     GPE
# over a decade ago                                 64     81     DATE
# Earth                                             144    149    LOC
# Melissa                                           305    312    PERSON
# 12 years ago                                      341    353    DATE
# Sydney                                            388    394    GPE
# Finland                                           433    440    GPE
# Melissa                                           475    482    PERSON
# Finns                                             494    499    NORP
# Australian                                        553    563    NORP
# Finns                                             586    591    NORP
# Finns                                             957    962    NORP
# Melissa Georgio's                                 1042   1059   PERSON
# Dark Night                                        1060   1070   WORK_OF_ART
# Northern Europe                                   1074   1089   LOC
# Finland                                           1090   1097   GPE
# the sixth year in a row                           1146   1169   DATE
# the “World Happiness Report”                      1173   1201   WORK_OF_ART
# the United Nations                                1214   1232   ORG
# Nordic                                            1239   1245   NORP
# Frank Martela                                     1383   1396   PERSON
# Frank Martela                                     1398   1411   PERSON
# Frank                                             1423   1428   PERSON
# Finland                                           1439   1446   GPE
# Finns                                             1507   1512   NORP
# Finnish                                           1661   1668   NORP
# Finnish                                           1700   1707   NORP
# Frank                                             1756   1761   PERSON
# Finns                                             1788   1793   NORP
# Finnish                                           1856   1863   NORP
# Finns                                             2033   2038   NORP
# Melissa                                           2255   2262   PERSON
# Finland                                           2273   2280   GPE
# Finland                                           2366   2373   GPE
# European                                          2388   2396   NORP
# Finland                                           2747   2754   GPE
# Melissa                                           2853   2860   PERSON
# Finland                                           3107   3114   GPE
# China                                             3119   3124   GPE
# the World Happiness Report                        3203   3229   ORG
# Nordic                                            3235   3241   NORP
# ten                                               3275   3278   CARDINAL
# year                                              3288   3292   DATE
# Finland                                           3303   3310   GPE
# Denmark                                           3329   3336   GPE
# 2nd                                               3338   3341   ORDINAL
# Iceland                                           3344   3351   GPE
# 3rd                                               3353   3356   ORDINAL
# Sweden                                            3359   3365   GPE
# 6th                                               3367   3370   ORDINAL
# Norway                                            3377   3383   GPE
# 7th                                               3385   3388   ORDINAL
# ten                                               3566   3569   CARDINAL
# Netherlands                                       3600   3611   GPE
# 5th                                               3613   3616   ORDINAL
# Switzerland                                       3619   3630   GPE
# 8th                                               3632   3635   ORDINAL
# Luxembourg                                        3638   3648   GPE
# 9th                                               3650   3653   ORDINAL
# New Zealand                                       3660   3671   GPE
# 10th                                              3673   3677   ORDINAL
# Australia                                         3680   3689   GPE
# 12th                                              3697   3701   ORDINAL
# Canada                                            3730   3736   GPE
# 13th                                              3738   3742   ORDINAL
# Ireland                                           3745   3752   GPE
# 14th                                              3754   3758   ORDINAL
# the United States                                 3765   3782   GPE
# 15th                                              3784   3788   ORDINAL
# Asia                                              3794   3798   LOC
# Singapore                                         3800   3809   GPE
# 25th                                              3817   3821   ORDINAL
# two                                               3839   3842   CARDINAL
# last year                                         3855   3864   DATE
# Taiwan                                            3866   3872   GPE
# one                                               3881   3884   CARDINAL
# last year                                         3896   3905   DATE
# 27th                                              3909   3913   ORDINAL
# Japan                                             3915   3920   GPE
# 47th                                              3929   3933   ORDINAL
# China                                             3944   3949   GPE
# 64th                                              3957   3961   ORDINAL
# Hong Kong                                         3967   3976   GPE
# 82nd                                              3984   3988   ORDINAL
# Ipsos Group                                       4020   4031   ORG
# Ipsos                                             4033   4038   ORG
# 32                                                4127   4129   CARDINAL
# China                                             4190   4195   GPE
# 91%                                               4197   4200   PERCENT
# Saudi Arabia                                      4215   4227   GPE
# 86%                                               4229   4232   PERCENT
# Netherlands                                       4239   4250   GPE
# 85%                                               4252   4255   PERCENT
# India                                             4258   4263   GPE
# 84%                                               4265   4268   PERCENT
# Brazil                                            4275   4281   GPE
# 83%                                               4283   4286   PERCENT
# Australia                                         4289   4298   GPE
# 9th                                               4306   4309   ORDINAL
# the World Bank                                    4451   4465   ORG

# %% [markdown]
# ## Entities per label

# %%
gpes = set()
locs = set()
orgs = set()
titles = set()
nationalities = set()
landmarks = set()

for entity in doc.ents:
    if entity.label_ == 'GPE':
        gpes.add(entity.text)
    elif entity.label_ == 'LOC':
        locs.add(entity.text)
    elif entity.label_ == 'ORG':
        orgs.add(entity.text)
    elif entity.label_ == 'WORK_OF_ART':
        titles.add(entity.text)
    elif entity.label_ == 'NORP':
        nationalities.add(entity.text)
    elif entity.label_ == 'FAC':
        landmarks.add(entity.text)

# %%
titles
# Out:
# {'Dark Night', 'the “World Happiness Report”'}

# %%
landmarks
# Out:
# set()

# %%
gpes
# Out:
# {'Australia',
#  'Brazil',
#  'Canada',
#  'China',
#  'Denmark',
#  'Finland',
#  'Hong Kong',
#  'Iceland',
#  'India',
#  'Ireland',
#  'Japan',
#  'Luxembourg',
#  'Netherlands',
#  'New Zealand',
#  'Norway',
#  'Saudi Arabia',
#  'Singapore',
#  'Sweden',
#  'Switzerland',
#  'Sydney',
#  'Taiwan',
#  'the United States'}

# %%
locs
# Out:
# {'Asia', 'Earth', 'Northern Europe'}

# %%
nationalities
# Out:
# {'Australian', 'European', 'Finnish', 'Finns', 'Nordic'}

# %%
orgs
# Out:
# {'Ipsos',
#  'Ipsos Group',
#  'the United Nations',
#  'the World Bank',
#  'the World Happiness Report'}

# %% [markdown]
# ### Exclude "ORDINAL", "CARDINAL", "PERCENT", "DATE", "NORP"

# %%
def clean(text: str):
    return re.sub(r'[“”"!`~%&*()]*', '', text)

# %%
def clean_text(text: str, lower: bool=False):
    text = text.lower() if lower else text
    return " ".join([
        clean(word)
        for word in text.split()
        if word not in stopwords
    ])

# %%
print("{}{}{}{}".format(
    "Entity".ljust(50), "Start".ljust(7), "End".ljust(7), "Label".ljust(10)
))
print("-" * 80)

words_in_entities = set()
entity_phrases= set()
selected_named_entities = {}

for ent in doc.ents:
    if (ent.text.lower() not in entity_phrases) and (ent.label_ not in ("ORDINAL", "CARDINAL", "PERCENT", "DATE", "NORP")):        
        _entity = clean_text(text=ent.text, lower=True)
        _ = [
            clean_text(word) 
            for word in ent.text.lower().split() 
            if word not in stopwords
        ]
        words_in_entities.update(_entity.split())
        entity_phrases.add(_entity)
        
        named_entity = clean_text(text=ent.text, lower=False)
        selected_named_entities[named_entity] = ent
        print(f"{named_entity:50}{ent.start_char:<7}{ent.end_char:<7}{ent.label_:10}")
# Out:
# Entity                                            Start  End    Label
# --------------------------------------------------------------------------------
# Melissa Georgiou                                  11     27     PERSON
# Finland                                           56     63     GPE
# Earth                                             144    149    LOC
# Melissa                                           305    312    PERSON
# Sydney                                            388    394    GPE
# Melissa Georgio's                                 1042   1059   PERSON
# Dark Night                                        1060   1070   WORK_OF_ART
# Northern Europe                                   1074   1089   LOC
# World Happiness Report                            1173   1201   WORK_OF_ART
# United Nations                                    1214   1232   ORG
# Frank Martela                                     1383   1396   PERSON
# Frank                                             1423   1428   PERSON
# China                                             3119   3124   GPE
# World Happiness Report                            3203   3229   ORG
# Denmark                                           3329   3336   GPE
# Iceland                                           3344   3351   GPE
# Sweden                                            3359   3365   GPE
# Norway                                            3377   3383   GPE
# Netherlands                                       3600   3611   GPE
# Switzerland                                       3619   3630   GPE
# Luxembourg                                        3638   3648   GPE
# New Zealand                                       3660   3671   GPE
# Australia                                         3680   3689   GPE
# Canada                                            3730   3736   GPE
# Ireland                                           3745   3752   GPE
# United States                                     3765   3782   GPE
# Asia                                              3794   3798   LOC
# Singapore                                         3800   3809   GPE
# Taiwan                                            3866   3872   GPE
# Japan                                             3915   3920   GPE
# Hong Kong                                         3967   3976   GPE
# Ipsos Group                                       4020   4031   ORG
# Ipsos                                             4033   4038   ORG
# Saudi Arabia                                      4215   4227   GPE
# India                                             4258   4263   GPE
# Brazil                                            4275   4281   GPE
# World Bank                                        4451   4465   ORG

# %%
set(selected_named_entities)
# Out:
# {'Asia',
#  'Australia',
#  'Brazil',
#  'Canada',
#  'China',
#  'Dark Night',
#  'Denmark',
#  'Earth',
#  'Finland',
#  'Frank',
#  'Frank Martela',
#  'Hong Kong',
#  'Iceland',
#  'India',
#  'Ipsos',
#  'Ipsos Group',
#  'Ireland',
#  'Japan',
#  'Luxembourg',
#  'Melissa',
#  "Melissa Georgio's",
#  'Melissa Georgiou',
#  'Netherlands',
#  'New Zealand',
#  'Northern Europe',
#  'Norway',
#  'Saudi Arabia',
#  'Singapore',
#  'Sweden',
#  'Switzerland',
#  'Sydney',
#  'Taiwan',
#  'United Nations',
#  'United States',
#  'World Bank',
#  'World Happiness Report'}

# %% [markdown]
# ---
# # Noun Phrases
#
# * [Noun chunks](https://spacy.io/usage/linguistic-features#noun-chunks)
#
# > **Noun chunks** are “base noun phrases” – flat phrases that **have a noun as their head**. You can think of noun chunks as a noun plus the words describing the noun – for example, “the lavish green grass” or “the world’s largest tech fund”.

# %%
for chunk in doc.noun_chunks:
    # if chunk.text.lower() != chunk.root.text.lower():
        print(f"phrase:[{chunk.text:50}] root:[{chunk.root.text:15}] type:[{chunk.root.dep_:6}]")
# Out:
# phrase:[Australian Melissa Georgiou                       ] root:[Georgiou       ] type:[nsubj ]
# phrase:[Melissa Georgiou                                  ] root:[Georgiou       ] type:[appos ]
# phrase:[Finland                                           ] root:[Finland        ] type:[pobj  ]
# phrase:[happiness                                         ] root:[happiness      ] type:[dobj  ]
# phrase:[the coldest and darkest places                    ] root:[places         ] type:[pobj  ]
# phrase:[Earth                                             ] root:[Earth          ] type:[pobj  ]
# phrase:[my favorite things                                ] root:[things         ] type:[pobj  ]
# phrase:[it                                                ] root:[it             ] type:[nsubj ]
# phrase:[nature                                            ] root:[nature         ] type:[pobj  ]
# phrase:[you                                               ] root:[you            ] type:[nsubj ]
# phrase:[a residential area                                ] root:[area           ] type:[pobj  ]
# phrase:[the middle                                        ] root:[middle         ] type:[pobj  ]
# phrase:[the city                                          ] root:[city           ] type:[pobj  ]
# phrase:[Melissa                                           ] root:[Melissa        ] type:[nsubj ]
# phrase:[she                                               ] root:[she            ] type:[nsubj ]
# phrase:[the beaches                                       ] root:[beaches        ] type:[pobj  ]
# phrase:[Sydney                                            ] root:[Sydney         ] type:[pobj  ]
# phrase:[the dark winters                                  ] root:[winters        ] type:[pobj  ]
# phrase:[cold lakes                                        ] root:[lakes          ] type:[conj  ]
# phrase:[Finland                                           ] root:[Finland        ] type:[pobj  ]
# phrase:[Melissa                                           ] root:[Melissa        ] type:[nsubj ]
# phrase:[Finns                                             ] root:[Finns          ] type:[pobj  ]
# phrase:[the concept                                       ] root:[concept        ] type:[nsubj ]
# phrase:[happiness                                         ] root:[happiness      ] type:[pobj  ]
# phrase:[the Australian concept                            ] root:[concept        ] type:[pobj  ]
# phrase:[happiness                                         ] root:[happiness      ] type:[pobj  ]
# phrase:[Finns                                             ] root:[Finns          ] type:[nsubj ]
# phrase:[she                                               ] root:[she            ] type:[nsubj ]
# phrase:[portrayals                                        ] root:[portrayals     ] type:[dobj  ]
# phrase:[themselves                                        ] root:[themselves     ] type:[pobj  ]
# phrase:[a popular local saying                            ] root:[saying         ] type:[nsubj ]
# phrase:[People                                            ] root:[People         ] type:[nsubj ]
# phrase:[who                                               ] root:[who            ] type:[nsubj ]
# phrase:[happiness                                         ] root:[happiness      ] type:[dobj  ]
# phrase:[it                                                ] root:[it             ] type:[dobj  ]
# phrase:[The first thing                                   ] root:[thing          ] type:[nsubj ]
# phrase:[I                                                 ] root:[I              ] type:[nsubj ]
# phrase:[you                                               ] root:[you            ] type:[nsubj ]
# phrase:[dinners                                           ] root:[dinners        ] type:[pobj  ]
# phrase:[barbecues                                         ] root:[barbecues      ] type:[conj  ]
# phrase:[you                                               ] root:[you            ] type:[nsubj ]
# phrase:[real estate                                       ] root:[estate         ] type:[pobj  ]
# phrase:[No one                                            ] root:[one            ] type:[nsubj ]
# phrase:[you                                               ] root:[you            ] type:[dobj  ]
# phrase:[you                                               ] root:[you            ] type:[nsubj ]
# phrase:[what suburb                                       ] root:[suburb         ] type:[pobj  ]
# phrase:[you                                               ] root:[you            ] type:[nsubj ]
# phrase:[your kids                                         ] root:[kids           ] type:[nsubj ]
# phrase:[school                                            ] root:[school         ] type:[pobj  ]
# phrase:[The Finns                                         ] root:[Finns          ] type:[nsubj ]
# phrase:[the status quo                                    ] root:[quo            ] type:[pobj  ]
# phrase:[they                                              ] root:[they           ] type:[nsubj ]
# phrase:[Melissa Georgio's Dark Night                      ] root:[Night          ] type:[nsubjpass]
# phrase:[Northern Europe                                   ] root:[Europe         ] type:[pobj  ]
# phrase:[Finland                                           ] root:[Finland        ] type:[appos ]
# phrase:[the happiest country                              ] root:[country        ] type:[oprd  ]
# phrase:[the world                                         ] root:[world          ] type:[pobj  ]
# phrase:[the sixth year                                    ] root:[year           ] type:[pobj  ]
# phrase:[a row                                             ] root:[row            ] type:[pobj  ]
# phrase:[the “World Happiness Report                       ] root:[Report         ] type:[pobj  ]
# phrase:[the United Nations                                ] root:[Nations        ] type:[pobj  ]
# phrase:[The Nordic countries                              ] root:[countries      ] type:[nsubj ]
# phrase:[countries                                         ] root:[countries      ] type:[attr  ]
# phrase:[(good) unemployment benefits                      ] root:[benefits       ] type:[pobj  ]
# phrase:[pensions                                          ] root:[pensions       ] type:[conj  ]
# phrase:[other benefits                                    ] root:[benefits       ] type:[conj  ]
# phrase:[happiness expert and researcher Frank Martela     ] root:[Martela        ] type:[nsubj ]
# phrase:[Frank Martela                                     ] root:[Martela        ] type:[appos ]
# phrase:[Frank                                             ] root:[Frank          ] type:[nsubj ]
# phrase:[Finland's position                                ] root:[position       ] type:[nsubj ]
# phrase:[the rankings                                      ] root:[rankings       ] type:[pobj  ]
# phrase:[its own people                                    ] root:[people         ] type:[dobj  ]
# phrase:[they                                              ] root:[they           ] type:[nsubj ]
# phrase:[they                                              ] root:[they           ] type:[nsubj ]
# phrase:[this                                              ] root:[this           ] type:[nsubj ]
# phrase:[We                                                ] root:[We             ] type:[nsubj ]
# phrase:[sad music                                         ] root:[music          ] type:[pobj  ]
# phrase:[hard rock                                         ] root:[rock           ] type:[conj  ]
# phrase:[happiness                                         ] root:[happiness      ] type:[nsubj ]
# phrase:[part                                              ] root:[part           ] type:[attr  ]
# phrase:[the Finnish self-image                            ] root:[image          ] type:[pobj  ]
# phrase:[The other side                                    ] root:[side           ] type:[nsubj ]
# phrase:[Finnish melancholy                                ] root:[melancholy     ] type:[pobj  ]
# phrase:[a cultural focus                                  ] root:[focus          ] type:[attr  ]
# phrase:[perseverance                                      ] root:[perseverance   ] type:[pobj  ]
# phrase:[Frank                                             ] root:[Frank          ] type:[nsubj ]
# phrase:[it                                                ] root:[it             ] type:[nsubj ]
# phrase:[the way                                           ] root:[way            ] type:[dobj  ]
# phrase:[Finns                                             ] root:[Finns          ] type:[nsubj ]
# phrase:[happiness                                         ] root:[happiness      ] type:[dobj  ]
# phrase:[a concept                                         ] root:[concept        ] type:[appos ]
# phrase:[“sisu                                             ] root:[sisu           ] type:[pobj  ]
# phrase:[which                                             ] root:[which          ] type:[nsubj ]
# phrase:[part                                              ] root:[part           ] type:[attr  ]
# phrase:[Finnish culture                                   ] root:[culture        ] type:[pobj  ]
# phrase:[will                                              ] root:[will           ] type:[pobj  ]
# phrase:[determination                                     ] root:[determination  ] type:[conj  ]
# phrase:[perseverance                                      ] root:[perseverance   ] type:[conj  ]
# phrase:[reason                                            ] root:[reason         ] type:[conj  ]
# phrase:[adversity                                         ] root:[adversity      ] type:[dobj  ]
# phrase:[This                                              ] root:[This           ] type:[nsubjpass]
# phrase:[he                                                ] root:[he             ] type:[nsubj ]
# phrase:[Finns' favorite pastime                           ] root:[pastime        ] type:[pobj  ]
# phrase:[a sauna                                           ] root:[sauna          ] type:[pobj  ]
# phrase:[a bath                                            ] root:[bath           ] type:[dobj  ]
# phrase:[freezing temperatures                             ] root:[temperatures   ] type:[pobj  ]
# phrase:[It                                                ] root:[It             ] type:[nsubj ]
# phrase:[this paradox                                      ] root:[paradox        ] type:[pobj  ]
# phrase:[one extreme                                       ] root:[extreme        ] type:[pobj  ]
# phrase:[it                                                ] root:[it             ] type:[nsubj ]
# phrase:[a pretty fun experience                           ] root:[experience     ] type:[attr  ]
# phrase:[you                                               ] root:[you            ] type:[nsubj ]
# phrase:[perseverance                                      ] root:[perseverance   ] type:[dobj  ]
# phrase:[Melissa                                           ] root:[Melissa        ] type:[nsubj ]
# phrase:[Finland                                           ] root:[Finland        ] type:[nsubj ]
# phrase:[many things                                       ] root:[things         ] type:[dobj  ]
# phrase:[that                                              ] root:[that           ] type:[nsubj ]
# phrase:[happiness                                         ] root:[happiness      ] type:[dobj  ]
# phrase:[people                                            ] root:[people         ] type:[pobj  ]
# phrase:[this country                                      ] root:[country        ] type:[pobj  ]
# phrase:[Finland                                           ] root:[Finland        ] type:[nsubj ]
# phrase:[the European countries                            ] root:[countries      ] type:[pobj  ]
# phrase:[the COVID-19 pandemic                             ] root:[pandemic       ] type:[pobj  ]
# phrase:[experts                                           ] root:[experts        ] type:[nsubj ]
# phrase:[this                                              ] root:[this           ] type:[dobj  ]
# phrase:[a high level                                      ] root:[level          ] type:[pobj  ]
# phrase:[trust                                             ] root:[trust          ] type:[pobj  ]
# phrase:[the government                                    ] root:[government     ] type:[pobj  ]
# phrase:[little resistance                                 ] root:[resistance     ] type:[conj  ]
# phrase:[restrictions                                      ] root:[restrictions   ] type:[pobj  ]
# phrase:[Trust                                             ] root:[Trust          ] type:[nsubj ]
# phrase:[government                                        ] root:[government     ] type:[pobj  ]
# phrase:[the other hand                                    ] root:[hand           ] type:[pobj  ]
# phrase:[a country's investment                            ] root:[investment     ] type:[pobj  ]
# phrase:[its citizens                                      ] root:[citizens       ] type:[pobj  ]
# phrase:[The public school system                          ] root:[system         ] type:[nsubj ]
# phrase:[children                                          ] root:[children       ] type:[dobj  ]
# phrase:[the world                                         ] root:[world          ] type:[pobj  ]
# phrase:[Finland                                           ] root:[Finland        ] type:[nsubj ]
# phrase:[a universal health care system                    ] root:[system         ] type:[dobj  ]
# phrase:[affordable childcare                              ] root:[childcare      ] type:[pobj  ]
# phrase:[strong support                                    ] root:[support        ] type:[conj  ]
# phrase:[parents                                           ] root:[parents        ] type:[pobj  ]
# phrase:[Melissa                                           ] root:[Melissa        ] type:[nsubj ]
# phrase:[The whole country                                 ] root:[country        ] type:[nsubj ]
# phrase:[care                                              ] root:[care           ] type:[dobj  ]
# phrase:[the child's development                           ] root:[development    ] type:[pobj  ]
# phrase:[This system                                       ] root:[system         ] type:[nsubjpass]
# phrase:[my son                                            ] root:[son            ] type:[dobj  ]
# phrase:[him                                               ] root:[him            ] type:[dobj  ]
# phrase:[home                                              ] root:[home           ] type:[pobj  ]
# phrase:[him                                               ] root:[him            ] type:[dobj  ]
# phrase:[daycare                                           ] root:[daycare        ] type:[pobj  ]
# phrase:[school                                            ] root:[school         ] type:[pobj  ]
# phrase:[I                                                 ] root:[I              ] type:[nsubjpass]
# phrase:[every aspect                                      ] root:[aspect         ] type:[pobj  ]
# phrase:[this                                              ] root:[this           ] type:[pobj  ]
# phrase:[China                                             ] root:[China          ] type:[pobj  ]
# phrase:[which country                                     ] root:[country        ] type:[nsubj ]
# phrase:[the strongest sense                               ] root:[sense          ] type:[dobj  ]
# phrase:[happiness                                         ] root:[happiness      ] type:[pobj  ]
# phrase:[the publication                                   ] root:[publication    ] type:[pobj  ]
# phrase:[the World Happiness Report                        ] root:[Report         ] type:[pobj  ]
# phrase:[the Nordic countries                              ] root:[countries      ] type:[nsubj ]
# phrase:[this year's report                                ] root:[report         ] type:[pobj  ]
# phrase:[Finland                                           ] root:[Finland        ] type:[nsubj ]
# phrase:[its neighbors                                     ] root:[neighbors      ] type:[conj  ]
# phrase:[Denmark                                           ] root:[Denmark        ] type:[appos ]
# phrase:[Iceland                                           ] root:[Iceland        ] type:[conj  ]
# phrase:[Sweden                                            ] root:[Sweden         ] type:[conj  ]
# phrase:[Norway                                            ] root:[Norway         ] type:[conj  ]
# phrase:[happiness indicators                              ] root:[indicators     ] type:[pobj  ]
# phrase:[healthy life expectancy                           ] root:[expectancy     ] type:[pobj  ]
# phrase:[per capita GDP                                    ] root:[GDP            ] type:[conj  ]
# phrase:[low levels                                        ] root:[levels         ] type:[conj  ]
# phrase:[corruption                                        ] root:[corruption     ] type:[pobj  ]
# phrase:[social support                                    ] root:[support        ] type:[conj  ]
# phrase:[freedom                                           ] root:[freedom        ] type:[conj  ]
# phrase:[trust                                             ] root:[trust          ] type:[conj  ]
# phrase:[generosity                                        ] root:[generosity     ] type:[conj  ]
# phrase:[Other top ten countries/regions                   ] root:[regions        ] type:[nsubj ]
# phrase:[the Netherlands                                   ] root:[Netherlands    ] type:[dobj  ]
# phrase:[Switzerland                                       ] root:[Switzerland    ] type:[conj  ]
# phrase:[Luxembourg                                        ] root:[Luxembourg     ] type:[conj  ]
# phrase:[New Zealand                                       ] root:[Zealand        ] type:[conj  ]
# phrase:[Australia                                         ] root:[Australia      ] type:[nsubj ]
# phrase:[this report                                       ] root:[report         ] type:[pobj  ]
# phrase:[Canada                                            ] root:[Canada         ] type:[pobj  ]
# phrase:[Ireland                                           ] root:[Ireland        ] type:[conj  ]
# phrase:[the United States                                 ] root:[States         ] type:[conj  ]
# phrase:[Asia                                              ] root:[Asia           ] type:[pobj  ]
# phrase:[Singapore                                         ] root:[Singapore      ] type:[nsubj ]
# phrase:[the world                                         ] root:[world          ] type:[pobj  ]
# phrase:[Taiwan                                            ] root:[Taiwan         ] type:[nsubj ]
# phrase:[last year                                         ] root:[year           ] type:[pobj  ]
# phrase:[Japan                                             ] root:[Japan          ] type:[nsubj ]
# phrase:[mainland China                                    ] root:[China          ] type:[nsubj ]
# phrase:[Hong Kong                                         ] root:[Kong           ] type:[nsubj ]
# phrase:[the polling agency                                ] root:[agency         ] type:[nsubj ]
# phrase:[Ipsos Group                                       ] root:[Group          ] type:[appos ]
# phrase:[Ipsos                                             ] root:[Ipsos          ] type:[appos ]
# phrase:[a survey report                                   ] root:[report         ] type:[dobj  ]
# phrase:[the global happiness index                        ] root:[index          ] type:[pobj  ]
# phrase:[The results                                       ] root:[results        ] type:[nsubj ]
# phrase:[32 countries                                      ] root:[countries      ] type:[pobj  ]
# phrase:[the country                                       ] root:[country        ] type:[nsubj ]
# phrase:[the highest happiness index                       ] root:[index          ] type:[pobj  ]
# phrase:[China                                             ] root:[China          ] type:[attr  ]
# phrase:[Saudi Arabia                                      ] root:[Arabia         ] type:[pobj  ]
# phrase:[the Netherlands                                   ] root:[Netherlands    ] type:[conj  ]
# phrase:[India                                             ] root:[India          ] type:[conj  ]
# phrase:[84%                                               ] root:[%              ] type:[appos ]
# phrase:[Brazil                                            ] root:[Brazil         ] type:[conj  ]
# phrase:[83%                                               ] root:[%              ] type:[appos ]
# phrase:[Australia                                         ] root:[Australia      ] type:[nsubj ]
# phrase:[this report                                       ] root:[report         ] type:[pobj  ]
# phrase:[the survey report                                 ] root:[report         ] type:[pobj  ]
# phrase:[happiness                                         ] root:[happiness      ] type:[nsubj ]
# phrase:[middle-income countries                           ] root:[countries      ] type:[pobj  ]
# phrase:[the World Bank                                    ] root:[Bank           ] type:[pobj  ]
# phrase:[high-income countries                             ] root:[countries      ] type:[pobj  ]

# %%
phrases = doc.noun_chunks
tokens = doc

phrase = next(phrases)
for sentence in doc.sents:
    print(sentence)
    while phrase.root.sent == sentence:
        print(
            f"phrase:[{phrase.text:30}] "\
            f"root:[{phrase.root.text:12}] "\
            f"type:[{phrase.root.dep_:6}] "\
            f"parent:[{phrase.root.head}]" 
        )
        phrase = next(phrases)
# Out:
# Australian Melissa Georgiou (Melissa Georgiou) moved to Finland over a decade ago to seek happiness in one of the coldest and darkest places on Earth.
# phrase:[Australian Melissa Georgiou   ] root:[Georgiou    ] type:[nsubj ] parent:[moved]
# phrase:[Melissa Georgiou              ] root:[Georgiou    ] type:[appos ] parent:[Georgiou]
# phrase:[Finland                       ] root:[Finland     ] type:[pobj  ] parent:[to]
# phrase:[happiness                     ] root:[happiness   ] type:[dobj  ] parent:[seek]
# phrase:[the coldest and darkest places] root:[places      ] type:[pobj  ] parent:[of]
# phrase:[Earth                         ] root:[Earth       ] type:[pobj  ] parent:[on]
# “One of my favorite things about living here is that it's easy to get close to nature whether you're in a residential area or in the middle of the city,” Melissa said.
# phrase:[my favorite things            ] root:[things      ] type:[pobj  ] parent:[of]
# phrase:[it                            ] root:[it          ] type:[nsubj ] parent:['s]
# phrase:[nature                        ] root:[nature      ] type:[pobj  ] parent:[to]
# phrase:[you                           ] root:[you         ] type:[nsubj ] parent:['re]
# phrase:[a residential area            ] root:[area        ] type:[pobj  ] parent:[in]
# phrase:[the middle                    ] root:[middle      ] type:[pobj  ] parent:[in]
# phrase:[the city                      ] root:[city        ] type:[pobj  ] parent:[of]
# phrase:[Melissa                       ] root:[Melissa     ] type:[nsubj ] parent:[said]
# Originally a teacher, 12 years ago, she switched from the beaches of Sydney to the dark winters and cold lakes of Finland, and has never looked back since.
# phrase:[she                           ] root:[she         ] type:[nsubj ] parent:[switched]
# phrase:[the beaches                   ] root:[beaches     ] type:[pobj  ] parent:[from]
# phrase:[Sydney                        ] root:[Sydney      ] type:[pobj  ] parent:[of]
# phrase:[the dark winters              ] root:[winters     ] type:[pobj  ] parent:[to]
# phrase:[cold lakes                    ] root:[lakes       ] type:[conj  ] parent:[winters]
# phrase:[Finland                       ] root:[Finland     ] type:[pobj  ] parent:[of]
# Melissa said, “For Finns, the concept of happiness is very different from the Australian concept of happiness.
# phrase:[Melissa                       ] root:[Melissa     ] type:[nsubj ] parent:[said]
# phrase:[Finns                         ] root:[Finns       ] type:[pobj  ] parent:[For]
# phrase:[the concept                   ] root:[concept     ] type:[nsubj ] parent:[is]
# phrase:[happiness                     ] root:[happiness   ] type:[pobj  ] parent:[of]
# phrase:[the Australian concept        ] root:[concept     ] type:[pobj  ] parent:[from]
# phrase:[happiness                     ] root:[happiness   ] type:[pobj  ] parent:[of]
# Finns, she said, are happy to accept portrayals of themselves as melancholy and stubborn — a popular local saying is, “People who have happiness must hide it.”
# phrase:[Finns                         ] root:[Finns       ] type:[nsubj ] parent:[are]
# phrase:[she                           ] root:[she         ] type:[nsubj ] parent:[said]
# phrase:[portrayals                    ] root:[portrayals  ] type:[dobj  ] parent:[accept]
# phrase:[themselves                    ] root:[themselves  ] type:[pobj  ] parent:[of]
# phrase:[a popular local saying        ] root:[saying      ] type:[nsubj ] parent:[is]
# phrase:[People                        ] root:[People      ] type:[nsubj ] parent:[hide]
# phrase:[who                           ] root:[who         ] type:[nsubj ] parent:[have]
# phrase:[happiness                     ] root:[happiness   ] type:[dobj  ] parent:[have]
# phrase:[it                            ] root:[it          ] type:[dobj  ] parent:[hide]
# “The first thing I noticed here is that you don't go to dinners or barbecues, and you don't talk about real estate.
# phrase:[The first thing               ] root:[thing       ] type:[nsubj ] parent:[is]
# phrase:[I                             ] root:[I           ] type:[nsubj ] parent:[noticed]
# phrase:[you                           ] root:[you         ] type:[nsubj ] parent:[go]
# phrase:[dinners                       ] root:[dinners     ] type:[pobj  ] parent:[to]
# phrase:[barbecues                     ] root:[barbecues   ] type:[conj  ] parent:[dinners]
# phrase:[you                           ] root:[you         ] type:[nsubj ] parent:[talk]
# phrase:[real estate                   ] root:[estate      ] type:[pobj  ] parent:[about]
# No one asks you where you live, what suburb do you live in, where your kids go to school.”
# phrase:[No one                        ] root:[one         ] type:[nsubj ] parent:[asks]
# phrase:[you                           ] root:[you         ] type:[dobj  ] parent:[asks]
# phrase:[you                           ] root:[you         ] type:[nsubj ] parent:[live]
# phrase:[what suburb                   ] root:[suburb      ] type:[pobj  ] parent:[in]
# phrase:[you                           ] root:[you         ] type:[nsubj ] parent:[live]
# phrase:[your kids                     ] root:[kids        ] type:[nsubj ] parent:[go]
# phrase:[school                        ] root:[school      ] type:[pobj  ] parent:[to]
# The Finns seem quite happy with the status quo, and they don't always seem to want more.
# phrase:[The Finns                     ] root:[Finns       ] type:[nsubj ] parent:[seem]
# phrase:[the status quo                ] root:[quo         ] type:[pobj  ] parent:[with]
# phrase:[they                          ] root:[they        ] type:[nsubj ] parent:[seem]
# Melissa Georgio's Dark Night in Northern Europe Finland was named the happiest country in the world for the sixth year in a row in the “World Happiness Report” released by the United Nations.
# phrase:[Melissa Georgio's Dark Night  ] root:[Night       ] type:[nsubjpass] parent:[named]
# phrase:[Northern Europe               ] root:[Europe      ] type:[pobj  ] parent:[in]
# phrase:[Finland                       ] root:[Finland     ] type:[appos ] parent:[Night]
# phrase:[the happiest country          ] root:[country     ] type:[oprd  ] parent:[named]
# phrase:[the world                     ] root:[world       ] type:[pobj  ] parent:[in]
# phrase:[the sixth year                ] root:[year        ] type:[pobj  ] parent:[for]
# phrase:[a row                         ] root:[row         ] type:[pobj  ] parent:[in]
# phrase:[the “World Happiness Report   ] root:[Report      ] type:[pobj  ] parent:[in]
# phrase:[the United Nations            ] root:[Nations     ] type:[pobj  ] parent:[by]
# “The Nordic countries are often countries with (good) unemployment benefits, pensions, and other benefits,” explains happiness expert and researcher Frank Martela (Frank Martela).
# phrase:[The Nordic countries          ] root:[countries   ] type:[nsubj ] parent:[are]
# phrase:[countries                     ] root:[countries   ] type:[attr  ] parent:[are]
# phrase:[(good) unemployment benefits  ] root:[benefits    ] type:[pobj  ] parent:[with]
# phrase:[pensions                      ] root:[pensions    ] type:[conj  ] parent:[benefits]
# phrase:[other benefits                ] root:[benefits    ] type:[conj  ] parent:[pensions]
# phrase:[happiness expert and researcher Frank Martela] root:[Martela     ] type:[nsubj ] parent:[explains]
# phrase:[Frank Martela                 ] root:[Martela     ] type:[appos ] parent:[Martela]
# However, Frank said that Finland's position in the rankings often surprised its own people.
# phrase:[Frank                         ] root:[Frank       ] type:[nsubj ] parent:[said]
# phrase:[Finland's position            ] root:[position    ] type:[nsubj ] parent:[surprised]
# phrase:[the rankings                  ] root:[rankings    ] type:[pobj  ] parent:[in]
# phrase:[its own people                ] root:[people      ] type:[dobj  ] parent:[surprised]
# “Finns, they're almost outraged because they don't think this can be true.
# phrase:[they                          ] root:[they        ] type:[nsubj ] parent:['re]
# phrase:[they                          ] root:[they        ] type:[nsubj ] parent:[think]
# phrase:[this                          ] root:[this        ] type:[nsubj ] parent:[be]
# We listen to sad music and hard rock.”
# phrase:[We                            ] root:[We          ] type:[nsubj ] parent:[listen]
# phrase:[sad music                     ] root:[music       ] type:[pobj  ] parent:[to]
# phrase:[hard rock                     ] root:[rock        ] type:[conj  ] parent:[music]
# “Therefore, happiness is not part of the Finnish self-image.”
# phrase:[happiness                     ] root:[happiness   ] type:[nsubj ] parent:[is]
# phrase:[part                          ] root:[part        ] type:[attr  ] parent:[is]
# phrase:[the Finnish self-image        ] root:[image       ] type:[pobj  ] parent:[of]
# The other side of Finnish melancholy is a cultural focus on perseverance.
# phrase:[The other side                ] root:[side        ] type:[nsubj ] parent:[is]
# phrase:[Finnish melancholy            ] root:[melancholy  ] type:[pobj  ] parent:[of]
# phrase:[a cultural focus              ] root:[focus       ] type:[attr  ] parent:[is]
# phrase:[perseverance                  ] root:[perseverance] type:[pobj  ] parent:[on]
# Frank said it redefines the way Finns view happiness — a concept known as “sisu” — which is part of Finnish culture and is hard to translate directly, but can be understood as will, determination, perseverance, and reason to face adversity.
# phrase:[Frank                         ] root:[Frank       ] type:[nsubj ] parent:[said]
# phrase:[it                            ] root:[it          ] type:[nsubj ] parent:[redefines]
# phrase:[the way                       ] root:[way         ] type:[dobj  ] parent:[redefines]
# phrase:[Finns                         ] root:[Finns       ] type:[nsubj ] parent:[view]
# phrase:[happiness                     ] root:[happiness   ] type:[dobj  ] parent:[view]
# phrase:[a concept                     ] root:[concept     ] type:[appos ] parent:[happiness]
# phrase:[“sisu                         ] root:[sisu        ] type:[pobj  ] parent:[as]
# phrase:[which                         ] root:[which       ] type:[nsubj ] parent:[is]
# phrase:[part                          ] root:[part        ] type:[attr  ] parent:[is]
# phrase:[Finnish culture               ] root:[culture     ] type:[pobj  ] parent:[of]
# phrase:[will                          ] root:[will        ] type:[pobj  ] parent:[as]
# phrase:[determination                 ] root:[determination] type:[conj  ] parent:[will]
# phrase:[perseverance                  ] root:[perseverance] type:[conj  ] parent:[determination]
# phrase:[reason                        ] root:[reason      ] type:[conj  ] parent:[perseverance]
# phrase:[adversity                     ] root:[adversity   ] type:[dobj  ] parent:[face]
# This, he said, is best reflected in Finns' favorite pastime — getting warm in a sauna after taking a bath in freezing temperatures.
# phrase:[This                          ] root:[This        ] type:[nsubjpass] parent:[reflected]
# phrase:[he                            ] root:[he          ] type:[nsubj ] parent:[said]
# phrase:[Finns' favorite pastime       ] root:[pastime     ] type:[pobj  ] parent:[in]
# phrase:[a sauna                       ] root:[sauna       ] type:[pobj  ] parent:[in]
# phrase:[a bath                        ] root:[bath        ] type:[dobj  ] parent:[taking]
# phrase:[freezing temperatures         ] root:[temperatures] type:[pobj  ] parent:[in]
# “It's about this paradox — from one extreme to the other, and it's a pretty fun experience... because you need perseverance.”
# phrase:[It                            ] root:[It          ] type:[nsubj ] parent:['s]
# phrase:[this paradox                  ] root:[paradox     ] type:[pobj  ] parent:[about]
# phrase:[one extreme                   ] root:[extreme     ] type:[pobj  ] parent:[from]
# phrase:[it                            ] root:[it          ] type:[nsubj ] parent:['s]
# phrase:[a pretty fun experience       ] root:[experience  ] type:[attr  ] parent:['s]
# phrase:[you                           ] root:[you         ] type:[nsubj ] parent:[need]
# phrase:[perseverance                  ] root:[perseverance] type:[dobj  ] parent:[need]
# Melissa said, but Finland has many things that are great and can provide happiness for people in this country.
# phrase:[Melissa                       ] root:[Melissa     ] type:[nsubj ] parent:[said]
# phrase:[Finland                       ] root:[Finland     ] type:[nsubj ] parent:[has]
# phrase:[many things                   ] root:[things      ] type:[dobj  ] parent:[has]
# phrase:[that                          ] root:[that        ] type:[nsubj ] parent:[are]
# phrase:[happiness                     ] root:[happiness   ] type:[dobj  ] parent:[provide]
# phrase:[people                        ] root:[people      ] type:[pobj  ] parent:[for]
# phrase:[this country                  ] root:[country     ] type:[pobj  ] parent:[in]
# Finland is one of the European countries least affected by the COVID-19 pandemic, and experts attribute this to a high level of trust in the government and little resistance to complying with restrictions.
# phrase:[Finland                       ] root:[Finland     ] type:[nsubj ] parent:[is]
# phrase:[the European countries        ] root:[countries   ] type:[pobj  ] parent:[of]
# phrase:[the COVID-19 pandemic         ] root:[pandemic    ] type:[pobj  ] parent:[by]
# phrase:[experts                       ] root:[experts     ] type:[nsubj ] parent:[attribute]
# phrase:[this                          ] root:[this        ] type:[dobj  ] parent:[attribute]
# phrase:[a high level                  ] root:[level       ] type:[pobj  ] parent:[to]
# phrase:[trust                         ] root:[trust       ] type:[pobj  ] parent:[of]
# phrase:[the government                ] root:[government  ] type:[pobj  ] parent:[in]
# phrase:[little resistance             ] root:[resistance  ] type:[conj  ] parent:[level]
# phrase:[restrictions                  ] root:[restrictions] type:[pobj  ] parent:[with]
# Trust in government, on the other hand, stems from a country's investment in its citizens.
# phrase:[Trust                         ] root:[Trust       ] type:[nsubj ] parent:[stems]
# phrase:[government                    ] root:[government  ] type:[pobj  ] parent:[in]
# phrase:[the other hand                ] root:[hand        ] type:[pobj  ] parent:[on]
# phrase:[a country's investment        ] root:[investment  ] type:[pobj  ] parent:[from]
# phrase:[its citizens                  ] root:[citizens    ] type:[pobj  ] parent:[in]
# The public school system rarely tests children and is one of the best in the world.
# phrase:[The public school system      ] root:[system      ] type:[nsubj ] parent:[tests]
# phrase:[children                      ] root:[children    ] type:[dobj  ] parent:[tests]
# phrase:[the world                     ] root:[world       ] type:[pobj  ] parent:[in]
# Finland also has a universal health care system with affordable childcare and strong support for parents.
# phrase:[Finland                       ] root:[Finland     ] type:[nsubj ] parent:[has]
# phrase:[a universal health care system] root:[system      ] type:[dobj  ] parent:[has]
# phrase:[affordable childcare          ] root:[childcare   ] type:[pobj  ] parent:[with]
# phrase:[strong support                ] root:[support     ] type:[conj  ] parent:[childcare]
# phrase:[parents                       ] root:[parents     ] type:[pobj  ] parent:[for]
# Melissa said, “The whole country is taking care of the child's development.
# phrase:[Melissa                       ] root:[Melissa     ] type:[nsubj ] parent:[said]
# phrase:[The whole country             ] root:[country     ] type:[nsubj ] parent:[taking]
# phrase:[care                          ] root:[care        ] type:[dobj  ] parent:[taking]
# phrase:[the child's development       ] root:[development ] type:[pobj  ] parent:[of]
# This system is very well set up.
# phrase:[This system                   ] root:[system      ] type:[nsubjpass] parent:[set]
# So from having my son to raising him at home, to sending him to daycare, to going to school, I was very well supported in every aspect of this.”
# phrase:[my son                        ] root:[son         ] type:[dobj  ] parent:[having]
# phrase:[him                           ] root:[him         ] type:[dobj  ] parent:[raising]
# phrase:[home                          ] root:[home        ] type:[pobj  ] parent:[at]
# phrase:[him                           ] root:[him         ] type:[dobj  ] parent:[sending]
# phrase:[daycare                       ] root:[daycare     ] type:[pobj  ] parent:[to]
# phrase:[school                        ] root:[school      ] type:[pobj  ] parent:[to]
# phrase:[I                             ] root:[I           ] type:[nsubjpass] parent:[supported]
# phrase:[every aspect                  ] root:[aspect      ] type:[pobj  ] parent:[in]
# phrase:[this                          ] root:[this        ] type:[pobj  ] parent:[of]
# Finland vs. China, which country has the strongest sense of happiness?
# phrase:[China                         ] root:[China       ] type:[pobj  ] parent:[vs.]
# phrase:[which country                 ] root:[country     ] type:[nsubj ] parent:[has]
# phrase:[the strongest sense           ] root:[sense       ] type:[dobj  ] parent:[has]
# phrase:[happiness                     ] root:[happiness   ] type:[pobj  ] parent:[of]
# Since the publication of the World Happiness Report, the Nordic countries have dominated the top ten.
# phrase:[the publication               ] root:[publication ] type:[pobj  ] parent:[Since]
# phrase:[the World Happiness Report    ] root:[Report      ] type:[pobj  ] parent:[of]
# phrase:[the Nordic countries          ] root:[countries   ] type:[nsubj ] parent:[dominated]
# In this year's report, Finland and its neighbors Denmark (2nd), Iceland (3rd), Sweden (6th), and Norway (7th) all scored high on happiness indicators, including healthy life expectancy, per capita GDP, low levels of corruption, social support, freedom, trust, and generosity.
# phrase:[this year's report            ] root:[report      ] type:[pobj  ] parent:[In]
# phrase:[Finland                       ] root:[Finland     ] type:[nsubj ] parent:[scored]
# phrase:[its neighbors                 ] root:[neighbors   ] type:[conj  ] parent:[Finland]
# phrase:[Denmark                       ] root:[Denmark     ] type:[appos ] parent:[neighbors]
# phrase:[Iceland                       ] root:[Iceland     ] type:[conj  ] parent:[Denmark]
# phrase:[Sweden                        ] root:[Sweden      ] type:[conj  ] parent:[Iceland]
# phrase:[Norway                        ] root:[Norway      ] type:[conj  ] parent:[Sweden]
# phrase:[happiness indicators          ] root:[indicators  ] type:[pobj  ] parent:[on]
# phrase:[healthy life expectancy       ] root:[expectancy  ] type:[pobj  ] parent:[including]
# phrase:[per capita GDP                ] root:[GDP         ] type:[conj  ] parent:[expectancy]
# phrase:[low levels                    ] root:[levels      ] type:[conj  ] parent:[GDP]
# phrase:[corruption                    ] root:[corruption  ] type:[pobj  ] parent:[of]
# phrase:[social support                ] root:[support     ] type:[conj  ] parent:[levels]
# phrase:[freedom                       ] root:[freedom     ] type:[conj  ] parent:[support]
# phrase:[trust                         ] root:[trust       ] type:[conj  ] parent:[freedom]
# phrase:[generosity                    ] root:[generosity  ] type:[conj  ] parent:[trust]
# Other top ten countries/regions include the Netherlands (5th), Switzerland (8th), Luxembourg (9th), and New Zealand (10th).
# phrase:[Other top ten countries/regions] root:[regions     ] type:[nsubj ] parent:[include]
# phrase:[the Netherlands               ] root:[Netherlands ] type:[dobj  ] parent:[include]
# phrase:[Switzerland                   ] root:[Switzerland ] type:[conj  ] parent:[Netherlands]
# phrase:[Luxembourg                    ] root:[Luxembourg  ] type:[conj  ] parent:[Switzerland]
# phrase:[New Zealand                   ] root:[Zealand     ] type:[conj  ] parent:[Luxembourg]
# Australia ranked 12th in this report, followed by Canada (13th), Ireland (14th), and the United States (15th).
# phrase:[Australia                     ] root:[Australia   ] type:[nsubj ] parent:[ranked]
# phrase:[this report                   ] root:[report      ] type:[pobj  ] parent:[in]
# phrase:[Canada                        ] root:[Canada      ] type:[pobj  ] parent:[by]
# phrase:[Ireland                       ] root:[Ireland     ] type:[conj  ] parent:[Canada]
# phrase:[the United States             ] root:[States      ] type:[conj  ] parent:[Ireland]
# In Asia, Singapore ranked 25th in the world, up two places from last year, Taiwan dropped one place from last year to 27th, Japan rose to 47th, mainland China ranked 64th, and Hong Kong ranked 82nd.
# phrase:[Asia                          ] root:[Asia        ] type:[pobj  ] parent:[In]
# phrase:[Singapore                     ] root:[Singapore   ] type:[nsubj ] parent:[ranked]
# phrase:[the world                     ] root:[world       ] type:[pobj  ] parent:[in]
# phrase:[Taiwan                        ] root:[Taiwan      ] type:[nsubj ] parent:[dropped]
# phrase:[last year                     ] root:[year        ] type:[pobj  ] parent:[from]
# phrase:[Japan                         ] root:[Japan       ] type:[nsubj ] parent:[rose]
# phrase:[mainland China                ] root:[China       ] type:[nsubj ] parent:[ranked]
# phrase:[Hong Kong                     ] root:[Kong        ] type:[nsubj ] parent:[ranked]
# Meanwhile, the polling agency Ipsos Group (Ipsos) released a survey report on the global happiness index.
# phrase:[the polling agency            ] root:[agency      ] type:[nsubj ] parent:[released]
# phrase:[Ipsos Group                   ] root:[Group       ] type:[appos ] parent:[agency]
# phrase:[Ipsos                         ] root:[Ipsos       ] type:[appos ] parent:[Group]
# phrase:[a survey report               ] root:[report      ] type:[dobj  ] parent:[released]
# phrase:[the global happiness index    ] root:[index       ] type:[pobj  ] parent:[on]
# The results showed that out of 32 countries, the country with the highest happiness index was China (91%), followed by Saudi Arabia (86%), the Netherlands (85%), India (84%), and Brazil (83%).
# phrase:[The results                   ] root:[results     ] type:[nsubj ] parent:[showed]
# phrase:[32 countries                  ] root:[countries   ] type:[pobj  ] parent:[of]
# phrase:[the country                   ] root:[country     ] type:[nsubj ] parent:[was]
# phrase:[the highest happiness index   ] root:[index       ] type:[pobj  ] parent:[with]
# phrase:[China                         ] root:[China       ] type:[attr  ] parent:[was]
# phrase:[Saudi Arabia                  ] root:[Arabia      ] type:[pobj  ] parent:[by]
# phrase:[the Netherlands               ] root:[Netherlands ] type:[conj  ] parent:[Arabia]
# phrase:[India                         ] root:[India       ] type:[conj  ] parent:[Netherlands]
# phrase:[84%                           ] root:[%           ] type:[appos ] parent:[India]
# phrase:[Brazil                        ] root:[Brazil      ] type:[conj  ] parent:[India]
# phrase:[83%                           ] root:[%           ] type:[appos ] parent:[Brazil]
# Australia ranked 9th in this report.
# phrase:[Australia                     ] root:[Australia   ] type:[nsubj ] parent:[ranked]
# phrase:[this report                   ] root:[report      ] type:[pobj  ] parent:[in]
# According to the survey report, on average, happiness increased more significantly in middle-income countries (as defined by the World Bank) than in high-income countries.
# phrase:[the survey report             ] root:[report      ] type:[pobj  ] parent:[to]
# phrase:[happiness                     ] root:[happiness   ] type:[nsubj ] parent:[increased]
# phrase:[middle-income countries       ] root:[countries   ] type:[pobj  ] parent:[in]
# phrase:[the World Bank                ] root:[Bank        ] type:[pobj  ] parent:[by]
# phrase:[high-income countries         ] root:[countries   ] type:[pobj  ] parent:[in]
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[34], line 14
#       7 while phrase.root.sent == sentence:
#       8     print(
#       9         f"phrase:[{phrase.text:30}] "\
#      10         f"root:[{phrase.root.text:12}] "\
#      11         f"type:[{phrase.root.dep_:6}] "\
#      12         f"parent:[{phrase.root.head}]"
#      13     )
# ---> 14     phrase = next(phrases)
#
# StopIteration:

# %%
for chunk in doc.noun_chunks:
    print(
        f"{chunk.text:32} " \
        f"tag:{chunk.root.dep_:10} " \
        f"root:{chunk.root.head.text:10} " \
#        sentence:{chunk.root.sent} " \
        f"children:{list(chunk.root.children)}"
    )

# %%
print("{}{}{}{}{}{}".format(
    "Token".ljust(15), "Lemma".ljust(15), "POS".ljust(10), "Tag".ljust(8), "Dependency".ljust(14), "StopWord"
))
print("-" * 80)
for token in doc:
    if (not token.is_stop) and len(token.text) > 1:
        print(f"{token.text:15}{token.lemma_:15}{token.pos_:10}{token.tag_:8}{token.dep_:14}{token.is_stop:}")

# %% [markdown]
# ---

# %% [markdown]
# # Key Noun Phrases
#
# Find a phrase that includes an identified named entity.

# %%
candidates = set()

for chunk in doc.noun_chunks:
    # --------------------------------------------------------------------------------
    # Skip the phrase if it is the same with its root.
    # --------------------------------------------------------------------------------
    if chunk.text.lower() != chunk.root.text.lower():
        
        # --------------------------------------------------------------------------------
        # Select a noun phrase that may include a named entity.
        # --------------------------------------------------------------------------------
        if set(chunk.text.lower().split()).intersection(words_in_entities):
            phrase = clean_text(text=chunk.text, lower=True)
            
            # --------------------------------------------------------------------------------
            # Select a phrase that a named entity is a part of. For instance, select
            # "happiness expert researcher Frank Martela" which the named entity 
            # "Frank Martela" is a part of.
            # --------------------------------------------------------------------------------
            # if any([set(entity.split()).issubset(phrase) for entity in words_in_entities]):
            if any([(entity.lower() in phrase.lower()) for entity in entity_phrases]):
                key_phrase_candidate = clean_text(text=chunk.text, lower=False)
                if key_phrase_candidate not in candidates:
                    # print(f"phrase:[{key_phrase_candidate:50}] root:[{chunk.root.text:15}] type:[{chunk.root.dep_:6}]")
                    candidates.add(key_phrase_candidate)

# --------------------------------------------------------------------------------
# Remove duplicates that are already in selected_named_entities
# --------------------------------------------------------------------------------
key_phrases = {
    candidate for candidate in candidates
    if candidate not in selected_named_entities
}
key_phrases
# Out:
# {'Australian Melissa Georgiou',
#  "Melissa Georgio's Dark Night",
#  'happiness expert researcher Frank Martela',
#  'mainland China'}

# %%
set(selected_named_entities)
# Out:
# {'Asia',
#  'Australia',
#  'Brazil',
#  'Canada',
#  'China',
#  'Dark Night',
#  'Denmark',
#  'Earth',
#  'Finland',
#  'Frank',
#  'Frank Martela',
#  'Hong Kong',
#  'Iceland',
#  'India',
#  'Ipsos',
#  'Ipsos Group',
#  'Ireland',
#  'Japan',
#  'Luxembourg',
#  'Melissa',
#  "Melissa Georgio's",
#  'Melissa Georgiou',
#  'Netherlands',
#  'New Zealand',
#  'Northern Europe',
#  'Norway',
#  'Saudi Arabia',
#  'Singapore',
#  'Sweden',
#  'Switzerland',
#  'Sydney',
#  'Taiwan',
#  'United Nations',
#  'United States',
#  'World Bank',
#  'World Happiness Report'}

# %% [markdown]
# ---
# # Keyword Extraction

# %%
import textacy

# %%
document = textacy.make_spacy_doc(text, lang="en_core_web_sm")

# %%
[kps for kps, weights in textacy.extract.keyterms.sgrank(doc=document, ngrams=[1,2,3,4,5], topn=20)]
# Out:
# ['World Happiness Report',
#  'Melissa Georgiou',
#  'Finland',
#  'happiness',
#  'Frank Martela',
#  'australian',
#  'Finns',
#  'thing',
#  'nordic country',
#  'year',
#  'concept',
#  'cold',
#  'favorite',
#  'place',
#  'happy',
#  'melancholy',
#  'middle',
#  'school',
#  'world',
#  'finnish']

# %%
[kps for kps, weights in textacy.extract.keyterms.textrank(doc=document, window_size=20, topn=20)]
# Out:
# ['high happiness index',
#  'global happiness index',
#  'happiness expert',
#  'happy country',
#  'happiness indicator',
#  'Northern Europe Finland',
#  'nordic country',
#  'european country',
#  'income country',
#  'australian Melissa Georgiou',
#  'universal health care system',
#  'public school system',
#  'World Happiness Report',
#  'polling agency Ipsos Group',
#  'way Finns',
#  'survey report',
#  'high level',
#  'strong support',
#  'researcher Frank Martela',
#  'sixth year']

# %% [markdown]
# ---

# %% [markdown]
# # Wordnet

# %%
import nltk
from itertools import chain
from nltk.corpus import wordnet

nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /Users/oonisim/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# ## Stem
#
# happy -> hapiness

# %%
# Just to make it a bit more readable
WN_NOUN = 'n'
WN_VERB = 'v'
WN_ADJECTIVE = 'a'
WN_ADJECTIVE_SATELLITE = 's'
WN_ADVERB = 'r'


def convert(word, from_pos, to_pos):    
    """ Transform words given from/to POS tags """
    synsets = wordnet.synsets(word, pos=from_pos)

    # Word not found
    if not synsets:
        return []

    # Get all lemmas of the word (consider 'a'and 's' equivalent)
    lemmas = []
    for s in synsets:
        for l in s.lemmas():
            if s.name().split('.')[1] == from_pos or from_pos in (WN_ADJECTIVE, WN_ADJECTIVE_SATELLITE) and s.name().split('.')[1] in (WN_ADJECTIVE, WN_ADJECTIVE_SATELLITE):
                lemmas += [l]

    # Get related forms
    derivationally_related_forms = [(l, l.derivationally_related_forms()) for l in lemmas]

    # filter only the desired pos (consider 'a' and 's' equivalent)
    related_noun_lemmas = []

    for drf in derivationally_related_forms:
        for l in drf[1]:
            if l.synset().name().split('.')[1] == to_pos or to_pos in (WN_ADJECTIVE, WN_ADJECTIVE_SATELLITE) and l.synset().name().split('.')[1] in (WN_ADJECTIVE, WN_ADJECTIVE_SATELLITE):
                related_noun_lemmas += [l]

    # Extract the words from the lemmas
    words = [l.name() for l in related_noun_lemmas]
    len_words = len(words)

    # Build the result in the form of a list containing tuples (word, probability)
    result = [(w, float(words.count(w)) / len_words) for w in set(words)]
    result.sort(key=lambda w:-w[1])

    # return all the possibilities sorted by probability
    return result

# %%
convert("happy", "a", "n")
# Out:
# [('happiness', 0.6), ('felicitousness', 0.2), ('felicity', 0.2)]

# %%
convert("happy", "a", "r")
# Out:
# []

# %%
convert("speedy", "a", "n")
# Out:
# [('speed', 0.375),
#  ('speediness', 0.25),
#  ('quickness', 0.125),
#  ('rapidness', 0.125),
#  ('rapidity', 0.125)]

# %%
convert("speedy", "a", "r")
# Out:
# []

# %%
def get_synonyms(text: str, pos=None):
    """Get synonym of the POS type. 
    
    "speed" can be verb and noun. To get the synonyms for verb, set pos='v'
    
    Args:
        text: text to find the synonyms
        pos: part of speech tag (n=noun, v=verb, a=adjective, r=adverb)
    Returns: set of synonyms
    """
    text = "_".join(text.split())
    synonyms = wordnet.synsets(text, pos=pos)
    lemmas = set(chain.from_iterable([word.lemma_names() for word in synonyms]))
    return lemmas - {text}

# %%
get_synonyms(text="speed", pos="v")
# Out:
# {'accelerate',
#  'belt_along',
#  'bucket_along',
#  'cannonball_along',
#  'hasten',
#  'hie',
#  'hotfoot',
#  'hurry',
#  'pelt_along',
#  'quicken',
#  'race',
#  'rush',
#  'rush_along',
#  'speed_up',
#  'step_on_it',
#  'travel_rapidly',
#  'zip'}
