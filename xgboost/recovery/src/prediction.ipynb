# %% [markdown]
# ---
# # Setup

# %%
import os
import sys
import logging
import datetime
import calendar
from typing import (
    List,
    Dict,
    Tuple,
    Any,
    Optional,
    Callable,
    Iterable,
)

import dateutil
import pandas as pd
import numpy as np

import xgboost as xgb
print(xgb.__version__)

from sklearn.metrics import (
    mean_squared_error
)
from sklearn.model_selection import (
    cross_val_score,
    RepeatedKFold,
    GridSearchCV
)
from xgboost import plot_importance
import matplotlib.pyplot as plt
from IPython.display import display, HTML

# %matplotlib inline
# Out:
# 1.7.3

# %% [markdown]
# ## Logging

# %%
# logging.basicConfig(stream=sys.stdout, level=logging.ERROR)
logger = logging.getLogger("analysis")

# %% [markdown]
# ## PYTHONPATH

# %%
sys.path.append(f"{os.getcwd()}/../../../lib")

# %%
# %load_ext autoreload
# %autoreload 2
from util_constant import (
    TYPE_FLOAT,
)
from util_datetime import (
    get_datetime_components,
    convert_date_into_datetime,
    convert_time_into_timedelta,
    convert_date_time_into_datetime,
    parse_date_string,
    parse_time_string,
    get_dates_from_string,
    has_date_in_string,
    parse_datetime_string,
    get_epoch_from_datetime,
    get_epoch_from_string,
    get_seconds_between_datetimes,
    get_datetime_after_duration,
    get_elapsed_time,
    get_holidays,
    is_holiday,
    is_weekend,
    get_cyclic_time_of_day,
    get_cyclic_day_of_week,
    get_cyclic_month_of_year,
)

# %%
from functions import (
    get_start_date_time,
    get_end_date_time,
    get_process_time,
    get_process_date,
    get_code_from_supplier,
    get_numeric_supplier_code,
    get_supplier_code,
    get_numeric_facility_code,
    get_facility_code,
    get_weekday,
    get_weekday_cyclic,
    get_holiday,
    get_start_hour,
    get_start_time_cyclic,
)

# %% [markdown]
# ## Pandas

# %%
# pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Constant

# %%
PATH_TO_DATA: str = "../data/schedules.json"

# %%
from constants import (
    # loation
    COUNTRY_CODE,
    # Actors
    COLUMN_FACILITY_CODE,
    COLUMN_FACILITY,
    COLUMN_SUPPLIER_CODE,
    # Timing
    COLUMN_PROCESS_DATE,
    COLUMN_START_TIME,
    COLUMN_START_HOUR,
    COLUMN_START_TIME_SINX,
    COLUMN_START_TIME_COSY,
    COLUMN_END_TIME,
    COLUMN_WEEKDAY,
    COLUMN_WEEKDAY_SINX,
    COLUMN_WEEKDAY_COSY,
    COLUMN_IS_HOLIDAY,
    # Performance
    COLUMN_PROCESS_TIME,
    COLUMN_INPUT,
    COLUMN_OUTPUT,
    COLUMN_THROUGHPUT,
    COLUMN_RECOVERY_RATE,

    # utility
    SECONDS_IN_MIN
)

# %%
# Utility
DEBUG = False

# %% [markdown]
# ---
# # Data

# %%
# Read columns as strings without auto-detect/convert.
raw_df = pd.read_json(
    PATH_TO_DATA,
    convert_dates=False
)

# %%
raw_df.columns
# Out:
# Index(['facility', 'date', 'time', 'supplier', 'volumeM3'], dtype='object')

# %%
raw_df.rename(
    columns={
        'time':'timeStart',
        'volumeM3': 'suppliedM3'
    }, 
    inplace=True
)

# %% [markdown]
# ### Add NaN column as supplierCode if not exist

# %%
if 'supplierCode' not in raw_df.columns:
    raw_df['supplierCode'] = raw_df['supplier']
    raw_df['supplierCode'] = np.nan

# %%
raw_df['facility'].unique()
# Out:
# array(['Bundaberg', 'Newcastle'], dtype=object)

# %%
raw_df['supplierCode'].unique()
# Out:
# array([nan])

# %%
raw_df['supplier'].unique() if 'supplier' in raw_df.columns else None
# Out:
# array(['Mary Anne', 'Dick Tracey', 'Mary', 'Tom Hanks', 'Mary Jane',
#        'Harry Houdini', 'Mary Therese'], dtype=object)

# %%
if DEBUG:
    display(raw_df[:10])

# %% [markdown]
# ---
# # Feature extractions

# %% [markdown]
# ## Start Time

# %%
start_date_time: pd.Series = raw_df.apply(func=get_start_date_time, axis=1)
start_date_time.name = COLUMN_START_TIME
if DEBUG:
    display(start_date_time[:5])

# %% [markdown]
# ## Process Date

# %%
process_date: pd.Series = start_date_time.to_frame().apply(func=get_process_date, axis=1)
process_date.name = COLUMN_PROCESS_DATE
if DEBUG:
    display(process_date[:5])

# %% [markdown]
# ## Supplier Code

# %%
supplier_code: pd.Series = raw_df.apply(func=get_supplier_code, axis=1)
supplier_code.name = COLUMN_SUPPLIER_CODE
if DEBUG:
    display(supplier_code[:5])

# %% [markdown]
# ## Facility

# %%
facility_code: pd.Series = raw_df.apply(func=get_facility_code, axis=1)
facility_code.name = COLUMN_FACILITY_CODE
if DEBUG:
    display(facility_code[:5])

# %% [markdown]
# ## Weekday

# %%
weekday: pd.Series = start_date_time.to_frame().apply(func=get_weekday, axis=1)
weekday.name = COLUMN_WEEKDAY

# %% [markdown]
# ## Weekday in cyclic

# %%
weekday_sin_x: pd.Series
weekday_cos_y: pd.Series
    
weekday_sin_x, weekday_cos_y = ( # Return views, hence modifying them will cause warnings.
    value 
    for _, value 
    in start_date_time.to_frame().apply(func=get_weekday_cyclic, axis=1).items()
)

# %% [markdown]
# ## Holiday

# %%
holiday: pd.Series = start_date_time.to_frame().apply(func=get_holiday, axis=1)
holiday.name = COLUMN_IS_HOLIDAY

# %% [markdown]
# ## Start Hour

# %%
start_hour: pd.Series = start_date_time.to_frame().apply(func=get_start_hour, axis=1)
start_hour.name = COLUMN_START_HOUR

# %% [markdown]
# ## Start time in cyclic

# %%
# https://stackoverflow.com/questions/23586510
# https://stackoverflow.com/questions/51225275
start_time_sin_x: pd.Series
start_time_cos_y: pd.Series
    
start_time_sin_x, start_time_cos_y = ( # Return views, hence modifying them will cause warnings.
    value 
    for _, value 
    in start_date_time.to_frame().apply(func=get_start_time_cyclic, axis=1).items()
)

# %%
start_time_sin_x.name = COLUMN_START_TIME_SINX
start_time_cos_y.name = COLUMN_START_TIME_COSY
if DEBUG:
    start_time_sin_x

# %% [markdown]
# ---
# # Prediction Input

# %%
df: pd.DataFrame = pd.DataFrame({
    COLUMN_FACILITY_CODE: facility_code,
    COLUMN_SUPPLIER_CODE: supplier_code,
    COLUMN_PROCESS_DATE: process_date,
    COLUMN_START_HOUR: start_hour,
    COLUMN_START_TIME_SINX: start_time_sin_x,
    COLUMN_START_TIME_COSY: start_time_cos_y,
    COLUMN_WEEKDAY: weekday,
    COLUMN_WEEKDAY_SINX: weekday_sin_x,
    COLUMN_WEEKDAY_COSY: weekday_cos_y,
    COLUMN_IS_HOLIDAY: holiday.astype(np.uint8),
    COLUMN_INPUT: raw_df['suppliedM3'].astype(TYPE_FLOAT),
})
df[:5]
# Out:
#    facility_code  supplier_code  process_date  start_hour  start_time_sin_x  \
# 0              1              2             9           8          0.809017
# 1              0              5             9           8          0.801254
# 2              1              1             9           9          0.625923
# 3              0              5             9          11          0.013090
# 4              1              2             9          12         -0.199368
#
#    start_time_cos_y  dayofweek  dayofweek_sin_x  dayofweek_cos_y  is_holiday  \
# 0         -0.587785          0              0.0              1.0           0
# 1         -0.598325          0              0.0              1.0           0
# 2         -0.779885          0              0.0              1.0           0
# 3         -0.999914          0              0.0              1.0           0
# 4         -0.979925          0              0.0              1.0           0
#
#    input
# 0    2.9
# 1    6.5
# 2    5.0
# 3    6.3
# 4    3.0

# %% [markdown]
# ---
# # Prediction

# %%
model = xgb.XGBRegressor()
model.load_model("xgb_model_sklearn.txt")

# %%
predictions = model.predict(df)

# %% [markdown]
# # Save Result

# %%
raw_df.drop(['supplierCode'], axis=1, inplace=True)
raw_df.rename(
    columns={
        'timeStart': 'time',
        'suppliedM3': 'volumeM3',
    }, 
    inplace=True
)
raw_df['prediction'] = predictions
raw_df
# Out:
#      facility          date         time       supplier  volumeM3  prediction
# 0   Bundaberg   Jan 9, 2023   8:24:00 AM      Mary Anne       2.9    2.377049
# 1   Newcastle   Jan 9, 2023   8:27:00 AM    Dick Tracey       6.5    4.767631
# 2   Bundaberg   Jan 9, 2023   9:25:00 AM           Mary       5.0    3.619180
# 3   Newcastle   Jan 9, 2023  11:57:00 AM    Dick Tracey       6.3    4.198112
# 4   Bundaberg   Jan 9, 2023  12:46:00 PM      Mary Anne       3.0    2.358366
# 5   Newcastle   Jan 9, 2023   1:49:00 PM      Tom Hanks       3.7    2.281763
# 6   Bundaberg   Jan 9, 2023   2:49:00 PM      Mary Anne       2.9    2.157882
# 7   Newcastle  Jan 10, 2023   8:17:00 AM    Dick Tracey       6.7    4.804445
# 8   Bundaberg  Jan 10, 2023   8:30:00 AM           Mary       5.1    3.839736
# 9   Newcastle  Jan 10, 2023  10:16:00 AM    Dick Tracey       7.0    4.433242
# 10  Bundaberg  Jan 10, 2023  10:44:00 AM      Mary Anne       3.1    2.462566
# 11  Bundaberg  Jan 10, 2023  11:39:00 AM      Mary Anne       2.8    2.283424
# 12  Bundaberg  Jan 10, 2023  12:33:00 PM      Mary Jane       4.9    3.473306
# 13  Newcastle  Jan 10, 2023   2:09:00 PM      Tom Hanks       4.0    2.443926
# 14  Newcastle  Jan 10, 2023   3:53:00 PM  Harry Houdini       1.9    1.351057
# 15  Bundaberg  Jan 11, 2023   8:10:00 AM   Mary Therese       4.1    2.941049
# 16  Newcastle  Jan 11, 2023   8:14:00 AM      Tom Hanks       4.2    3.073305
# 17  Bundaberg  Jan 11, 2023   9:16:00 AM           Mary       4.9    3.621850
# 18  Newcastle  Jan 11, 2023  11:37:00 AM  Harry Houdini       2.1    1.597542
# 19  Bundaberg  Jan 11, 2023  12:41:00 PM      Mary Anne       2.9    2.318316
# 20  Newcastle  Jan 11, 2023  12:45:00 PM      Tom Hanks       3.9    2.529098
# 21  Newcastle  Jan 11, 2023   2:22:00 PM  Harry Houdini       2.0    1.413155
# 22  Bundaberg  Jan 11, 2023   2:29:00 PM           Mary       5.0    3.261283
# 23  Newcastle  Jan 11, 2023   3:35:00 PM  Harry Houdini       2.0    1.375865
# 24  Bundaberg  Jan 12, 2023   8:13:00 AM   Mary Therese       3.7    2.543845
# 25  Newcastle  Jan 12, 2023   8:21:00 AM  Harry Houdini       2.0    1.587385
# 26  Newcastle  Jan 12, 2023   9:21:00 AM      Tom Hanks       3.7    2.475707
# 27  Bundaberg  Jan 12, 2023  10:59:00 AM      Mary Anne       2.9    2.356963
# 28  Newcastle  Jan 12, 2023  11:34:00 AM      Tom Hanks       4.3    2.900730
# 29  Bundaberg  Jan 12, 2023  12:26:00 PM           Mary       4.9    3.482243
# 30  Newcastle  Jan 12, 2023   1:11:00 PM  Harry Houdini       2.0    1.440276
# 31  Newcastle  Jan 12, 2023   2:46:00 PM  Harry Houdini       1.9    1.388327
# 32  Bundaberg  Jan 12, 2023   3:19:00 PM   Mary Therese       4.3    2.615183
# 33  Newcastle  Jan 13, 2023   8:17:00 AM  Harry Houdini       1.9    1.566623
# 34  Bundaberg  Jan 13, 2023   8:18:00 AM   Mary Therese       4.7    3.597565
# 35  Newcastle  Jan 13, 2023   9:24:00 AM    Dick Tracey       5.5    3.702491
# 36  Bundaberg  Jan 13, 2023   9:47:00 AM           Mary       4.9    3.621850
# 37  Newcastle  Jan 13, 2023  11:31:00 AM      Tom Hanks       4.2    2.900730
# 38  Bundaberg  Jan 13, 2023   1:12:00 PM      Mary Anne       3.1    2.344704
# 39  Newcastle  Jan 13, 2023   1:13:00 PM      Tom Hanks       4.0    2.463518
# 40  Bundaberg  Jan 13, 2023   2:18:00 PM      Mary Jane       5.2    3.372303
# 41  Newcastle  Jan 13, 2023   2:42:00 PM  Harry Houdini       2.1    1.450016
# 42  Bundaberg  Jan 13, 2023   3:50:00 PM      Mary Anne       3.1    2.262899
# 43  Bundaberg  Jan 14, 2023   8:34:00 AM   Mary Therese       3.9    2.611086
# 44  Newcastle  Jan 14, 2023   8:45:00 AM    Dick Tracey       5.8    3.664656
# 45  Bundaberg  Jan 14, 2023  10:17:00 AM      Mary Jane       5.3    3.451031
# 46  Newcastle  Jan 14, 2023  11:20:00 AM  Harry Houdini       1.9    1.390640
# 47  Bundaberg  Jan 14, 2023   1:05:00 PM   Mary Therese       4.6    2.790801
# 48  Newcastle  Jan 14, 2023   1:13:00 PM    Dick Tracey       6.8    4.035265
# 49  Bundaberg  Jan 15, 2023   9:01:00 AM           Mary       5.0    3.573573
# 50  Newcastle  Jan 15, 2023   9:16:00 AM  Harry Houdini       2.0    1.576333
# 51  Newcastle  Jan 15, 2023  11:12:00 AM      Tom Hanks       4.2    2.807280
# 52  Bundaberg  Jan 15, 2023  12:10:00 PM      Mary Jane       5.2    3.485299
# 53  Newcastle  Jan 15, 2023   4:02:00 PM      Tom Hanks       3.8    2.214139

# %%
raw_df.to_json("prediction.json", orient='records')
